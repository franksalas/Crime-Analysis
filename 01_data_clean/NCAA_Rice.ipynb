# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import glob, os
import numpy as np
import matplotlib.pyplot as plt
import datetime  as dt
import seaborn as sns

# %% [markdown]
# ## Data Directory

# %%
sports = 'NCAA'

# %%
data_directory = os.path.join('..','data','sports_data/{}/RU08_17.csv'.format(sports))
data_directory_saves = os.path.join( '..','data','clean_data','sports_data/{}/'.format(sports))

# %%
df = pd.read_csv(data_directory)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 16 columns):
# G              125 non-null int64
# Date           125 non-null object
# Time           63 non-null object
# Day            125 non-null object
# School         125 non-null object
# Unnamed: 5     67 non-null object
# Opponent       125 non-null object
# Conf           125 non-null object
# Unnamed: 8     125 non-null object
# Pts            125 non-null int64
# Opp            125 non-null int64
# W              125 non-null int64
# L              125 non-null int64
# Streak         125 non-null object
# Notes          26 non-null object
# Unnamed: 15    1 non-null object
# dtypes: int64(5), object(11)
# memory usage: 15.7+ KB

# %%
df.head()
# Out:
#    G         Date Time  Day School Unnamed: 5     Opponent      Conf  \
# 0  1  Aug 29 2008  NaN  Fri   Rice        NaN          SMU      CUSA
# 1  2   Sep 6 2008  NaN  Sat   Rice          @      Memphis      CUSA
# 2  3  Sep 13 2008  NaN  Sat   Rice          @   Vanderbilt       SEC
# 3  4  Sep 20 2008  NaN  Sat   Rice          @    (7) Texas    Big 12
# 4  5  Sep 27 2008  NaN  Sat   Rice        NaN  North Texas  Sun Belt
#
#   Unnamed: 8  Pts  Opp  W  L Streak Notes Unnamed: 15
# 0          W   56   27  1  0    W 1   NaN         NaN
# 1          W   42   35  2  0    W 2   NaN         NaN
# 2          L   21   38  2  1    L 1   NaN         NaN
# 3          L   10   52  2  2    L 2   NaN         NaN
# 4          W   77   20  3  2    W 1   NaN         NaN

# %% [markdown]
# ## Drop columns

# %%
df
# Out:
#       G         Date      Time  Day School Unnamed: 5               Opponent  \
# 0     1  Aug 29 2008       NaN  Fri   Rice        NaN                    SMU
# 1     2   Sep 6 2008       NaN  Sat   Rice          @                Memphis
# 2     3  Sep 13 2008       NaN  Sat   Rice          @             Vanderbilt
# 3     4  Sep 20 2008       NaN  Sat   Rice          @              (7) Texas
# 4     5  Sep 27 2008       NaN  Sat   Rice        NaN            North Texas
# 5     6   Oct 4 2008       NaN  Sat   Rice          @                  Tulsa
# 6     7  Oct 18 2008       NaN  Sat   Rice        NaN   Southern Mississippi
# 7     8  Oct 25 2008       NaN  Sat   Rice          @                 Tulane
# 8     9   Nov 1 2008       NaN  Sat   Rice          @                   UTEP
# 9    10   Nov 8 2008       NaN  Sat   Rice        NaN                   Army
# 10   11  Nov 22 2008       NaN  Sat   Rice        NaN               Marshall
# 11   12  Nov 29 2008       NaN  Sat   Rice        NaN                Houston
# 12   13  Dec 30 2008       NaN  Tue   Rice        NaN       Western Michigan
# 13    1   Sep 5 2009       NaN  Sat   Rice          @                    UAB
# 14    2  Sep 12 2009       NaN  Sat   Rice          @             Texas Tech
# 15    3  Sep 19 2009       NaN  Sat   Rice          @    (16) Oklahoma State
# 16    4  Sep 26 2009       NaN  Sat   Rice        NaN             Vanderbilt
# 122  10  Nov 11 2017   3:30 PM  Sat   Rice        NaN   Southern Mississippi
# 123  11  Nov 18 2017   2:00 PM  Sat   Rice          @           Old Dominion
# 124  12  Nov 25 2017   1:00 PM  Sat   Rice        NaN            North Texas
#
#           Conf Unnamed: 8  Pts  Opp   W   L Streak  \
# 0         CUSA          W   56   27   1   0    W 1
# 1         CUSA          W   42   35   2   0    W 2
# 2          SEC          L   21   38   2   1    L 1
# 3       Big 12          L   10   52   2   2    L 2
# 4     Sun Belt          W   77   20   3   2    W 1
# 5         CUSA          L   28   63   3   3    L 1
# 6         CUSA          W   45   40   4   3    W 1
# 7         CUSA          W   42   17   5   3    W 2
# 8         CUSA          W   49   44   6   3    W 3
# 9          Ind          W   38   31   7   3    W 4
# 10        CUSA          W   35   10   8   3    W 5
# 11        CUSA          W   56   42   9   3    W 6
# 12         MAC          W   38   14  10   3    W 7
# 13        CUSA          L   24   44   0   1    L 1
# 14      Big 12          L   10   55   0   2    L 2
# 15      Big 12          L   24   41   0   3    L 3
# 16         SEC          L   17   36   0   4    L 4
# 17        CUSA          L   10   27   0   5    L 5
# 18         Ind          L   14   63   0   6    L 6
# 19        CUSA          L   13   49   0   7    L 7
# 20        CUSA          L    7   49   0   8    L 8
# 21        CUSA          L   28   31   0   9    L 9
# 22        CUSA          W   28   20   1   9    W 1
# 23        CUSA          W   30   29   2   9    W 2
# 24        CUSA          L   14   73   2  10    L 1
# 25      Big 12          L   17   34   0   1    L 1
# 26    Sun Belt          W   32   31   1   1    W 1
# 27     Big Ten          L   13   30   1   2    L 1
# 28      Big 12          L   13   30   1   3    L 2
# 29        CUSA          L   31   42   1   4    L 3
# ..         ...        ...  ...  ...  ..  ..    ...
# 95         Ind          W   38   31   4   3    W 2
# 96        CUSA          L   17   42   4   4    L 1
# 97        CUSA          L   21   24   4   5    L 2
# 98        CUSA          L   10   65   4   6    L 3
# 99        CUSA          L   24   34   4   7    L 4
# 100       CUSA          W   27    7   5   7    W 1
# 101       CUSA          L   14   46   0   1    L 1
# 102        Ind          L   14   31   0   2    L 2
# 103     Big 12          L   10   38   0   3    L 3
# 104       CUSA          L   35   42   0   4    L 4
# 105       CUSA          L   28   44   0   5    L 5
# 106       CUSA          L   13   14   0   6    L 6
# 107  Non-Major          W   65   44   1   6    W 1
# 108       CUSA          L   16   61   1   7    L 1
# 109       CUSA          L   25   42   1   8    L 2
# 110       CUSA          W   22   21   2   8    W 1
# 111       CUSA          W   44   24   3   8    W 2
# 112     Pac-12          L   17   41   3   9    L 1
# 113     Pac-12          L    7   62   0   1    L 1
# 114       CUSA          W   31   14   1   1    W 1
# 115   American          L    3   38   1   2    L 1
# 116       CUSA          L    7   13   1   3    L 2
# 117        ACC          L   10   42   1   4    L 3
# 118        Ind          L   12   49   1   5    L 4
# 119       CUSA          L    7   20   1   6    L 5
# 120       CUSA          L   28   42   1   7    L 6
# 121       CUSA          L   21   52   1   8    L 7
# 122       CUSA          L   34   43   1   9    L 8
# 123       CUSA          L   21   24   1  10    L 9
# 124       CUSA          L   14   30   1  11   L 10
#
#                                     Notes Unnamed: 15
# 0                                     NaN         NaN
# 1                                     NaN         NaN
# 2                                     NaN         NaN
# 3                                     NaN         NaN
# 4                                     NaN         NaN
# 5                                     NaN         NaN
# 6                                     NaN         NaN
# 7                                     NaN         NaN
# 8                                     NaN         NaN
# 9                                     NaN         NaN
# 10                                    NaN         NaN
# 11                                    NaN         NaN
# 12   Texas Bowl (Texas Bowl (Houston TX))         NaN
# 13                                    NaN         NaN
# 14                                    NaN         NaN
# 15                                    NaN         NaN
# 16                                    NaN         NaN
# 17                                    NaN         NaN
# 18                                    NaN         NaN
# 19                                    NaN         NaN
# 20                                    NaN         NaN
# 21                                    NaN         NaN
# 22                                    NaN         NaN
# 23                                    NaN         NaN
# 24                                    NaN         NaN
# 25                             Houston TX         NaN
# 26                                    NaN         NaN
# 27                                    NaN         NaN
# 28                                    NaN         NaN
# 29                                    NaN         NaN
# ..                                    ...         ...
# 95                                    NaN         NaN
# 96                                    NaN         NaN
# 97                                  CBSSN         NaN
# 98                                    NaN         NaN
# 99                                    NaN         NaN
# 100                                   NaN         NaN
# 101                                 CBSSN         NaN
# 102                                 CBSSN         NaN
# 103                                  ESPN         NaN
# 104                                   NaN         NaN
# 105                                   NaN         NaN
# 106                                   NaN         NaN
# 107                                   NaN         NaN
# 108                                   NaN         NaN
# 109                                 ESPN3         NaN
# 110                                   NaN         NaN
# 111                                 ESPN3         NaN
# 112                                   NaN         NaN
# 113                                   NaN         NaN
# 114                                   NaN         NaN
# 115                                   NaN         NaN
# 116                                   NaN         NaN
# 117                                   NaN         NaN
# 118                                   NaN         NaN
# 119                                   NaN         NaN
# 120                                   NaN         NaN
# 121                                   NaN         NaN
# 122                                   NaN         NaN
# 123                                   NaN         NaN
# 124                                   NaN         NaN
#
# [125 rows x 16 columns]

# %%
df.drop(['G','Time',
 'Day',
 'Conf',
 'W',
 'L',
 'Streak',
 'Notes',
 'Unnamed: 15'],axis=1,inplace=True)

# %%
df.head()
# Out:
#           Date School Unnamed: 5     Opponent Unnamed: 8  Pts  Opp
# 0  Aug 29 2008   Rice        NaN          SMU          W   56   27
# 1   Sep 6 2008   Rice          @      Memphis          W   42   35
# 2  Sep 13 2008   Rice          @   Vanderbilt          L   21   38
# 3  Sep 20 2008   Rice          @    (7) Texas          L   10   52
# 4  Sep 27 2008   Rice        NaN  North Texas          W   77   20

# %% [markdown]
# ## change date to datetime index

# %%
# Map the lowering function to all column names
df.columns = map(str.lower, df.columns)

# %%
df.date = pd.to_datetime(df['date'])
df = df.set_index('date').sort_index(ascending=True)

# %%
df.head()
# Out:
#            school unnamed: 5     opponent unnamed: 8  pts  opp
# date
# 2008-08-29   Rice        NaN          SMU          W   56   27
# 2008-09-06   Rice          @      Memphis          W   42   35
# 2008-09-13   Rice          @   Vanderbilt          L   21   38
# 2008-09-20   Rice          @    (7) Texas          L   10   52
# 2008-09-27   Rice        NaN  North Texas          W   77   20

# %% [markdown]
# ## chane unnamed:5 to home_away

# %%
df.rename(columns={
    'unnamed: 5': 'home_away',
    'unnamed: 8': 'win_lost',
}, inplace=True)

# %%
df.home_away.fillna('home',inplace=True)

# %%
df.head()
# Out:
#            school home_away     opponent win_lost  pts  opp
# date
# 2008-08-29   Rice      home          SMU        W   56   27
# 2008-09-06   Rice         @      Memphis        W   42   35
# 2008-09-13   Rice         @   Vanderbilt        L   21   38
# 2008-09-20   Rice         @    (7) Texas        L   10   52
# 2008-09-27   Rice      home  North Texas        W   77   20

# %% [markdown]
# ## select home games

# %%
home_games = df.home_away == 'home'
df = df[home_games]
df.drop(['home_away'],axis=1,inplace=True)

# %%
df.head()
# Out:
#            school              opponent win_lost  pts  opp
# date
# 2008-08-29   Rice                   SMU        W   56   27
# 2008-09-27   Rice           North Texas        W   77   20
# 2008-10-18   Rice  Southern Mississippi        W   45   40
# 2008-11-08   Rice                  Army        W   38   31
# 2008-11-22   Rice              Marshall        W   35   10

# %% [markdown]
# ## clean columns

# %%
df.school.unique()
# Out:
# array(['Rice'], dtype=object)

# %%
df.opponent.unique()
# Out:
# array(['SMU', 'North Texas', 'Southern Mississippi', 'Army', 'Marshall',
#        'Houston', 'Western Michigan', 'Vanderbilt', 'Tulsa', 'Navy',
#        'UCF', 'Tulane', 'UTEP', '(5) Texas', 'Northwestern', 'Baylor',
#        'East Carolina', 'UAB', 'Purdue', 'Memphis', 'UCLA', 'UTSA',
#        'Kansas', 'Florida Atlantic', 'Louisiana Tech', 'Old Dominion',
#        'Hawaii', 'Wagner', 'Western Kentucky', 'Charlotte', '(21) Baylor',
#        'Prairie View A&M', 'Florida International'], dtype=object)

# %% [markdown]
# ## remove extra characters line

# %%
df.opponent = df.opponent.str.replace(r"\(.*\)"," ")

# %%
df.opponent.unique()
# Out:
# array(['SMU', 'North Texas', 'Southern Mississippi', 'Army', 'Marshall',
#        'Houston', 'Western Michigan', 'Vanderbilt', 'Tulsa', 'Navy',
#        'UCF', 'Tulane', 'UTEP', '  Texas', 'Northwestern', 'Baylor',
#        'East Carolina', 'UAB', 'Purdue', 'Memphis', 'UCLA', 'UTSA',
#        'Kansas', 'Florida Atlantic', 'Louisiana Tech', 'Old Dominion',
#        'Hawaii', 'Wagner', 'Western Kentucky', 'Charlotte', '  Baylor',
#        'Prairie View A&M', 'Florida International'], dtype=object)

# %%
df.win_lost.unique()
# Out:
# array(['W', 'L'], dtype=object)

# %%
df.pts.unique()
# Out:
# array([56, 77, 45, 38, 35, 17, 10, 14,  7, 28, 30, 13, 31, 34, 62, 24, 20,
#        41, 19, 51, 44, 36, 23, 18, 52, 42, 27, 65, 25, 12])

# %%
df.opp.unique()
# Out:
# array([27, 20, 40, 31, 10, 42, 14, 36, 63, 49, 29, 34, 30, 38, 23, 22,  6,
#        37,  7, 54, 17, 13, 24, 45, 21, 16, 65, 44, 43])

# %% [markdown]
# ## display null values

# %%
df.apply(lambda x: sum(x.isnull()))
# Out:
# school      0
# opponent    0
# win_lost    0
# pts         0
# opp         0
# dtype: int64

# %% [markdown]
# ## save dataset

# %%
df.to_csv(data_directory_saves+'Rice_2010_2017.csv')
