# %%
#!pip install folium

# %%
import geojsonio
import geopandas as gpd
import pandas as pd
# %matplotlib inline
pd.options.display.max_rows = 10

# %%
import folium

# %%
states = gpd.read_file('states.geojson')

# %%
states.head()
# Out:
#   adm1_code          featurecla  \
# 0  USA-3514  Admin-1 scale rank
# 1  USA-3515  Admin-1 scale rank
# 2  USA-3516  Admin-1 scale rank
# 3  USA-3517  Admin-1 scale rank
# 4  USA-3518  Admin-1 scale rank
#
#                                             geometry  scalerank
# 0  POLYGON ((-89.59940899999999 48.010274, -89.48...          2
# 1  POLYGON ((-111.194189 44.561156, -111.291548 4...          2
# 2  POLYGON ((-96.601359 46.351357, -96.5389080000...          2
# 3  (POLYGON ((-155.93665 19.05939, -155.90806 19....          2
# 4  POLYGON ((-111.049728 44.488163, -111.050245 4...          2

# %%
states.plot()

# %%
type(states)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
states.geometry
# Out:
# 0     POLYGON ((-89.59940899999999 48.010274, -89.48...
# 1     POLYGON ((-111.194189 44.561156, -111.291548 4...
# 2     POLYGON ((-96.601359 46.351357, -96.5389080000...
# 3     (POLYGON ((-155.93665 19.05939, -155.90806 19....
# 4     POLYGON ((-111.049728 44.488163, -111.050245 4...
#                             ...
# 46    POLYGON ((-74.679028 41.355486, -74.840439 41....
# 47    POLYGON ((-74.89175400000001 40.081791, -75.12...
# 48    POLYGON ((-67.137344 45.137452, -66.9646599999...
# 49    POLYGON ((-90.395278 46.611677, -90.3555900000...
# 50    (POLYGON ((-153.228729 57.968968, -152.564791 ...
# Name: geometry, Length: 51, dtype: object

# %%
states.to_json()
# Out:
# '{"type": "FeatureCollection", "features": [{"id": "0", "type": "Feature", "properties": {"adm1_code": "USA-3514", "featurecla": "Admin-1 scale rank", "scalerank": 2}, "geometry": {"type": "Polygon", "coordinates": [[[-89.599409, 48.010274], [-89.488885, 48.013439], [-89.522695, 47.960535], [-89.613698, 47.819252], [-89.728006, 47.641976], [-89.842831, 47.464726], [-89.957656, 47.286907], [-90.131754, 47.292747], [-90.305852, 47.298018], [-90.47995, 47.303857], [-90.654048, 47.309128], [-90.857782, 47.212829], [-91.060974, 47.117047], [-91.264708, 47.021265], [-91.468442, 46.924966], [-91.592259, 46.87626], [-91.716618, 46.827607], [-91.840978, 46.778385], [-91.964794, 46.729706], [-92.011898, 46.711723], [-92.274879, 46.656145], [-92.264828, 46.095223], [-92.296583, 46.096282], [-92.5437, 45.985695], [-92.756968, 45.889912], [-92.899828, 45.705763], [-92.689221, 45.518436], [-92.765417, 45.267082], [-92.766477, 44.996143], [-92.796656, 44.776027], [-92.505072, 44.58392], [-92.385492
# ...

# %%
m = folium.Map([29.8566, -95.3429], zoom_start=6, tiles="OpenStreetMap")
folium.GeoJson(states.to_json()).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
beats = gpd.read_file('Houston_Police_Beats.geojson')
County_Boundaries

# %%
ls
# Out:
# AAA.geojson/                   NBA_Cleanup.ipynb*           stadiums.csv*
# County_Boundaries.kml*         new_map.csv/                 stadiums_final.csv*
# Dynamo_Cleanup.ipynb*          NFL_API_Cleanup.ipynb*       stadiums.ipynb*
# folium.ipynb*                  NFL_JSON_API_example.ipynb*  states.geojson*
# geojson.ipynb*                 NFP_POST_Cleanup.ipynb*      story_nfl.ipynb*
# geopandas.ipynb*               pedesign10im01en.pdf*        test.geojson*
# Houston_Police_Beats.geojson*  pedesign10im01es.pdf*        TSU_Cleanup.ipynb*
# index.html*                    Rice_Cleanup.ipynb*          UH_Cleanup.ipynb*
# mapAA.geojson*                 sports_data_clean/           Untitled1.ipynb*
# mapBBB.geojson*                sports_data_raw/             Untitled2.ipynb*
# MLB_Cleanup.ipynb*             stadium_beats_geocode.csv*   Untitled.ipynb*
# MLS_Cleanup.ipynb*             stadium_beats.geojson/

# %%
mapBBB= gpd.read_file('county.geojson')

# %%
tt = mapBBB['geometry']
tt
# Out:
# 0     POLYGON ((-95.76867943039726 30.89268426671356...
# 1     POLYGON ((-95.82457072290777 30.62736411422872...
# 2     POLYGON ((-95.16590329647558 30.34497181439463...
# 3     POLYGON ((-95.80431574101516 30.24568371896723...
# 4     POLYGON ((-95.09671549769892 30.16721986434578...
#                             ...
# 8     POLYGON ((-95.82622839647411 29.78828663246195...
# 9     POLYGON ((-94.37177831326065 29.59713600351098...
# 10    POLYGON ((-96.17558326314142 29.63377815527443...
# 11    POLYGON ((-95.42412561850594 29.58023804904531...
# 12    POLYGON ((-95.87403515088108 29.2297086172414,...
# Name: geometry, Length: 13, dtype: object

# %%
test = beats['geometry']
test2 = stadium_beats['geometry']

# %%
m = folium.Map([29.8566, -95.3429], tiles="Stamen Toner")
folium.GeoJson(mapBBB.to_json()).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
stadium_beats.plot()

# %%
selected_beats = ['3B10','1A10','10H30','10H50','10H60','10H80','15E40' ]

# %%
stadium_beats = beats[beats['Beats'].isin(selected_beats)]

# %%
stadium_beats.to_file('new_map.csv')

# %%
stadium_beats
# Out:
#     Area_sq_mi  Beats Beats_0  District  OBJECTID  OBJECTID_1  OBJECTID_12  \
# 2     1.746467   1A10   01A10         1         1           3            3
# 13    6.820688   3B10   03B10         3        12          14           14
# 42    1.026912  10H30   10H30        10        41          43           43
# 44    2.308431  10H50   10H50        10        43          45           45
# 45    3.089310  10H60   10H60        10        44          46           46
# 47    2.738628  10H80   10H80        10        46          48           48
# 72   10.007917  15E40   15E40        15        71          73           73
#
#     Perimet_mi    Shape_Leng  \
# 2     6.236709  32929.823999
# 13   11.999392  63356.790014
# 42    4.603059  24304.152463
# 44    6.798055  35893.732656
# 45    8.593036  45371.231143
# 47    7.586783  40058.215548
# 72   15.298455  80775.842906
#
#                                              geometry
# 2   POLYGON ((-95.35056999661641 29.76698019505118...
# ...

# %%
stadium_beats.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 7 entries, 2 to 72
# Data columns (total 10 columns):
# Area_sq_mi     7 non-null float64
# Beats          7 non-null object
# Beats_0        7 non-null object
# District       7 non-null int64
# OBJECTID       7 non-null int64
# OBJECTID_1     7 non-null int64
# OBJECTID_12    7 non-null int64
# Perimet_mi     7 non-null float64
# Shape_Leng     7 non-null float64
# geometry       7 non-null object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 936.0+ bytes

# %%
import fiona; fiona.supported_drivers
# Out:
# {'ARCGEN': 'r',
#  'AeronavFAA': 'r',
#  'BNA': 'raw',
#  'DGN': 'raw',
#  'DXF': 'raw',
#  'ESRI Shapefile': 'raw',
#  'GPKG': 'rw',
#  'GPSTrackMaker': 'raw',
#  'GPX': 'raw',
#  'GeoJSON': 'rw',
#  'Idrisi': 'r',
#  'MapInfo File': 'raw',
#  'OpenFileGDB': 'r',
#  'PCIDSK': 'r',
#  'SEGY': 'r',
#  'SUA': 'r'}
