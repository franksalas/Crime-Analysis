# %%
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns

# %%
ls data/sports_scores/
# Out:
# astros_1A10.csv*   Rice_10H80.csv*    Tex_15E40.csv*
# dynamo_10H30.csv*  rockets_1A10.csv*  UH_10H50.csv*

# %%
ls data/crime_beat/
# Out:
# crime_10H30_10_17.csv*  crime_10H80_10_17.csv*  crime_1A10_10_17.csv*
# crime_10H50_10_17.csv*  crime_15E40_10_17.csv*

# %%
games = 'data/sports_scores/astros_1A10.csv'
crime = 'data/crime_beat/crime_1A10_10_17.csv'

# %% [markdown]
# # scores df

# %%
df = pd.read_csv(games,index_col='date').sort_index(ascending=True)

## win column
df['win'] =  np.where(df['team_score'] > df['opp_score'],1,0)

# only oposing name and win boolean
df = df[['opposing','win','beat']]

# show

df.head()
# Out:
#            opposing  win  beat
# date
# 2010-04-05      SFG    0  1A10
# 2010-04-06      SFG    0  1A10
# 2010-04-07      SFG    0  1A10
# 2010-04-09      PHI    0  1A10
# 2010-04-10      PHI    0  1A10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 658 entries, 2010-04-05 to 2017-10-29
# Data columns (total 3 columns):
# opposing    658 non-null object
# win         658 non-null int64
# beat        658 non-null object
# dtypes: int64(1), object(2)
# memory usage: 20.6+ KB

# %% [markdown]
# # Crime df

# %%
# crime_df = pd.read_csv(crime).sort_index(ascending=True)

# crime_df['Date_Hour'] = pd.to_datetime(crime_df['Date_Hour'])
# crime_df['Date_Hour'] = crime_df['Date_Hour'].dt.date

# crime_df = crime_df.set_index('Date_Hour')


# # selectd columns
# crime_df = crime_df[['OffenseType']]

# # count Offense type given date
# date_crimes = crime_df.groupby(crime_df.index)['OffenseType',].count()

# ## show
# date_crimes.head()




crime_df = pd.read_csv(crime).sort_index(ascending=True)

crime_df['Date_Hour'] = pd.to_datetime(crime_df['Date_Hour'])
crime_df['Date_Hour'] = crime_df['Date_Hour'].dt.date

crime_df = crime_df.set_index('Date_Hour')


# # selectd columns
crime_df = crime_df[['OffenseType']]

# count Offense type given date
date_crimes = crime_df.groupby(crime_df.index)['OffenseType',].count()

## show
date_crimes.head()
# Out:
#             OffenseType
# Date_Hour
# 2010-01-01           11
# 2010-01-02           11
# 2010-01-03            8
# 2010-01-04            6
# 2010-01-05            5

# %%
crime_dum = pd.get_dummies(crime_df)

# %%
crime_dum.head()
# Out:
#             OffenseType_Aggravated Assault  OffenseType_Auto Theft  \
# Date_Hour
# 2010-01-01                               0                       1
# 2010-01-01                               0                       0
# 2010-01-01                               0                       0
# 2010-01-01                               0                       0
# 2010-01-01                               0                       0
#
#             OffenseType_Burglary  OffenseType_Murder  OffenseType_Rape  \
# Date_Hour
# 2010-01-01                     0                   0                 0
# 2010-01-01                     0                   0                 0
# 2010-01-01                     1                   0                 0
# 2010-01-01                     0                   0                 0
# 2010-01-01                     0                   0                 0
#
#             OffenseType_Robbery  OffenseType_Theft
# Date_Hour
# 2010-01-01                    0                  0
# 2010-01-01                    0                  1
# 2010-01-01                    0                  0
# 2010-01-01                    0                  1
# 2010-01-01                    0                  1

# %%
sns.heatmap(crime_dum.corr(), annot=True, fmt=".2f")

# %%
sns.jointplot(data=crime_df, x='Hour', y='OffenseType', kind='reg', color='g')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-2192fbedaf1c> in <module>()
# ----> 1 sns.jointplot(data=crime_df, x='Hour', y='OffenseType', kind='reg', color='g')
#
# ~/miniconda3/envs/springboard/lib/python3.6/site-packages/seaborn/axisgrid.py in jointplot(x, y, data, kind, stat_func, color, size, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2239     grid = JointGrid(x, y, data, dropna=dropna,
#    2240                      size=size, ratio=ratio, space=space,
# -> 2241                      xlim=xlim, ylim=ylim)
#    2242
#    2243     # Plot the data using the grid
#
# ~/miniconda3/envs/springboard/lib/python3.6/site-packages/seaborn/axisgrid.py in __init__(self, x, y, data, size, ratio, space, dropna, xlim, ylim)
#    1681             if isinstance(var, string_types):
#    1682                 err = "Could not interpret input '{}'".format(var)
# -> 1683                 raise ValueError(err)
#    1684
#    1685         # Possibly drop NA
#
# ValueError: Could not interpret input 'Hour'

# %%
crime_df = pd.read_csv(crime).sort_index(ascending=True)

crime_df.head()

# %%
len(crime_df.Premise.value_counts())

# %%
crime_df.Premise.value_counts()

# %% [markdown]
# # Days Df
# - create a df with everyday timestamp from Jan 2010 to Dec 2017

# %%
days = pd.date_range(start='01/01/2010', end='12/31/2017')
days = pd.DataFrame(days)

days.columns = ['days']
days = days.set_index('days').sort_index(ascending=True)
days.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [2010-01-01 00:00:00, 2010-01-02 00:00:00, 2010-01-03 00:00:00, 2010-01-04 00:00:00, 2010-01-05 00:00:00]

# %%
365 * 8

# %%
len(days)/365

# %%
days.tail()

# %% [markdown]
# # Merge days df with crimes_df

# %%
calendar_crimes = pd.merge(days,date_crimes,  left_index=True, right_index=True, how='left')
calendar_crimes.head()
# Out:
#             OffenseType
# days
# 2010-01-01         11.0
# 2010-01-02         11.0
# 2010-01-03          8.0
# 2010-01-04          6.0
# 2010-01-05          5.0

# %%
calendar_crimes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2922 entries, 2010-01-01 to 2017-12-31
# Data columns (total 1 columns):
# OffenseType    2891 non-null float64
# dtypes: float64(1)
# memory usage: 125.7 KB

# %%
calendar_crimes.OffenseType.value_counts(dropna=False)
# Out:
#  5.0     459
#  4.0     453
#  3.0     402
#  6.0     353
#  2.0     282
#  7.0     274
#  8.0     205
#  1.0     149
#  9.0     118
#  10.0     61
#  11.0     35
# NaN       31
#  12.0     30
#  13.0     21
#  14.0     19
#  15.0      7
#  18.0      5
#  16.0      4
#  17.0      4
#  21.0      3
#  20.0      3
#  19.0      2
#  22.0      1
#  36.0      1
# Name: OffenseType, dtype: int64

# %% [markdown]
# ## Change nans with 0

# %%
calendar_crimes.OffenseType.replace( np.nan,0, inplace=True)

# %%
calendar_crimes.OffenseType.value_counts(dropna=False)
# Out:
# 5.0     459
# 4.0     453
# 3.0     402
# 6.0     353
# 2.0     282
# 7.0     274
# 8.0     205
# 1.0     149
# 9.0     118
# 10.0     61
# 11.0     35
# 0.0      31
# 12.0     30
# 13.0     21
# 14.0     19
# 15.0      7
# 18.0      5
# 16.0      4
# 17.0      4
# 21.0      3
# 20.0      3
# 19.0      2
# 22.0      1
# 36.0      1
# Name: OffenseType, dtype: int64

# %%
calendar_crimes.head()
# Out:
#             OffenseType
# days
# 2010-01-01         11.0
# 2010-01-02         11.0
# 2010-01-03          8.0
# 2010-01-04          6.0
# 2010-01-05          5.0

# %% [markdown]
# # merge calendar_crimes with score

# %%
merge_data = pd.merge(calendar_crimes,df,  left_index=True, right_index=True, how='left')

# change column names
#merge_data.columns = ['offenses','away_team','win']

merge_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2923 entries, 2010-01-01 to 2017-12-31
# Data columns (total 4 columns):
# OffenseType    2923 non-null float64
# opposing       658 non-null object
# win            658 non-null float64
# beat           658 non-null object
# dtypes: float64(2), object(2)
# memory usage: 114.2+ KB

# %%
merge_data.head()
# Out:
#             OffenseType opposing  win beat
# 2010-01-01         11.0      NaN  NaN  NaN
# 2010-01-02         11.0      NaN  NaN  NaN
# 2010-01-03          8.0      NaN  NaN  NaN
# 2010-01-04          6.0      NaN  NaN  NaN
# 2010-01-05          5.0      NaN  NaN  NaN

# %% [markdown]
# ## Change nan value on beat to beat value

# %%
merge_data.beat.value_counts(dropna=False)
# Out:
# NaN     2265
# 1A10     658
# Name: beat, dtype: int64

# %%
merge_data.beat.replace( np.nan,'1A10', inplace=True)

# %%
merge_data.beat.value_counts(dropna=False)
# Out:
# 1A10    2923
# Name: beat, dtype: int64

# %% [markdown]
# ## Cleanup colums

# %%
merge_data.columns  = ['crime', 'away_team', 'won','beat']

# %%
merge_data.head()
# Out:
#             crime away_team  won  beat
# 2010-01-01   11.0       NaN  NaN  1A10
# 2010-01-02   11.0       NaN  NaN  1A10
# 2010-01-03    8.0       NaN  NaN  1A10
# 2010-01-04    6.0       NaN  NaN  1A10
# 2010-01-05    5.0       NaN  NaN  1A10

# %%
merge_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2923 entries, 2010-01-01 to 2017-12-31
# Data columns (total 4 columns):
# crime        2923 non-null float64
# away_team    658 non-null object
# won          658 non-null float64
# beat         2923 non-null object
# dtypes: float64(2), object(2)
# memory usage: 114.2+ KB

# %%
merge_data.crime.value_counts(dropna=False)
# Out:
# 5.0     459
# 4.0     453
# 3.0     402
# 6.0     353
# 2.0     282
# 7.0     275
# 8.0     205
# 1.0     149
# 9.0     118
# 10.0     61
# 11.0     35
# 0.0      31
# 12.0     30
# 13.0     21
# 14.0     19
# 15.0      7
# 18.0      5
# 16.0      4
# 17.0      4
# 21.0      3
# 20.0      3
# 19.0      2
# 22.0      1
# 36.0      1
# Name: crime, dtype: int64

# %%
merge_data.crime = merge_data.crime.astype(int)

# %%
merge_data.crime.value_counts(dropna=False)
# Out:
# 5     459
# 4     453
# 3     402
# 6     353
# 2     282
# 7     275
# 8     205
# 1     149
# 9     118
# 10     61
# 11     35
# 0      31
# 12     30
# 13     21
# 14     19
# 15      7
# 18      5
# 17      4
# 16      4
# 21      3
# 20      3
# 19      2
# 36      1
# 22      1
# Name: crime, dtype: int64

# %%
merge_data.head()
# Out:
#             crime away_team  won  beat
# 2010-01-01     11       NaN  NaN  1A10
# 2010-01-02     11       NaN  NaN  1A10
# 2010-01-03      8       NaN  NaN  1A10
# 2010-01-04      6       NaN  NaN  1A10
# 2010-01-05      5       NaN  NaN  1A10

# %%
merge_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2923 entries, 2010-01-01 to 2017-12-31
# Data columns (total 4 columns):
# crime        2923 non-null int64
# away_team    658 non-null object
# won          658 non-null float64
# beat         2923 non-null object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 114.2+ KB

# %% [markdown]
# # Display non-nans

# %%
merge_data.dropna(subset=['away_team', 'won'])
# Out:
#             crime    away_team  won  beat
# 2010-04-05     12          SFG  0.0  1A10
# 2010-04-06      7          SFG  0.0  1A10
# 2010-04-07      6          SFG  0.0  1A10
# 2010-04-09      9          PHI  0.0  1A10
# 2010-04-10      9          PHI  0.0  1A10
# 2010-04-11      6          PHI  0.0  1A10
# 2010-04-20      2          FLA  1.0  1A10
# 2010-04-21      1          FLA  1.0  1A10
# 2010-04-22      7          FLA  0.0  1A10
# 2010-04-23      8          PIT  1.0  1A10
# 2010-04-24      5          PIT  1.0  1A10
# 2010-04-25      6          PIT  1.0  1A10
# 2010-04-27      8          CIN  0.0  1A10
# 2010-04-28      2          CIN  0.0  1A10
# 2010-04-29      9          CIN  0.0  1A10
# 2010-05-03      8          ARI  0.0  1A10
# 2010-05-04      8          ARI  0.0  1A10
# 2010-05-05      2          ARI  1.0  1A10
# 2010-05-06      1          ARI  0.0  1A10
# 2010-05-07     12          SDP  0.0  1A10
# 2010-05-08      7          SDP  0.0  1A10
# 2010-05-09      5          SDP  1.0  1A10
# 2010-05-19      8          COL  1.0  1A10
# 2010-05-20      9          COL  0.0  1A10
# 2010-05-21      8          TBR  1.0  1A10
# 2010-05-22      5          TBR  0.0  1A10
# 2010-05-23      6          TBR  0.0  1A10
# 2010-05-31      1          WSN  0.0  1A10
# 2010-06-01     12          WSN  1.0  1A10
# 2010-06-02      8          WSN  1.0  1A10
# ...           ...          ...  ...   ...
# 2017-08-17     10          ARI  0.0  1A10
# 2017-08-18      4          OAK  1.0  1A10
# 2017-08-19      1          OAK  1.0  1A10
# 2017-08-20      2          OAK  0.0  1A10
# 2017-08-22      5          WSN  0.0  1A10
# 2017-08-23      6          WSN  1.0  1A10
# 2017-08-24      4          WSN  0.0  1A10
# 2017-08-29      1          TEX  0.0  1A10
# 2017-08-30      3          TEX  0.0  1A10
# 2017-08-31      2          TEX  1.0  1A10
# 2017-09-02      7          NYM  1.0  1A10
# 2017-09-02      7          NYM  1.0  1A10
# 2017-09-03      7          NYM  1.0  1A10
# 2017-09-15      4          SEA  1.0  1A10
# 2017-09-16      2          SEA  1.0  1A10
# 2017-09-17      3          SEA  1.0  1A10
# 2017-09-19      7          CHW  1.0  1A10
# 2017-09-20      5          CHW  1.0  1A10
# 2017-09-21      4          CHW  0.0  1A10
# 2017-09-22      2          LAA  1.0  1A10
# 2017-09-23      4          LAA  1.0  1A10
# 2017-09-24      4          LAA  0.0  1A10
# 2017-10-06      6       Boston  1.0  1A10
# 2017-10-13      4     New York  1.0  1A10
# 2017-10-14      6     New York  1.0  1A10
# 2017-10-20      5     New York  1.0  1A10
# 2017-10-21      5     New York  1.0  1A10
# 2017-10-27      7  Los Angeles  1.0  1A10
# 2017-10-28      7  Los Angeles  0.0  1A10
# 2017-10-29      4  Los Angeles  1.0  1A10
#
# [658 rows x 4 columns]

# %% [markdown]
# ## Add sport col

# %%
merge_data['sport'] = 'bas'

# %%
merge_data.head()
# Out:
#             crime away_team  won  beat sport
# 2010-01-01     11       NaN  NaN  1A10   bas
# 2010-01-02     11       NaN  NaN  1A10   bas
# 2010-01-03      8       NaN  NaN  1A10   bas
# 2010-01-04      6       NaN  NaN  1A10   bas
# 2010-01-05      5       NaN  NaN  1A10   bas

# %%
merge_data = merge_data[['crime','won','beat', 'sport']]

# %%
merge_data.head()
# Out:
#             crime  won  beat sport
# 2010-01-01     11  NaN  1A10   bas
# 2010-01-02     11  NaN  1A10   bas
# 2010-01-03      8  NaN  1A10   bas
# 2010-01-04      6  NaN  1A10   bas
# 2010-01-05      5  NaN  1A10   bas

# %%
merge_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2923 entries, 2010-01-01 to 2017-12-31
# Data columns (total 4 columns):
# crime    2923 non-null int64
# won      658 non-null float64
# beat     2923 non-null object
# sport    2923 non-null object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 194.2+ KB

# %%
def game_feature(df):
    if df.won == 1:
        val = 'Won_Game'
    elif df.won == 0:
        val = 'Lost_Game'
    else:
        val = 'No_Game'
    return val

merge_data['game'] = merge_data.apply(game_feature,axis=1)

# %%
merge_data.head()
# Out:
#             crime  won  beat sport     game
# 2010-01-01     11  NaN  1A10   bas  No_Game
# 2010-01-02     11  NaN  1A10   bas  No_Game
# 2010-01-03      8  NaN  1A10   bas  No_Game
# 2010-01-04      6  NaN  1A10   bas  No_Game
# 2010-01-05      5  NaN  1A10   bas  No_Game

# %%
merge_data.won.value_counts(dropna=False)
# Out:
# NaN     2265
#  0.0     336
#  1.0     322
# Name: won, dtype: int64

# %%
merge_data
# Out:
#             crime  beat sport     game
# 2010-01-01     11  1A10   bas  No_Game
# 2010-01-02     11  1A10   bas  No_Game
# 2010-01-03      8  1A10   bas  No_Game
# 2010-01-04      6  1A10   bas  No_Game
# 2010-01-05      5  1A10   bas  No_Game
# 2010-01-06      7  1A10   bas  No_Game
# 2010-01-07      8  1A10   bas  No_Game
# 2010-01-08      4  1A10   bas  No_Game
# 2010-01-09     10  1A10   bas  No_Game
# 2010-01-10      8  1A10   bas  No_Game
# 2010-01-11      7  1A10   bas  No_Game
# 2010-01-12      4  1A10   bas  No_Game
# 2010-01-13      5  1A10   bas  No_Game
# 2010-01-14      4  1A10   bas  No_Game
# 2010-01-15     11  1A10   bas  No_Game
# 2010-01-16      5  1A10   bas  No_Game
# 2010-01-17      6  1A10   bas  No_Game
# 2010-01-18      8  1A10   bas  No_Game
# 2010-01-19      3  1A10   bas  No_Game
# 2010-01-20      4  1A10   bas  No_Game
# 2010-01-21      9  1A10   bas  No_Game
# 2010-01-22      8  1A10   bas  No_Game
# 2010-01-23      6  1A10   bas  No_Game
# 2010-01-24      7  1A10   bas  No_Game
# 2010-01-25      8  1A10   bas  No_Game
# 2010-01-26      8  1A10   bas  No_Game
# 2010-01-27      8  1A10   bas  No_Game
# 2010-01-28      5  1A10   bas  No_Game
# 2010-01-29      6  1A10   bas  No_Game
# 2010-01-30      7  1A10   bas  No_Game
# ...           ...   ...   ...      ...
# 2017-12-02      5  1A10   bas  No_Game
# 2017-12-03      2  1A10   bas  No_Game
# 2017-12-04      7  1A10   bas  No_Game
# 2017-12-05      3  1A10   bas  No_Game
# 2017-12-06      4  1A10   bas  No_Game
# 2017-12-07      5  1A10   bas  No_Game
# 2017-12-08      4  1A10   bas  No_Game
# 2017-12-09      4  1A10   bas  No_Game
# 2017-12-10      2  1A10   bas  No_Game
# 2017-12-11      6  1A10   bas  No_Game
# 2017-12-12      2  1A10   bas  No_Game
# 2017-12-13      6  1A10   bas  No_Game
# 2017-12-14      4  1A10   bas  No_Game
# 2017-12-15      9  1A10   bas  No_Game
# 2017-12-16     10  1A10   bas  No_Game
# 2017-12-17     12  1A10   bas  No_Game
# 2017-12-18     10  1A10   bas  No_Game
# 2017-12-19      7  1A10   bas  No_Game
# 2017-12-20      5  1A10   bas  No_Game
# 2017-12-21      8  1A10   bas  No_Game
# 2017-12-22      6  1A10   bas  No_Game
# 2017-12-23      2  1A10   bas  No_Game
# 2017-12-24      4  1A10   bas  No_Game
# 2017-12-25      2  1A10   bas  No_Game
# 2017-12-26      3  1A10   bas  No_Game
# 2017-12-27      4  1A10   bas  No_Game
# 2017-12-28      2  1A10   bas  No_Game
# 2017-12-29      5  1A10   bas  No_Game
# 2017-12-30      2  1A10   bas  No_Game
# 2017-12-31      4  1A10   bas  No_Game
#
# [2923 rows x 4 columns]

# %%
merge_data = merge_data[['crime','beat','sport','game']]

# %%
merge_data.to_csv('data/final/redo_Astros1017_final.csv')

# %%
merge_data.head()
merge_data.columns = ['1A10_crime','beat','sports','bas_game']

# %%
merge_data.head()

# %%
pd.get_dummies(merge_data)

# %%
merge_data.add_prefix('1A10_')
