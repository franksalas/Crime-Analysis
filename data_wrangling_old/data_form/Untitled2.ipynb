# %%
import numpy as np
import pandas as pd

# %%
ls data/ready/
# Out:
# Astros_clean.csv*        DUMMY_Dynamo_final.csv*   fb.csv*
# bas.csv*                 DUMMY_Rice_final.csv*     Rice_clean.csv*
# bkb.csv*                 DUMMY_Rockets_final.csv*  Rockets_clean.csv*
# cfbRU.csv*               DUMMY_Texans_final.csv*   soc.csv*
# cfbUH.csv*               DUMMY_UH_final.csv*       Texans_clean.csv*
# DUMMY_Astros_final.csv*  dynamo_clean.csv*         UH_clean.csv*

# %%
df = pd.read_csv('data/ready/Astros_clean.csv', index_col=[0], parse_dates=True)

# %%
pd.get_dummies(df)
# reg.
# date * beat as miindex
# beat in
# days wkn/hol/ dummy
#df.head()
# Out:
#             crime  game_Lost Game  game_No Game  game_Won Game
# 2010-01-01     11               0             1              0
# 2010-01-02     11               0             1              0
# 2010-01-03      8               0             1              0
# 2010-01-04      6               0             1              0
# 2010-01-05      5               0             1              0
# 2010-01-06      7               0             1              0
# 2010-01-07      8               0             1              0
# 2010-01-08      4               0             1              0
# 2010-01-09     10               0             1              0
# 2010-01-10      8               0             1              0
# 2010-01-11      7               0             1              0
# 2010-01-12      4               0             1              0
# 2010-01-13      5               0             1              0
# 2010-01-14      4               0             1              0
# ...

# %%
df.game.value_counts()
# Out:
# No Game      2265
# Lost Game     336
# Won Game      322
# Name: game, dtype: int64

# %%
df2 = pd.read_csv('data/ready/DUMMY_Astros_final.csv',index_col=[0],parse_dates=True)

# %%
df2.head()
# Out:
#             Hour  OffenseType_Aggravated Assault  OffenseType_Auto Theft  \
# 2010-01-01     0                               0                       1
# 2010-01-01     0                               0                       0
# 2010-01-01     0                               0                       0
# 2010-01-01     0                               0                       0
# 2010-01-01     0                               0                       0
#
#             OffenseType_Burglary  OffenseType_Murder  OffenseType_Rape  \
# 2010-01-01                     0                   0                 0
# 2010-01-01                     0                   0                 0
# 2010-01-01                     1                   0                 0
# 2010-01-01                     0                   0                 0
# 2010-01-01                     0                   0                 0
#
#             OffenseType_Robbery  OffenseType_Theft     game
# ...

# %%
df3 = pd.read_csv('data/ready/bas.csv',index_col=[0], parse_dates=True)

# %%
df3.head()
# Out:
#             crime  game  beat sport
# days
# 2010-01-01     11     0  1A10   bas
# 2010-01-02     11     0  1A10   bas
# 2010-01-03      8     0  1A10   bas
# 2010-01-04      6     0  1A10   bas
# 2010-01-05      5     0  1A10   bas
