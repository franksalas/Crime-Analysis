# %%
import mglearn
import pandas as pd
import numpy as np

# %%
#!pip install mglearn

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mglearn.plots.plot_tree_not_monotone()
# Out:
# Feature importances: [0. 1.]

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('ASTROSFINAL.csv')

df.drop(['date'],axis=1, inplace=True)
df.head()

df = pd.get_dummies(df,drop_first=True)

# %%
X = df.drop('sum_crimes', axis=1)
y = df['sum_crimes']

# %%
X_train, X_test, y_train, y_test = train_test_split(
X, y,
    random_state=42)

# %%
tree = DecisionTreeClassifier(random_state=0)

# %%
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')

# %%
print('Accuracy on the training subset: {: 3f}'.format(tree.score(X_train,y_train)))

print('Accuracy on the test subset: {: 3f}'.format(tree.score(X_test,y_test)))
# Out:
# Accuracy on the training subset:  0.705075
# Accuracy on the test subset:  0.094521

# %%
df = pd.DataFrame(np.c_[cancer['data'], cancer['target']],
                  columns= np.append(cancer['feature_names'], ['target']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-e5c86abd92af> in <module>()
# ----> 1 df = pd.DataFrame(np.c_[cancer['data'], cancer['target']],
#       2                   columns= np.append(cancer['feature_names'], ['target']))
#
# NameError: name 'cancer' is not defined

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2917 entries, 0 to 2916
# Data columns (total 23 columns):
# sum_crimes           2917 non-null int64
# mode_hr              2917 non-null int64
# weekday_Monday       2917 non-null uint8
# weekday_Saturday     2917 non-null uint8
# weekday_Sunday       2917 non-null uint8
# weekday_Thursday     2917 non-null uint8
# weekday_Tuesday      2917 non-null uint8
# weekday_Wednesday    2917 non-null uint8
# month_Aug            2917 non-null uint8
# month_Dec            2917 non-null uint8
# month_Feb            2917 non-null uint8
# month_Jan            2917 non-null uint8
# month_Jul            2917 non-null uint8
# month_Jun            2917 non-null uint8
# month_Mar            2917 non-null uint8
# month_May            2917 non-null uint8
# month_Nov            2917 non-null uint8
# month_Oct            2917 non-null uint8
# month_Sep            2917 non-null uint8
# game_No Game         2917 non-null uint8
# ...

# %%
fn = df.drop(['sum_crimes'],axis=1).columns

# %% [markdown]
# # prooning
# - pre
# - post

# %%
tree = DecisionTreeClassifier(max_depth=4, random_state=0)
tree.fit(X_train, y_train)
print('Accuracy on the training subset: {: 3f}'.format(tree.score(X_train,y_train)))

print('Accuracy on the test subset: {: 3f}'.format(tree.score(X_test,y_test)))
# Out:
# Accuracy on the training subset:  0.152263
# Accuracy on the test subset:  0.132877

# %%
import graphviz
from sklearn.tree import export_graphviz

# %%
export_graphviz(tree, out_file='cancertree.dot', class_names=['malignant'], feature_names=fn,
               impurity=False,filled=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-56-b2d3500f85ca> in <module>()
#       1 export_graphviz(tree, out_file='cancertree.dot', class_names=['malignant'], feature_names=fn,
# ----> 2                impurity=False,filled=True)
#
# ~/miniconda3/envs/springboard/lib/python3.6/site-packages/sklearn/tree/export.py in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters, precision)
#     462             recurse(decision_tree, 0, criterion="impurity")
#     463         else:
# --> 464             recurse(decision_tree.tree_, 0, criterion=decision_tree.criterion)
#     465
#     466         # If required, draw leaf nodes at same depth as each other
#
# ...

# %%
ls

# %%
import graphviz

with open("cancertree.dot") as f:
    dot_graph = f.read()

# remove the display(...)

graphviz.Source(dot_graph)
# Out:
# Error: <stdin>: syntax error in line 3
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# ~/miniconda3/envs/springboard/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/miniconda3/envs/springboard/lib/python3.6/site-packages/graphviz/files.py in _repr_svg_(self)
#     104
#     105     def _repr_svg_(self):
# --> 106         return self.pipe(format='svg').decode(self._encoding)
#     107
#     108     def pipe(self, format=None):
#
# ~/miniconda3/envs/springboard/lib/python3.6/site-packages/graphviz/files.py in pipe(self, format)
#     123         data = text_type(self.source).encode(self._encoding)
#     124
# ...
