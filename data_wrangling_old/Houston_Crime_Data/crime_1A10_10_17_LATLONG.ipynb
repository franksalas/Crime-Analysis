# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import googlemaps
import gmaps
import requests
API_KEY = 'AIzaSyDx5QmI3U_EDK3N8uVW32D65fdLdv82C58'

import gmaps_func as gf
import datetime as dt

# %%
path = 'crime_data_clean/crime_1A10_10_17.csv'
df = pd.read_csv(path,index_col='Date_Hour', parse_dates=True)

# %%
df.head()
# Out:
#             Beat BlockRange               StreetName OffenseType  \
# Date_Hour
# 2010-01-01  1A10    300-399                 HAMILTON  Auto Theft
# 2010-01-01  1A10  1200-1299                 CAROLINE       Theft
# 2010-01-01  1A10    400-499                     MAIN    Burglary
# 2010-01-01  1A10  1200-1299                   TRAVIS       Theft
# 2010-01-01  1A10  1000-1099  AVENIDA DE LAS AMERICAS       Theft
#
#                                     Premise  NumOffenses  Hour  day weekday  \
# Date_Hour
# 2010-01-01       bar/night club parking lot            1     0    1  Friday
# 2010-01-01                   bar/night club            1     0    1  Friday
# 2010-01-01                  office building            1     0    1  Friday
# 2010-01-01                    other/unknown            1     0    1  Friday
# 2010-01-01  convention center/exhibit halls            1     0    1  Friday
#
#            month  year
# Date_Hour
# 2010-01-01   Jan  2010
# 2010-01-01   Jan  2010
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 15204 entries, 2010-01-01 00:00:00 to 2017-12-31 22:00:00
# Data columns (total 11 columns):
# Beat           15204 non-null object
# BlockRange     15204 non-null object
# StreetName     15204 non-null object
# OffenseType    15204 non-null object
# Premise        15204 non-null object
# NumOffenses    15204 non-null int64
# Hour           15204 non-null int64
# day            15204 non-null int64
# weekday        15204 non-null object
# month          15204 non-null object
# year           15204 non-null int64
# dtypes: int64(4), object(7)
# memory usage: 1.4+ MB

# %% [markdown]
# ## Return a good blockrange value

# %%
gf.block_split(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-015b151337a5> in <module>()
# ----> 1 gf.block_split(df)
#
# /mnt/c/Users/frank/Documents/linux_dev/springboardCapstone/data_wrangling/Houston_Crime_Data/gmaps_func.py in block_split(df)
#       9     then give median value as a string
#      10     '''
# ---> 11     first = df.BlockRange.str.split(pat='-',expand=True)[0].astype('int')
#      12     second = df.BlockRange.str.split(pat='-',expand=True)[1].astype('int')
#      13     med = np.ceil((second + first)/2).astype('int')
#
# ~/miniconda3/envs/springboard/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# ...

# %% [markdown]
# ## Drop 'UNK' values

# %%
unk = df.BlockRange == 'UNK'

# %%
df = df[~unk]

# %%
df.head()
# Out:
#             Beat BlockRange               StreetName OffenseType  \
# Date_Hour
# 2010-01-01  1A10    300-399                 HAMILTON  Auto Theft
# 2010-01-01  1A10  1200-1299                 CAROLINE       Theft
# 2010-01-01  1A10    400-499                     MAIN    Burglary
# 2010-01-01  1A10  1200-1299                   TRAVIS       Theft
# 2010-01-01  1A10  1000-1099  AVENIDA DE LAS AMERICAS       Theft
#
#                                     Premise  NumOffenses  Hour  day weekday  \
# Date_Hour
# 2010-01-01       bar/night club parking lot            1     0    1  Friday
# 2010-01-01                   bar/night club            1     0    1  Friday
# 2010-01-01                  office building            1     0    1  Friday
# 2010-01-01                    other/unknown            1     0    1  Friday
# 2010-01-01  convention center/exhibit halls            1     0    1  Friday
#
#            month  year
# Date_Hour
# 2010-01-01   Jan  2010
# 2010-01-01   Jan  2010
# ...

# %%
df['block'] = gf.block_split(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-8d2e0cff0d90> in <module>()
# ----> 1 df['block'] = gf.block_split(df)
#
# /mnt/c/Users/frank/Documents/linux_dev/springboardCapstone/data_wrangling/Houston_Crime_Data/gmaps_func.py in block_split(df)
#       9     then give median value as a string
#      10     '''
# ---> 11     first = df.BlockRange.str.split(pat='-',expand=True)[0].astype('int')
#      12     second = df.BlockRange.str.split(pat='-',expand=True)[1].astype('int')
#      13     med = np.ceil((second + first)/2).astype('int')
#
# ~/miniconda3/envs/springboard/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
# ...

# %%
df.BlockRange.value_counts()
# Out:
# 1200-1299      1555
# 900-999        1132
# 1000-1099      1061
# 1500-1599       973
# 1100-1199       924
# 500-599         921
# 800-899         868
# 700-799         865
# 1600-1699       819
# 1400-1499       783
# 1300-1399       728
# 400-499         598
# 600-699         543
# 1800-1899       522
# 1900-1999       419
# 1700-1799       415
# 300-399         407
# 100-199         292
# 200-299         271
# 2000-2099       117
# 0-99             90
# 2400-2499        30
# 2800-2899        26
# 2100-2199        18
# 2300-2399        18
# 5000-5099        14
# 3100-3199        14
# 2500-2599        12
# 3000-3099        12
# 8200-8299        11
#                ...
# 16200-16299       1
# 33400-33499       1
# 12100-12199       1
# 14500-14599       1
# 21600-21699       1
# 17300-17399       1
# 22900-22999       1
# 13000-13099       1
# 16800-16899       1
# 15800-15899       1
# 13100-13199       1
# 18200-18299       1
# 13600-13699       1
# 14600-14699       1
# ...

# %%
ran = df.BlockRange == '1.1103e+006-1.1104e+006'

# %%
df[ran]
# Out:
#                      Beat               BlockRange               StreetName  \
# Date_Hour
# 2017-09-01 21:00:00  1A10  1.1103e+006-1.1104e+006  AVENIDA DE LAS AMERICAS
#
#                     OffenseType                             Premise  \
# Date_Hour
# 2017-09-01 21:00:00       Theft  convention center or exhibit halls
#
#                      NumOffenses  Hour  day weekday month  year
# Date_Hour
# 2017-09-01 21:00:00            1    21    1  Friday   Sep  2017

# %%
av = df.StreetName == 'AVENIDA DE LAS AMERICAS'

# %%
df[av]
# Out:
#                      Beat               BlockRange               StreetName  \
# Date_Hour
# 2010-01-01 00:00:00  1A10                1000-1099  AVENIDA DE LAS AMERICAS
# 2010-01-02 14:00:00  1A10                1000-1099  AVENIDA DE LAS AMERICAS
# 2010-02-22 19:00:00  1A10                1000-1099  AVENIDA DE LAS AMERICAS
# 2010-02-28 09:00:00  1A10                1000-1099  AVENIDA DE LAS AMERICAS
# 2010-03-27 13:00:00  1A10                1000-1099  AVENIDA DE LAS AMERICAS
# 2010-03-28 10:00:00  1A10                1000-1099  AVENIDA DE LAS AMERICAS
# 2010-04-03 11:00:00  1A10                1000-1099  AVENIDA DE LAS AMERICAS
# 2010-05-01 15:00:00  1A10                1000-1099  AVENIDA DE LAS AMERICAS
# 2010-05-02 11:00:00  1A10                1000-1099  AVENIDA DE LAS AMERICAS
# 2010-06-08 14:00:00  1A10                1000-1099  AVENIDA DE LAS AMERICAS
# 2010-06-12 10:00:00  1A10                1000-1099  AVENIDA DE LAS AMERICAS
# ...

# %%
df.BlockRange[df.BlockRange == '1.1103e+006-1.1104e+006']= '1000-1099'

# %%
df[ran].BlockRange
# Out:
# Date_Hour
# 2017-09-01 21:00:00    1000-1099
# Name: BlockRange, dtype: object

# %%
df.head()
# Out:
#             Beat BlockRange               StreetName OffenseType  \
# Date_Hour
# 2010-01-01  1A10    300-399                 HAMILTON  Auto Theft
# 2010-01-01  1A10  1200-1299                 CAROLINE       Theft
# 2010-01-01  1A10    400-499                     MAIN    Burglary
# 2010-01-01  1A10  1200-1299                   TRAVIS       Theft
# 2010-01-01  1A10  1000-1099  AVENIDA DE LAS AMERICAS       Theft
#
#                                     Premise  NumOffenses  Hour  day weekday  \
# Date_Hour
# 2010-01-01       bar/night club parking lot            1     0    1  Friday
# 2010-01-01                   bar/night club            1     0    1  Friday
# 2010-01-01                  office building            1     0    1  Friday
# 2010-01-01                    other/unknown            1     0    1  Friday
# 2010-01-01  convention center/exhibit halls            1     0    1  Friday
#
#            month  year
# Date_Hour
# 2010-01-01   Jan  2010
# 2010-01-01   Jan  2010
# ...

# %%
df['block'] = gf.block_split(df)

# %%
df.head()
# Out:
#             Beat BlockRange               StreetName OffenseType  \
# Date_Hour
# 2010-01-01  1A10    300-399                 HAMILTON  Auto Theft
# 2010-01-01  1A10  1200-1299                 CAROLINE       Theft
# 2010-01-01  1A10    400-499                     MAIN    Burglary
# 2010-01-01  1A10  1200-1299                   TRAVIS       Theft
# 2010-01-01  1A10  1000-1099  AVENIDA DE LAS AMERICAS       Theft
#
#                                     Premise  NumOffenses  Hour  day weekday  \
# Date_Hour
# 2010-01-01       bar/night club parking lot            1     0    1  Friday
# 2010-01-01                   bar/night club            1     0    1  Friday
# 2010-01-01                  office building            1     0    1  Friday
# 2010-01-01                    other/unknown            1     0    1  Friday
# 2010-01-01  convention center/exhibit halls            1     0    1  Friday
#
#            month  year block
# Date_Hour
# 2010-01-01   Jan  2010   350
# ...

# %% [markdown]
# ## Create full addres col

# %%
df['address']  = df[['block', 'StreetName']].apply(lambda x: ' '.join(x), axis=1)

# %%
df.head()
# Out:
#             Beat BlockRange               StreetName OffenseType  \
# Date_Hour
# 2010-01-01  1A10    300-399                 HAMILTON  Auto Theft
# 2010-01-01  1A10  1200-1299                 CAROLINE       Theft
# 2010-01-01  1A10    400-499                     MAIN    Burglary
# 2010-01-01  1A10  1200-1299                   TRAVIS       Theft
# 2010-01-01  1A10  1000-1099  AVENIDA DE LAS AMERICAS       Theft
#
#                                     Premise  NumOffenses  Hour  day weekday  \
# Date_Hour
# 2010-01-01       bar/night club parking lot            1     0    1  Friday
# 2010-01-01                   bar/night club            1     0    1  Friday
# 2010-01-01                  office building            1     0    1  Friday
# 2010-01-01                    other/unknown            1     0    1  Friday
# 2010-01-01  convention center/exhibit halls            1     0    1  Friday
#
#            month  year block                       address
# Date_Hour
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 14978 entries, 2010-01-01 00:00:00 to 2017-12-31 22:00:00
# Data columns (total 13 columns):
# Beat           14978 non-null object
# BlockRange     14978 non-null object
# StreetName     14978 non-null object
# OffenseType    14978 non-null object
# Premise        14978 non-null object
# NumOffenses    14978 non-null int64
# Hour           14978 non-null int64
# day            14978 non-null int64
# weekday        14978 non-null object
# month          14978 non-null object
# year           14978 non-null int64
# block          14978 non-null object
# address        14978 non-null object
# dtypes: int64(4), object(9)
# memory usage: 2.2+ MB

# %% [markdown]
# # get full lat long and address from google

# %%
df_4000 = df.iloc[:4000].copy()
df_8000 = df.iloc[4000:8000].copy()
df_12000 = df.iloc[8000:12000].copy()
df_14978  = df.iloc[12000:].copy()

# %% [markdown]
# ## Test

# %%
df_20 = df.iloc[:20].copy()
df_20['tup_add'] = df_20['address'].apply(gf.gm_geocode,args=(API_KEY,))
df_20.head()
# Out:
#             Beat BlockRange               StreetName OffenseType  \
# Date_Hour
# 2010-01-01  1A10    300-399                 HAMILTON  Auto Theft
# 2010-01-01  1A10  1200-1299                 CAROLINE       Theft
# 2010-01-01  1A10    400-499                     MAIN    Burglary
# 2010-01-01  1A10  1200-1299                   TRAVIS       Theft
# 2010-01-01  1A10  1000-1099  AVENIDA DE LAS AMERICAS       Theft
#
#                                     Premise  NumOffenses  Hour  day weekday  \
# Date_Hour
# 2010-01-01       bar/night club parking lot            1     0    1  Friday
# 2010-01-01                   bar/night club            1     0    1  Friday
# 2010-01-01                  office building            1     0    1  Friday
# 2010-01-01                    other/unknown            1     0    1  Friday
# 2010-01-01  convention center/exhibit halls            1     0    1  Friday
#
#            month  year block                       address  \
# Date_Hour
# ...

# %%
tt = df_20.tup_add

# %%
tt[4].to_json(orient='split')
# Out:
# '{"name":"tup_add","index":[4],"data":[{"address_components":[{"long_name":"1050","short_name":"1050","types":["street_number"]},{"long_name":"Avenida De Las Americas","short_name":"Avenida De Las Americas","types":["route"]},{"long_name":"Downtown","short_name":"Downtown","types":["neighborhood","political"]},{"long_name":"Houston","short_name":"Houston","types":["locality","political"]},{"long_name":"Harris County","short_name":"Harris County","types":["administrative_area_level_2","political"]},{"long_name":"Texas","short_name":"TX","types":["administrative_area_level_1","political"]},{"long_name":"United States","short_name":"US","types":["country","political"]},{"long_name":"77010","short_name":"77010","types":["postal_code"]}],"formatted_address":"1050 Avenida De Las Americas, Houston, TX 77010, USA","geometry":{"location":{"lat":29.7520152,"lng":-95.359181},"location_type":"RANGE_INTERPOLATED","viewport":{"northeast":{"lat":29.7533641803,"lng":-95.3578320197},"southwest":{"lat
# ...

# %% [markdown]
# ## Attempt

# %%
df_4000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4000 entries, 2010-01-01 00:00:00 to 2012-01-16 12:00:00
# Data columns (total 13 columns):
# Beat           4000 non-null object
# BlockRange     4000 non-null object
# StreetName     4000 non-null object
# OffenseType    4000 non-null object
# Premise        4000 non-null object
# NumOffenses    4000 non-null int64
# Hour           4000 non-null int64
# day            4000 non-null int64
# weekday        4000 non-null object
# month          4000 non-null object
# year           4000 non-null int64
# block          4000 non-null object
# address        4000 non-null object
# dtypes: int64(4), object(9)
# memory usage: 437.5+ KB

# %%
bf = dt.datetime.now().time().strftime("%X")
print('start:{}'.format(bf))
df_4000['tup_add'] = df_4000['address'].apply(gf.gm_geocode,args=(API_KEY,))

af = dt.datetime.now().time().strftime("%X")
print('end:{}'.format(af))
# Out:
# start:16:16:11
# end:16:41:44

# %%
df_4000.head(2)
# Out:
#             Beat BlockRange StreetName OffenseType  \
# Date_Hour
# 2010-01-01  1A10    300-399   HAMILTON  Auto Theft
# 2010-01-01  1A10  1200-1299   CAROLINE       Theft
#
#                                Premise  NumOffenses  Hour  day weekday month  \
# Date_Hour
# 2010-01-01  bar/night club parking lot            1     0    1  Friday   Jan
# 2010-01-01              bar/night club            1     0    1  Friday   Jan
#
#             year block        address  \
# Date_Hour
# 2010-01-01  2010   350   350 HAMILTON
# 2010-01-01  2010  1250  1250 CAROLINE
#
#                                                       tup_add
# Date_Hour
# 2010-01-01  [{'address_components': [{'long_name': '350', ...
# 2010-01-01  [{'address_components': [{'long_name': '1250',...

# %%
len(df_4000[df_4000.tup_add.isnull()])
df_4000.to_csv('crime_data_clean/crime_1A10_10_17df_4000.csv')

# %%
bf = dt.datetime.now().time().strftime("%X")
print('start:{}'.format(bf))
df_8000['tup_add'] = df_8000['address'].apply(gf.gm_geocode,args=(API_KEY,))

af = dt.datetime.now().time().strftime("%X")
print('end:{}'.format(af))
# Out:
# start:16:54:21
# end:17:19:00

# %%
print(len(df_8000[df_8000.tup_add.isnull()]))

df_8000.to_csv('crime_data_clean/crime_1A10_10_17df_8000.csv')
# Out:
# 0

# %% [markdown]
# ## split df_1200 into 4 parts

# %%
df_12000.head()
# Out:
#                      Beat BlockRange   StreetName         OffenseType  \
# Date_Hour
# 2014-05-08 00:00:00  1A10  1800-1899         RUIZ               Theft
# 2014-05-08 13:00:00  1A10  1000-1099       FANNIN               Theft
# 2014-05-08 18:00:00  1A10    600-699        LAMAR  Aggravated Assault
# 2014-05-09 04:00:00  1A10    900-999         MAIN               Theft
# 2014-05-09 10:00:00  1A10  9400-9499  SAM HOUSTON               Theft
#
#                                   Premise  NumOffenses  Hour  day   weekday  \
# Date_Hour
# 2014-05-08 00:00:00       residence/house            1     0    8  Thursday
# 2014-05-08 13:00:00   commercial building            1    13    8  Thursday
# 2014-05-08 18:00:00  road/street/sidewalk            1    18    8  Thursday
# 2014-05-09 04:00:00        clothing store            1     4    9    Friday
# 2014-05-09 10:00:00              no label            1    10    9    Friday
#
#                     month  year block           address
# ...

# %%
df_p1 = df_12000.iloc[:1000].copy()
df_p2 = df_12000.iloc[1000:2000].copy()
df_p3 = df_12000.iloc[2000:3000].copy()
df_p4 = df_12000.iloc[3000:].copy()

# %%
bf = dt.datetime.now().time().strftime("%X")
print('start:{}'.format(bf))
df_p1['tup_add'] = df_p1['address'].apply(gf.gm_geocode,args=(API_KEY,))

af = dt.datetime.now().time().strftime("%X")
print('end:{}'.format(af))
df_p1.to_csv('crime_data_clean/crime_1A10_10_17df_p1.csv')
# Out:
# start:18:45:27
# end:18:54:01

# %%
bf = dt.datetime.now().time().strftime("%X")
print('start:{}'.format(bf))
df_p2['tup_add'] = df_p2['address'].apply(gf.gm_geocode,args=(API_KEY,))

af = dt.datetime.now().time().strftime("%X")
print('end:{}'.format(af))
df_p2.to_csv('crime_data_clean/crime_1A10_10_17df_p2.csv')
# Out:
# start:18:55:03
# end:19:01:08

# %%
bf = dt.datetime.now().time().strftime("%X")
print('start:{}'.format(bf))
df_p3['tup_add'] = df_p3['address'].apply(gf.gm_geocode,args=(API_KEY,))

af = dt.datetime.now().time().strftime("%X")
print('end:{}'.format(af))
df_p3.to_csv('crime_data_clean/crime_1A10_10_17df_p3.csv')
# Out:
# start:19:01:19
# end:19:07:07

# %%
bf = dt.datetime.now().time().strftime("%X")
print('start:{}'.format(bf))
df_p4['tup_add'] = df_p4['address'].apply(gf.gm_geocode,args=(API_KEY,))

af = dt.datetime.now().time().strftime("%X")
print('end:{}'.format(af))
df_p4.to_csv('crime_data_clean/crime_1A10_10_17df_p4.csv')
# Out:
# start:19:08:58
# end:19:15:43

# %%
df_12000_merge = pd.concat([df_p1,df_p2,df_p3,df_p4])

# %%
df_12000_merge.head()
# Out:
#                      Beat BlockRange   StreetName         OffenseType  \
# Date_Hour
# 2014-05-08 00:00:00  1A10  1800-1899         RUIZ               Theft
# 2014-05-08 13:00:00  1A10  1000-1099       FANNIN               Theft
# 2014-05-08 18:00:00  1A10    600-699        LAMAR  Aggravated Assault
# 2014-05-09 04:00:00  1A10    900-999         MAIN               Theft
# 2014-05-09 10:00:00  1A10  9400-9499  SAM HOUSTON               Theft
#
#                                   Premise  NumOffenses  Hour  day   weekday  \
# Date_Hour
# 2014-05-08 00:00:00       residence/house            1     0    8  Thursday
# 2014-05-08 13:00:00   commercial building            1    13    8  Thursday
# 2014-05-08 18:00:00  road/street/sidewalk            1    18    8  Thursday
# 2014-05-09 04:00:00        clothing store            1     4    9    Friday
# 2014-05-09 10:00:00              no label            1    10    9    Friday
#
#                     month  year block           address  \
# ...

# %%
df_12000_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4000 entries, 2014-05-08 00:00:00 to 2016-04-28 00:00:00
# Data columns (total 14 columns):
# Beat           4000 non-null object
# BlockRange     4000 non-null object
# StreetName     4000 non-null object
# OffenseType    4000 non-null object
# Premise        4000 non-null object
# NumOffenses    4000 non-null int64
# Hour           4000 non-null int64
# day            4000 non-null int64
# weekday        4000 non-null object
# month          4000 non-null object
# year           4000 non-null int64
# block          4000 non-null object
# address        4000 non-null object
# tup_add        4000 non-null object
# dtypes: int64(4), object(10)
# memory usage: 468.8+ KB

# %%
# bf = dt.datetime.now().time().strftime("%X")
# print('start:{}'.format(bf))
# df_12000['tup_add'] = df_12000['address'].apply(gf.gm_geocode,args=(API_KEY,))

# af = dt.datetime.now().time().strftime("%X")
# print('end:{}'.format(af))
# Out:
# start:17:19:21
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/miniconda3/envs/springboard/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     375             try:  # Python 2.7, use buffering of HTTP responses
# --> 376                 httplib_response = conn.getresponse(buffering=True)
#     377             except TypeError:  # Python 2.6 and older
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-0f39609b28fa> in <module>()
#       1 bf = dt.datetime.now().time().strftime("%X")
#       2 print('start:{}'.format(bf))
# ...

# %%
print(len(df_12000[df_8000.tup_add.isnull()]))
df_12000.to_csv('crime_data_clean/crime_1A10_10_17df_12000.csv')

# %%
bf = dt.datetime.now().time().strftime("%X")
print('start:{}'.format(bf))
df_14978['tup_add'] = df_14978['address'].apply(gf.gm_geocode,args=(API_KEY,))

af = dt.datetime.now().time().strftime("%X")
print('end:{}'.format(af))
# Out:
# start:18:13:22
# end:18:38:36

# %%
print(len(df_14978[df_14978.tup_add.isnull()]))
df_14978.to_csv('crime_data_clean/crime_1A10_10_17df_14978.csv')
# Out:
# 0

# %% [markdown]
# ## Concat all

# %%
df_final = pd.concat([df_4000,df_8000,df_12000_merge,df_14978])

# %%
df_final.head()
# Out:
#             Beat BlockRange               StreetName OffenseType  \
# Date_Hour
# 2010-01-01  1A10    300-399                 HAMILTON  Auto Theft
# 2010-01-01  1A10  1200-1299                 CAROLINE       Theft
# 2010-01-01  1A10    400-499                     MAIN    Burglary
# 2010-01-01  1A10  1200-1299                   TRAVIS       Theft
# 2010-01-01  1A10  1000-1099  AVENIDA DE LAS AMERICAS       Theft
#
#                                     Premise  NumOffenses  Hour  day weekday  \
# Date_Hour
# 2010-01-01       bar/night club parking lot            1     0    1  Friday
# 2010-01-01                   bar/night club            1     0    1  Friday
# 2010-01-01                  office building            1     0    1  Friday
# 2010-01-01                    other/unknown            1     0    1  Friday
# 2010-01-01  convention center/exhibit halls            1     0    1  Friday
#
#            month  year block                       address  \
# Date_Hour
# ...

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 14978 entries, 2010-01-01 00:00:00 to 2017-12-31 22:00:00
# Data columns (total 14 columns):
# Beat           14978 non-null object
# BlockRange     14978 non-null object
# StreetName     14978 non-null object
# OffenseType    14978 non-null object
# Premise        14978 non-null object
# NumOffenses    14978 non-null int64
# Hour           14978 non-null int64
# day            14978 non-null int64
# weekday        14978 non-null object
# month          14978 non-null object
# year           14978 non-null int64
# block          14978 non-null object
# address        14978 non-null object
# tup_add        14978 non-null object
# dtypes: int64(4), object(10)
# memory usage: 1.7+ MB

# %%
df_final.to_csv('crime_data_clean/crime_1A10_10_17ADD.csv')

# %%
df_final.head()
# Out:
#             Beat BlockRange               StreetName OffenseType  \
# Date_Hour
# 2010-01-01  1A10    300-399                 HAMILTON  Auto Theft
# 2010-01-01  1A10  1200-1299                 CAROLINE       Theft
# 2010-01-01  1A10    400-499                     MAIN    Burglary
# 2010-01-01  1A10  1200-1299                   TRAVIS       Theft
# 2010-01-01  1A10  1000-1099  AVENIDA DE LAS AMERICAS       Theft
#
#                                     Premise  NumOffenses  Hour  day weekday  \
# Date_Hour
# 2010-01-01       bar/night club parking lot            1     0    1  Friday
# 2010-01-01                   bar/night club            1     0    1  Friday
# 2010-01-01                  office building            1     0    1  Friday
# 2010-01-01                    other/unknown            1     0    1  Friday
# 2010-01-01  convention center/exhibit halls            1     0    1  Friday
#
#            month  year block                       address  \
# Date_Hour
# ...

# %%
new_add = df.tup_add.apply(pd.Series,index=['lat_lon','full_address'])

# %%
new_add.head()

# %%
df = df.join(new_add)

# %%
df.drop(['block','BlockRange','StreetName','address','tup_add','address','tup_add',],axis=1,inplace=True)

# %%
#df.drop('block', axis=1,inplace=True)

# %%
df_final.head()
# Out:
#             Beat BlockRange               StreetName OffenseType  \
# Date_Hour
# 2010-01-01  1A10    300-399                 HAMILTON  Auto Theft
# 2010-01-01  1A10  1200-1299                 CAROLINE       Theft
# 2010-01-01  1A10    400-499                     MAIN    Burglary
# 2010-01-01  1A10  1200-1299                   TRAVIS       Theft
# 2010-01-01  1A10  1000-1099  AVENIDA DE LAS AMERICAS       Theft
#
#                                     Premise  NumOffenses  Hour  day weekday  \
# Date_Hour
# 2010-01-01       bar/night club parking lot            1     0    1  Friday
# 2010-01-01                   bar/night club            1     0    1  Friday
# 2010-01-01                  office building            1     0    1  Friday
# 2010-01-01                    other/unknown            1     0    1  Friday
# 2010-01-01  convention center/exhibit halls            1     0    1  Friday
#
#            month  year block                       address  \
# Date_Hour
# ...

# %%
df_final.to_csv('crime_data_clean/crime_1A10_10_17FINAL.csv')
