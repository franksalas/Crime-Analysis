# %%
! pip install folium

# %%
# !pip install geopy

# %%
! pip install geopandas

# %%
import pandas as pd
import numpy as np
import folium

import geopy.distance
from geopy.distance import lonlat, distance
import matplotlib.pyplot as plt
from folium import plugins
import seaborn as sns
import geopandas as gpd

# %% [markdown]
# # BEATS [1A10, 10H30, 10H10]

# %%
beat1 = 'beat_geojson/1A10.geojson'
beat2 = 'beat_geojson/10H30.geojson'
beat3 = 'beat_geojson/10H10.geojson'

# %%
dynamo_stadium = [29.7522, -95.3524]  # 10H30

# %%
m = folium.Map([29.7281, -95.2298],     tiles='Stamen Toner',
zoom_start=11)

# convert to (n, 2) nd-array format for heatmap
#stationArr = df[['lat', 'lon']].as_matrix()
folium.Marker(dynamo_stadium, popup='<i>Dynamo Stadium</i>').add_to(m)


# add beat geojson file
folium.GeoJson(beat1,
    name='geojson'
).add_to(m)


# add beat geojson file
folium.GeoJson(beat2,
    name='geojson'
).add_to(m)

# add beat geojson file
folium.GeoJson(beat3,
    name='geojson'
).add_to(m)


folium.Circle(
    radius=1609,
    location=dynamo_stadium,
    popup='The Waterfront',
    color='crimson',
    fill=False,
).add_to(m)

# plot heatmap
#m.add_child(plugins.HeatMap(stationArr.tolist(), radius=15))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 1A10

# %%
path = 'crime_data_clean/df_1A10FINAL.csv'
df = pd.read_csv(path)
df.drop(['Unnamed: 0'],axis=1,inplace=True)
df.head(2)
# Out:
#              Date_Hour  Beat OffenseType                     Premise  \
# 0  2010-01-01 00:00:00  1A10  Auto Theft  bar/night club parking lot
# 1  2010-01-01 00:00:00  1A10       Theft              bar/night club
#
#    NumOffenses  Hour  day weekday month  year        lat        lon  \
# 0            1     0    1  Friday   Jan  2010  29.757212 -95.353294
# 1            1     0    1  Friday   Jan  2010  29.753512 -95.363811
#
#                                         add
# 0   350 Hamilton St, Houston, TX 77002, USA
# 1  1250 Caroline St, Houston, TX 77002, USA

# %%
stadium = dynamo_stadium[::-1]



subset = df[['lat','lon']]
tp = [tuple(x) for x in subset.values]


dd = []
for i,p in tp:
    c =  (p,i)
    start = lonlat(*stadium)
    end = lonlat(*c)
    dis = distance(start,end).miles
    #dis =  geopy.distance.distance(stadium, c).miles
    dd.append(dis)
    
dist = pd.Series(dd,name='dist_stadium')

# %%
df = df.join(dist)

# %%
df.head(2)
# Out:
#              Date_Hour  Beat OffenseType                     Premise  \
# 0  2010-01-01 00:00:00  1A10  Auto Theft  bar/night club parking lot
# 1  2010-01-01 00:00:00  1A10       Theft              bar/night club
#
#    NumOffenses  Hour  day weekday month  year        lat        lon  \
# 0            1     0    1  Friday   Jan  2010  29.757212 -95.353294
# 1            1     0    1  Friday   Jan  2010  29.753512 -95.363811
#
#                                         add  dist_stadium
# 0   350 Hamilton St, Houston, TX 77002, USA      0.349360
# 1  1250 Caroline St, Houston, TX 77002, USA      0.691728

# %%
one_mile =  df.dist_stadium < 1.0
one = df[one_mile]

# %%
m = folium.Map([29.7281, -95.2298],     tiles='Stamen Toner',
zoom_start=11)

# convert to (n, 2) nd-array format for heatmap
stationArr = one[['lat', 'lon']].as_matrix()
folium.Marker(dynamo_stadium, popup='<i>Dynamo Stadium</i>').add_to(m)


# add beat geojson file
folium.GeoJson(beat1,
    name='geojson'
).add_to(m)


# add beat geojson file
folium.GeoJson(beat2,
    name='geojson'
).add_to(m)

# add beat geojson file
folium.GeoJson(beat3,
    name='geojson'
).add_to(m)


folium.Circle(
    radius=1609,
    location=dynamo_stadium,
    popup='The Waterfront',
    color='crimson',
    fill=False,
).add_to(m)

# plot heatmap
m.add_child(plugins.HeatMap(stationArr.tolist(), radius=15))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 10H10

# %%
path = 'crime_data_clean/df_10H10FINAL.csv'
df1 = pd.read_csv(path)
df1.drop(['Unnamed: 0'],axis=1,inplace=True)
df1.head(2)
# Out:
#              Date_Hour   Beat OffenseType                        Premise  \
# 0  2010-01-01 00:00:00  10H10    Burglary  misc. business (non-specific)
# 1  2010-01-01 06:00:00  10H10        Rape                residence/house
#
#    NumOffenses  Hour  day weekday month  year        lat        lon  \
# 0            1     0    1  Friday   Jan  2010  29.743716 -95.332731
# 1            1     6    1  Friday   Jan  2010  29.755055 -95.348144
#
#                                        add
# 0  550 Eastwood St, Houston, TX 77011, USA
# 1  2350 Sperber Ln, Houston, TX 77003, USA

# %%
stadium = dynamo_stadium[::-1]



subset = df1[['lat','lon']]
tp = [tuple(x) for x in subset.values]


dd = []
for i,p in tp:
    c =  (p,i)
    start = lonlat(*stadium)
    end = lonlat(*c)
    dis = distance(start,end).miles
    #dis =  geopy.distance.distance(stadium, c).miles
    dd.append(dis)
    
dist = pd.Series(dd,name='dist_stadium')

df1 = df1.join(dist)
df1.head(2)
# Out:
#              Date_Hour   Beat OffenseType                        Premise  \
# 0  2010-01-01 00:00:00  10H10    Burglary  misc. business (non-specific)
# 1  2010-01-01 06:00:00  10H10        Rape                residence/house
#
#    NumOffenses  Hour  day weekday month  year        lat        lon  \
# 0            1     0    1  Friday   Jan  2010  29.743716 -95.332731
# 1            1     6    1  Friday   Jan  2010  29.755055 -95.348144
#
#                                        add  dist_stadium
# 0  550 Eastwood St, Houston, TX 77011, USA      1.318724
# 1  2350 Sperber Ln, Houston, TX 77003, USA      0.322654

# %%
one_mile =  df1.dist_stadium < 1.0
one = df1[one_mile]

# %%
m = folium.Map([29.7281, -95.2298],     tiles='Stamen Toner',
zoom_start=11)

# convert to (n, 2) nd-array format for heatmap
stationArr = one[['lat', 'lon']].as_matrix()
folium.Marker(dynamo_stadium, popup='<i>Dynamo Stadium</i>').add_to(m)


# add beat geojson file
folium.GeoJson(beat1,
    name='geojson'
).add_to(m)


# add beat geojson file
folium.GeoJson(beat2,
    name='geojson'
).add_to(m)

# add beat geojson file
folium.GeoJson(beat3,
    name='geojson'
).add_to(m)


folium.Circle(
    radius=1609,
    location=dynamo_stadium,
    popup='The Waterfront',
    color='crimson',
    fill=False,
).add_to(m)

# plot heatmap
m.add_child(plugins.HeatMap(stationArr.tolist(), radius=15))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 10H30

# %%
path = 'crime_data_clean/df_10H30FINAL.csv'
df2 = pd.read_csv(path)
df2.drop(['Unnamed: 0'],axis=1,inplace=True)
df2=df2.rename(columns = {'full_address':'add'})
df2.head(2)
# Out:
#              Date_Hour   Beat OffenseType                Premise  NumOffenses  \
# 0  2010-01-01 00:00:00  10H30       Theft        residence/house            1
# 1  2010-01-01 19:00:00  10H30       Theft  apartment parking lot            1
#
#    Hour  day weekday month  year        lat        lon  \
# 0     0    1  Friday   Jan  2010  29.739066 -95.348975
# 1    19    1  Friday   Jan  2010  29.753648 -95.351078
#
#                                        add
# 0  1750 Sampson St, Houston, TX 77003, USA
# 1   550 Bastrop St, Houston, TX 77003, USA

# %%
stadium = dynamo_stadium[::-1]



subset = df2[['lat','lon']]
tp = [tuple(x) for x in subset.values]


dd = []
for i,p in tp:
    c =  (p,i)
    start = lonlat(*stadium)
    end = lonlat(*c)
    dis = distance(start,end).miles
    #dis =  geopy.distance.distance(stadium, c).miles
    dd.append(dis)
    
dist = pd.Series(dd,name='dist_stadium')

df2 = df2.join(dist)
df2.head(2)
# Out:
#              Date_Hour   Beat OffenseType                Premise  NumOffenses  \
# 0  2010-01-01 00:00:00  10H30       Theft        residence/house            1
# 1  2010-01-01 19:00:00  10H30       Theft  apartment parking lot            1
#
#    Hour  day weekday month  year        lat        lon  \
# 0     0    1  Friday   Jan  2010  29.739066 -95.348975
# 1    19    1  Friday   Jan  2010  29.753648 -95.351078
#
#                                        add  dist_stadium
# 0  1750 Sampson St, Houston, TX 77003, USA      0.927775
# 1   550 Bastrop St, Houston, TX 77003, USA      0.127539

# %%
one_mile =  df2.dist_stadium < 1.0
one = df2[one_mile]

# %%
m = folium.Map([29.7281, -95.2298],     tiles='Stamen Toner',
zoom_start=11)

# convert to (n, 2) nd-array format for heatmap
stationArr = one[['lat', 'lon']].as_matrix()
folium.Marker(dynamo_stadium, popup='<i>Dynamo Stadium</i>').add_to(m)


# add beat geojson file
folium.GeoJson(beat1,
    name='geojson'
).add_to(m)


# add beat geojson file
folium.GeoJson(beat2,
    name='geojson'
).add_to(m)

# add beat geojson file
folium.GeoJson(beat3,
    name='geojson'
).add_to(m)


folium.Circle(
    radius=1609,
    location=dynamo_stadium,
    popup='The Waterfront',
    color='crimson',
    fill=False,
).add_to(m)

# plot heatmap
m.add_child(plugins.HeatMap(stationArr.tolist(), radius=15))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Joing df1,df2,df3

# %%
# df 3987,df2 
frames = [df,df1,df2]
dynamo = pd.concat(frames)

# %%
dynamo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23939 entries, 0 to 5017
# Data columns (total 14 columns):
# Date_Hour       23939 non-null object
# Beat            23939 non-null object
# OffenseType     23939 non-null object
# Premise         23939 non-null object
# NumOffenses     23939 non-null int64
# Hour            23939 non-null int64
# day             23939 non-null int64
# weekday         23939 non-null object
# month           23939 non-null object
# year            23939 non-null int64
# lat             23939 non-null float64
# lon             23939 non-null float64
# add             23939 non-null object
# dist_stadium    23939 non-null float64
# dtypes: float64(3), int64(4), object(7)
# memory usage: 2.7+ MB

# %%
dynamo.head(2)
# Out:
#              Date_Hour  Beat OffenseType                     Premise  \
# 0  2010-01-01 00:00:00  1A10  Auto Theft  bar/night club parking lot
# 1  2010-01-01 00:00:00  1A10       Theft              bar/night club
#
#    NumOffenses  Hour  day weekday month  year        lat        lon  \
# 0            1     0    1  Friday   Jan  2010  29.757212 -95.353294
# 1            1     0    1  Friday   Jan  2010  29.753512 -95.363811
#
#                                         add  dist_stadium
# 0   350 Hamilton St, Houston, TX 77002, USA      0.349360
# 1  1250 Caroline St, Houston, TX 77002, USA      0.691728

# %% [markdown]
# ## get distance from stadium to crime location

# %%
m = folium.Map([29.7281, -95.2298],     tiles='Stamen Toner',
zoom_start=11)

# convert to (n, 2) nd-array format for heatmap
stationArr = dynamo[['lat', 'lon']].as_matrix()
folium.Marker(dynamo_stadium, popup='<i>Dynamo Stadium</i>').add_to(m)


# add beat geojson file
folium.GeoJson(beat1,
    name='geojson'
).add_to(m)


# add beat geojson file
folium.GeoJson(beat2,
    name='geojson'
).add_to(m)

# add beat geojson file
folium.GeoJson(beat3,
    name='geojson'
).add_to(m)


folium.Circle(
    radius=1609,
    location=dynamo_stadium,
    popup='The Waterfront',
    color='crimson',
    fill=False,
).add_to(m)

# plot heatmap
m.add_child(plugins.HeatMap(stationArr.tolist(), radius=15))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## separate .25, .50, 1 miles

# %%
les_mile =  dynamo.dist_stadium <= 2.0
more_mile = dynamo.dist_stadium > 1.0 
one_mile =  dynamo.dist_stadium <= 1.0
h_mile = dynamo.dist_stadium < 0.5
q_mile = dynamo.dist_stadium < 0.25

# %%
out = dynamo[more_mile&les_mile]
one = dynamo[one_mile]
half = dynamo[h_mile]
qtr =  dynamo[q_mile]

# %% [markdown]
# # outside

# %%
m = folium.Map([29.7281, -95.2298],     tiles='Stamen Toner',
zoom_start=11)

# convert to (n, 2) nd-array format for heatmap
stationArr = out[['lat', 'lon']].as_matrix()
folium.Marker(dynamo_stadium, popup='<i>Dynamo Stadium</i>').add_to(m)


# add beat geojson file
folium.GeoJson(beat1,
    name='geojson'
).add_to(m)


# add beat geojson file
folium.GeoJson(beat2,
    name='geojson'
).add_to(m)

# add beat geojson file
folium.GeoJson(beat3,
    name='geojson'
).add_to(m)


folium.Circle(
    radius=(1609),
    location=dynamo_stadium,
    popup='The Waterfront',
    color='crimson',
    fill=False,
).add_to(m)

# plot heatmap
m.add_child(plugins.HeatMap(stationArr.tolist(), radius=15))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## One mile

# %%
m = folium.Map([29.7281, -95.2298],     tiles='Stamen Toner',
zoom_start=11)

# convert to (n, 2) nd-array format for heatmap
stationArr = one[['lat', 'lon']].as_matrix()
folium.Marker(dynamo_stadium, popup='<i>Dynamo Stadium</i>').add_to(m)


# add beat geojson file
folium.GeoJson(beat1,
    name='geojson'
).add_to(m)


# add beat geojson file
folium.GeoJson(beat2,
    name='geojson'
).add_to(m)

# add beat geojson file
folium.GeoJson(beat3,
    name='geojson'
).add_to(m)


folium.Circle(
    radius=(1609),
    location=dynamo_stadium,
    popup='The Waterfront',
    color='crimson',
    fill=False,
).add_to(m)

# plot heatmap
m.add_child(plugins.HeatMap(stationArr.tolist(), radius=15))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Half mle

# %%
m = folium.Map([29.7281, -95.2298],     tiles='Stamen Toner',
zoom_start=11)

# convert to (n, 2) nd-array format for heatmap
stationArr = half[['lat', 'lon']].as_matrix()
folium.Marker(dynamo_stadium, popup='<i>Dynamo Stadium</i>').add_to(m)


# add beat geojson file
folium.GeoJson(beat1,
    name='geojson'
).add_to(m)


# add beat geojson file
folium.GeoJson(beat2,
    name='geojson'
).add_to(m)

# add beat geojson file
folium.GeoJson(beat3,
    name='geojson'
).add_to(m)


folium.Circle(
    radius=(1609/2),
    location=dynamo_stadium,
    popup='The Waterfront',
    color='crimson',
    fill=False,
).add_to(m)

# plot heatmap
m.add_child(plugins.HeatMap(stationArr.tolist(), radius=15))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map([29.7281, -95.2298],     tiles='Stamen Toner',
zoom_start=11)

# convert to (n, 2) nd-array format for heatmap
stationArr = qtr[['lat', 'lon']].as_matrix()
folium.Marker(dynamo_stadium, popup='<i>Dynamo Stadium</i>').add_to(m)


# add beat geojson file
folium.GeoJson(beat1,
    name='geojson'
).add_to(m)


# add beat geojson file
folium.GeoJson(beat2,
    name='geojson'
).add_to(m)

# add beat geojson file
folium.GeoJson(beat3,
    name='geojson'
).add_to(m)


folium.Circle(
    radius=(1609/4),
    location=dynamo_stadium,
    popup='The Waterfront',
    color='crimson',
    fill=False,
).add_to(m)

# plot heatmap
m.add_child(plugins.HeatMap(stationArr.tolist(), radius=15))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
