# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import googlemaps
import gmaps
import requests
API_KEY = 'AIzaSyDx5QmI3U_EDK3N8uVW32D65fdLdv82C58'

import gmaps_func as gf
import datetime as dt

# %%
ls crime_data_clean/
# Out:
# beats_alternate_10_17.csv*      crime_10H60_10_17LATLON.csv*
# beats_filter_10_17.csv*         crime_10H70_10_17.csv*
# crime_10H10_10_17.csv*          crime_10H80_10_17ADD.csv*
# crime_10H30_10_17ADD.csv*       crime_10H80_10_17.csv*
# crime_10H30_10_17.csv*          crime_10H80_10_17FINAL.csv*
# crime_10H30_10_17FINAL.csv*     crime_15E40_10_17ADD.csv*
# crime_10H40_10_17.csv*          crime_15E40_10_17.csv*
# crime_10H40_10_17df_10000.csv*  crime_15E40_10_17df_12000.csv*
# crime_10H40_10_17df_1000.csv*   crime_15E40_10_17df_16281.csv*
# crime_10H40_10_17df_2000.csv*   crime_15E40_10_17df_4000.csv*
# crime_10H40_10_17df_3000.csv*   crime_15E40_10_17df_8000.csv*
# crime_10H40_10_17df_4000.csv*   crime_15E40_10_17FINAL.csv*
# crime_10H40_10_17df_5000.csv*   crime_1A10_10_17ADD.csv*
# crime_10H40_10_17df_6000.csv*   crime_1A10_10_17.csv*
# crime_10H40_10_17df_7000.csv*   crime_1A10_10_17df_14978.csv*
# crime_10H40_10_17df_8000.csv*   crime_1A10_10_17df_4000.csv*
# crime_10H40_10_17df_9000.csv*   crime_1A10_10_17df_8000.csv*
# crime_10H50_10_17ADD.csv*       crime_1A10_10_17df_p1.csv*
# crime_10H50_10_17.csv*          crime_1A10_10_17df_p2.csv*
# crime_10H50_10_17FINAL.csv*     crime_1A10_10_17df_p3.csv*
# crime_10H60_10_17ADD.csv*       crime_1A10_10_17df_p4.csv*
# crime_10H60_10_17.csv*          crime_1A10_10_17FINAL.csv*
# crime_10H60_10_17df_1000.csv*   crime_1A10_10_17LATLON.csv*
# crime_10H60_10_17df_2000.csv*   crime_final_clean10_17.csv*
# crime_10H60_10_17df_3000.csv*   new/
# crime_10H60_10_17df_4000.csv*   stadium_beats_geocode.csv*
# crime_10H60_10_17df_5000.csv*   stadiums_final.csv*
# crime_10H60_10_17df_6000.csv*   years/
# crime_10H60_10_17df_7000.csv*

# %%
path = 'crime_data_clean/crime_10H10_10_17.csv'
df = pd.read_csv(path,index_col='Date_Hour', parse_dates=True)

# %%
df.head()
# Out:
#                       Beat BlockRange StreetName OffenseType  \
# Date_Hour
# 2010-01-01 00:00:00  10H10    500-599   EASTWOOD    Burglary
# 2010-01-01 06:00:00  10H10  2300-2399    SPERBER        Rape
# 2010-01-01 17:00:00  10H10  1900-1999    RUNNELS    Burglary
# 2010-01-01 20:00:00  10H10  1900-1999    RUNNELS       Theft
# 2010-01-02 19:00:00  10H10       0-99       YORK    Burglary
#
#                                            Premise  NumOffenses  Hour  day  \
# Date_Hour
# 2010-01-01 00:00:00  misc. business (non-specific)            1     0    1
# 2010-01-01 06:00:00                residence/house            1     6    1
# 2010-01-01 17:00:00                      apartment            1    17    1
# 2010-01-01 20:00:00           road/street/sidewalk            1    20    1
# 2010-01-02 19:00:00                residence/house            1    19    2
#
#                       weekday month  year
# Date_Hour
# 2010-01-01 00:00:00    Friday   Jan  2010
# 2010-01-01 06:00:00    Friday   Jan  2010
# 2010-01-01 17:00:00    Friday   Jan  2010
# 2010-01-01 20:00:00    Friday   Jan  2010
# 2010-01-02 19:00:00  Saturday   Jan  2010

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4071 entries, 2010-01-01 00:00:00 to 2017-12-31 18:00:00
# Data columns (total 11 columns):
# Beat           4071 non-null object
# BlockRange     4071 non-null object
# StreetName     4071 non-null object
# OffenseType    4071 non-null object
# Premise        4071 non-null object
# NumOffenses    4071 non-null int64
# Hour           4071 non-null int64
# day            4071 non-null int64
# weekday        4071 non-null object
# month          4071 non-null object
# year           4071 non-null int64
# dtypes: int64(4), object(7)
# memory usage: 381.7+ KB

# %% [markdown]
# ## Return a good blockrange value

# %%
gf.block_split(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-015b151337a5> in <module>()
# ----> 1 gf.block_split(df)
#
# /mnt/c/Users/frank/Documents/linux_dev/springboardCapstone/data_wrangling/Houston_Crime_Data/gmaps_func.py in block_split(df)
#       9     then give median value as a string
#      10     '''
# ---> 11     first = df.BlockRange.str.split(pat='-',expand=True)[0].astype('int')
#      12     second = df.BlockRange.str.split(pat='-',expand=True)[1].astype('int')
#      13     med = np.ceil((second + first)/2).astype('int')
#
# ~/miniconda3/envs/springboard/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# ~/miniconda3/envs/springboard/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4002         # else, only a single dtype is given
#    4003         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4004                                      **kwargs)
#    4005         return self._constructor(new_data).__finalize__(self)
#    4006
#
# ~/miniconda3/envs/springboard/lib/python3.6/site-packages/pandas/core/internals.py in astype(self, dtype, **kwargs)
#    3460
#    3461     def astype(self, dtype, **kwargs):
# -> 3462         return self.apply('astype', dtype=dtype, **kwargs)
#    3463
#    3464     def convert(self, **kwargs):
#
# ~/miniconda3/envs/springboard/lib/python3.6/site-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3327
#    3328             kwargs['mgr'] = self
# -> 3329             applied = getattr(b, f)(**kwargs)
#    3330             result_blocks = _extend_blocks(applied, result_blocks)
#    3331
#
# ~/miniconda3/envs/springboard/lib/python3.6/site-packages/pandas/core/internals.py in astype(self, dtype, copy, errors, values, **kwargs)
#     542     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     543         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 544                             **kwargs)
#     545
#     546     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# ~/miniconda3/envs/springboard/lib/python3.6/site-packages/pandas/core/internals.py in _astype(self, dtype, copy, errors, values, klass, mgr, **kwargs)
#     623
#     624                 # _astype_nansafe works fine with 1-d only
# --> 625                 values = astype_nansafe(values.ravel(), dtype, copy=True)
#     626                 values = values.reshape(self.shape)
#     627
#
# ~/miniconda3/envs/springboard/lib/python3.6/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy)
#     690     elif arr.dtype == np.object_ and np.issubdtype(dtype.type, np.integer):
#     691         # work around NumPy brokenness, #1987
# --> 692         return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     693
#     694     if dtype.name in ("datetime64", "timedelta64"):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# pandas/_libs/src/util.pxd in util.set_value_at_unsafe()
#
# ValueError: invalid literal for int() with base 10: 'UNK'

# %% [markdown]
# ## Drop 'UNK' values

# %%
unk = df.BlockRange == 'UNK'

# %%
df = df[~unk]

# %%
df.head()
# Out:
#                       Beat BlockRange StreetName OffenseType  \
# Date_Hour
# 2010-01-01 00:00:00  10H10    500-599   EASTWOOD    Burglary
# 2010-01-01 06:00:00  10H10  2300-2399    SPERBER        Rape
# 2010-01-01 17:00:00  10H10  1900-1999    RUNNELS    Burglary
# 2010-01-01 20:00:00  10H10  1900-1999    RUNNELS       Theft
# 2010-01-02 19:00:00  10H10       0-99       YORK    Burglary
#
#                                            Premise  NumOffenses  Hour  day  \
# Date_Hour
# 2010-01-01 00:00:00  misc. business (non-specific)            1     0    1
# 2010-01-01 06:00:00                residence/house            1     6    1
# 2010-01-01 17:00:00                      apartment            1    17    1
# 2010-01-01 20:00:00           road/street/sidewalk            1    20    1
# 2010-01-02 19:00:00                residence/house            1    19    2
#
#                       weekday month  year
# Date_Hour
# 2010-01-01 00:00:00    Friday   Jan  2010
# 2010-01-01 06:00:00    Friday   Jan  2010
# 2010-01-01 17:00:00    Friday   Jan  2010
# 2010-01-01 20:00:00    Friday   Jan  2010
# 2010-01-02 19:00:00  Saturday   Jan  2010

# %%
df['block'] = gf.block_split(df)
# Out:
# /home/salas/miniconda3/envs/springboard/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df.BlockRange.value_counts()[:10]
# Out:
# 200-299      367
# 100-199      335
# 2100-2199    324
# 300-399      282
# 1900-1999    280
# 2300-2399    119
# 400-499      116
# 0-99         108
# 500-599       93
# 3400-3499     91
# Name: BlockRange, dtype: int64

# %%
df.head()
# Out:
#                       Beat BlockRange StreetName OffenseType  \
# Date_Hour
# 2010-01-01 00:00:00  10H10    500-599   EASTWOOD    Burglary
# 2010-01-01 06:00:00  10H10  2300-2399    SPERBER        Rape
# 2010-01-01 17:00:00  10H10  1900-1999    RUNNELS    Burglary
# 2010-01-01 20:00:00  10H10  1900-1999    RUNNELS       Theft
# 2010-01-02 19:00:00  10H10       0-99       YORK    Burglary
#
#                                            Premise  NumOffenses  Hour  day  \
# Date_Hour
# 2010-01-01 00:00:00  misc. business (non-specific)            1     0    1
# 2010-01-01 06:00:00                residence/house            1     6    1
# 2010-01-01 17:00:00                      apartment            1    17    1
# 2010-01-01 20:00:00           road/street/sidewalk            1    20    1
# 2010-01-02 19:00:00                residence/house            1    19    2
#
#                       weekday month  year block
# Date_Hour
# 2010-01-01 00:00:00    Friday   Jan  2010   550
# 2010-01-01 06:00:00    Friday   Jan  2010  2350
# 2010-01-01 17:00:00    Friday   Jan  2010  1950
# 2010-01-01 20:00:00    Friday   Jan  2010  1950
# 2010-01-02 19:00:00  Saturday   Jan  2010    50

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3988 entries, 2010-01-01 00:00:00 to 2017-12-31 18:00:00
# Data columns (total 12 columns):
# Beat           3988 non-null object
# BlockRange     3988 non-null object
# StreetName     3988 non-null object
# OffenseType    3988 non-null object
# Premise        3988 non-null object
# NumOffenses    3988 non-null int64
# Hour           3988 non-null int64
# day            3988 non-null int64
# weekday        3988 non-null object
# month          3988 non-null object
# year           3988 non-null int64
# block          3988 non-null object
# dtypes: int64(4), object(8)
# memory usage: 565.0+ KB

# %% [markdown]
# ## Create full addres col

# %%
df['address']  = df[['block', 'StreetName']].apply(lambda x: ' '.join(x), axis=1)
# Out:
# /home/salas/miniconda3/envs/springboard/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#                       Beat BlockRange StreetName OffenseType  \
# Date_Hour
# 2010-01-01 00:00:00  10H10    500-599   EASTWOOD    Burglary
# 2010-01-01 06:00:00  10H10  2300-2399    SPERBER        Rape
# 2010-01-01 17:00:00  10H10  1900-1999    RUNNELS    Burglary
# 2010-01-01 20:00:00  10H10  1900-1999    RUNNELS       Theft
# 2010-01-02 19:00:00  10H10       0-99       YORK    Burglary
#
#                                            Premise  NumOffenses  Hour  day  \
# Date_Hour
# 2010-01-01 00:00:00  misc. business (non-specific)            1     0    1
# 2010-01-01 06:00:00                residence/house            1     6    1
# 2010-01-01 17:00:00                      apartment            1    17    1
# 2010-01-01 20:00:00           road/street/sidewalk            1    20    1
# 2010-01-02 19:00:00                residence/house            1    19    2
#
#                       weekday month  year block       address
# Date_Hour
# 2010-01-01 00:00:00    Friday   Jan  2010   550  550 EASTWOOD
# 2010-01-01 06:00:00    Friday   Jan  2010  2350  2350 SPERBER
# 2010-01-01 17:00:00    Friday   Jan  2010  1950  1950 RUNNELS
# 2010-01-01 20:00:00    Friday   Jan  2010  1950  1950 RUNNELS
# 2010-01-02 19:00:00  Saturday   Jan  2010    50       50 YORK

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3988 entries, 2010-01-01 00:00:00 to 2017-12-31 18:00:00
# Data columns (total 13 columns):
# Beat           3988 non-null object
# BlockRange     3988 non-null object
# StreetName     3988 non-null object
# OffenseType    3988 non-null object
# Premise        3988 non-null object
# NumOffenses    3988 non-null int64
# Hour           3988 non-null int64
# day            3988 non-null int64
# weekday        3988 non-null object
# month          3988 non-null object
# year           3988 non-null int64
# block          3988 non-null object
# address        3988 non-null object
# dtypes: int64(4), object(9)
# memory usage: 596.2+ KB

# %% [markdown]
# # get full lat long and address from google

# %%
df_1000 = df.iloc[:1000].copy()
df_2000 = df.iloc[1000:2000].copy()
df_3000 = df.iloc[2000:3000].copy()
df_4000 = df.iloc[3000:].copy()

# %% [markdown]
# ## Test

# %%
df_10 = df.iloc[:20].copy()
df_20['tup_add'] = df_20['address'].apply(gf.gm_geocode,args=(API_KEY,))
df_20.head()

# %% [markdown]
# ## Attempt

# %%
bf = dt.datetime.now().time().strftime("%X")
print('start:{}'.format(bf))
df_1000['tup_add'] = df_1000['address'].apply(gf.gm_geocode,args=(API_KEY,))

af = dt.datetime.now().time().strftime("%X")
print('end:{}'.format(af))
df_1000.to_csv('crime_data_clean/crime_10H10_10_17df_1000.csv')
# Out:
# start:14:35:40
# end:14:43:07

# %%
df_1000.head()
# Out:
#                       Beat BlockRange StreetName OffenseType  \
# Date_Hour
# 2010-01-01 00:00:00  10H10    500-599   EASTWOOD    Burglary
# 2010-01-01 06:00:00  10H10  2300-2399    SPERBER        Rape
# 2010-01-01 17:00:00  10H10  1900-1999    RUNNELS    Burglary
# 2010-01-01 20:00:00  10H10  1900-1999    RUNNELS       Theft
# 2010-01-02 19:00:00  10H10       0-99       YORK    Burglary
#
#                                            Premise  NumOffenses  Hour  day  \
# Date_Hour
# 2010-01-01 00:00:00  misc. business (non-specific)            1     0    1
# 2010-01-01 06:00:00                residence/house            1     6    1
# 2010-01-01 17:00:00                      apartment            1    17    1
# 2010-01-01 20:00:00           road/street/sidewalk            1    20    1
# 2010-01-02 19:00:00                residence/house            1    19    2
#
#                       weekday month  year block       address  \
# Date_Hour
# 2010-01-01 00:00:00    Friday   Jan  2010   550  550 EASTWOOD
# 2010-01-01 06:00:00    Friday   Jan  2010  2350  2350 SPERBER
# 2010-01-01 17:00:00    Friday   Jan  2010  1950  1950 RUNNELS
# 2010-01-01 20:00:00    Friday   Jan  2010  1950  1950 RUNNELS
# 2010-01-02 19:00:00  Saturday   Jan  2010    50       50 YORK
#
#                                                                tup_add
# Date_Hour
# 2010-01-01 00:00:00  [{'address_components': [{'long_name': '550', ...
# 2010-01-01 06:00:00  [{'address_components': [{'long_name': '2350',...
# 2010-01-01 17:00:00  [{'address_components': [{'long_name': '1950',...
# 2010-01-01 20:00:00  [{'address_components': [{'long_name': '1950',...
# 2010-01-02 19:00:00  [{'address_components': [{'long_name': '50', '...

# %%
bf = dt.datetime.now().time().strftime("%X")
print('start:{}'.format(bf))
df_2000['tup_add'] = df_2000['address'].apply(gf.gm_geocode,args=(API_KEY,))

af = dt.datetime.now().time().strftime("%X")
print('end:{}'.format(af))
df_2000.to_csv('crime_data_clean/crime_10H10_10_17df_2000.csv')
# Out:
# start:14:43:59
# end:14:50:52

# %%
bf = dt.datetime.now().time().strftime("%X")
print('start:{}'.format(bf))
df_3000['tup_add'] = df_3000['address'].apply(gf.gm_geocode,args=(API_KEY,))

af = dt.datetime.now().time().strftime("%X")
print('end:{}'.format(af))
df_3000.to_csv('crime_data_clean/crime_10H10_10_17df_3000.csv')
# Out:
# start:14:50:57
# end:14:57:20

# %%
bf = dt.datetime.now().time().strftime("%X")
print('start:{}'.format(bf))
df_4000['tup_add'] = df_4000['address'].apply(gf.gm_geocode,args=(API_KEY,))

af = dt.datetime.now().time().strftime("%X")
print('end:{}'.format(af))
df_4000.to_csv('crime_data_clean/crime_10H10_10_17df_4000.csv')
# Out:
# start:14:57:20
# end:15:04:05

# %% [markdown]
# ## Concat all

# %%
df_final = pd.concat([df_1000,df_2000,df_3000,df_4000])

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3988 entries, 2010-01-01 00:00:00 to 2017-12-31 18:00:00
# Data columns (total 14 columns):
# Beat           3988 non-null object
# BlockRange     3988 non-null object
# StreetName     3988 non-null object
# OffenseType    3988 non-null object
# Premise        3988 non-null object
# NumOffenses    3988 non-null int64
# Hour           3988 non-null int64
# day            3988 non-null int64
# weekday        3988 non-null object
# month          3988 non-null object
# year           3988 non-null int64
# block          3988 non-null object
# address        3988 non-null object
# tup_add        3988 non-null object
# dtypes: int64(4), object(10)
# memory usage: 467.3+ KB

# %%
df_final.head()
# Out:
#                       Beat BlockRange StreetName OffenseType  \
# Date_Hour
# 2010-01-01 00:00:00  10H10    500-599   EASTWOOD    Burglary
# 2010-01-01 06:00:00  10H10  2300-2399    SPERBER        Rape
# 2010-01-01 17:00:00  10H10  1900-1999    RUNNELS    Burglary
# 2010-01-01 20:00:00  10H10  1900-1999    RUNNELS       Theft
# 2010-01-02 19:00:00  10H10       0-99       YORK    Burglary
#
#                                            Premise  NumOffenses  Hour  day  \
# Date_Hour
# 2010-01-01 00:00:00  misc. business (non-specific)            1     0    1
# 2010-01-01 06:00:00                residence/house            1     6    1
# 2010-01-01 17:00:00                      apartment            1    17    1
# 2010-01-01 20:00:00           road/street/sidewalk            1    20    1
# 2010-01-02 19:00:00                residence/house            1    19    2
#
#                       weekday month  year block       address  \
# Date_Hour
# 2010-01-01 00:00:00    Friday   Jan  2010   550  550 EASTWOOD
# 2010-01-01 06:00:00    Friday   Jan  2010  2350  2350 SPERBER
# 2010-01-01 17:00:00    Friday   Jan  2010  1950  1950 RUNNELS
# 2010-01-01 20:00:00    Friday   Jan  2010  1950  1950 RUNNELS
# 2010-01-02 19:00:00  Saturday   Jan  2010    50       50 YORK
#
#                                                                tup_add
# Date_Hour
# 2010-01-01 00:00:00  [{'address_components': [{'long_name': '550', ...
# 2010-01-01 06:00:00  [{'address_components': [{'long_name': '2350',...
# 2010-01-01 17:00:00  [{'address_components': [{'long_name': '1950',...
# 2010-01-01 20:00:00  [{'address_components': [{'long_name': '1950',...
# 2010-01-02 19:00:00  [{'address_components': [{'long_name': '50', '...

# %%
df_final.to_csv('crime_data_clean/crime_10H10_10_17ADD.csv')

# %%
df_final.head()
# Out:
#                       Beat BlockRange StreetName OffenseType  \
# Date_Hour
# 2010-01-01 00:00:00  10H10    500-599   EASTWOOD    Burglary
# 2010-01-01 06:00:00  10H10  2300-2399    SPERBER        Rape
# 2010-01-01 17:00:00  10H10  1900-1999    RUNNELS    Burglary
# 2010-01-01 20:00:00  10H10  1900-1999    RUNNELS       Theft
# 2010-01-02 19:00:00  10H10       0-99       YORK    Burglary
#
#                                            Premise  NumOffenses  Hour  day  \
# Date_Hour
# 2010-01-01 00:00:00  misc. business (non-specific)            1     0    1
# 2010-01-01 06:00:00                residence/house            1     6    1
# 2010-01-01 17:00:00                      apartment            1    17    1
# 2010-01-01 20:00:00           road/street/sidewalk            1    20    1
# 2010-01-02 19:00:00                residence/house            1    19    2
#
#                       weekday month  year block       address  \
# Date_Hour
# 2010-01-01 00:00:00    Friday   Jan  2010   550  550 EASTWOOD
# 2010-01-01 06:00:00    Friday   Jan  2010  2350  2350 SPERBER
# 2010-01-01 17:00:00    Friday   Jan  2010  1950  1950 RUNNELS
# 2010-01-01 20:00:00    Friday   Jan  2010  1950  1950 RUNNELS
# 2010-01-02 19:00:00  Saturday   Jan  2010    50       50 YORK
#
#                                                                tup_add
# Date_Hour
# 2010-01-01 00:00:00  [{'address_components': [{'long_name': '550', ...
# 2010-01-01 06:00:00  [{'address_components': [{'long_name': '2350',...
# 2010-01-01 17:00:00  [{'address_components': [{'long_name': '1950',...
# 2010-01-01 20:00:00  [{'address_components': [{'long_name': '1950',...
# 2010-01-02 19:00:00  [{'address_components': [{'long_name': '50', '...
