# %%
import geojsonio
import geopandas as gpd
import pandas as pd
import folium
# %matplotlib inline
pd.options.display.max_rows = 10
from folium import plugins

# %%
path ='crime_data_clean/crime_10H50_10_17FINAL.csv'

# %%
import folium


m = folium.Map(location=[45.5236, -122.6750])

# %%
df = pd.read_csv(path)
df.head()
# Out:
#              Date_Hour   Beat OffenseType  \
# 0  2010-01-01 09:00:00  10H50       Theft
# 1  2010-01-01 12:00:00  10H50    Burglary
# 2  2010-01-01 12:00:00  10H50    Burglary
# 3  2010-01-01 12:00:00  10H50       Theft
# 4  2010-01-01 12:00:00  10H50       Theft
#
#                                              Premise  NumOffenses  Hour  day  \
# 0                                    residence/house            1     9    1
# 1  vacant single occupancy residence (houses,town...            1    12    1
# 2  vacant single occupancy residence (houses,town...            1    12    1
# 3                                    residence/house            1    12    1
# 4                                    residence/house            1    12    1
#
#   weekday month  year                          lat_lon  \
# 0  Friday   Jan  2010  (29.731311, -95.36411439999999)
# 1  Friday   Jan  2010  (29.728306, -95.36597750000001)
# 2  Friday   Jan  2010        (29.7294834, -95.3507063)
# ...

# %%
df['lat_lon'] = df['lat_lon'].str.extract(r"\((.*?)\)", expand=False)
df.head()
# Out:
#              Date_Hour   Beat OffenseType  \
# 0  2010-01-01 09:00:00  10H50       Theft
# 1  2010-01-01 12:00:00  10H50    Burglary
# 2  2010-01-01 12:00:00  10H50    Burglary
# 3  2010-01-01 12:00:00  10H50       Theft
# 4  2010-01-01 12:00:00  10H50       Theft
#
#                                              Premise  NumOffenses  Hour  day  \
# 0                                    residence/house            1     9    1
# 1  vacant single occupancy residence (houses,town...            1    12    1
# 2  vacant single occupancy residence (houses,town...            1    12    1
# 3                                    residence/house            1    12    1
# 4                                    residence/house            1    12    1
#
#   weekday month  year                        lat_lon  \
# 0  Friday   Jan  2010  29.731311, -95.36411439999999
# 1  Friday   Jan  2010  29.728306, -95.36597750000001
# 2  Friday   Jan  2010        29.7294834, -95.3507063
# ...

# %%
tt.lat_lon.str.replace('(','')

# %%
tt.lat_lon.str.replace(')','')

# %%
df['lat_lon'] = df['lat_lon'].str.extract(r"\((.*?)\)", expand=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-aa825baefa60> in <module>()
# ----> 1 df['lat_lon'] = df['lat_lon'].str.extract(r"\((.*?)\)", expand=False)
#
# NameError: name 'df' is not defined

# %%
loc = pd.DataFrame(df.lat_lon.str.split(',',1).tolist(), columns=['lat','lon'])

# %%
loc.dtypes
# Out:
# lat    float64
# lon    float64
# dtype: object

# %%
loc.lat = loc.lat.astype('float')
loc.lon = loc.lon.astype('float')

# %%
df = df.join(loc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-f5f410636149> in <module>()
# ----> 1 df = df.join(loc)
#
# ~/miniconda3/envs/springboard/lib/python3.6/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    5314         # For SparseDataFrame's benefit
#    5315         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 5316                                  rsuffix=rsuffix, sort=sort)
#    5317
#    5318     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# ~/miniconda3/envs/springboard/lib/python3.6/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    5329             return merge(self, other, left_on=on, how=how,
#    5330                          left_index=on is None, right_index=True,
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9155 entries, 0 to 9154
# Data columns (total 14 columns):
# Date_Hour       9155 non-null object
# Beat            9155 non-null object
# OffenseType     9155 non-null object
# Premise         9155 non-null object
# NumOffenses     9155 non-null int64
# Hour            9155 non-null int64
# day             9155 non-null int64
# weekday         9155 non-null object
# month           9155 non-null object
# year            9155 non-null int64
# lat_lon         9155 non-null object
# full_address    9155 non-null object
# lat             9155 non-null float64
# lon             9155 non-null float64
# dtypes: float64(2), int64(4), object(8)
# memory usage: 1001.4+ KB

# %%
locations = ttt[['lat', 'lon']]
locationlist = locations.values.tolist()
len(locationlist)
locationlist[7]

# %%
map = folium.Map(location=[29.9, -95.05], tiles='Stamen Toner',zoom_start=12)
for point in range(0, len(locationlist)):
    folium.Marker(locationlist[point],popup=df.loc[point].full_address).add_to(map)

# %%
map.save('add.html')

# %%
df.loc[9].full_address

# %%
df

# %%
m = folium.Map([29.7281, -95.2298],     tiles='Stamen Toner',
zoom_start=11)
# convert to (n, 2) nd-array format for heatmap
stationArr = df[['lat', 'lon']].as_matrix()
folium.Marker([29.721944, -95.349167], popup='<i>UH Stadium</i>').add_to(m)

m.add_child(plugins.HeatMap(stationArr.tolist(), radius=15))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for index, row in df.iterrows():
    folium.CircleMarker([row['lat'], row['lon']],
                        radius=15,
                        fill_color="#3db7e4", # divvy color
                       ).add_to(m)

# %%
# convert to (n, 2) nd-array format for heatmap
stationArr = df[['lat', 'lon']].as_matrix()
folium.Marker([29.721944, -95.349167], popup='<i>UH Stadium</i>').add_to(m)

# %%
# plot heatmap
m.add_child(plugins.HeatMap(stationArr.tolist(), radius=15))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save('mmm.html')

# %%
df.OffenseType.value_counts()
# Out:
# Theft                 3943
# Aggravated Assault    1791
# Burglary              1646
# Robbery               1064
# Auto Theft             591
# Rape                    75
# Murder                  45
# Name: OffenseType, dtype: int64

# %%
tf =df[df.OffenseType == 'Theft']
bu =df[df.OffenseType == 'Burglary']
aa =df[df.OffenseType == 'Aggravated Assault']
at =df[df.OffenseType == 'Auto Theft']
ro =df[df.OffenseType == 'Robbery']
mu =df[df.OffenseType == 'Murder']
ra =df[df.OffenseType == 'Rape']

# %%
m = folium.Map([29.7281, -95.2298],     tiles='Stamen Toner',
zoom_start=11)

# convert to (n, 2) nd-array format for heatmap
stationArr = mu[['lat', 'lon']].as_matrix()

# plot heatmap
m.add_child(plugins.HeatMap(stationArr.tolist(), radius=15))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map([29.7281, -95.2298],     tiles='Stamen Toner',
zoom_start=11)

# convert to (n, 2) nd-array format for heatmap
stationArr = at[['lat', 'lon']].as_matrix()

# plot heatmap
m.add_child(plugins.HeatMap(stationArr.tolist(), radius=15))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map([29.7281, -95.2298],     tiles='Stamen Toner',
zoom_start=11)

# convert to (n, 2) nd-array format for heatmap
stationArr = ra[['lat', 'lon']].as_matrix()

# plot heatmap
m.add_child(plugins.HeatMap(stationArr.tolist(), radius=15))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map([29.7281, -95.2298],     tiles='Stamen Toner',
zoom_start=11)

# convert to (n, 2) nd-array format for heatmap
stationArr = ro[['lat', 'lon']].as_matrix()
folium.Marker([29.721944, -95.349167], popup='<i>UH Stadium</i>').add_to(m)

# plot heatmap
m.add_child(plugins.HeatMap(stationArr.tolist(), radius=15))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_1 = folium.Map(location=[45.372, -121.6972],
                   zoom_start=12,
                   tiles='Stamen Terrain')
folium.Marker([45.3288, -121.6625],
              popup='Mt. Hood Meadows',
              icon=folium.Icon(icon='cloud')
             ).add_to(map_1)
folium.Marker([45.3311, -121.7113],
              popup='Timberline Lodge',
              icon=folium.Icon(color='green')
             ).add_to(map_1)
folium.Marker([45.3300, -121.6823],
              popup='Some Other Location',
              icon=folium.Icon(color='red',icon='info-sign')
              ).add_to(map_1)
map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
help(folium.Icon)
# Out:
# Help on class Icon in module folium.map:
#
# class Icon(branca.element.MacroElement)
#  |  Creates an Icon object that will be rendered
#  |  using Leaflet.awesome-markers.
#  |
#  |  Parameters
#  |  ----------
#  |  color : str, default 'blue'
#  |      The color of the marker. You can use:
#  |
#  |          ['red', 'blue', 'green', 'purple', 'orange', 'darkred',
#  |           'lightred', 'beige', 'darkblue', 'darkgreen', 'cadetblue',
#  |           'darkpurple', 'white', 'pink', 'lightblue', 'lightgreen',
#  |           'gray', 'black', 'lightgray']
#  |
#  |  icon_color : str, default 'white'
#  |      The color of the drawing on the marker. You can use colors above,
#  |      or an html color code.
#  |  icon : str, default 'info-sign'
#  |      The name of the marker sign.
#  |      See Font-Awesome website to choose yours.
#  |      Warning : depending on the icon you choose you may need to adapt
#  |      the `prefix` as well.
#  |  angle : int, default 0
# ...

# %%
from folium.features import CustomIcon
import os
m = folium.Map(location=[45.372, -121.6972], zoom_start=12, tiles='Stamen Terrain')

url = 'http://leafletjs.com/examples/custom-icons/{}'.format
icon_image = url('leaf-red.png')
shadow_image = url('leaf-shadow.png')

icon = CustomIcon(
    icon_image,
    icon_size=(38, 95),
    icon_anchor=(22, 94),
    shadow_image=shadow_image,
    shadow_size=(50, 64),
    shadow_anchor=(4, 62),
    popup_anchor=(-3, -76)
)

marker = folium.Marker(
    location=[45.3288, -121.6625],
    icon=icon,
    popup='Mt. Hood Meadows'
)


m.add_child(marker)

#m.save(os.path.join('results', 'CustomIcon.html'))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from folium.features import CustomIcon

m = folium.Map(location=[45.372, -121.6972], zoom_start=12, tiles='Stamen Terrain')

url = 'http://leafletjs.com/examples/custom-icons/{}'.format
icon_image = url('leaf-red.png')
shadow_image = url('leaf-shadow.png')

icon = CustomIcon(
    icon_image,
    icon_size=(38, 95),
    icon_anchor=(22, 94),
    shadow_image=shadow_image,
    shadow_size=(50, 64),
    shadow_anchor=(4, 62),
    popup_anchor=(-3, -76)
)

marker = folium.Marker(
    location=[45.3288, -121.6625],
    icon=icon,
    popup='Mt. Hood Meadows'
)


m.add_child(marker)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
