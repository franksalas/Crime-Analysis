# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd
from collections import Counter
from sklearn import preprocessing
import scipy
import statsmodels.api as sm
from statsmodels.formula.api import ols
sns.set_context("talk")
# Out:
# /home/frank/miniconda3/envs/springboard/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
ls data
# Out:
# crime_astros_finalA.csv*   crime_rockets_finalB.csv*  crime_texans_final.csv*
# crime_astros_finalB.csv*   crime_rockets_final.csv*   crime_uh_finalA.csv*
# crime_astros_final.csv*    crime_ru_finalB.csv*       crime_uh_finalB.csv*
# crime_dynamo_finalA.csv*   crime_ru_final.csv*        crime_uh_final.csv*
# crime_dynamo_finalB.csv*   crime_ru_final.csvA.csv*   Position_Salaries.csv*
# crime_dynamo_final.csv*    crime_texans_finalA.csv*
# crime_rockets_finalA.csv*  crime_texans_finalB.csv*

# %%
path = 'data/crime_astros_finalB.csv'
team = 'Houston Astros'
df = pd.read_csv(path)
#df.drop(['date','dist_stadium_meadian','premise_mode'],axis=1,inplace=True)
df.drop(['date'],axis=1,inplace=True)

nogame = df.game =='No Game'
df = df[~nogame]


#df.drop(['month','offense_mode'],axis=1,inplace=True) # 194
#df.drop(['month','offense_mode','premise_mode'],axis=1,inplace=True) # 119
#df.drop(['month','offense_mode','season'],axis=1,inplace=True) # 192
#df.drop(['offense_mode','season',],axis=1,inplace=True) # 199
#df.drop(['offense_mode','dist_stadium_meadian'],axis=1,inplace=True) # 199
#df.drop(['weekday','dist_stadium_meadian'],axis=1,inplace=True) # 206
#df.drop(['weekday','dist_stadium_meadian','premise_mode'],axis=1,inplace=True) # 139
#df.drop(['offense_mode','dist_stadium_meadian','premise_mode'],axis=1,inplace=True) # 126
#df.drop(['offense_mode','premise_mode','season','dist_stadium_meadian'],axis=1,inplace=True) # 126
#df.drop(['offense_mode','season','premise_mode'],axis=1,inplace=True) # 128
#df.drop(['premise_mode','offense_mode'],axis=1,inplace=True) # 128
#df.drop(['weekday','dist_stadium_meadian','premise_mode'],axis=1,inplace=True) # 139

# %%
### get dummies
dfd = pd.get_dummies(df,drop_first=True)
dfd.columns = [c.replace("'", '') for c in dfd.columns]
dfd.columns = [c.replace(".", '') for c in dfd.columns]
dfd.columns = [c.replace("&", 'n') for c in dfd.columns]
dfd.columns = [c.replace(' ', '_') for c in dfd.columns]
dfd.head()
# Out:
#     crime_total  year  dist_stadium_meadian  hour_mode  weekday_Monday  \
# 94           14  2010              0.331182         19               1
# 95            7  2010              0.511708          0               0
# 96            7  2010              0.498919         12               0
# 98            9  2010              0.594481         12               0
# 99            9  2010              0.621294          0               0
#
#     weekday_Saturday  weekday_Sunday  weekday_Thursday  weekday_Tuesday  \
# 94                 0               0                 0                0
# 95                 0               0                 0                1
# 96                 0               0                 0                0
# 98                 0               0                 0                0
# 99                 1               0                 0                0
#
#     weekday_Wednesday      ...        premise_mode_stadium  \
# 94                  0      ...                           0
# 95                  0      ...                           0
# 96                  1      ...                           0
# 98                  0      ...                           0
# 99                  0      ...                           0
#
#     premise_mode_store  premise_mode_street  premise_mode_unk  \
# 94                   0                    0                 0
# 95                   0                    0                 0
# 96                   0                    0                 0
# 98                   1                    0                 0
# 99                   0                    0                 0
#
#     premise_mode_warehouse  offense_mode_Auto_Theft  offense_mode_Burglary  \
# 94                       0                        0                      0
# 95                       0                        1                      0
# 96                       0                        0                      0
# 98                       0                        0                      0
# 99                       0                        0                      0
#
#     offense_mode_Robbery  offense_mode_Theft  game_Won_Game
# 94                     0                   1              0
# 95                     0                   0              0
# 96                     0                   1              0
# 98                     0                   1              0
# 99                     0                   1              0
#
# [5 rows x 59 columns]

# %%
X = dfd.drop(['crime_total'],axis=1)  # predictors

#X = dfd[['dist_stadium_meadian']]
cols = X.columns
formula = '+'.join(list(cols))

y = dfd.crime_total

form = 'crime_total ~'+ formula
#form = 'crime_total ~ hour_mode + year'
m = ols(form,dfd).fit()
print(m.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            crime_total   R-squared:                       0.233
# Model:                            OLS   Adj. R-squared:                  0.161
# Method:                 Least Squares   F-statistic:                     3.246
# Date:                Wed, 25 Jul 2018   Prob (F-statistic):           8.86e-13
# Time:                        23:30:21   Log-Likelihood:                -1612.5
# No. Observations:                 655   AIC:                             3339.
# Df Residuals:                     598   BIC:                             3595.
# Df Model:                          56
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# Intercept                                   264.3627     86.980      3.039      0.002      93.539     435.186
# year                                         -0.1656      0.055     -3.026      0.003      -0.273      -0.058
# dist_stadium_meadian                         -0.1415      0.893     -0.158      0.874      -1.895       1.612
# hour_mode                                     0.0730      0.018      4.105      0.000       0.038       0.108
# weekday_Monday                               -0.6280      0.472     -1.332      0.183      -1.554       0.298
# weekday_Saturday                              0.6175      0.420      1.472      0.142      -0.207       1.442
# weekday_Sunday                               -0.4569      0.426     -1.073      0.284      -1.293       0.379
# weekday_Thursday                             -0.4319      0.497     -0.870      0.385      -1.407       0.543
# weekday_Tuesday                              -1.1610      0.430     -2.701      0.007      -2.005      -0.317
# weekday_Wednesday                            -0.8863      0.431     -2.055      0.040      -1.734      -0.039
# month_Aug                                    17.3695      5.808      2.991      0.003       5.963      28.776
# month_Jul                                    17.5776      5.801      3.030      0.003       6.184      28.971
# month_Jun                                    17.4938      5.791      3.021      0.003       6.120      28.867
# month_Mar                                    -1.4848      3.067     -0.484      0.628      -7.508       4.538
# month_May                                    -0.1242      0.413     -0.300      0.764      -0.936       0.688
# month_Oct                                    71.7948     23.260      3.087      0.002      26.114     117.476
# month_Sep                                    70.1024     23.177      3.025      0.003      24.584     115.621
# season_Spring                                70.0246     23.173      3.022      0.003      24.514     115.535
# season_Summer                                52.4409     17.385      3.016      0.003      18.298      86.584
# part_day_mode_Evening                         0.2399      0.341      0.702      0.483      -0.431       0.911
# part_day_mode_Morning                         0.3682      0.354      1.041      0.298      -0.327       1.063
# part_day_mode_Night                           0.9578      0.325      2.951      0.003       0.320       1.595
# premise_mode_apartment                        1.5954      3.079      0.518      0.605      -4.451       7.642
# premise_mode_apartment_prk                    1.9283      3.068      0.628      0.530      -4.098       7.955
# premise_mode_bank                            -0.3725      4.279     -0.087      0.931      -8.775       8.030
# premise_mode_bank_prk                         1.9436      4.278      0.454      0.650      -6.458      10.345
# premise_mode_bar_nc                           1.2961      3.076      0.421      0.674      -4.746       7.338
# premise_mode_bar_nc_prk                       0.8259      3.193      0.259      0.796      -5.446       7.097
# premise_mode_bus_rail                        -0.3093      3.259     -0.095      0.924      -6.711       6.092
# premise_mode_church__synagogue__or_temple    -1.4748      3.695     -0.399      0.690      -8.731       5.782
# premise_mode_comm_bld                         1.4112      3.168      0.445      0.656      -4.811       7.633
# premise_mode_comm_prk                         2.3464      3.020      0.777      0.437      -3.584       8.277
# premise_mode_constr                          -0.9093      3.326     -0.273      0.785      -7.441       5.622
# premise_mode_convention                       0.3585      3.317      0.108      0.914      -6.155       6.872
# premise_mode_credit_union                     1.3183      4.240      0.311      0.756      -7.009       9.645
# premise_mode_driveway                         1.1788      3.699      0.319      0.750      -6.085       8.443
# premise_mode_field_woods                     -0.3830      4.266     -0.090      0.929      -8.761       7.995
# premise_mode_gym                              2.7929      3.715      0.752      0.452      -4.503      10.089
# premise_mode_hospital                        -0.4251      3.465     -0.123      0.902      -7.231       6.380
# premise_mode_hotel                            1.1743      3.119      0.377      0.707      -4.951       7.300
# premise_mode_hotel_prk                        2.3523      3.714      0.633      0.527      -4.942       9.646
# premise_mode_house                            2.2880      3.190      0.717      0.474      -3.977       8.553
# premise_mode_libraries                       -1.0810      3.715     -0.291      0.771      -8.377       6.215
# premise_mode_office_bld                      -1.3663      3.709     -0.368      0.713      -8.650       5.917
# premise_mode_parks                            1.8366      3.228      0.569      0.570      -4.502       8.175
# premise_mode_physicians_office                0.4165      4.237      0.098      0.922      -7.904       8.737
# premise_mode_prk                              2.3632      3.048      0.775      0.438      -3.623       8.350
# premise_mode_rest                            -0.2350      3.361     -0.070      0.944      -6.835       6.365
# premise_mode_rest_prk                         1.4789      3.384      0.437      0.662      -5.168       8.126
# premise_mode_stadium                          2.5449      3.720      0.684      0.494      -4.760       9.850
# premise_mode_store                            1.6653      3.247      0.513      0.608      -4.711       8.042
# premise_mode_street                           2.9013      3.020      0.961      0.337      -3.030       8.832
# premise_mode_unk                              1.8387      3.031      0.607      0.544      -4.114       7.791
# premise_mode_warehouse                        3.8586      4.263      0.905      0.366      -4.514      12.232
# offense_mode_Auto_Theft                       1.1056      0.954      1.158      0.247      -0.769       2.980
# offense_mode_Burglary                         2.2631      1.406      1.610      0.108      -0.497       5.024
# offense_mode_Robbery                          0.0798      1.562      0.051      0.959      -2.987       3.147
# offense_mode_Theft                            2.9952      0.790      3.793      0.000       1.444       4.546
# game_Won_Game                                -0.0019      0.245     -0.008      0.994      -0.483       0.479
# ==============================================================================
# Omnibus:                       68.171   Durbin-Watson:                   1.867
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              100.632
# Skew:                           0.738   Prob(JB):                     1.41e-22
# Kurtosis:                       4.228   Cond. No.                     1.00e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.65e-23. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
df.head()
# Out:
#     crime_total    weekday month  year  dist_stadium_meadian  season  \
# 94           14     Monday   Apr  2010              0.331182  Spring
# 95            7    Tuesday   Apr  2010              0.511708  Spring
# 96            7  Wednesday   Apr  2010              0.498919  Spring
# 98            9     Friday   Apr  2010              0.594481  Spring
# 99            9   Saturday   Apr  2010              0.621294  Spring
#
#    part_day_mode  hour_mode premise_mode offense_mode       game
# 94       Evening         19     comm prk        Theft  Lost Game
# 95     Afternoon          0     comm prk   Auto Theft  Lost Game
# 96     Afternoon         12     comm prk        Theft  Lost Game
# 98       Evening         12        store        Theft  Lost Game
# 99     Afternoon          0          prk        Theft  Lost Game

# %% [markdown]
# ## EDA & Summary Statistics

# %%
fig,ax = plt.subplots(figsize=(10,5))

sns.distplot(m.fittedvalues)
plt.show()
# Out:
# /home/frank/miniconda3/envs/springboard/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6448: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
fig,ax = plt.subplots(figsize=(10,5))

sns.distplot(dfd['crime_total'])
plt.show()
# Out:
# /home/frank/miniconda3/envs/springboard/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6448: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
title = 'Sum Crimes  by weekday: {}'.format(team)
fig,ax = plt.subplots(figsize=(15,5))

sns.boxplot(x="weekday", y="crime_total", hue="game", data=df, palette="PRGn")
sns.despine(offset=10, trim=True)
plt.title(title)
plt.savefig(title.replace(' ','_'))

# %%
title = 'Sum Crimes  by Month: {}'.format(team)
fig,ax = plt.subplots(figsize=(15,5))

sns.boxplot(x="month", y="crime_total", hue="game", data=df, palette="PRGn")
sns.despine(offset=10, trim=True)
plt.title(title)
plt.savefig(title.replace(' ','_'))
plt.show()

# %%
title = 'Sum Crimes  by year: {}'.format(team)
fig,ax = plt.subplots(figsize=(15,5))

sns.boxplot(x="year", y="crime_total", hue="game", data=df, palette="PRGn")
sns.despine(offset=10, trim=True)
plt.title(title)
plt.savefig(title.replace(' ','_'))
plt.show()

# %%
title = 'crimes distance by weekday: {}'.format(team)
fig,ax = plt.subplots(figsize=(15,5))

sns.boxplot(x="weekday", y="dist_stadium_meadian", hue="game", data=df, palette="PRGn")
sns.despine(offset=10, trim=True)
plt.title(title)
plt.savefig(title.replace(' ','_'))
plt.show()

# %%
title = 'Sum Crimes  by Season: {}'.format(team)
fig,ax = plt.subplots(figsize=(15,5))

sns.boxplot(x="season", y="crime_total", hue="game", data=df, palette="PRGn")
sns.despine(offset=10, trim=True)

plt.title(title)
plt.savefig(title.replace(' ','_'))
plt.show()

# %% [markdown]
# ## Relationships

# %% [markdown]
# ## linear regression

# %%
### get dummies

dfd = pd.get_dummies(df,drop_first=True)
dfd.columns = [c.replace(' ', '_') for c in dfd.columns]
dfd.head()
# Out:
#     crime_total  year  dist_stadium_meadian  hour_mode  weekday_Monday  \
# 94           14  2010              0.331182         19               1
# 95            7  2010              0.511708          0               0
# 96            7  2010              0.498919         12               0
# 98            9  2010              0.594481         12               0
# 99            9  2010              0.621294          0               0
#
#     weekday_Saturday  weekday_Sunday  weekday_Thursday  weekday_Tuesday  \
# 94                 0               0                 0                0
# 95                 0               0                 0                1
# 96                 0               0                 0                0
# 98                 0               0                 0                0
# 99                 1               0                 0                0
#
#     weekday_Wednesday      ...        premise_mode_stadium  \
# 94                  0      ...                           0
# 95                  0      ...                           0
# 96                  1      ...                           0
# 98                  0      ...                           0
# 99                  0      ...                           0
#
#     premise_mode_store  premise_mode_street  premise_mode_unk  \
# 94                   0                    0                 0
# 95                   0                    0                 0
# 96                   0                    0                 0
# 98                   1                    0                 0
# 99                   0                    0                 0
#
#     premise_mode_warehouse  offense_mode_Auto_Theft  offense_mode_Burglary  \
# 94                       0                        0                      0
# 95                       0                        1                      0
# 96                       0                        0                      0
# 98                       0                        0                      0
# 99                       0                        0                      0
#
#     offense_mode_Robbery  offense_mode_Theft  game_Won_Game
# 94                     0                   1              0
# 95                     0                   0              0
# 96                     0                   1              0
# 98                     0                   1              0
# 99                     0                   1              0
#
# [5 rows x 59 columns]

# %%
from sklearn import cross_validation, metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression, Ridge, Lasso
# Out:
# /home/frank/miniconda3/envs/springboard/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
alg1 = LinearRegression(normalize=True)
alg2 = Ridge(alpha=0.1,normalize=True)
alg3 = Lasso(alpha=0.1,normalize=True)

# %%
def modelfit(alg, X,y):
    '''
    target = y
    predictors = X
    '''
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=42)
    #Fit the algorithm on the data
    alg.fit(X_train,y_train)
    #Predict training set:
    train_predictions = alg.predict(X_train)
    #Perform cross-validation:
    cv_score = cross_val_score(alg, X, y, cv=10, scoring='neg_mean_squared_error')
    cv_score = np.sqrt(np.abs(cv_score))
    
    #Print model report:
    print ("\nModel Report")
    print( "RMSE : %.4g" % np.sqrt(metrics.mean_squared_error(y_train, train_predictions)))
    print ("CV Score : Mean  %.4g | Std  %.4g | Min  %.4g | Max  %.4g" % (np.mean(cv_score),np.std(cv_score),np.min(cv_score),np.max(cv_score))
)

# %%
X_cols = list(X.columns)

# %%
title = 'Baseball Astros: Linear Model Coefficients'
modelfit(alg1,X,y)
coef1 = pd.Series(alg1.coef_, X_cols).sort_values()
coef1.plot(kind='bar', title=title,figsize=(15,5))
plt.savefig(title.replace(' ','_'),bbox_inches="tight")
plt.show()
# Out:
# Model Report
# RMSE : 2.811
# CV Score : Mean  6.38e+13 | Std  1.081e+14 | Min  2.994 | Max  3.154e+14

# %%
title = 'Baseball Astros: Ridge Model Coefficients'

modelfit(alg2,X,y)
coef2 = pd.Series(alg2.coef_, X_cols).sort_values()
coef2.plot(kind='bar', title=title,figsize=(15,5))
plt.savefig(title.replace(' ','_'),bbox_inches="tight")
plt.show()
# Out:
# Model Report
# RMSE : 2.818
# CV Score : Mean  3.085 | Std  0.3041 | Min  2.538 | Max  3.513

# %%
title = 'Baseball Astros: Lasso Model Coefficients'
modelfit(alg3,X,y)
coef3 = pd.Series(alg3.coef_, X_cols).sort_values()
coef3.plot(kind='bar', title=title,figsize=(15,5))
plt.savefig(title.replace(' ','_'),bbox_inches="tight")
plt.show()
# Out:
# Model Report
# RMSE : 3.231
# CV Score : Mean  3.249 | Std  0.3112 | Min  2.772 | Max  3.79
