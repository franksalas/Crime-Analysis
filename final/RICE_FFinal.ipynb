# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd
from collections import Counter
from sklearn import preprocessing
import scipy
import statsmodels.api as sm
from statsmodels.formula.api import ols
sns.set_context("talk")
# Out:
# /home/frank/miniconda3/envs/springboard/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
ls data
# Out:
# crime_astros_finalA.csv*   crime_rockets_finalB.csv*  crime_texans_final.csv*
# crime_astros_finalB.csv*   crime_rockets_final.csv*   crime_uh_finalA.csv*
# crime_astros_final.csv*    crime_ru_finalB.csv*       crime_uh_finalB.csv*
# crime_dynamo_finalA.csv*   crime_ru_final.csv*        crime_uh_final.csv*
# crime_dynamo_finalB.csv*   crime_ru_final.csvA.csv*   Position_Salaries.csv*
# crime_dynamo_final.csv*    crime_texans_finalA.csv*
# crime_rockets_finalA.csv*  crime_texans_finalB.csv*

# %%
path = 'data/crime_ru_finalB.csv'
team = 'Rice Football '
df = pd.read_csv(path)
#df.drop(['date','dist_stadium_meadian','premise_mode'],axis=1,inplace=True)
df.drop(['date'],axis=1,inplace=True)

nogame = df.game =='No Game'
df = df[~nogame]


#df.drop(['month','offense_mode'],axis=1,inplace=True) # 694
#df.drop(['month','offense_mode','premise_mode'],axis=1,inplace=True) # 313
#df.drop(['month','offense_mode','season'],axis=1,inplace=True) # 672
#df.drop(['offense_mode','season',],axis=1,inplace=True) # 788
#df.drop(['offense_mode','dist_stadium_meadian'],axis=1,inplace=True) # 704
#df.drop(['weekday','dist_stadium_meadian'],axis=1,inplace=True) # 75
#df.drop(['weekday','dist_stadium_meadian','premise_mode'],axis=1,inplace=True) # 323
#df.drop(['offense_mode','dist_stadium_meadian','premise_mode'],axis=1,inplace=True) # 319
#df.drop(['offense_mode','premise_mode','season','dist_stadium_meadian'],axis=1,inplace=True) # 319
#df.drop(['offense_mode','season','premise_mode'],axis=1,inplace=True) # 347
#df.drop(['premise_mode','offense_mode'],axis=1,inplace=True) # 347
#df.drop(['weekday','dist_stadium_meadian','premise_mode'],axis=1,inplace=True) #  32

# %%
### get dummies
dfd = pd.get_dummies(df,drop_first=True)
dfd.columns = [c.replace("'", '') for c in dfd.columns]
dfd.columns = [c.replace(".", '') for c in dfd.columns]
dfd.columns = [c.replace("&", 'n') for c in dfd.columns]
dfd.columns = [c.replace(' ', '_') for c in dfd.columns]
dfd.head()
# Out:
#      crime_total  year  dist_stadium_meadian  hour_mode  weekday_Saturday  \
# 221            1  2010              0.344389          0                 1
# 234            1  2010              0.827295          8                 1
# 241            1  2010              0.534264         15                 1
# 248            2  2010              0.483141          6                 1
# 261            1  2010              0.794013         19                 1
#
#      weekday_Thursday  month_Dec  month_Nov  month_Oct  month_Sep  \
# 221                 0          0          0          0          1
# 234                 0          0          0          0          1
# 241                 0          0          0          0          1
# 248                 0          0          0          1          0
# 261                 0          0          0          1          0
#
#          ...        premise_mode_prk  premise_mode_rest_prk  \
# 221      ...                       0                      0
# 234      ...                       0                      0
# 241      ...                       0                      1
# 248      ...                       0                      0
# 261      ...                       0                      0
#
#      premise_mode_store  premise_mode_store_prk  premise_mode_street  \
# 221                   0                       0                    0
# 234                   0                       0                    0
# 241                   0                       0                    0
# 248                   1                       0                    0
# 261                   0                       0                    1
#
#      premise_mode_unk  offense_mode_Auto_Theft  offense_mode_Burglary  \
# 221                 0                        1                      0
# 234                 0                        0                      0
# 241                 0                        0                      0
# 248                 0                        1                      0
# 261                 0                        0                      0
#
#      offense_mode_Theft  game_Won_Game
# 221                   0              0
# 234                   1              0
# 241                   1              0
# 248                   0              0
# 261                   1              1
#
# [5 rows x 38 columns]

# %%
X = dfd.drop(['crime_total'],axis=1)  # predictors

#X = dfd[['dist_stadium_meadian']]
cols = X.columns
formula = '+'.join(list(cols))

y = dfd.crime_total

form = 'crime_total ~'+ formula
#form = 'crime_total ~ hour_mode + year'
m = ols(form,dfd).fit()
print(m.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            crime_total   R-squared:                       0.843
# Model:                            OLS   Adj. R-squared:                  0.177
# Method:                 Least Squares   F-statistic:                     1.266
# Date:                Wed, 25 Jul 2018   Prob (F-statistic):              0.385
# Time:                        23:12:34   Log-Likelihood:                -31.702
# No. Observations:                  43   AIC:                             133.4
# Df Residuals:                       8   BIC:                             195.0
# Df Model:                          34
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   -281.8730    275.654     -1.023      0.336    -917.531     353.785
# year                           0.1780      0.171      1.038      0.330      -0.217       0.573
# dist_stadium_meadian          -6.3895      2.930     -2.180      0.061     -13.147       0.368
# hour_mode                     -0.0954      0.092     -1.038      0.330      -0.307       0.117
# weekday_Saturday              -1.1659      1.595     -0.731      0.486      -4.845       2.513
# weekday_Thursday             -35.5730     34.354     -1.035      0.331    -114.792      43.646
# month_Dec                    -36.1931     34.713     -1.043      0.328    -116.242      43.856
# month_Nov                    -71.5897     69.025     -1.037      0.330    -230.762      87.582
# month_Oct                    -70.5400     68.911     -1.024      0.336    -229.449      88.369
# month_Sep                    -67.9773     68.696     -0.990      0.351    -226.391      90.437
# season_Summer                -35.5730     34.354     -1.035      0.331    -114.792      43.646
# season_Winter                -36.1931     34.713     -1.043      0.328    -116.242      43.856
# part_day_mode_Evening         -1.2089      1.107     -1.092      0.307      -3.762       1.344
# part_day_mode_Morning         -1.1523      1.237     -0.932      0.379      -4.005       1.700
# part_day_mode_Night           -2.3182      2.023     -1.146      0.285      -6.983       2.347
# premise_mode_apartment         0.9866      1.832      0.538      0.605      -3.238       5.212
# premise_mode_apartment_prk     0.7186      2.594      0.277      0.789      -5.264       6.701
# premise_mode_auto_repair      -2.7757      3.002     -0.924      0.382      -9.699       4.148
# premise_mode_bar_nc            0.3669      2.123      0.173      0.867      -4.529       5.263
# premise_mode_bus_rail         -1.7065      2.324     -0.734      0.484      -7.067       3.654
# premise_mode_college           2.0875      2.750      0.759      0.470      -4.254       8.429
# premise_mode_comm_prk         -1.3990      2.156     -0.649      0.535      -6.371       3.573
# premise_mode_driveway         -3.9707      2.989     -1.329      0.221     -10.863       2.922
# premise_mode_hospital         -0.8587      1.695     -0.507      0.626      -4.768       3.050
# premise_mode_hotel             1.3027      2.529      0.515      0.620      -4.529       7.134
# premise_mode_hotel_prk        -0.2485      2.303     -0.108      0.917      -5.559       5.062
# premise_mode_house             0.1814      2.091      0.087      0.933      -4.639       5.002
# premise_mode_parks             0.7465      1.759      0.424      0.682      -3.309       4.802
# premise_mode_prk              -3.2990      2.868     -1.150      0.283      -9.912       3.314
# premise_mode_rest_prk         -3.3019      2.223     -1.485      0.176      -8.428       1.824
# premise_mode_store             0.4756      1.737      0.274      0.791      -3.529       4.480
# premise_mode_store_prk        -5.6988      3.153     -1.807      0.108     -12.970       1.572
# premise_mode_street           -1.4983      1.845     -0.812      0.440      -5.754       2.757
# premise_mode_unk              -1.6595      2.198     -0.755      0.472      -6.729       3.410
# offense_mode_Auto_Theft        2.7847      2.244      1.241      0.250      -2.391       7.960
# offense_mode_Burglary          3.7797      3.024      1.250      0.247      -3.194      10.753
# offense_mode_Theft             2.4424      2.612      0.935      0.377      -3.580       8.465
# game_Won_Game                  3.0479      1.176      2.592      0.032       0.336       5.760
# ==============================================================================
# Omnibus:                        2.908   Durbin-Watson:                   2.121
# Prob(Omnibus):                  0.234   Jarque-Bera (JB):                2.185
# Skew:                           0.049   Prob(JB):                        0.335
# Kurtosis:                       4.100   Cond. No.                     1.00e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.74e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
df.head()
# Out:
#      crime_total   weekday month  year  dist_stadium_meadian  season  \
# 221            1  Saturday   Sep  2010              0.344389  Autumn
# 234            1  Saturday   Sep  2010              0.827295  Autumn
# 241            1  Saturday   Sep  2010              0.534264  Autumn
# 248            2  Saturday   Oct  2010              0.483141  Autumn
# 261            1  Saturday   Oct  2010              0.794013  Autumn
#
#     part_day_mode  hour_mode premise_mode offense_mode       game
# 221         Night          0     driveway   Auto Theft  Lost Game
# 234       Morning          8     hospital        Theft  Lost Game
# 241     Afternoon         15     rest prk        Theft  Lost Game
# 248       Evening          6        store   Auto Theft  Lost Game
# 261       Evening         19       street        Theft   Won Game

# %% [markdown]
# ## EDA & Summary Statistics

# %%
fig,ax = plt.subplots(figsize=(10,5))

sns.distplot(m.fittedvalues)
plt.show()
# Out:
# /home/frank/miniconda3/envs/springboard/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6448: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
fig,ax = plt.subplots(figsize=(10,5))

sns.distplot(dfd['crime_total'])
plt.show()
# Out:
# /home/frank/miniconda3/envs/springboard/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6448: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
title = 'Sum Crimes  by weekday: {}'.format(team)
fig,ax = plt.subplots(figsize=(15,5))

sns.boxplot(x="weekday", y="crime_total", hue="game", data=df, palette="PRGn")
sns.despine(offset=10, trim=True)
plt.title(title)
plt.savefig(title.replace(' ','_'))

# %%
title = 'Sum Crimes  by Month: {}'.format(team)
fig,ax = plt.subplots(figsize=(15,5))

sns.boxplot(x="month", y="crime_total", hue="game", data=df, palette="PRGn")
sns.despine(offset=10, trim=True)
plt.title(title)
plt.savefig(title.replace(' ','_'))
plt.show()

# %%
title = 'Sum Crimes  by year: {}'.format(team)
fig,ax = plt.subplots(figsize=(15,5))

sns.boxplot(x="year", y="crime_total", hue="game", data=df, palette="PRGn")
sns.despine(offset=10, trim=True)
plt.title(title)
plt.savefig(title.replace(' ','_'))
plt.show()

# %%
title = 'crimes distance by weekday: {}'.format(team)
fig,ax = plt.subplots(figsize=(15,5))

sns.boxplot(x="weekday", y="dist_stadium_meadian", hue="game", data=df, palette="PRGn")
sns.despine(offset=10, trim=True)
plt.title(title)
plt.savefig(title.replace(' ','_'))
plt.show()

# %%
title = 'Sum Crimes  by Season: {}'.format(team)
fig,ax = plt.subplots(figsize=(15,5))

sns.boxplot(x="season", y="crime_total", hue="game", data=df, palette="PRGn")
sns.despine(offset=10, trim=True)

plt.title(title)
plt.savefig(title.replace(' ','_'))
plt.show()

# %% [markdown]
# ## Relationships

# %% [markdown]
# ## linear regression

# %%
### get dummies

dfd = pd.get_dummies(df,drop_first=True)
dfd.columns = [c.replace(' ', '_') for c in dfd.columns]
dfd.head()
# Out:
#      crime_total  year  dist_stadium_meadian  hour_mode  weekday_Saturday  \
# 221            1  2010              0.344389          0                 1
# 234            1  2010              0.827295          8                 1
# 241            1  2010              0.534264         15                 1
# 248            2  2010              0.483141          6                 1
# 261            1  2010              0.794013         19                 1
#
#      weekday_Thursday  month_Dec  month_Nov  month_Oct  month_Sep  \
# 221                 0          0          0          0          1
# 234                 0          0          0          0          1
# 241                 0          0          0          0          1
# 248                 0          0          0          1          0
# 261                 0          0          0          1          0
#
#          ...        premise_mode_prk  premise_mode_rest_prk  \
# 221      ...                       0                      0
# 234      ...                       0                      0
# 241      ...                       0                      1
# 248      ...                       0                      0
# 261      ...                       0                      0
#
#      premise_mode_store  premise_mode_store_prk  premise_mode_street  \
# 221                   0                       0                    0
# 234                   0                       0                    0
# 241                   0                       0                    0
# 248                   1                       0                    0
# 261                   0                       0                    1
#
#      premise_mode_unk  offense_mode_Auto_Theft  offense_mode_Burglary  \
# 221                 0                        1                      0
# 234                 0                        0                      0
# 241                 0                        0                      0
# 248                 0                        1                      0
# 261                 0                        0                      0
#
#      offense_mode_Theft  game_Won_Game
# 221                   0              0
# 234                   1              0
# 241                   1              0
# 248                   0              0
# 261                   1              1
#
# [5 rows x 38 columns]

# %%
X = dfd.drop(['crime_total'],axis=1)  # predictors

#X = dfd[['dist_stadium_meadian']]
cols = X.columns
formula = '+'.join(list(cols))

y = dfd.crime_total





form = 'crime_total ~'+ formula

m = ols(form,dfd).fit()
print(m.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            crime_total   R-squared:                       0.843
# Model:                            OLS   Adj. R-squared:                  0.177
# Method:                 Least Squares   F-statistic:                     1.266
# Date:                Wed, 25 Jul 2018   Prob (F-statistic):              0.385
# Time:                        23:12:36   Log-Likelihood:                -31.702
# No. Observations:                  43   AIC:                             133.4
# Df Residuals:                       8   BIC:                             195.0
# Df Model:                          34
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   -281.8730    275.654     -1.023      0.336    -917.531     353.785
# year                           0.1780      0.171      1.038      0.330      -0.217       0.573
# dist_stadium_meadian          -6.3895      2.930     -2.180      0.061     -13.147       0.368
# hour_mode                     -0.0954      0.092     -1.038      0.330      -0.307       0.117
# weekday_Saturday              -1.1659      1.595     -0.731      0.486      -4.845       2.513
# weekday_Thursday             -35.5730     34.354     -1.035      0.331    -114.792      43.646
# month_Dec                    -36.1931     34.713     -1.043      0.328    -116.242      43.856
# month_Nov                    -71.5897     69.025     -1.037      0.330    -230.762      87.582
# month_Oct                    -70.5400     68.911     -1.024      0.336    -229.449      88.369
# month_Sep                    -67.9773     68.696     -0.990      0.351    -226.391      90.437
# season_Summer                -35.5730     34.354     -1.035      0.331    -114.792      43.646
# season_Winter                -36.1931     34.713     -1.043      0.328    -116.242      43.856
# part_day_mode_Evening         -1.2089      1.107     -1.092      0.307      -3.762       1.344
# part_day_mode_Morning         -1.1523      1.237     -0.932      0.379      -4.005       1.700
# part_day_mode_Night           -2.3182      2.023     -1.146      0.285      -6.983       2.347
# premise_mode_apartment         0.9866      1.832      0.538      0.605      -3.238       5.212
# premise_mode_apartment_prk     0.7186      2.594      0.277      0.789      -5.264       6.701
# premise_mode_auto_repair      -2.7757      3.002     -0.924      0.382      -9.699       4.148
# premise_mode_bar_nc            0.3669      2.123      0.173      0.867      -4.529       5.263
# premise_mode_bus_rail         -1.7065      2.324     -0.734      0.484      -7.067       3.654
# premise_mode_college           2.0875      2.750      0.759      0.470      -4.254       8.429
# premise_mode_comm_prk         -1.3990      2.156     -0.649      0.535      -6.371       3.573
# premise_mode_driveway         -3.9707      2.989     -1.329      0.221     -10.863       2.922
# premise_mode_hospital         -0.8587      1.695     -0.507      0.626      -4.768       3.050
# premise_mode_hotel             1.3027      2.529      0.515      0.620      -4.529       7.134
# premise_mode_hotel_prk        -0.2485      2.303     -0.108      0.917      -5.559       5.062
# premise_mode_house             0.1814      2.091      0.087      0.933      -4.639       5.002
# premise_mode_parks             0.7465      1.759      0.424      0.682      -3.309       4.802
# premise_mode_prk              -3.2990      2.868     -1.150      0.283      -9.912       3.314
# premise_mode_rest_prk         -3.3019      2.223     -1.485      0.176      -8.428       1.824
# premise_mode_store             0.4756      1.737      0.274      0.791      -3.529       4.480
# premise_mode_store_prk        -5.6988      3.153     -1.807      0.108     -12.970       1.572
# premise_mode_street           -1.4983      1.845     -0.812      0.440      -5.754       2.757
# premise_mode_unk              -1.6595      2.198     -0.755      0.472      -6.729       3.410
# offense_mode_Auto_Theft        2.7847      2.244      1.241      0.250      -2.391       7.960
# offense_mode_Burglary          3.7797      3.024      1.250      0.247      -3.194      10.753
# offense_mode_Theft             2.4424      2.612      0.935      0.377      -3.580       8.465
# game_Won_Game                  3.0479      1.176      2.592      0.032       0.336       5.760
# ==============================================================================
# Omnibus:                        2.908   Durbin-Watson:                   2.121
# Prob(Omnibus):                  0.234   Jarque-Bera (JB):                2.185
# Skew:                           0.049   Prob(JB):                        0.335
# Kurtosis:                       4.100   Cond. No.                     1.00e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.74e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
from sklearn import cross_validation, metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression, Ridge, Lasso
# Out:
# /home/frank/miniconda3/envs/springboard/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
alg1 = LinearRegression(normalize=True)
alg2 = Ridge(alpha=0.1,normalize=True)
alg3 = Lasso(alpha=0.1,normalize=True)

# %%
def modelfit(alg, X,y):
    '''
    target = y
    predictors = X
    '''
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=42)
    #Fit the algorithm on the data
    alg.fit(X_train,y_train)
    #Predict training set:
    train_predictions = alg.predict(X_train)
    #Perform cross-validation:
    cv_score = cross_val_score(alg, X, y, cv=10, scoring='neg_mean_squared_error')
    cv_score = np.sqrt(np.abs(cv_score))
    
    #Print model report:
    print ("\nModel Report")
    print( "RMSE : %.4g" % np.sqrt(metrics.mean_squared_error(y_train, train_predictions)))
    print ("CV Score : Mean  %.4g | Std  %.4g | Min  %.4g | Max  %.4g" % (np.mean(cv_score),np.std(cv_score),np.min(cv_score),np.max(cv_score))
)

# %%
X_cols = list(X.columns)

# %%
title = 'Rice Football: Linear Model Coefficients'
modelfit(alg1,X,y)
coef1 = pd.Series(alg1.coef_, X_cols).sort_values()
coef1.plot(kind='bar', title=title,figsize=(15,5))
plt.savefig(title.replace(' ','_'),bbox_inches="tight")
plt.show()
# Out:
# Model Report
# RMSE : 0.0716
# CV Score : Mean  2.004e+14 | Std  4.137e+14 | Min  1.32 | Max  1.32e+15

# %%
title = 'Rice Football: Ridge Model Coefficients'

modelfit(alg2,X,y)
coef2 = pd.Series(alg2.coef_, X_cols).sort_values()
coef2.plot(kind='bar', title=title,figsize=(15,5))
plt.savefig(title.replace(' ','_'),bbox_inches="tight")
plt.show()
# Out:
# Model Report
# RMSE : 0.6496
# CV Score : Mean  1.595 | Std  0.7066 | Min  0.2395 | Max  2.417

# %%
title = 'Rice Football: Lasso Model Coefficients'
modelfit(alg3,X,y)
coef3 = pd.Series(alg3.coef_, X_cols).sort_values()
coef3.plot(kind='bar', title=title,figsize=(15,5))
plt.savefig(title.replace(' ','_'),bbox_inches="tight")
plt.show()
# Out:
# Model Report
# RMSE : 1.357
# CV Score : Mean  1.283 | Std  0.4084 | Min  0.7061 | Max  2.274
