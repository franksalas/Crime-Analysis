# %% [markdown]
# ## Source
#
# ####  baseball-reference.com
#
# https://www.baseball-reference.com/teams/HOU/2018-schedule-scores.shtml
#
# - saved regular seasons from 2008 - 2017 to csv

# %%
import pandas as pd
import numpy as np
import glob, os

import warnings
warnings.filterwarnings('ignore')

# %%
ls data/MLB/plo
# Out:
# mlb_h_15_plo.csv*  mlb_h_17_plo.csv*

# %%
path = 'data/MLB/plo'

# %%
all_files = glob.glob(os.path.join(path, "*.csv")) 

df_from_each_file = (pd.read_csv(f) for f in all_files)
df   = pd.concat(df_from_each_file, ignore_index=True)

# %%
df.head()
# Out:
#    Unnamed: 7  Unnamed: 8  Unnamed: 9                       date  \
# 0         NaN         NaN         NaN   Tuesday, October 6, 2015
# 1         NaN         NaN         NaN  Thursday, October 8, 2015
# 2         NaN         NaN         NaN    Friday, October 9, 2015
# 3         NaN         NaN         NaN   Sunday, October 11, 2015
# 4         NaN         NaN         NaN   Monday, October 12, 2015
#
#              location  score_1  score_2       team_1       team_2   time
# 0  Yankee Stadium III        3        0      Houston     New York   8:10
# 1    Kauffman Stadium        5        2      Houston  Kansas City   6:37
# 2    Kauffman Stadium        4        5      Houston  Kansas City   2:47
# 3    Minute Maid Park        2        4  Kansas City      Houston   3:10
# 4    Minute Maid Park        9        6  Kansas City      Houston  12:07

# %% [markdown]
# ## slice neede cols

# %%
mlb = df[['date','time','location','team_1','score_1','team_2','score_2']]
mlb.head()
# Out:
#                         date   time            location       team_1  score_1  \
# 0   Tuesday, October 6, 2015   8:10  Yankee Stadium III      Houston        3
# 1  Thursday, October 8, 2015   6:37    Kauffman Stadium      Houston        5
# 2    Friday, October 9, 2015   2:47    Kauffman Stadium      Houston        4
# 3   Sunday, October 11, 2015   3:10    Minute Maid Park  Kansas City        2
# 4   Monday, October 12, 2015  12:07    Minute Maid Park  Kansas City        9
#
#         team_2  score_2
# 0     New York        0
# 1  Kansas City        2
# 2  Kansas City        5
# 3      Houston        4
# 4      Houston        6

# %% [markdown]
# ## Convert date to datetime

# %%
mlb['date'] = pd.to_datetime(mlb['date'])

mlb = mlb.set_index('date').sort_index(ascending=True)

# %%
mlb.head()
# Out:
#              time            location       team_1  score_1       team_2  \
# date
# 2015-10-06   8:10  Yankee Stadium III      Houston        3     New York
# 2015-10-08   6:37    Kauffman Stadium      Houston        5  Kansas City
# 2015-10-09   2:47    Kauffman Stadium      Houston        4  Kansas City
# 2015-10-11   3:10    Minute Maid Park  Kansas City        2      Houston
# 2015-10-12  12:07    Minute Maid Park  Kansas City        9      Houston
#
#             score_2
# date
# 2015-10-06        0
# 2015-10-08        2
# 2015-10-09        5
# 2015-10-11        4
# 2015-10-12        6

# %%
mlb.location.value_counts()
# Out:
# Minute Maid Park      10
# Yankee Stadium III     4
# Dodger Stadium         4
# Kauffman Stadium       3
# Fenway Park            2
#  Minute Maid Park      1
# Name: location, dtype: int64

# %%
mlb['location'] = mlb.location.str.strip()

# %%
mlb.location.value_counts()
# Out:
# Minute Maid Park      11
# Yankee Stadium III     4
# Dodger Stadium         4
# Kauffman Stadium       3
# Fenway Park            2
# Name: location, dtype: int64

# %%
mlb[mlb.team_1 == 'Houston']
# Out:
#             time            location   team_1  score_1       team_2  score_2
# date
# 2015-10-06  8:10  Yankee Stadium III  Houston        3     New York        0
# 2015-10-08  6:37    Kauffman Stadium  Houston        5  Kansas City        2
# 2015-10-09  2:47    Kauffman Stadium  Houston        4  Kansas City        5
# 2015-10-14  7:08    Kauffman Stadium  Houston        2  Kansas City        7
# 2017-10-08  2:30         Fenway Park  Houston        3       Boston       10
# 2017-10-16  8:00  Yankee Stadium III  Houston        1     New York        8
# 2017-10-17  5:00  Yankee Stadium III  Houston        4     New York        6
# 2017-10-18  5:00  Yankee Stadium III  Houston        0     New York        5
# 2017-10-24  8:00      Dodger Stadium  Houston        1  Los Angeles        3
# 2017-10-25  8:00      Dodger Stadium  Houston        7  Los Angeles        6
# 2017-10-31  8:00      Dodger Stadium  Houston        1  Los Angeles        3
# 2017-11-01  8:00      Dodger Stadium  Houston        5  Los Angeles        1

# %%
mlb[mlb.team_2 == 'Houston']
# Out:
#              time          location       team_1  score_1   team_2  score_2
# date
# 2015-10-11   3:10  Minute Maid Park  Kansas City        2  Houston        4
# 2015-10-12  12:07  Minute Maid Park  Kansas City        9  Houston        6
# 2017-10-05    4pm  Minute Maid Park       Boston        2  Houston        8
# 2017-10-06    2pm  Minute Maid Park       Boston        2  Houston        8
# 2017-10-13  8:00   Minute Maid Park     New York        1  Houston        2
# 2017-10-14   4:00  Minute Maid Park     New York        1  Houston        2
# 2017-10-20   8:00  Minute Maid Park     New York        1  Houston        7
# 2017-10-21   8:00  Minute Maid Park     New York        0  Houston        4
# 2017-10-27   8:00  Minute Maid Park  Los Angeles        3  Houston        5
# 2017-10-28   8:00  Minute Maid Park  Los Angeles        6  Houston        2
# 2017-10-29   8:00  Minute Maid Park  Los Angeles       12  Houston       13

# %% [markdown]
# ## Crete new col for home_away

# %%
mlb['home_away'] = np.where(mlb.location == 'Minute Maid Park' , 'HOME', 'AWAY')

# %%
mlb.head()
# Out:
#              time            location       team_1  score_1       team_2  \
# date
# 2015-10-06   8:10  Yankee Stadium III      Houston        3     New York
# 2015-10-08   6:37    Kauffman Stadium      Houston        5  Kansas City
# 2015-10-09   2:47    Kauffman Stadium      Houston        4  Kansas City
# 2015-10-11   3:10    Minute Maid Park  Kansas City        2      Houston
# 2015-10-12  12:07    Minute Maid Park  Kansas City        9      Houston
#
#             score_2 home_away
# date
# 2015-10-06        0      AWAY
# 2015-10-08        2      AWAY
# 2015-10-09        5      AWAY
# 2015-10-11        4      HOME
# 2015-10-12        6      HOME

# %% [markdown]
# ## Create column for seaason

# %%
mlb['season'] = 'plo'
mlb.head()
# Out:
#              time            location       team_1  score_1       team_2  \
# date
# 2015-10-06   8:10  Yankee Stadium III      Houston        3     New York
# 2015-10-08   6:37    Kauffman Stadium      Houston        5  Kansas City
# 2015-10-09   2:47    Kauffman Stadium      Houston        4  Kansas City
# 2015-10-11   3:10    Minute Maid Park  Kansas City        2      Houston
# 2015-10-12  12:07    Minute Maid Park  Kansas City        9      Houston
#
#             score_2 home_away season
# date
# 2015-10-06        0      AWAY    plo
# 2015-10-08        2      AWAY    plo
# 2015-10-09        5      AWAY    plo
# 2015-10-11        4      HOME    plo
# 2015-10-12        6      HOME    plo

# %% [markdown]
# ## Select columns

# %%
mlb.head()
# Out:
#              time            location       team_1  score_1       team_2  \
# date
# 2015-10-06   8:10  Yankee Stadium III      Houston        3     New York
# 2015-10-08   6:37    Kauffman Stadium      Houston        5  Kansas City
# 2015-10-09   2:47    Kauffman Stadium      Houston        4  Kansas City
# 2015-10-11   3:10    Minute Maid Park  Kansas City        2      Houston
# 2015-10-12  12:07    Minute Maid Park  Kansas City        9      Houston
#
#             score_2 home_away season
# date
# 2015-10-06        0      AWAY    plo
# 2015-10-08        2      AWAY    plo
# 2015-10-09        5      AWAY    plo
# 2015-10-11        4      HOME    plo
# 2015-10-12        6      HOME    plo

# %%
mlb = mlb[['team_2','score_2','home_away','team_1','score_1','season']]

# %%
mlb.rename(columns = {'team_2':'team','score_2':'team_score','team_1':'opposing','score_1':'opp_score'}, inplace=True)

# %% [markdown]
# ## select only home games

# %%
hou = mlb.team == 'Houston'
home = mlb.home_away =='HOME'

# %%
mlb[hou]
# Out:
#                team  team_score home_away     opposing  opp_score season
# date
# 2015-10-11  Houston           4      HOME  Kansas City          2    plo
# 2015-10-12  Houston           6      HOME  Kansas City          9    plo
# 2017-10-05  Houston           8      HOME       Boston          2    plo
# 2017-10-06  Houston           8      HOME       Boston          2    plo
# 2017-10-13  Houston           2      HOME     New York          1    plo
# 2017-10-14  Houston           2      HOME     New York          1    plo
# 2017-10-20  Houston           7      HOME     New York          1    plo
# 2017-10-21  Houston           4      HOME     New York          0    plo
# 2017-10-27  Houston           5      HOME  Los Angeles          3    plo
# 2017-10-28  Houston           2      HOME  Los Angeles          6    plo
# 2017-10-29  Houston          13      HOME  Los Angeles         12    plo

# %%
mlb = mlb[home]

# %% [markdown]
# ## change team name to HOU

# %%
mlb.team = 'HOU'

# %%
mlb
# Out:
#            team  team_score home_away     opposing  opp_score season
# date
# 2015-10-11  HOU           4      HOME  Kansas City          2    plo
# 2015-10-12  HOU           6      HOME  Kansas City          9    plo
# 2017-10-05  HOU           8      HOME       Boston          2    plo
# 2017-10-06  HOU           8      HOME       Boston          2    plo
# 2017-10-13  HOU           2      HOME     New York          1    plo
# 2017-10-14  HOU           2      HOME     New York          1    plo
# 2017-10-20  HOU           7      HOME     New York          1    plo
# 2017-10-21  HOU           4      HOME     New York          0    plo
# 2017-10-27  HOU           5      HOME  Los Angeles          3    plo
# 2017-10-28  HOU           2      HOME  Los Angeles          6    plo
# 2017-10-29  HOU          13      HOME  Los Angeles         12    plo

# %%
mlb.to_csv('data/clean/astros_clean_plo.csv')

# %% [markdown]
# ## Merge reg season and plo

# %%
path = 'data/clean/astros_clean_reg.csv'

# %%
reg = pd.read_csv(path,index_col='date')

# %%
reg.head()
# Out:
#            team  team_score home_away opposing  opp_score win_lost season
# date
# 2010-04-05  HOU           2      HOME      SFG          5        L    reg
# 2010-04-06  HOU           0      HOME      SFG          3        L    reg
# 2010-04-07  HOU           4      HOME      SFG         10        L    reg
# 2010-04-09  HOU           0      HOME      PHI          8        L    reg
# 2010-04-10  HOU           6      HOME      PHI          9        L    reg

# %%
mlb.head()
# Out:
#            team  team_score home_away     opposing  opp_score season
# date
# 2015-10-11  HOU           4      HOME  Kansas City          2    plo
# 2015-10-12  HOU           6      HOME  Kansas City          9    plo
# 2017-10-05  HOU           8      HOME       Boston          2    plo
# 2017-10-06  HOU           8      HOME       Boston          2    plo
# 2017-10-13  HOU           2      HOME     New York          1    plo

# %%
frames = [reg,mlb]
astros = pd.concat(frames)

# %%
astros
# Out:
#                     home_away  opp_score     opposing season team  team_score  \
# date
# 2010-04-05               HOME          5          SFG    reg  HOU           2
# 2010-04-06               HOME          3          SFG    reg  HOU           0
# 2010-04-07               HOME         10          SFG    reg  HOU           4
# 2010-04-09               HOME          8          PHI    reg  HOU           0
# 2010-04-10               HOME          9          PHI    reg  HOU           6
# 2010-04-11               HOME          2          PHI    reg  HOU           1
# 2010-04-20               HOME          5          FLA    reg  HOU           7
# 2010-04-21               HOME          4          FLA    reg  HOU           5
# 2010-04-22               HOME          5          FLA    reg  HOU           1
# 2010-04-23               HOME          3          PIT    reg  HOU           4
# 2010-04-24               HOME          2          PIT    reg  HOU           5
# 2010-04-25               HOME          3          PIT    reg  HOU          10
# 2010-04-27               HOME          6          CIN    reg  HOU           2
# 2010-04-28               HOME          6          CIN    reg  HOU           4
# 2010-04-29               HOME          4          CIN    reg  HOU           2
# 2010-05-03               HOME          9          ARI    reg  HOU           1
# 2010-05-04               HOME          1          ARI    reg  HOU           0
# 2010-05-05               HOME          2          ARI    reg  HOU           4
# 2010-05-06               HOME          6          ARI    reg  HOU           3
# 2010-05-07               HOME          7          SDP    reg  HOU           0
# 2010-05-08               HOME          2          SDP    reg  HOU           1
# 2010-05-09               HOME          3          SDP    reg  HOU           4
# 2010-05-19               HOME          3          COL    reg  HOU           7
# 2010-05-20               HOME          4          COL    reg  HOU           0
# 2010-05-21               HOME          1          TBR    reg  HOU           2
# 2010-05-22               HOME          4          TBR    reg  HOU           2
# 2010-05-23               HOME         10          TBR    reg  HOU           6
# 2010-05-31               HOME         14          WSN    reg  HOU           4
# 2010-06-01               HOME          7          WSN    reg  HOU           8
# 2010-06-02               HOME          1          WSN    reg  HOU           5
# ...                       ...        ...          ...    ...  ...         ...
# 2017-08-20               HOME          3          OAK    reg  HOU           2
# 2017-08-22               HOME          4          WSN    reg  HOU           3
# 2017-08-23               HOME          1          WSN    reg  HOU           6
# 2017-08-24               HOME          5          WSN    reg  HOU           4
# 2017-08-29               HOME         12          TEX    reg  HOU           2
# 2017-08-30               HOME          8          TEX    reg  HOU           1
# 2017-08-31               HOME          1          TEX    reg  HOU           5
# 2017-09-02               HOME          8          NYM    reg  HOU          12
# 2017-09-02               HOME          1          NYM    reg  HOU           4
# 2017-09-03               HOME          6          NYM    reg  HOU           8
# 2017-09-15               HOME          2          SEA    reg  HOU           5
# 2017-09-16               HOME          6          SEA    reg  HOU           8
# 2017-09-17               HOME          1          SEA    reg  HOU           7
# 2017-09-19               HOME          1          CHW    reg  HOU           3
# 2017-09-20               HOME          3          CHW    reg  HOU           4
# 2017-09-21               HOME          3          CHW    reg  HOU           1
# 2017-09-22               HOME          0          LAA    reg  HOU           3
# 2017-09-23               HOME          2          LAA    reg  HOU           6
# 2017-09-24               HOME          7          LAA    reg  HOU           5
# 2015-10-11 00:00:00      HOME          2  Kansas City    plo  HOU           4
# 2015-10-12 00:00:00      HOME          9  Kansas City    plo  HOU           6
# 2017-10-05 00:00:00      HOME          2       Boston    plo  HOU           8
# 2017-10-06 00:00:00      HOME          2       Boston    plo  HOU           8
# 2017-10-13 00:00:00      HOME          1     New York    plo  HOU           2
# 2017-10-14 00:00:00      HOME          1     New York    plo  HOU           2
# 2017-10-20 00:00:00      HOME          1     New York    plo  HOU           7
# 2017-10-21 00:00:00      HOME          0     New York    plo  HOU           4
# 2017-10-27 00:00:00      HOME          3  Los Angeles    plo  HOU           5
# 2017-10-28 00:00:00      HOME          6  Los Angeles    plo  HOU           2
# 2017-10-29 00:00:00      HOME         12  Los Angeles    plo  HOU          13
#
#                     win_lost
# date
# 2010-04-05                 L
# 2010-04-06                 L
# 2010-04-07                 L
# 2010-04-09                 L
# 2010-04-10                 L
# 2010-04-11                 L
# 2010-04-20                 W
# 2010-04-21                 W
# 2010-04-22                 L
# 2010-04-23                 W
# 2010-04-24                 W
# 2010-04-25                 W
# 2010-04-27                 L
# 2010-04-28                 L
# 2010-04-29                 L
# 2010-05-03                 L
# 2010-05-04                 L
# 2010-05-05                 W
# 2010-05-06                 L
# 2010-05-07                 L
# 2010-05-08                 L
# 2010-05-09                 W
# 2010-05-19                 W
# 2010-05-20                 L
# 2010-05-21                 W
# 2010-05-22                 L
# 2010-05-23                 L
# 2010-05-31                 L
# 2010-06-01                 W
# 2010-06-02                 W
# ...                      ...
# 2017-08-20                 L
# 2017-08-22                 L
# 2017-08-23                 W
# 2017-08-24                 L
# 2017-08-29                 L
# 2017-08-30                 L
# 2017-08-31                 W
# 2017-09-02                 W
# 2017-09-02                 W
# 2017-09-03                 W
# 2017-09-15                 W
# 2017-09-16                 W
# 2017-09-17                 W
# 2017-09-19                 W
# 2017-09-20                 W
# 2017-09-21                 L
# 2017-09-22                 W
# 2017-09-23                 W
# 2017-09-24                 L
# 2015-10-11 00:00:00      NaN
# 2015-10-12 00:00:00      NaN
# 2017-10-05 00:00:00      NaN
# 2017-10-06 00:00:00      NaN
# 2017-10-13 00:00:00      NaN
# 2017-10-14 00:00:00      NaN
# 2017-10-20 00:00:00      NaN
# 2017-10-21 00:00:00      NaN
# 2017-10-27 00:00:00      NaN
# 2017-10-28 00:00:00      NaN
# 2017-10-29 00:00:00      NaN
#
# [659 rows x 7 columns]

# %%
astros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 659 entries, 2010-04-05 to 2017-10-29 00:00:00
# Data columns (total 7 columns):
# home_away     659 non-null object
# opp_score     659 non-null int64
# opposing      659 non-null object
# season        659 non-null object
# team          659 non-null object
# team_score    659 non-null int64
# win_lost      648 non-null object
# dtypes: int64(2), object(5)
# memory usage: 41.2+ KB

# %%
astros.apply(lambda x: sum(x.isnull()))
# Out:
# home_away      0
# opp_score      0
# opposing       0
# season         0
# team           0
# team_score     0
# win_lost      11
# dtype: int64

# %%
astros.to_csv('data/clean/astros_clean.csv')

# %%
ls data/clean
# Out:
# astros_clean.csv*      astros_clean_reg.csv*  UH_clean.csv*
# astros_clean_plo.csv*  Rice_clean.csv*
