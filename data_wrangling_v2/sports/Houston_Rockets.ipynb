# %% [markdown]
# # Source
#
# #### basketball-reference.com
# https://www.basketball-reference.com/teams/HOU/2017_games.html
#
# - saved regular and playoff seasons from 2010 - 2017 to csv

# %%
import pandas as pd
import numpy as np
import glob, os
import warnings
warnings.filterwarnings('ignore')

# %%
path = 'data/NBA/reg'
all_files = glob.glob(os.path.join(path, "*.csv")) 

df_from_each_file = (pd.read_csv(f) for f in all_files)
df_reg   = pd.concat(df_from_each_file, ignore_index=True)

# %%
path = 'data/NBA/plo'
all_files = glob.glob(os.path.join(path, "*.csv")) 

df_from_each_file = (pd.read_csv(f) for f in all_files)
df_plo   = pd.concat(df_from_each_file, ignore_index=True)

# %% [markdown]
# # Regular Season

# %%
df_reg['season'] = 'reg'

# %%
hou_rockets = df_reg[['Date','Unnamed: 2','Unnamed: 5','Opponent','Unnamed: 7','Tm','Opp','season']]

# %% [markdown]
# # Create col with home team name

# %%
hou_rockets['team'] ='Houston Rockets'

# %%
hou_rockets = hou_rockets[['Date','Unnamed: 2', 'team','Tm','Unnamed: 5','Opponent','Opp','Unnamed: 7','season']]

# %% [markdown]
# ## Rename cols

# %%
hou_rockets.rename(columns={
    'Unnamed: 2':'Time',
    'team': 'Team',
    'Tm': 'Team_score',
    'Unnamed: 5': 'Location',
    'Opp': 'Opponent_score',
    'Unnamed: 7': 'Result'
},inplace=True)

# %%
hou_rockets.head()
# Out:
#                 Date      Time             Team  Team_score Location  \
# 0  Tue, Oct 27, 2009  7:00p ET  Houston Rockets          87        @
# 1  Wed, Oct 28, 2009  7:30p ET  Houston Rockets         108        @
# 2  Sat, Oct 31, 2009  7:30p ET  Houston Rockets         111      NaN
# 3   Mon, Nov 2, 2009  7:00p ET  Houston Rockets         113        @
# 4   Wed, Nov 4, 2009  7:30p ET  Houston Rockets         102      NaN
#
#                  Opponent  Opponent_score Result season
# 0  Portland Trail Blazers              96      L    reg
# 1   Golden State Warriors             107      W    reg
# 2  Portland Trail Blazers             107      W    reg
# 3               Utah Jazz              96      W    reg
# 4      Los Angeles Lakers             103      L    reg

# %% [markdown]
# ## Check for missing values

# %%
hou_rockets.apply(lambda x: sum(x.isnull()))
# Out:
# Date                0
# Time                0
# Team                0
# Team_score          0
# Location          320
# Opponent            0
# Opponent_score      0
# Result              0
# season              0
# dtype: int64

# %% [markdown]
# ## Location Column
#
# - change @ to away, nan to home

# %%
hou_rockets.Location.value_counts(dropna=False)
# Out:
# @      320
# NaN    320
# Name: Location, dtype: int64

# %%
hou_rockets['Location'] = np.where(hou_rockets['Location'] =='@', 'away', 'home')

# %%
hou_rockets.Location.value_counts(dropna=False)
# Out:
# away    320
# home    320
# Name: Location, dtype: int64

# %% [markdown]
# ## Date col

# %%
hou_rockets.head()
# Out:
#                 Date      Time             Team  Team_score Location  \
# 0  Tue, Oct 27, 2009  7:00p ET  Houston Rockets          87     away
# 1  Wed, Oct 28, 2009  7:30p ET  Houston Rockets         108     away
# 2  Sat, Oct 31, 2009  7:30p ET  Houston Rockets         111     home
# 3   Mon, Nov 2, 2009  7:00p ET  Houston Rockets         113     away
# 4   Wed, Nov 4, 2009  7:30p ET  Houston Rockets         102     home
#
#                  Opponent  Opponent_score Result season
# 0  Portland Trail Blazers              96      L    reg
# 1   Golden State Warriors             107      W    reg
# 2  Portland Trail Blazers             107      W    reg
# 3               Utah Jazz              96      W    reg
# 4      Los Angeles Lakers             103      L    reg

# %%
hou_rockets['Date'] = pd.to_datetime(hou_rockets['Date'])
hou_rockets = hou_rockets.set_index('Date').sort_index(ascending=True)

# %%
hou_rockets.head()
# Out:
#                 Time             Team  Team_score Location  \
# Date
# 2009-10-27  7:00p ET  Houston Rockets          87     away
# 2009-10-28  7:30p ET  Houston Rockets         108     away
# 2009-10-31  7:30p ET  Houston Rockets         111     home
# 2009-11-02  7:00p ET  Houston Rockets         113     away
# 2009-11-04  7:30p ET  Houston Rockets         102     home
#
#                           Opponent  Opponent_score Result season
# Date
# 2009-10-27  Portland Trail Blazers              96      L    reg
# 2009-10-28   Golden State Warriors             107      W    reg
# 2009-10-31  Portland Trail Blazers             107      W    reg
# 2009-11-02               Utah Jazz              96      W    reg
# 2009-11-04      Los Angeles Lakers             103      L    reg

# %%
hou_rockets.apply(lambda x: sum(x.isnull()))
# Out:
# Time              0
# Team              0
# Team_score        0
# Location          0
# Opponent          0
# Opponent_score    0
# Result            0
# season            0
# dtype: int64

# %% [markdown]
# ## save

# %%
hou_rockets.to_csv('data/clean/hou_rockets_reg.csv')

# %% [markdown]
# ## Playoffs

# %%
df_plo.head()
# Out:
#    G               Date Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0  1  Sun, Apr 21, 2013   9:30p ET         NaN  Box Score          @
# 1  2  Wed, Apr 24, 2013   7:00p ET         NaN  Box Score          @
# 2  3  Sat, Apr 27, 2013   9:30p ET         NaN  Box Score        NaN
# 3  4  Mon, Apr 29, 2013   9:30p ET         NaN  Box Score        NaN
# 4  5   Wed, May 1, 2013   9:30p ET         NaN  Box Score          @
#
#                 Opponent Unnamed: 7 Unnamed: 8   Tm  Opp  W  L Streak  Notes
# 0  Oklahoma City Thunder          L        NaN   91  120  0  1    L 1    NaN
# 1  Oklahoma City Thunder          L        NaN  102  105  0  2    L 2    NaN
# 2  Oklahoma City Thunder          L        NaN  101  104  0  3    L 3    NaN
# 3  Oklahoma City Thunder          W        NaN  105  103  1  3    W 1    NaN
# 4  Oklahoma City Thunder          W        NaN  107  100  2  3    W 2    NaN

# %% [markdown]
# ## Create col for plo

# %%
df_plo['season'] = 'plo'

# %%
hou_rockets_plo = df_plo[['Date','Unnamed: 2','Unnamed: 5','Opponent','Unnamed: 7','Tm','Opp','season']]

# %%
hou_rockets_plo['team'] ='Houston Rockets'

# %%
hou_rockets_plo = hou_rockets_plo[['Date','Unnamed: 2', 'team','Tm','Unnamed: 5','Opponent','Opp','Unnamed: 7','season']]

# %% [markdown]
# ## rename col

# %%
hou_rockets_plo.rename(columns={
    'Unnamed: 2':'Time',
    'team': 'Team',
    'Tm': 'Team_score',
    'Unnamed: 5': 'Location',
    'Opp': 'Opponent_score',
    'Unnamed: 7': 'Result'
},inplace=True)

# %%
hou_rockets_plo.head()
# Out:
#                 Date      Time             Team  Team_score Location  \
# 0  Sun, Apr 21, 2013  9:30p ET  Houston Rockets          91        @
# 1  Wed, Apr 24, 2013  7:00p ET  Houston Rockets         102        @
# 2  Sat, Apr 27, 2013  9:30p ET  Houston Rockets         101      NaN
# 3  Mon, Apr 29, 2013  9:30p ET  Houston Rockets         105      NaN
# 4   Wed, May 1, 2013  9:30p ET  Houston Rockets         107        @
#
#                 Opponent  Opponent_score Result season
# 0  Oklahoma City Thunder             120      L    plo
# 1  Oklahoma City Thunder             105      L    plo
# 2  Oklahoma City Thunder             104      L    plo
# 3  Oklahoma City Thunder             103      W    plo
# 4  Oklahoma City Thunder             100      W    plo

# %% [markdown]
# ## Check missing values

# %%
hou_rockets_plo.apply(lambda x: sum(x.isnull()))
# Out:
# Date               0
# Time               0
# Team               0
# Team_score         0
# Location          23
# Opponent           0
# Opponent_score     0
# Result             0
# season             0
# dtype: int64

# %% [markdown]
# ## Location Column
#
# - change @ to away, nan to home

# %%
hou_rockets_plo.Location.value_counts(dropna=False)
# Out:
# NaN    23
# @      22
# Name: Location, dtype: int64

# %%
hou_rockets_plo['Location'] = np.where(hou_rockets_plo['Location'] =='@', 'away', 'home')

# %%
hou_rockets_plo.Location.value_counts(dropna=False)
# Out:
# home    23
# away    22
# Name: Location, dtype: int64

# %% [markdown]
# ## Date col

# %%
hou_rockets_plo.head()
# Out:
#                 Date      Time             Team  Team_score Location  \
# 0  Sun, Apr 21, 2013  9:30p ET  Houston Rockets          91     away
# 1  Wed, Apr 24, 2013  7:00p ET  Houston Rockets         102     away
# 2  Sat, Apr 27, 2013  9:30p ET  Houston Rockets         101     home
# 3  Mon, Apr 29, 2013  9:30p ET  Houston Rockets         105     home
# 4   Wed, May 1, 2013  9:30p ET  Houston Rockets         107     away
#
#                 Opponent  Opponent_score Result season
# 0  Oklahoma City Thunder             120      L    plo
# 1  Oklahoma City Thunder             105      L    plo
# 2  Oklahoma City Thunder             104      L    plo
# 3  Oklahoma City Thunder             103      W    plo
# 4  Oklahoma City Thunder             100      W    plo

# %%
hou_rockets_plo['Date'] = pd.to_datetime(hou_rockets_plo['Date'])
hou_rockets_plo = hou_rockets_plo.set_index('Date').sort_index(ascending=True)
hou_rockets_plo.head()
# Out:
#                 Time             Team  Team_score Location  \
# Date
# 2009-12-13         Toronto Raptors             101      L    reg
# 2009-12-15         Detroit Pistons              96      W    reg
# 2009-12-16          Denver Nuggets             111      L    reg
# 2009-12-18        Dallas Mavericks             108      W    reg
# 2009-12-19   Oklahoma City Thunder              90      W    reg
# 2009-12-22    Los Angeles Clippers              99      W    reg
# 2009-12-23           Orlando Magic             102      L    reg
# 2009-12-26         New Jersey Nets              93      W    reg
# ...                            ...             ...    ...    ...
# 2015-04-26        Dallas Mavericks             121      L    plo
# 2015-04-28        Dallas Mavericks              94      W    plo
# 2015-05-04    Los Angeles Clippers             117      L    plo
# 2015-05-06    Los Angeles Clippers             109      W    plo
# 2015-05-08    Los Angeles Clippers             124      L    plo
# 2015-05-10    Los Angeles Clippers             128      L    plo
# 2015-05-12    Los Angeles Clippers             103      W    plo
# 2015-05-14    Los Angeles Clippers             107      W    plo
# 2015-05-17    Los Angeles Clippers             100      W    plo
# 2015-05-19   Golden State Warriors             110      L    plo
# 2015-05-21   Golden State Warriors              99      L    plo
# 2015-05-23   Golden State Warriors             115      L    plo
# 2015-05-25   Golden State Warriors             115      W    plo
# 2015-05-27   Golden State Warriors             104      L    plo
# 2016-04-16   Golden State Warriors             104      L    plo
# 2016-04-18   Golden State Warriors             115      L    plo
# 2016-04-21   Golden State Warriors              96      W    plo
# 2016-04-24   Golden State Warriors             121      L    plo
# 2016-04-27   Golden State Warriors             114      L    plo
# 2017-04-16   Oklahoma City Thunder              87      W    plo
# 2017-04-19   Oklahoma City Thunder             111      W    plo
# 2017-04-21   Oklahoma City Thunder             115      L    plo
# 2017-04-23   Oklahoma City Thunder             109      W    plo
# 2017-04-25   Oklahoma City Thunder              99      W    plo
# 2017-05-01       San Antonio Spurs              99      W    plo
# 2017-05-03       San Antonio Spurs             121      L    plo
# 2017-05-05       San Antonio Spurs             103      L    plo
# 2017-05-07       San Antonio Spurs             104      W    plo
# 2017-05-09       San Antonio Spurs             110      L    plo
# 2017-05-11       San Antonio Spurs             114      L    plo
#
# [685 rows x 8 columns]

# %% [markdown]
# ## Only home games

# %%
rockets = rockets[rockets.Location =='home']

# %% [markdown]
# ## select cols

# %%
rockets = rockets[['Team','Team_score','Location','Opponent','Opponent_score','season']]

# %%
rockets.head()
# Out:
#                        Team  Team_score Location                Opponent  \
# Date
# 2009-10-31  Houston Rockets         111     home  Portland Trail Blazers
# 2009-11-04  Houston Rockets         102     home      Los Angeles Lakers
# 2009-11-06  Houston Rockets         105     home   Oklahoma City Thunder
# 2009-11-11  Houston Rockets         104     home       Memphis Grizzlies
# 2009-11-17  Houston Rockets         105     home            Phoenix Suns
#
#             Opponent_score season
# Date
# 2009-10-31             107    reg
# 2009-11-04             103    reg
# 2009-11-06              94    reg
# 2009-11-11              79    reg
# 2009-11-17             111    reg

# %%
rockets.to_csv('data/clean/rockets_clean.csv')
