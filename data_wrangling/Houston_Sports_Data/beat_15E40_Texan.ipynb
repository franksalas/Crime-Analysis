# %%
import pandas as pd

# %%
ls sports_data_clean
# Out:
# astros_10_17_plo_clean.csv*       nfl_08_17_clean.csv*
# astros_10_17_reg_clean.csv*       nfl10clean.csv*
# astros_1A10.csv*                  nfl10yearsfull.csv*
# dynamo_10_17_plo.csv*             nfl17years_clean.csv*
# dynamo_10_17__reg.csv*            nfl17years_PST_clean.csv*
# dynamo_10H30.csv*                 rice_08_17_clean.csv*
# hou_nfl_1017_post.csv*            Rice_10H80.csv*
# hou_nfl_1017_reg.csv*             rockets_1A10.csv*
# hou_rockets_08_17_clean.csv*      uh_08_17_clean.csv*
# hou_rockets_10_17_plo_clean.csv*  UH_10H50.csv*
# hou_rockets_10_17_reg_clean.csv*

# %%
hou_reg = 'sports_data_clean/hou_nfl_1017_reg.csv'
hou_pos = 'sports_data_clean/hou_nfl_1017_post.csv'

# %%
df_reg = pd.read_csv(hou_reg)
df_pos = pd.read_csv(hou_pos)

# %%
frame = [df_reg, df_pos]

tex = pd.concat(frame)

# %%
tex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 69 entries, 2010-01-03 18:02:38 to 2017-12-25 21:30:00
# Data columns (total 6 columns):
# home.alias             69 non-null object
# scoring.home_points    69 non-null float64
# away.alias             69 non-null object
# scoring.away_points    69 non-null float64
# winner                 69 non-null object
# season                 69 non-null object
# dtypes: float64(2), object(4)
# memory usage: 3.8+ KB

# %%
# date
tex.scheduled = pd.to_datetime(tex.scheduled)

tex = tex.set_index('scheduled').sort_index(ascending=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-4de528e8da2c> in <module>()
#       1 # date
# ----> 2 tex.scheduled = pd.to_datetime(tex.scheduled)
#       3
#       4 tex = tex.set_index('scheduled').sort_index(ascending=True)
#
# ~/miniconda3/envs/springboard/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'scheduled'

# %%
tex
# Out:
#                     home.alias  scoring.home_points away.alias  \
# scheduled
# 2010-01-03 18:02:38        HOU                 34.0         NE
# 2010-09-12 17:02:50        HOU                 34.0        IND
# 2010-09-26 17:03:12        HOU                 13.0        DAL
# 2010-10-10 17:03:05        HOU                 10.0        NYG
# 2010-10-17 17:03:31        HOU                 35.0         KC
# 2010-11-07 18:02:28        HOU                 23.0         SD
# 2010-11-28 18:02:39        HOU                 20.0        TEN
# 2010-12-14 01:40:41        HOU                 28.0        BAL
# 2011-01-02 21:16:48        HOU                 34.0        JAC
# 2011-09-11 17:05:39        HOU                 34.0        IND
# 2011-10-02 17:03:06        HOU                 17.0        PIT
# 2011-10-09 17:02:25        HOU                 20.0        OAK
# 2011-10-30 17:02:39        HOU                 24.0        JAC
# 2011-11-06 18:03:11        HOU                 30.0        CLE
# ...

# %%
tex['beat'] = '15E40'

# %%
tex
# Out:
#                     home.alias  scoring.home_points away.alias  \
# scheduled
# 2010-01-03 18:02:38        HOU                 34.0         NE
# 2010-09-12 17:02:50        HOU                 34.0        IND
# 2010-09-26 17:03:12        HOU                 13.0        DAL
# 2010-10-10 17:03:05        HOU                 10.0        NYG
# 2010-10-17 17:03:31        HOU                 35.0         KC
# 2010-11-07 18:02:28        HOU                 23.0         SD
# 2010-11-28 18:02:39        HOU                 20.0        TEN
# 2010-12-14 01:40:41        HOU                 28.0        BAL
# 2011-01-02 21:16:48        HOU                 34.0        JAC
# 2011-09-11 17:05:39        HOU                 34.0        IND
# 2011-10-02 17:03:06        HOU                 17.0        PIT
# 2011-10-09 17:02:25        HOU                 20.0        OAK
# 2011-10-30 17:02:39        HOU                 24.0        JAC
# 2011-11-06 18:03:11        HOU                 30.0        CLE
# ...

# %%
tex.to_csv('sports_data_clean/Tex_15E40.csv')

# %%
ls sports_data_clean/
# Out:
# astros_10_17_plo_clean.csv*       nfl_08_17_clean.csv*
# astros_10_17_reg_clean.csv*       nfl10clean.csv*
# astros_1A10.csv*                  nfl10yearsfull.csv*
# dynamo_10_17_plo.csv*             nfl17years_clean.csv*
# dynamo_10_17__reg.csv*            nfl17years_PST_clean.csv*
# dynamo_10H30.csv*                 rice_08_17_clean.csv*
# hou_nfl_1017_post.csv*            Rice_10H80.csv*
# hou_nfl_1017_reg.csv*             rockets_1A10.csv*
# hou_rockets_08_17_clean.csv*      Tex_15E40.csv*
# hou_rockets_10_17_plo_clean.csv*  uh_08_17_clean.csv*
# hou_rockets_10_17_reg_clean.csv*  UH_10H50.csv*
