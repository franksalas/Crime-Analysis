# %%
import pandas as pd
import glob, os


import numpy as np
import matplotlib.pyplot as plt
import googlemaps
import gmaps
API_KEY = 'AIzaSyC-mLUTfYy6RwWdhnXQ5y4bYnPJLl_NRE0' 
gmaps_dev = googlemaps.Client(key=API_KEY) ## 
gmaps.configure(api_key=API_KEY) #

# %%
ls crime_data/2016
# Out:
# apr16.xls*  dec16.xls*  jan16.xls*  jun16.xls*  may16.xls*  oct16.xls*
# aug16.xls*  feb16.xls*  jul16.xls*  mar16.xls*  nov16.xls*  sep16.xls*

# %%
path = 'crime_data/2016'                     # use your path
all_files = glob.glob(os.path.join(path, "*.xls"))     # advisable to use os.path.join as this makes concatenation OS independent

df_from_each_file = (pd.read_excel(f) for f in all_files)
df2016   = pd.concat(df_from_each_file, ignore_index=True)
# doesn't create a list, nor does it append to on

# %% [markdown]
# ## Set the Date col as the index

# %%
df2016 = df2016.set_index('Date')

# %%
df2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 122693 entries, 2016-04-10 to 2016-09-30
# Data columns (total 9 columns):
# Hour            122693 non-null int64
# Offense Type    122693 non-null object
# Beat            122693 non-null object
# Premise         121293 non-null object
# BlockRange      122693 non-null object
# StreetName      122693 non-null object
# Type            122693 non-null object
# Suffix          122693 non-null object
# # offenses      122693 non-null int64
# dtypes: int64(2), object(7)
# memory usage: 9.4+ MB

# %%
df2016.head()
# Out:
#             Hour        Offense Type   Beat                    Premise  \
# Date
# 2016-04-10    20             Robbery  10H10  Road, Street, or Sidewalk
# 2016-04-11    19  Aggravated Assault  10H10  Road, Street, or Sidewalk
# 2016-04-12    20             Robbery  10H10                  Apartment
# 2016-04-13     2          Auto Theft  10H10                   Driveway
# 2016-04-14     3            Burglary  10H10     Service or Gas Station
#
#            BlockRange StreetName Type Suffix  # offenses
# Date
# 2016-04-10  4000-4099      MILBY    -      -           1
# 2016-04-11    400-499       YORK    -      -           2
# 2016-04-12  1900-1999    RUNNELS    -      -           1
# 2016-04-13    100-199     SIDNEY    -      -           1
# 2016-04-14  3300-3399      CANAL   ST      -           1

# %% [markdown]
# ## Find all the beats around houston

# %%
df2016['Beat'].unique()
# Out:
# array(['10H10', '10H20', '10H30', '10H40', '10H50', '10H60', '10H70',
#        '10H80', '11H10', '11H20', '11H30', '11H40', '11H50', '12D10',
#        '12D20', '12D30', '12D40', '12D50', '12D60', '12D70', '13D10',
#        '13D20', '13D30', '13D40', '14D10', '14D20', '14D30', '14D40',
#        '14D50', '15E10', '15E20', '15E30', '15E40', '16E10', '16E20',
#        '16E30', '16E40', '17E10', '17E20', '17E30', '17E40', '18F10',
#        '18F20', '18F30', '18F40', '18F50', '18F60', '19G10', '19G20',
#        '19G30', '19G40', '19G50', '1A10', '1A20', '1A30', '1A40', '1A50',
#        '20G10', '20G20', '20G30', '20G40', '20G50', '20G60', '20G70',
#        '20G80', '21I10', '21I30', '21I40', '21I50', '21I60', '23J50',
#        '24C10', '24C20', '24C30', '24C40', '24C50', '24C60', '2A10',
#        '2A20', '2A30', '2A40', '2A50', '2A60', '3B10', '3B30', '3B40',
#        '3B50', '4F10', '4F20', '4F30', '5F10', '5F20', '5F30', '5F40',
# ...

# %% [markdown]
# ## beat 15E40
# ### reliant stadium
# create a subset for just the reliant stadium

# %%
reliant2016 = df2016[df2016['Beat'] =='15E40']

reliant2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2099 entries, 2016-04-19 to 2016-09-30
# Data columns (total 9 columns):
# Hour            2099 non-null int64
# Offense Type    2099 non-null object
# Beat            2099 non-null object
# Premise         2073 non-null object
# BlockRange      2099 non-null object
# StreetName      2099 non-null object
# Type            2099 non-null object
# Suffix          2099 non-null object
# # offenses      2099 non-null int64
# dtypes: int64(2), object(7)
# memory usage: 164.0+ KB

# %% [markdown]
# ## Find nan values

# %%
reliant2016[reliant2016['Premise'].isnull()]
# Out:
#             Hour        Offense Type   Beat Premise BlockRange   StreetName  \
# Date
# 2016-04-16    21               Theft  15E40     NaN  8400-8499        KIRBY
# 2016-08-06    22  Aggravated Assault  15E40     NaN  2600-2699    WESTRIDGE
# 2016-08-04    13               Theft  15E40     NaN  8300-8399         MAIN
# 2016-08-14     5               Theft  15E40     NaN  2300-2399         LOOP
# 2016-12-17     6               Theft  15E40     NaN  1800-1899     EL PASEO
# 2016-02-13    16               Theft  15E40     NaN  7900-7999         MAIN
# 2016-02-09    12  Aggravated Assault  15E40     NaN  7500-7599       FANNIN
# 2016-02-07     5            Burglary  15E40     NaN  2700-2799         LOOP
# 2016-02-01     4  Aggravated Assault  15E40     NaN  1700-1799       IH 610
# 2016-02-27     6            Burglary  15E40     NaN  1400-1499         LOOP
# 2014-12-14    15               Theft  15E40     NaN  2400-2499   HOLLY HALL
# ...

# %% [markdown]
# # only show sundays!

# %%
rel_2016_sun = reliant2016[reliant2016.index.dayofweek == 6]

rel_2016_sun.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 254 entries, 2016-04-17 to 2016-09-18
# Data columns (total 9 columns):
# Hour            254 non-null int64
# Offense Type    254 non-null object
# Beat            254 non-null object
# Premise         249 non-null object
# BlockRange      254 non-null object
# StreetName      254 non-null object
# Type            254 non-null object
# Suffix          254 non-null object
# # offenses      254 non-null int64
# dtypes: int64(2), object(7)
# memory usage: 19.8+ KB

# %% [markdown]
# ## combine address

# %%
rel_2016_sun['address'] = rel_2016_sun[['BlockRange', 'StreetName']].apply(lambda x: ' '.join(x), axis=1)

rel_2016_sun
# Out:
# /home/salas/miniconda3/envs/sbc/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#             Hour        Offense Type   Beat  \
# Date
# 2016-04-17    23               Theft  15E40
# 2016-04-17    12               Theft  15E40
# 2016-04-17    13             Robbery  15E40
# 2016-04-17     7               Theft  15E40
# 2016-04-10     5               Theft  15E40
# 2016-04-10     5               Theft  15E40
# 2016-04-03    19               Theft  15E40
# 2016-04-03    19          Auto Theft  15E40
# 2016-04-03    18               Theft  15E40
# 2016-04-03     8               Theft  15E40
# 2016-04-03     0  Aggravated Assault  15E40
# ...

# %%
def get_loc(row):
    acc = []
    #print('{}, Houston, TX'.format(row))
    gps = gmaps_dev.geocode('{}, Houston, TX'.format(row))
    result = tuple(gps[0]['geometry']['location'].values())
    print(result)

# %%
def get_loc(row):
    gps = gmaps_dev.geocode('{}, Houston, TX'.format(row))
    result = tuple(gps[0]['geometry']['location'].values())
    return result

# %%
rel_2016_sun['address'].apply(get_loc)
# Out:
# (29.6966603, -95.41297949999999)
# (29.685262, -95.4000069)
# (29.6799183, -95.42535520000001)
# (29.685262, -95.4000069)
# (29.679237, -95.415899)
# (29.6706157, -95.42023329999999)
# (29.6784009, -95.4168471)
# (29.80467509999999, -95.44989489999999)
# (29.6966603, -95.41297949999999)
# (29.6920048, -95.4132582)
# (29.68142, -95.4221518)
# (29.6847027, -95.4109208)
# (29.6870171, -95.4203794)
# (29.6870171, -95.4203794)
# (29.8132311, -95.3802049)
# (29.6847027, -95.4109208)
# (29.6847027, -95.4109208)
# (29.7474286, -95.47368519999999)
# (29.6991193, -95.60916859999999)
# (29.6923462, -95.41644850000002)
# (29.8098666, -95.4398933)
# (29.685262, -95.4000069)
# (29.6798371, -95.426024)
# (29.685262, -95.4000069)
# (29.7261105, -95.4161764)
# (29.6707645, -95.4248326)
# (29.667682, -95.392416)
# (29.6799183, -95.42535520000001)
# (29.6966603, -95.41297949999999)
# (29.667682, -95.392416)
# (29.6783249, -95.4129509)
# (29.6916999, -95.4172361)
# (29.6783249, -95.4129509)
# ...

# %% [markdown]
# ## find rows with missing BlockRange

# %%
rel_2016_sun.loc[rel_2016_sun['BlockRange'] == 'UNK']
# Out:
#             Hour Offense Type   Beat                            Premise  \
# Date
# 2016-08-28    12        Theft  15E40  Stadium, Sports Arena, Race Track
# 2016-01-03    12        Theft  15E40  Stadium, Sports Arena, Race Track
# 2016-06-05    12        Theft  15E40  Stadium, Sports Arena, Race Track
# 2016-05-29    16        Theft  15E40              Apartment Parking Lot
# 2016-11-13    12        Theft  15E40  Stadium, Sports Arena, Race Track
# 2016-10-30    15        Theft  15E40         Hotel or Motel Parking Lot
#
#            BlockRange  StreetName  Type Suffix  # offenses         address
# Date
# 2016-08-28        UNK     RELIANT     -      -           1     UNK RELIANT
# 2016-01-03        UNK     RELIANT     -      -           1     UNK RELIANT
# 2016-06-05        UNK       KIRBY    DR      -           1       UNK KIRBY
# 2016-05-29        UNK     BARTELL    DR      -           1     UNK BARTELL
# 2016-11-13        UNK     RELIANT  PKWY      -           1     UNK RELIANT
# ...

# %% [markdown]
# ## create new df with removed unk

# %%
clean = rel_2016_sun[rel_2016_sun['BlockRange']  != 'UNK']

# %%
clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 248 entries, 2016-04-17 to 2016-09-18
# Data columns (total 10 columns):
# Hour            248 non-null int64
# Offense Type    248 non-null object
# Beat            248 non-null object
# Premise         243 non-null object
# BlockRange      248 non-null object
# StreetName      248 non-null object
# Type            248 non-null object
# Suffix          248 non-null object
# # offenses      248 non-null int64
# address         248 non-null object
# dtypes: int64(2), object(8)
# memory usage: 21.3+ KB

# %%
rel_2016_sun.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 254 entries, 2016-04-17 to 2016-09-18
# Data columns (total 10 columns):
# Hour            254 non-null int64
# Offense Type    254 non-null object
# Beat            254 non-null object
# Premise         249 non-null object
# BlockRange      254 non-null object
# StreetName      254 non-null object
# Type            254 non-null object
# Suffix          254 non-null object
# # offenses      254 non-null int64
# address         254 non-null object
# dtypes: int64(2), object(8)
# memory usage: 26.8+ KB

# %%
clean['gps'] = clean['address'].apply(get_loc)
# Out:
# /home/salas/miniconda3/envs/sbc/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
clean
# Out:
#             Hour        Offense Type   Beat  \
# Date
# 2016-04-17    23               Theft  15E40
# 2016-04-17    12               Theft  15E40
# 2016-04-17    13             Robbery  15E40
# 2016-04-17     7               Theft  15E40
# 2016-04-10     5               Theft  15E40
# 2016-04-10     5               Theft  15E40
# 2016-04-03    19               Theft  15E40
# 2016-04-03    19          Auto Theft  15E40
# 2016-04-03    18               Theft  15E40
# 2016-04-03     8               Theft  15E40
# 2016-04-03     0  Aggravated Assault  15E40
# 2016-03-13     6               Theft  15E40
# 2016-04-24     6               Theft  15E40
# 2016-04-24     7               Theft  15E40
# 2016-04-24    20            Burglary  15E40
# 2016-08-28    20               Theft  15E40
# 2016-08-28    21               Theft  15E40
# 2016-08-28     9               Theft  15E40
# 2016-08-28     8               Theft  15E40
# 2016-08-21    10               Theft  15E40
# ...

# %%
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(clean['gps'].values))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
