# %%
import pandas as pd
import numpy as np

# %%
ls crime_data_clean/
# Out:
# beats_alternate_10_17.csv*      crime_10H70_10_17df_2000.csv*
# beats_filter_10_17.csv*         crime_10H70_10_17df_3000.csv*
# crime_10H10_10_17ADD.csv*       crime_10H70_10_17df_4000.csv*
# crime_10H10_10_17.csv*          crime_10H70_10_17df_5000.csv*
# crime_10H10_10_17df_1000.csv*   crime_10H70_10_17df_6000.csv*
# crime_10H10_10_17df_2000.csv*   crime_10H70_10_17df_7000.csv*
# crime_10H10_10_17df_3000.csv*   crime_10H70_10_17df_8000.csv*
# crime_10H10_10_17df_4000.csv*   crime_10H70_10_17df_9000.csv*
# crime_10H30_10_17ADD.csv*       crime_10H80_10_17ADD.csv*
# crime_10H30_10_17.csv*          crime_10H80_10_17.csv*
# crime_10H30_10_17FINAL.csv*     crime_10H80_10_17FINAL.csv*
# crime_10H40_10_17ADD.csv*       crime_15E40_10_17ADD.csv*
# crime_10H40_10_17.csv*          crime_15E40_10_17.csv*
# crime_10H40_10_17df_10000.csv*  crime_15E40_10_17df_12000.csv*
# crime_10H40_10_17df_1000.csv*   crime_15E40_10_17df_16281.csv*
# ...

# %% [markdown]
# ##  ~~10H40~~ , ~~10H60~~, 10H70, ~~10H10~~

# %% [markdown]
# # 10H40

# %%
path = 'crime_data_clean/crime_10H40_10_17LATLON.csv'

# %%
df_10H40 = pd.read_csv(path)

# %%
df_10H40.head(2)
# Out:
#              Date_Hour   Beat OffenseType            Premise  NumOffenses  \
# 0  2010-01-01 01:00:00  10H40       Theft     bar/night club            1
# 1  2010-01-01 03:00:00  10H40       Theft  other parking lot            1
#
#    Hour  day weekday month  year        lat        lon  \
# 0     1    1  Friday   Jan  2010  29.745307 -95.371946
# 1     3    1  Friday   Jan  2010  29.738960 -95.397363
#
#                                            add
# 0  2450 San Jacinto St, Houston, TX 77002, USA
# 1    1450 W Alabama St, Houston, TX 77006, USA

# %%
df_10H40 = df_10H40[[
 'Date_Hour',
 'Beat',
 'OffenseType',
 'Premise',
 'NumOffenses',
 'Hour',
 'day',
 'weekday',
 'month',
 'year',
 'lat',
 'lon',
 'add']]

# %%
df_10H40.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10406 entries, 0 to 10405
# Data columns (total 13 columns):
# Date_Hour      10406 non-null object
# Beat           10406 non-null object
# OffenseType    10406 non-null object
# Premise        10406 non-null object
# NumOffenses    10406 non-null int64
# Hour           10406 non-null int64
# day            10406 non-null int64
# weekday        10406 non-null object
# month          10406 non-null object
# year           10406 non-null int64
# lat            10406 non-null float64
# lon            10406 non-null float64
# add            10406 non-null object
# dtypes: float64(2), int64(4), object(7)
# memory usage: 1.0+ MB

# %%
df_10H40.head()
# Out:
#              Date_Hour   Beat OffenseType               Premise  NumOffenses  \
# 0  2010-01-01 01:00:00  10H40       Theft        bar/night club            1
# 1  2010-01-01 03:00:00  10H40       Theft     other parking lot            1
# 2  2010-01-01 05:00:00  10H40       Theft        bar/night club            1
# 3  2010-01-02 00:00:00  10H40       Theft  road/street/sidewalk            1
# 4  2010-01-02 17:00:00  10H40       Theft     other parking lot            1
#
#    Hour  day   weekday month  year        lat        lon  \
# 0     1    1    Friday   Jan  2010  29.745307 -95.371946
# 1     3    1    Friday   Jan  2010  29.738960 -95.397363
# 2     5    1    Friday   Jan  2010  29.745307 -95.371946
# 3     0    2  Saturday   Jan  2010  29.741186 -95.373694
# 4    17    2  Saturday   Jan  2010  29.734911 -95.382958
#
#                                            add
# 0  2450 San Jacinto St, Houston, TX 77002, USA
# 1    1450 W Alabama St, Houston, TX 77006, USA
# ...

# %%
df_10H40.to_csv('crime_data_clean/df_10H40FINAL.csv')

# %% [markdown]
# # 10H60

# %%
ls crime_data_clean/
# Out:
# beats_alternate_10_17.csv*      crime_10H60_10_17df_6000.csv*
# beats_filter_10_17.csv*         crime_10H60_10_17df_7000.csv*
# crime_10H10_10_17ADD.csv*       crime_10H60_10_17LATLON.csv*
# crime_10H10_10_17.csv*          crime_10H70_10_17.csv*
# crime_10H10_10_17df_1000.csv*   crime_10H70_10_17df_1000.csv*
# crime_10H10_10_17df_2000.csv*   crime_10H70_10_17df_2000.csv*
# crime_10H10_10_17df_3000.csv*   crime_10H70_10_17df_3000.csv*
# crime_10H10_10_17df_4000.csv*   crime_10H80_10_17ADD.csv*
# crime_10H30_10_17ADD.csv*       crime_10H80_10_17.csv*
# crime_10H30_10_17.csv*          crime_10H80_10_17FINAL.csv*
# crime_10H30_10_17FINAL.csv*     crime_15E40_10_17ADD.csv*
# crime_10H40_10_17ADD.csv*       crime_15E40_10_17.csv*
# crime_10H40_10_17.csv*          crime_15E40_10_17df_12000.csv*
# crime_10H40_10_17df_10000.csv*  crime_15E40_10_17df_16281.csv*
# crime_10H40_10_17df_1000.csv*   crime_15E40_10_17df_4000.csv*
# crime_10H40_10_17df_2000.csv*   crime_15E40_10_17df_8000.csv*
# ...

# %%
# crime_10H60_10_17LATLON

path = 'crime_data_clean/crime_10H60_10_17LATLON.csv'
df_10H60 = pd.read_csv(path)

# %%
df_10H60.head()
# Out:
#    Unnamed: 0            Date_Hour   Beat BlockRange StreetName OffenseType  \
# 0           0  2010-01-01 00:00:00  10H60  2500-2599  SOUTHMORE    Burglary
# 1           1  2010-01-01 00:00:00  10H60  3500-3599  MACGREGOR       Theft
# 2           2  2010-01-01 04:00:00  10H60  4000-4099   CANFIELD     Robbery
# 3           3  2010-01-01 06:00:00  10H60  3700-3799       ODIN       Theft
# 4           4  2010-01-01 14:00:00  10H60  5500-5599   LIVE OAK       Theft
#
#                                Premise  NumOffenses  Hour  day weekday month  \
# 0                            apartment            1     0    1  Friday   Jan
# 1                            apartment            1     0    1  Friday   Jan
# 2  bank/saving institution parking lot            1     4    1  Friday   Jan
# 3                            apartment            1     6    1  Friday   Jan
# 4                            apartment            1    14    1  Friday   Jan
#
#    year  block         address  \
# ...

# %%
df_10H60 = df_10H60[[
 'Date_Hour',
 'Beat',
 'OffenseType',
 'Premise',
 'NumOffenses',
 'Hour',
 'day',
 'weekday',
 'month',
 'year',
 'lat',
 'lon',
 'add']]

# %%
df_10H60.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7671 entries, 0 to 7670
# Data columns (total 13 columns):
# Date_Hour      7671 non-null object
# Beat           7671 non-null object
# OffenseType    7671 non-null object
# Premise        7671 non-null object
# NumOffenses    7671 non-null int64
# Hour           7671 non-null int64
# day            7671 non-null int64
# weekday        7671 non-null object
# month          7671 non-null object
# year           7671 non-null int64
# lat            7671 non-null float64
# lon            7671 non-null float64
# add            7671 non-null object
# dtypes: float64(2), int64(4), object(7)
# memory usage: 779.2+ KB

# %%
df_10H60.head()
# Out:
#              Date_Hour   Beat OffenseType  \
# 0  2010-01-01 00:00:00  10H60    Burglary
# 1  2010-01-01 00:00:00  10H60       Theft
# 2  2010-01-01 04:00:00  10H60     Robbery
# 3  2010-01-01 06:00:00  10H60       Theft
# 4  2010-01-01 14:00:00  10H60       Theft
#
#                                Premise  NumOffenses  Hour  day weekday month  \
# 0                            apartment            1     0    1  Friday   Jan
# 1                            apartment            1     0    1  Friday   Jan
# 2  bank/saving institution parking lot            1     4    1  Friday   Jan
# 3                            apartment            1     6    1  Friday   Jan
# 4                            apartment            1    14    1  Friday   Jan
#
#    year        lat        lon                                           add
# 0  2010  29.719598 -95.373216   2550 Southmore Blvd, Houston, TX 77004, USA
# 1  2010  29.709357 -95.362421  3550 S MacGregor Way, Houston, TX 77021, USA
# ...

# %%
df_10H60.to_csv('crime_data_clean/df_10H60FINAL.csv')

# %% [markdown]
# # 10H10

# %%
# crime_10H60_10_17LATLON

path = 'crime_data_clean/crime_10H10_10_17ADD.csv'
df_10H10 = pd.read_csv(path)

# %%
df_10H10
# Out:
#       Unnamed: 0            Date_Hour   Beat   BlockRange       StreetName  \
# 0              0  2010-01-01 00:00:00  10H10      500-599         EASTWOOD
# 1              1  2010-01-01 06:00:00  10H10    2300-2399          SPERBER
# 2              2  2010-01-01 17:00:00  10H10    1900-1999          RUNNELS
# 3              3  2010-01-01 20:00:00  10H10    1900-1999          RUNNELS
# 4              4  2010-01-02 19:00:00  10H10         0-99             YORK
# 5              5  2010-01-03 00:00:00  10H10      200-299            GRACE
# 6              6  2010-01-03 12:00:00  10H10      500-599            BRYAN
# 7              7  2010-01-04 08:00:00  10H10      400-499             HUNT
# 8              8  2010-01-04 14:00:00  10H10    1900-1999          RUNNELS
# 9              9  2010-01-05 02:00:00  10H10    3300-3399            CANAL
# 10            10  2010-01-07 17:00:00  10H10      600-699       NAVIGATION
# ...

# %%
df_10H10 = df_10H10[[
 'Date_Hour',
 'Beat',
 'OffenseType',
 'Premise',
 'NumOffenses',
 'Hour',
 'day',
 'weekday',
 'month',
 'year',
 'lat',
 'lon',
 'add']]

# %%
df_10H10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3987 entries, 0 to 3986
# Data columns (total 13 columns):
# Date_Hour      3987 non-null object
# Beat           3987 non-null object
# OffenseType    3987 non-null object
# Premise        3987 non-null object
# NumOffenses    3987 non-null int64
# Hour           3987 non-null int64
# day            3987 non-null int64
# weekday        3987 non-null object
# month          3987 non-null object
# year           3987 non-null int64
# lat            3987 non-null float64
# lon            3987 non-null float64
# add            3987 non-null object
# dtypes: float64(2), int64(4), object(7)
# memory usage: 405.0+ KB

# %%
df_10H10.head()
# Out:
#              Date_Hour   Beat OffenseType                        Premise  \
# 0  2010-01-01 00:00:00  10H10    Burglary  misc. business (non-specific)
# 1  2010-01-01 06:00:00  10H10        Rape                residence/house
# 2  2010-01-01 17:00:00  10H10    Burglary                      apartment
# 3  2010-01-01 20:00:00  10H10       Theft           road/street/sidewalk
# 4  2010-01-02 19:00:00  10H10    Burglary                residence/house
#
#    NumOffenses  Hour  day   weekday month  year        lat        lon  \
# 0            1     0    1    Friday   Jan  2010  29.743716 -95.332731
# 1            1     6    1    Friday   Jan  2010  29.755055 -95.348144
# 2            1    17    1    Friday   Jan  2010  29.762874 -95.351209
# 3            1    20    1    Friday   Jan  2010  29.762874 -95.351209
# 4            1    19    2  Saturday   Jan  2010  29.750896 -95.337716
#
#                                        add
# 0  550 Eastwood St, Houston, TX 77011, USA
# ...

# %%
df_10H10.to_csv('crime_data_clean/df_10H10FINAL.csv')

# %% [markdown]
# # 1A10

# %%
path = 'crime_data_clean/crime_1A10_10_17LATLON.csv'
df_1A10 = pd.read_csv(path)

# %%
df_1A10
# Out:
#        Unnamed: 0            Date_Hour  Beat   BlockRange  \
# 0               0  2010-01-01 00:00:00  1A10      300-399
# 1               1  2010-01-01 00:00:00  1A10    1200-1299
# 2               2  2010-01-01 00:00:00  1A10      400-499
# 3               3  2010-01-01 00:00:00  1A10    1200-1299
# 4               4  2010-01-01 00:00:00  1A10    1000-1099
# 5               5  2010-01-01 01:00:00  1A10    1200-1299
# 6               6  2010-01-01 02:00:00  1A10      700-799
# 7               7  2010-01-01 02:00:00  1A10      400-499
# 8               8  2010-01-01 06:00:00  1A10    1200-1299
# 9               9  2010-01-01 23:00:00  1A10      700-799
# 10             10  2010-01-01 23:00:00  1A10      600-699
# 11             11  2010-01-02 00:00:00  1A10    1000-1099
# 12             12  2010-01-02 00:00:00  1A10      100-199
# 13             13  2010-01-02 01:00:00  1A10    1200-1299
# 14             14  2010-01-02 03:00:00  1A10      300-399
# ...

# %%
df_1A10 = df_1A10[[
 'Date_Hour',
 'Beat',
 'OffenseType',
 'Premise',
 'NumOffenses',
 'Hour',
 'day',
 'weekday',
 'month',
 'year',
 'lat',
 'lon',
 'add']]

# %%
df_1A10.head()
# Out:
#              Date_Hour  Beat OffenseType                          Premise  \
# 0  2010-01-01 00:00:00  1A10  Auto Theft       bar/night club parking lot
# 1  2010-01-01 00:00:00  1A10       Theft                   bar/night club
# 2  2010-01-01 00:00:00  1A10    Burglary                  office building
# 3  2010-01-01 00:00:00  1A10       Theft                    other/unknown
# 4  2010-01-01 00:00:00  1A10       Theft  convention center/exhibit halls
#
#    NumOffenses  Hour  day weekday month  year        lat        lon  \
# 0            1     0    1  Friday   Jan  2010  29.757212 -95.353294
# 1            1     0    1  Friday   Jan  2010  29.753512 -95.363811
# 2            1     0    1  Friday   Jan  2010  29.760954 -95.362089
# 3            1     0    1  Friday   Jan  2010  29.755595 -95.367677
# 4            1     0    1  Friday   Jan  2010  29.752015 -95.359181
#
#                                                  add
# 0            350 Hamilton St, Houston, TX 77002, USA
# ...

# %%
df_1A10.to_csv('crime_data_clean/df_1A10FINAL.csv')

# %% [markdown]
# ## 10H70

# %%
ls crime_data_clean/
# Out:
# beats_alternate_10_17.csv*      crime_10H70_10_17df_1000.csv*
# beats_filter_10_17.csv*         crime_10H70_10_17df_2000.csv*
# crime_10H10_10_17ADD.csv*       crime_10H70_10_17df_3000.csv*
# crime_10H10_10_17.csv*          crime_10H70_10_17df_4000.csv*
# crime_10H10_10_17df_1000.csv*   crime_10H70_10_17df_5000.csv*
# crime_10H10_10_17df_2000.csv*   crime_10H70_10_17df_6000.csv*
# crime_10H10_10_17df_3000.csv*   crime_10H70_10_17df_7000.csv*
# crime_10H10_10_17df_4000.csv*   crime_10H70_10_17df_8000.csv*
# crime_10H30_10_17ADD.csv*       crime_10H70_10_17df_9000.csv*
# crime_10H30_10_17.csv*          crime_10H80_10_17ADD.csv*
# crime_10H30_10_17FINAL.csv*     crime_10H80_10_17.csv*
# crime_10H40_10_17ADD.csv*       crime_10H80_10_17FINAL.csv*
# crime_10H40_10_17.csv*          crime_15E40_10_17ADD.csv*
# crime_10H40_10_17df_10000.csv*  crime_15E40_10_17.csv*
# crime_10H40_10_17df_1000.csv*   crime_15E40_10_17df_12000.csv*
# ...

# %%
path = 'crime_data_clean/crime_10H70_10_17ADD.csv'
df_10H70 = pd.read_csv(path)

# %%
df_10H70.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11109 entries, 0 to 11108
# Data columns (total 19 columns):
# Unnamed: 0     11109 non-null int64
# Date_Hour      11109 non-null object
# Beat           11109 non-null object
# BlockRange     11109 non-null object
# StreetName     11109 non-null object
# OffenseType    11109 non-null object
# Premise        11109 non-null object
# NumOffenses    11109 non-null int64
# Hour           11109 non-null int64
# day            11109 non-null int64
# weekday        11109 non-null object
# month          11109 non-null object
# year           11109 non-null int64
# block          11109 non-null int64
# address        11109 non-null object
# tup_add        11109 non-null object
# lat            11109 non-null float64
# lon            11109 non-null float64
# add            11109 non-null object
# dtypes: float64(2), int64(6), object(11)
# memory usage: 1.6+ MB

# %%
df_10H70.head()
# Out:
#    Unnamed: 0            Date_Hour   Beat BlockRange StreetName  \
# 0           0  2010-01-01 19:00:00  10H70  6500-6599     FANNIN
# 1           1  2010-01-01 21:00:00  10H70  4800-4899     AUSTIN
# 2           2  2010-01-01 23:00:00  10H70  1900-1999  WENTWORTH
# 3           3  2010-01-02 15:00:00  10H70  6600-6699     FANNIN
# 4           4  2010-01-02 15:00:00  10H70  6400-6499     FANNIN
#
#           OffenseType          Premise  NumOffenses  Hour  day   weekday  \
# 0  Aggravated Assault         hospital            1    19    1    Friday
# 1            Burglary  residence/house            1    21    1    Friday
# 2  Aggravated Assault  residence/house            1    23    1    Friday
# 3               Theft         hospital            1    15    2  Saturday
# 4               Theft         hospital            1    15    2  Saturday
#
#   month  year  block         address  \
# 0   Jan  2010   6550     6550 FANNIN
# 1   Jan  2010   4850     4850 AUSTIN
# ...

# %%
df_10H70 = df_10H70[[
 'Date_Hour',
 'Beat',
 'OffenseType',
 'Premise',
 'NumOffenses',
 'Hour',
 'day',
 'weekday',
 'month',
 'year',
 'lat',
 'lon',
 'add']]

# %%
df_10H70.to_csv('crime_data_clean/df_10H70FINAL.csv')

# %%
df_10H70.head()
# Out:
#              Date_Hour   Beat         OffenseType          Premise  \
# 0  2010-01-01 19:00:00  10H70  Aggravated Assault         hospital
# 1  2010-01-01 21:00:00  10H70            Burglary  residence/house
# 2  2010-01-01 23:00:00  10H70  Aggravated Assault  residence/house
# 3  2010-01-02 15:00:00  10H70               Theft         hospital
# 4  2010-01-02 15:00:00  10H70               Theft         hospital
#
#    NumOffenses  Hour  day   weekday month  year        lat        lon  \
# 0            1    19    1    Friday   Jan  2010  29.711448 -95.399988
# 1            1    21    1    Friday   Jan  2010  29.728541 -95.382676
# 2            1    23    1    Friday   Jan  2010  29.726239 -95.376586
# 3            1    15    2  Saturday   Jan  2010  29.707713 -95.403292
# 4            1    15    2  Saturday   Jan  2010  29.712163 -95.399011
#
#                                          add
# 0     6550 Fannin St, Houston, TX 77030, USA
# 1     4850 Austin St, Houston, TX 77004, USA
# ...

# %% [markdown]
# # 10H30

# %%
path = 'crime_data_clean/crime_10H30_10_17FINAL.csv'
df2 = pd.read_csv(path)
#df2.drop(['Unnamed: 0'],axis=1,inplace=True)
df2.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3de7e916179f> in <module>()
#       1 path = 'crime_data_clean/crime_10H30_10_17FINAL.csv'
# ----> 2 df2 = pd.read_csv(path)
#       3 #df2.drop(['Unnamed: 0'],axis=1,inplace=True)
#       4 df2.head(2)
#
# NameError: name 'pd' is not defined

# %%
df2[['lat','lon']]= df2['lat_lon'].str.extract(r"\((.*?)\)", expand=False).str.split(',',expand=True)

# %%
df2[['lat','lon']].dtypes
# Out:
# lat    object
# lon    object
# dtype: object

# %%
df2[['lat','lon']].dtypes
# Out:
# lat    object
# lon    object
# dtype: object

# %%
df2['lat'] =  pd.to_numeric(df2['lat'])
df2['lon'] =  pd.to_numeric(df2['lon'])

# %%
df2[['lat','lon']].dtypes
# Out:
# lat    float64
# lon    float64
# dtype: object

# %%
df2.head(2)
# Out:
#              Date_Hour   Beat OffenseType                Premise  NumOffenses  \
# 0  2010-01-01 00:00:00  10H30       Theft        residence/house            1
# 1  2010-01-01 19:00:00  10H30       Theft  apartment parking lot            1
#
#    Hour  day weekday month  year                           lat_lon  \
# 0     0    1  Friday   Jan  2010  (29.7390659, -95.34897509999999)
# 1    19    1  Friday   Jan  2010         (29.7536483, -95.3510778)
#
#                               full_address        lat        lon
# 0  1750 Sampson St, Houston, TX 77003, USA  29.739066 -95.348975
# 1   550 Bastrop St, Houston, TX 77003, USA  29.753648 -95.351078

# %%
df_10H30 = df2[[
 'Date_Hour',
 'Beat',
 'OffenseType',
 'Premise',
 'NumOffenses',
 'Hour',
 'day',
 'weekday',
 'month',
 'year',
 'lat',
 'lon',
 'full_address']]

# %%
df2.head()
# Out:
#              Date_Hour   Beat OffenseType                        Premise  \
# 0  2010-01-01 00:00:00  10H30       Theft                residence/house
# 1  2010-01-01 19:00:00  10H30       Theft          apartment parking lot
# 2  2010-01-01 20:00:00  10H30       Theft                residence/house
# 3  2010-01-02 01:00:00  10H30       Theft           road/street/sidewalk
# 4  2010-01-03 04:00:00  10H30       Theft  commercial parking lot/garage
#
#    NumOffenses  Hour  day   weekday month  year        lat        lon  \
# 0            1     0    1    Friday   Jan  2010  29.739066 -95.348975
# 1            1    19    1    Friday   Jan  2010  29.753648 -95.351078
# 2            1    20    1    Friday   Jan  2010  29.745298 -95.359324
# 3            1     1    2  Saturday   Jan  2010  29.746607 -95.359335
# 4            1     4    3    Sunday   Jan  2010  29.758830 -95.351403
#
#                                full_address
# 0   1750 Sampson St, Houston, TX 77003, USA
# ...

# %%
df_10H30.to_csv('crime_data_clean/df_10H30FINAL.csv')

# %%
df_10H30.head()
# Out:
#              Date_Hour   Beat OffenseType                        Premise  \
# 0  2010-01-01 00:00:00  10H30       Theft                residence/house
# 1  2010-01-01 19:00:00  10H30       Theft          apartment parking lot
# 2  2010-01-01 20:00:00  10H30       Theft                residence/house
# 3  2010-01-02 01:00:00  10H30       Theft           road/street/sidewalk
# 4  2010-01-03 04:00:00  10H30       Theft  commercial parking lot/garage
#
#    NumOffenses  Hour  day   weekday month  year        lat        lon  \
# 0            1     0    1    Friday   Jan  2010  29.739066 -95.348975
# 1            1    19    1    Friday   Jan  2010  29.753648 -95.351078
# 2            1    20    1    Friday   Jan  2010  29.745298 -95.359324
# 3            1     1    2  Saturday   Jan  2010  29.746607 -95.359335
# 4            1     4    3    Sunday   Jan  2010  29.758830 -95.351403
#
#                                full_address
# 0   1750 Sampson St, Houston, TX 77003, USA
# ...

# %% [markdown]
# # 10H50

# %%
path = 'crime_data_clean/crime_10H50_10_17FINAL.csv'
df3 = pd.read_csv(path)
#df2.drop(['Unnamed: 0'],axis=1,inplace=True)
df3.head(2)
# Out:
#              Date_Hour   Beat OffenseType  \
# 0  2010-01-01 09:00:00  10H50       Theft
# 1  2010-01-01 12:00:00  10H50    Burglary
#
#                                              Premise  NumOffenses  Hour  day  \
# 0                                    residence/house            1     9    1
# 1  vacant single occupancy residence (houses,town...            1    12    1
#
#   weekday month  year                          lat_lon  \
# 0  Friday   Jan  2010  (29.731311, -95.36411439999999)
# 1  Friday   Jan  2010  (29.728306, -95.36597750000001)
#
#                                full_address
# 0     3450 Nagle St, Houston, TX 77004, USA
# 1  2650 Truxillo St, Houston, TX 77004, USA

# %%
df3[['lat','lon']]= df3['lat_lon'].str.extract(r"\((.*?)\)", expand=False).str.split(',',expand=True)

# %%
df3[['lat','lon']].dtypes
# Out:
# lat    object
# lon    object
# dtype: object

# %%
df3['lat'] =  pd.to_numeric(df3['lat'])
df3['lon'] =  pd.to_numeric(df3['lon'])

# %%
df3[['lat','lon']].dtypes
# Out:
# lat    float64
# lon    float64
# dtype: object

# %%
df3.head(2)
# Out:
#              Date_Hour   Beat OffenseType  \
# 0  2010-01-01 09:00:00  10H50       Theft
# 1  2010-01-01 12:00:00  10H50    Burglary
#
#                                              Premise  NumOffenses  Hour  day  \
# 0                                    residence/house            1     9    1
# 1  vacant single occupancy residence (houses,town...            1    12    1
#
#   weekday month  year                          lat_lon  \
# 0  Friday   Jan  2010  (29.731311, -95.36411439999999)
# 1  Friday   Jan  2010  (29.728306, -95.36597750000001)
#
#                                full_address        lat        lon
# 0     3450 Nagle St, Houston, TX 77004, USA  29.731311 -95.364114
# 1  2650 Truxillo St, Houston, TX 77004, USA  29.728306 -95.365977

# %%
df_10H50 = df3[[
 'Date_Hour',
 'Beat',
 'OffenseType',
 'Premise',
 'NumOffenses',
 'Hour',
 'day',
 'weekday',
 'month',
 'year',
 'lat',
 'lon',
 'full_address']]

# %%
df_10H50.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9155 entries, 0 to 9154
# Data columns (total 13 columns):
# Date_Hour       9155 non-null object
# Beat            9155 non-null object
# OffenseType     9155 non-null object
# Premise         9155 non-null object
# NumOffenses     9155 non-null int64
# Hour            9155 non-null int64
# day             9155 non-null int64
# weekday         9155 non-null object
# month           9155 non-null object
# year            9155 non-null int64
# lat             9155 non-null float64
# lon             9155 non-null float64
# full_address    9155 non-null object
# dtypes: float64(2), int64(4), object(7)
# memory usage: 929.9+ KB

# %%
df_10H50.to_csv('crime_data_clean/df_10H50FINAL.csv')

# %% [markdown]
# # 15E40

# %%
path = 'crime_data_clean/crime_15E40_10_17FINAL.csv'
df4 = pd.read_csv(path)
#df2.drop(['Unnamed: 0'],axis=1,inplace=True)
df4.head(2)
# Out:
#              Date_Hour          Beat         OffenseType    Premise  \
# 0  2010-01-01 23:00:00  1.500000e+41  Aggravated Assault  apartment
# 1  2010-01-01 23:00:00  1.500000e+41  Aggravated Assault  apartment
#
#    NumOffenses  Hour  day weekday month  year  \
# 0            1    23    1  Friday   Jan  2010
# 1            1    23    1  Friday   Jan  2010
#
#                             lat_lon                               full_address
# 0         (29.6823316, -95.4169951)  2550 Westridge St, Houston, TX 77054, USA
# 1  (29.6845315, -95.40031289999999)     8350 Knight Rd, Houston, TX 77054, USA

# %%
df4.Beat = '15E40x'
df4.head(2)
# Out:
#              Date_Hour    Beat         OffenseType    Premise  NumOffenses  \
# 0  2010-01-01 23:00:00  15E40x  Aggravated Assault  apartment            1
# 1  2010-01-01 23:00:00  15E40x  Aggravated Assault  apartment            1
#
#    Hour  day weekday month  year                           lat_lon  \
# 0    23    1  Friday   Jan  2010         (29.6823316, -95.4169951)
# 1    23    1  Friday   Jan  2010  (29.6845315, -95.40031289999999)
#
#                                 full_address
# 0  2550 Westridge St, Houston, TX 77054, USA
# 1     8350 Knight Rd, Houston, TX 77054, USA

# %%
df4.lat_lon.value_counts(dropna=False)
# Out:
# (29.68949839999999, -95.4136259)           1223
# (29.6904116, -95.4176631)                   671
# (29.6899253, -95.4143501)                   545
# (29.6851906, -95.3985319)                   494
# (29.7604267, -95.3698028)                   465
# (29.6820484, -95.38725389999999)            456
# (29.6890022, -95.3990941)                   405
# (29.6810444, -95.4221614)                   386
# (29.6821382, -95.41636129999999)            385
# (29.6814768, -95.4253667)                   378
# (29.67808119999999, -95.41922129999999)     343
# (29.6745626, -95.4248057)                   340
# (29.6694014, -95.4201861)                   340
# (29.6856544, -95.4256395)                   316
# (29.680448, -95.42042839999999)             310
# (29.6869435, -95.40331019999999)            299
# (29.68490329999999, -95.3970744)            263
# (29.6823316, -95.4169951)                   260
# (29.6826402, -95.4202601)                   258
# (29.6986054, -95.4032943)                   257
# ...

# %%
df4[['lat','lon']]= df4['lat_lon'].str.extract(r"\((.*?)\)", expand=False).str.split(',',expand=True)
df4[['lat','lon']].dtypes
# Out:
# lat    object
# lon    object
# dtype: object

# %%
df4['lat'] =  pd.to_numeric(df4['lat'])
df4['lon'] =  pd.to_numeric(df4['lon'])

# %%
df4[['lat','lon']].dtypes
# Out:
# lat    float64
# lon    float64
# dtype: object

# %%
df4.head(2)
# Out:
#              Date_Hour    Beat         OffenseType    Premise  NumOffenses  \
# 0  2010-01-01 23:00:00  15E40x  Aggravated Assault  apartment            1
# 1  2010-01-01 23:00:00  15E40x  Aggravated Assault  apartment            1
#
#    Hour  day weekday month  year                           lat_lon  \
# 0    23    1  Friday   Jan  2010         (29.6823316, -95.4169951)
# 1    23    1  Friday   Jan  2010  (29.6845315, -95.40031289999999)
#
#                                 full_address        lat        lon
# 0  2550 Westridge St, Houston, TX 77054, USA  29.682332 -95.416995
# 1     8350 Knight Rd, Houston, TX 77054, USA  29.684531 -95.400313

# %%
df_15E40 = df4[[
 'Date_Hour',
 'Beat',
 'OffenseType',
 'Premise',
 'NumOffenses',
 'Hour',
 'day',
 'weekday',
 'month',
 'year',
 'lat',
 'lon',
 'full_address']]

# %%
df_15E40.head()
# Out:
#              Date_Hour    Beat         OffenseType            Premise  \
# 0  2010-01-01 23:00:00  15E40x  Aggravated Assault          apartment
# 1  2010-01-01 23:00:00  15E40x  Aggravated Assault          apartment
# 2  2010-01-01 23:00:00  15E40x               Theft  convenience store
# 3  2010-01-01 23:00:00  15E40x               Theft  convenience store
# 4  2010-01-02 00:00:00  15E40x               Theft      other/unknown
#
#    NumOffenses  Hour  day   weekday month  year        lat        lon  \
# 0            1    23    1    Friday   Jan  2010  29.682332 -95.416995
# 1            1    23    1    Friday   Jan  2010  29.684531 -95.400313
# 2            1    23    1    Friday   Jan  2010  29.682332 -95.416995
# 3            1    23    1    Friday   Jan  2010  29.684531 -95.400313
# 4            1     0    2  Saturday   Jan  2010  29.685654 -95.425640
#
#                                 full_address
# 0  2550 Westridge St, Houston, TX 77054, USA
# ...

# %%
df_15E40.to_csv('crime_data_clean/df_15E40FINAL.csv')

# %%
ls crime_data_clean
# Out:
# beats_alternate_10_17.csv*      crime_10H70_10_17df_3000.csv*
# beats_filter_10_17.csv*         crime_10H70_10_17df_4000.csv*
# crime_10H10_10_17ADD.csv*       crime_10H70_10_17df_5000.csv*
# crime_10H10_10_17.csv*          crime_10H70_10_17df_6000.csv*
# crime_10H10_10_17df_1000.csv*   crime_10H70_10_17df_7000.csv*
# crime_10H10_10_17df_2000.csv*   crime_10H70_10_17df_8000.csv*
# crime_10H10_10_17df_3000.csv*   crime_10H70_10_17df_9000.csv*
# crime_10H10_10_17df_4000.csv*   crime_10H80_10_17ADD.csv*
# crime_10H30_10_17ADD.csv*       crime_10H80_10_17.csv*
# crime_10H30_10_17.csv*          crime_10H80_10_17FINAL.csv*
# crime_10H30_10_17FINAL.csv*     crime_15E40_10_17ADD.csv*
# crime_10H40_10_17ADD.csv*       crime_15E40_10_17.csv*
# crime_10H40_10_17.csv*          crime_15E40_10_17df_12000.csv*
# crime_10H40_10_17df_10000.csv*  crime_15E40_10_17df_16281.csv*
# crime_10H40_10_17df_1000.csv*   crime_15E40_10_17df_4000.csv*
# ...

# %% [markdown]
# # 10H80_

# %%
path = 'crime_data_clean/crime_10H80_10_17FINAL.csv'
df5 = pd.read_csv(path)
#df2.drop(['Unnamed: 0'],axis=1,inplace=True)
df5.head(2)
# Out:
#              Date_Hour   Beat OffenseType                             Premise  \
# 0  2010-01-03 16:00:00  10H80       Theft  gym,recreat,club hse,indr pool,spa
# 1  2010-01-03 17:00:00  10H80    Burglary     garden supply, nursery, florist
#
#    NumOffenses  Hour  day weekday month  year                    lat_lon  \
# 0            1    16    3  Sunday   Jan  2010   (29.781236, -95.3678655)
# 1            1    17    3  Sunday   Jan  2010  (29.7193942, -95.4151567)
#
#                                   full_address
# 0        2450 South St, Houston, TX 77009, USA
# 1  5150 Morningside Dr, Houston, TX 77005, USA

# %%
df5[['lat','lon']]= df5['lat_lon'].str.extract(r"\((.*?)\)", expand=False).str.split(',',expand=True)
df5[['lat','lon']].dtypes
# Out:
# lat    object
# lon    object
# dtype: object

# %%
df5['lat'] =  pd.to_numeric(df5['lat'])
df5['lon'] =  pd.to_numeric(df5['lon'])

# %%
df5[['lat','lon']].dtypes
# Out:
# lat    float64
# lon    float64
# dtype: object

# %%
df5.head(2)
# Out:
#              Date_Hour   Beat OffenseType                             Premise  \
# 0  2010-01-03 16:00:00  10H80       Theft  gym,recreat,club hse,indr pool,spa
# 1  2010-01-03 17:00:00  10H80    Burglary     garden supply, nursery, florist
#
#    NumOffenses  Hour  day weekday month  year                    lat_lon  \
# 0            1    16    3  Sunday   Jan  2010   (29.781236, -95.3678655)
# 1            1    17    3  Sunday   Jan  2010  (29.7193942, -95.4151567)
#
#                                   full_address        lat        lon
# 0        2450 South St, Houston, TX 77009, USA  29.781236 -95.367866
# 1  5150 Morningside Dr, Houston, TX 77005, USA  29.719394 -95.415157

# %%
df_10H80 = df5[[
 'Date_Hour',
 'Beat',
 'OffenseType',
 'Premise',
 'NumOffenses',
 'Hour',
 'day',
 'weekday',
 'month',
 'year',
 'lat',
 'lon',
 'full_address']]

# %%
df_10H80.head()
# Out:
#              Date_Hour   Beat OffenseType                             Premise  \
# 0  2010-01-03 16:00:00  10H80       Theft  gym,recreat,club hse,indr pool,spa
# 1  2010-01-03 17:00:00  10H80    Burglary     garden supply, nursery, florist
# 2  2010-01-03 22:00:00  10H80       Theft                            driveway
# 3  2010-01-03 22:00:00  10H80       Theft                            driveway
# 4  2010-01-03 22:00:00  10H80       Theft                            driveway
#
#    NumOffenses  Hour  day weekday month  year        lat        lon  \
# 0            1    16    3  Sunday   Jan  2010  29.781236 -95.367866
# 1            1    17    3  Sunday   Jan  2010  29.719394 -95.415157
# 2            1    22    3  Sunday   Jan  2010  29.728945 -95.405608
# 3            1    22    3  Sunday   Jan  2010  29.730343 -95.406391
# 4            1    22    3  Sunday   Jan  2010  29.728945 -95.405608
#
#                                   full_address
# ...

# %%
df_10H80.to_csv('crime_data_clean/df_10H80FINAL.csv')
