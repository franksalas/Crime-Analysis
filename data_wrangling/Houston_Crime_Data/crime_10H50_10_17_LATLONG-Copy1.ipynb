# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import googlemaps
import gmaps
import requests
API_KEY = 'your_apikey'

import gmaps_func as gf

# %%
path = 'crime_data_clean/crime_10H50_10_17.csv'
df = pd.read_csv(path,index_col='Date_Hour', parse_dates=True)

# %%
df.head()
# Out:
#                       Beat BlockRange StreetName         OffenseType  \
# Date_Hour
# 2010-01-01 09:00:00  10H50  3400-3499      NAGLE               Theft
# 2010-01-01 12:00:00  10H50  2600-2699   TRUXILLO            Burglary
# 2010-01-01 12:00:00  10H50  3400-3499    ROSALIE               Theft
# 2010-01-01 18:00:00  10H50  3100-3199      ENNIS  Aggravated Assault
# 2010-01-01 21:00:00  10H50  3400-3499    ROSALIE  Aggravated Assault
#
#                                                                Premise  \
# Date_Hour
# 2010-01-01 09:00:00                                    residence/house
# 2010-01-01 12:00:00  vacant single occupancy residence (houses,town...
# 2010-01-01 12:00:00                                    residence/house
# 2010-01-01 18:00:00                               road/street/sidewalk
# 2010-01-01 21:00:00                 multi-plex hme(duplex,triplex etc)
#
#                      NumOffenses  Hour  day weekday month  year
# Date_Hour
# 2010-01-01 09:00:00            1     9    1  Friday   Jan  2010
# 2010-01-01 12:00:00            1    12    1  Friday   Jan  2010
# 2010-01-01 12:00:00            1    12    1  Friday   Jan  2010
# 2010-01-01 18:00:00            1    18    1  Friday   Jan  2010
# 2010-01-01 21:00:00            1    21    1  Friday   Jan  2010

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8017 entries, 2010-01-01 09:00:00 to 2017-12-30 10:00:00
# Data columns (total 11 columns):
# Beat           8017 non-null object
# BlockRange     8017 non-null object
# StreetName     8017 non-null object
# OffenseType    8017 non-null object
# Premise        8017 non-null object
# NumOffenses    8017 non-null int64
# Hour           8017 non-null int64
# day            8017 non-null int64
# weekday        8017 non-null object
# month          8017 non-null object
# year           8017 non-null int64
# dtypes: int64(4), object(7)
# memory usage: 751.6+ KB

# %% [markdown]
# ## Return a good blockrange value

# %%
gf.block_split(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-015b151337a5> in <module>()
# ----> 1 gf.block_split(df)
#
# /mnt/c/Users/frank/Documents/linux_dev/springboardCapstone/data_wrangling/Houston_Crime_Data/gmaps_func.py in block_split(df)
#       9     then give median value as a string
#      10     '''
# ---> 11     first = df.BlockRange.str.split(pat='-',expand=True)[0].astype('int')
#      12     second = df.BlockRange.str.split(pat='-',expand=True)[1].astype('int')
#      13     med = np.ceil((second + first)/2).astype('int')
#
# ~/miniconda3/envs/springboard/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# ~/miniconda3/envs/springboard/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4002         # else, only a single dtype is given
#    4003         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4004                                      **kwargs)
#    4005         return self._constructor(new_data).__finalize__(self)
#    4006
#
# ~/miniconda3/envs/springboard/lib/python3.6/site-packages/pandas/core/internals.py in astype(self, dtype, **kwargs)
#    3460
#    3461     def astype(self, dtype, **kwargs):
# -> 3462         return self.apply('astype', dtype=dtype, **kwargs)
#    3463
#    3464     def convert(self, **kwargs):
#
# ~/miniconda3/envs/springboard/lib/python3.6/site-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3327
#    3328             kwargs['mgr'] = self
# -> 3329             applied = getattr(b, f)(**kwargs)
#    3330             result_blocks = _extend_blocks(applied, result_blocks)
#    3331
#
# ~/miniconda3/envs/springboard/lib/python3.6/site-packages/pandas/core/internals.py in astype(self, dtype, copy, errors, values, **kwargs)
#     542     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     543         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 544                             **kwargs)
#     545
#     546     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# ~/miniconda3/envs/springboard/lib/python3.6/site-packages/pandas/core/internals.py in _astype(self, dtype, copy, errors, values, klass, mgr, **kwargs)
#     623
#     624                 # _astype_nansafe works fine with 1-d only
# --> 625                 values = astype_nansafe(values.ravel(), dtype, copy=True)
#     626                 values = values.reshape(self.shape)
#     627
#
# ~/miniconda3/envs/springboard/lib/python3.6/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy)
#     690     elif arr.dtype == np.object_ and np.issubdtype(dtype.type, np.integer):
#     691         # work around NumPy brokenness, #1987
# --> 692         return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     693
#     694     if dtype.name in ("datetime64", "timedelta64"):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# pandas/_libs/src/util.pxd in util.set_value_at_unsafe()
#
# ValueError: invalid literal for int() with base 10: 'UNK'

# %% [markdown]
# ## Drop 'UNK' values

# %%
unk = df.BlockRange == 'UNK'

# %%
df = df[~unk]

# %%
df.head()
# Out:
#                       Beat BlockRange StreetName         OffenseType  \
# Date_Hour
# 2010-01-01 09:00:00  10H50  3400-3499      NAGLE               Theft
# 2010-01-01 12:00:00  10H50  2600-2699   TRUXILLO            Burglary
# 2010-01-01 12:00:00  10H50  3400-3499    ROSALIE               Theft
# 2010-01-01 18:00:00  10H50  3100-3199      ENNIS  Aggravated Assault
# 2010-01-01 21:00:00  10H50  3400-3499    ROSALIE  Aggravated Assault
#
#                                                                Premise  \
# Date_Hour
# 2010-01-01 09:00:00                                    residence/house
# 2010-01-01 12:00:00  vacant single occupancy residence (houses,town...
# 2010-01-01 12:00:00                                    residence/house
# 2010-01-01 18:00:00                               road/street/sidewalk
# 2010-01-01 21:00:00                 multi-plex hme(duplex,triplex etc)
#
#                      NumOffenses  Hour  day weekday month  year
# Date_Hour
# 2010-01-01 09:00:00            1     9    1  Friday   Jan  2010
# 2010-01-01 12:00:00            1    12    1  Friday   Jan  2010
# 2010-01-01 12:00:00            1    12    1  Friday   Jan  2010
# 2010-01-01 18:00:00            1    18    1  Friday   Jan  2010
# 2010-01-01 21:00:00            1    21    1  Friday   Jan  2010

# %%
df['block'] = gf.block_split(df)
# Out:
# /home/salas/miniconda3/envs/springboard/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#                       Beat BlockRange StreetName         OffenseType  \
# Date_Hour
# 2010-01-01 09:00:00  10H50  3400-3499      NAGLE               Theft
# 2010-01-01 12:00:00  10H50  2600-2699   TRUXILLO            Burglary
# 2010-01-01 12:00:00  10H50  3400-3499    ROSALIE               Theft
# 2010-01-01 18:00:00  10H50  3100-3199      ENNIS  Aggravated Assault
# 2010-01-01 21:00:00  10H50  3400-3499    ROSALIE  Aggravated Assault
#
#                                                                Premise  \
# Date_Hour
# 2010-01-01 09:00:00                                    residence/house
# 2010-01-01 12:00:00  vacant single occupancy residence (houses,town...
# 2010-01-01 12:00:00                                    residence/house
# 2010-01-01 18:00:00                               road/street/sidewalk
# 2010-01-01 21:00:00                 multi-plex hme(duplex,triplex etc)
#
#                      NumOffenses  Hour  day weekday month  year block
# Date_Hour
# 2010-01-01 09:00:00            1     9    1  Friday   Jan  2010  3450
# 2010-01-01 12:00:00            1    12    1  Friday   Jan  2010  2650
# 2010-01-01 12:00:00            1    12    1  Friday   Jan  2010  3450
# 2010-01-01 18:00:00            1    18    1  Friday   Jan  2010  3150
# 2010-01-01 21:00:00            1    21    1  Friday   Jan  2010  3450

# %% [markdown]
# ## Create full addres col

# %%
df['address']  = df[['block', 'StreetName']].apply(lambda x: ' '.join(x), axis=1)
# Out:
# /home/salas/miniconda3/envs/springboard/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#                       Beat BlockRange StreetName         OffenseType  \
# Date_Hour
# 2010-01-01 09:00:00  10H50  3400-3499      NAGLE               Theft
# 2010-01-01 12:00:00  10H50  2600-2699   TRUXILLO            Burglary
# 2010-01-01 12:00:00  10H50  3400-3499    ROSALIE               Theft
# 2010-01-01 18:00:00  10H50  3100-3199      ENNIS  Aggravated Assault
# 2010-01-01 21:00:00  10H50  3400-3499    ROSALIE  Aggravated Assault
#
#                                                                Premise  \
# Date_Hour
# 2010-01-01 09:00:00                                    residence/house
# 2010-01-01 12:00:00  vacant single occupancy residence (houses,town...
# 2010-01-01 12:00:00                                    residence/house
# 2010-01-01 18:00:00                               road/street/sidewalk
# 2010-01-01 21:00:00                 multi-plex hme(duplex,triplex etc)
#
#                      NumOffenses  Hour  day weekday month  year block  \
# Date_Hour
# 2010-01-01 09:00:00            1     9    1  Friday   Jan  2010  3450
# 2010-01-01 12:00:00            1    12    1  Friday   Jan  2010  2650
# 2010-01-01 12:00:00            1    12    1  Friday   Jan  2010  3450
# 2010-01-01 18:00:00            1    18    1  Friday   Jan  2010  3150
# 2010-01-01 21:00:00            1    21    1  Friday   Jan  2010  3450
#
#                            address
# Date_Hour
# 2010-01-01 09:00:00     3450 NAGLE
# 2010-01-01 12:00:00  2650 TRUXILLO
# 2010-01-01 12:00:00   3450 ROSALIE
# 2010-01-01 18:00:00     3150 ENNIS
# 2010-01-01 21:00:00   3450 ROSALIE

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7987 entries, 2010-01-01 09:00:00 to 2017-12-30 10:00:00
# Data columns (total 13 columns):
# Beat           7987 non-null object
# BlockRange     7987 non-null object
# StreetName     7987 non-null object
# OffenseType    7987 non-null object
# Premise        7987 non-null object
# NumOffenses    7987 non-null int64
# Hour           7987 non-null int64
# day            7987 non-null int64
# weekday        7987 non-null object
# month          7987 non-null object
# year           7987 non-null int64
# block          7987 non-null object
# address        7987 non-null object
# dtypes: int64(4), object(9)
# memory usage: 1.2+ MB

# %%
df.head()
# Out:
#                       Beat BlockRange StreetName         OffenseType  \
# Date_Hour
# 2010-01-01 09:00:00  10H50  3400-3499      NAGLE               Theft
# 2010-01-01 12:00:00  10H50  2600-2699   TRUXILLO            Burglary
# 2010-01-01 12:00:00  10H50  3400-3499    ROSALIE               Theft
# 2010-01-01 18:00:00  10H50  3100-3199      ENNIS  Aggravated Assault
# 2010-01-01 21:00:00  10H50  3400-3499    ROSALIE  Aggravated Assault
#
#                                                                Premise  \
# Date_Hour
# 2010-01-01 09:00:00                                    residence/house
# 2010-01-01 12:00:00  vacant single occupancy residence (houses,town...
# 2010-01-01 12:00:00                                    residence/house
# 2010-01-01 18:00:00                               road/street/sidewalk
# 2010-01-01 21:00:00                 multi-plex hme(duplex,triplex etc)
#
#                      NumOffenses  Hour  day weekday month  year block  \
# Date_Hour
# 2010-01-01 09:00:00            1     9    1  Friday   Jan  2010  3450
# 2010-01-01 12:00:00            1    12    1  Friday   Jan  2010  2650
# 2010-01-01 12:00:00            1    12    1  Friday   Jan  2010  3450
# 2010-01-01 18:00:00            1    18    1  Friday   Jan  2010  3150
# 2010-01-01 21:00:00            1    21    1  Friday   Jan  2010  3450
#
#                            address
# Date_Hour
# 2010-01-01 09:00:00     3450 NAGLE
# 2010-01-01 12:00:00  2650 TRUXILLO
# 2010-01-01 12:00:00   3450 ROSALIE
# 2010-01-01 18:00:00     3150 ENNIS
# 2010-01-01 21:00:00   3450 ROSALIE

# %% [markdown]
# # get full lat long and address from google

# %%
df['tup_add'] = df['address'].apply(gf.gm_geocode,args=(API_KEY,))

# %%
df_100 = df.iloc[:100].copy()
df_20 = df.iloc[:20].copy()
df_30 = df.iloc[:30].copy()

# %% [markdown]
# ## Test

# %%
df_20 = df.iloc[:20].copy()
df_20['tup_add'] = df_20['address'].apply(gf.gm_geocode,args=(API_KEY,))
df_20.head()

# %% [markdown]
# ## Attempt

# %%
# 4:33
df['tup_add'] = df['address'].apply(gf.gm_geocode,args=(API_KEY,))
df.head()
# Out:
# /home/salas/miniconda3/envs/springboard/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                       Beat BlockRange StreetName         OffenseType  \
# Date_Hour
# 2010-01-01 09:00:00  10H50  3400-3499      NAGLE               Theft
# 2010-01-01 12:00:00  10H50  2600-2699   TRUXILLO            Burglary
# 2010-01-01 12:00:00  10H50  3400-3499    ROSALIE               Theft
# 2010-01-01 18:00:00  10H50  3100-3199      ENNIS  Aggravated Assault
# 2010-01-01 21:00:00  10H50  3400-3499    ROSALIE  Aggravated Assault
#
#                                                                Premise  \
# Date_Hour
# 2010-01-01 09:00:00                                    residence/house
# 2010-01-01 12:00:00  vacant single occupancy residence (houses,town...
# 2010-01-01 12:00:00                                    residence/house
# 2010-01-01 18:00:00                               road/street/sidewalk
# 2010-01-01 21:00:00                 multi-plex hme(duplex,triplex etc)
#
#                      NumOffenses  Hour  day weekday month  year block  \
# Date_Hour
# 2010-01-01 09:00:00            1     9    1  Friday   Jan  2010  3450
# 2010-01-01 12:00:00            1    12    1  Friday   Jan  2010  2650
# 2010-01-01 12:00:00            1    12    1  Friday   Jan  2010  3450
# 2010-01-01 18:00:00            1    18    1  Friday   Jan  2010  3150
# 2010-01-01 21:00:00            1    21    1  Friday   Jan  2010  3450
#
#                            address  \
# Date_Hour
# 2010-01-01 09:00:00     3450 NAGLE
# 2010-01-01 12:00:00  2650 TRUXILLO
# 2010-01-01 12:00:00   3450 ROSALIE
# 2010-01-01 18:00:00     3150 ENNIS
# 2010-01-01 21:00:00   3450 ROSALIE
#
#                                                                tup_add
# Date_Hour
# 2010-01-01 09:00:00  ((29.731311, -95.36411439999999), 3450 Nagle S...
# 2010-01-01 12:00:00  ((29.728306, -95.36597750000001), 2650 Truxill...
# 2010-01-01 12:00:00  ((29.7294834, -95.3507063), 3450 Rosalie St, H...
# 2010-01-01 18:00:00  ((29.7315931, -95.3599416), 3150 Ennis St, Hou...
# 2010-01-01 21:00:00  ((29.7294834, -95.3507063), 3450 Rosalie St, H...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7987 entries, 2010-01-01 09:00:00 to 2017-12-30 10:00:00
# Data columns (total 14 columns):
# Beat           7987 non-null object
# BlockRange     7987 non-null object
# StreetName     7987 non-null object
# OffenseType    7987 non-null object
# Premise        7987 non-null object
# NumOffenses    7987 non-null int64
# Hour           7987 non-null int64
# day            7987 non-null int64
# weekday        7987 non-null object
# month          7987 non-null object
# year           7987 non-null int64
# block          7987 non-null object
# address        7987 non-null object
# tup_add        7987 non-null object
# dtypes: int64(4), object(10)
# memory usage: 1.2+ MB

# %%
df.to_csv('crime_data_clean/crime_10H50_10_17ADD.csv')

# %%
df.head()
# Out:
#                       Beat BlockRange StreetName         OffenseType  \
# Date_Hour
# 2010-01-01 09:00:00  10H50  3400-3499      NAGLE               Theft
# 2010-01-01 12:00:00  10H50  2600-2699   TRUXILLO            Burglary
# 2010-01-01 12:00:00  10H50  3400-3499    ROSALIE               Theft
# 2010-01-01 18:00:00  10H50  3100-3199      ENNIS  Aggravated Assault
# 2010-01-01 21:00:00  10H50  3400-3499    ROSALIE  Aggravated Assault
#
#                                                                Premise  \
# Date_Hour
# 2010-01-01 09:00:00                                    residence/house
# 2010-01-01 12:00:00  vacant single occupancy residence (houses,town...
# 2010-01-01 12:00:00                                    residence/house
# 2010-01-01 18:00:00                               road/street/sidewalk
# 2010-01-01 21:00:00                 multi-plex hme(duplex,triplex etc)
#
#                      NumOffenses  Hour  day weekday month  year block  \
# Date_Hour
# 2010-01-01 09:00:00            1     9    1  Friday   Jan  2010  3450
# 2010-01-01 12:00:00            1    12    1  Friday   Jan  2010  2650
# 2010-01-01 12:00:00            1    12    1  Friday   Jan  2010  3450
# 2010-01-01 18:00:00            1    18    1  Friday   Jan  2010  3150
# 2010-01-01 21:00:00            1    21    1  Friday   Jan  2010  3450
#
#                            address  \
# Date_Hour
# 2010-01-01 09:00:00     3450 NAGLE
# 2010-01-01 12:00:00  2650 TRUXILLO
# 2010-01-01 12:00:00   3450 ROSALIE
# 2010-01-01 18:00:00     3150 ENNIS
# 2010-01-01 21:00:00   3450 ROSALIE
#
#                                                                tup_add
# Date_Hour
# 2010-01-01 09:00:00  ((29.731311, -95.36411439999999), 3450 Nagle S...
# 2010-01-01 12:00:00  ((29.728306, -95.36597750000001), 2650 Truxill...
# 2010-01-01 12:00:00  ((29.7294834, -95.3507063), 3450 Rosalie St, H...
# 2010-01-01 18:00:00  ((29.7315931, -95.3599416), 3150 Ennis St, Hou...
# 2010-01-01 21:00:00  ((29.7294834, -95.3507063), 3450 Rosalie St, H...

# %%
new_add = df.tup_add.apply(pd.Series,index=['lat_lon','full_address'])

# %%
new_add.head()
# Out:
#                                              lat_lon  \
# Date_Hour
# 2010-01-01 09:00:00  (29.731311, -95.36411439999999)
# 2010-01-01 12:00:00  (29.728306, -95.36597750000001)
# 2010-01-01 12:00:00        (29.7294834, -95.3507063)
# 2010-01-01 18:00:00        (29.7315931, -95.3599416)
# 2010-01-01 21:00:00        (29.7294834, -95.3507063)
#
#                                                  full_address
# Date_Hour
# 2010-01-01 09:00:00     3450 Nagle St, Houston, TX 77004, USA
# 2010-01-01 12:00:00  2650 Truxillo St, Houston, TX 77004, USA
# 2010-01-01 12:00:00   3450 Rosalie St, Houston, TX 77004, USA
# 2010-01-01 18:00:00     3150 Ennis St, Houston, TX 77004, USA
# 2010-01-01 21:00:00   3450 Rosalie St, Houston, TX 77004, USA

# %%
df = df.join(new_add)

# %%
df.drop(['block','BlockRange','StreetName','address','tup_add','address','tup_add',],axis=1,inplace=True)

# %%
#df.drop('block', axis=1,inplace=True)

# %%
df.head()
# Out:
#                       Beat OffenseType  \
# Date_Hour
# 2010-01-01 09:00:00  10H50       Theft
# 2010-01-01 12:00:00  10H50    Burglary
# 2010-01-01 12:00:00  10H50    Burglary
# 2010-01-01 12:00:00  10H50       Theft
# 2010-01-01 12:00:00  10H50       Theft
#
#                                                                Premise  \
# Date_Hour
# 2010-01-01 09:00:00                                    residence/house
# 2010-01-01 12:00:00  vacant single occupancy residence (houses,town...
# 2010-01-01 12:00:00  vacant single occupancy residence (houses,town...
# 2010-01-01 12:00:00                                    residence/house
# 2010-01-01 12:00:00                                    residence/house
#
#                      NumOffenses  Hour  day weekday month  year  \
# Date_Hour
# 2010-01-01 09:00:00            1     9    1  Friday   Jan  2010
# 2010-01-01 12:00:00            1    12    1  Friday   Jan  2010
# 2010-01-01 12:00:00            1    12    1  Friday   Jan  2010
# 2010-01-01 12:00:00            1    12    1  Friday   Jan  2010
# 2010-01-01 12:00:00            1    12    1  Friday   Jan  2010
#
#                                              lat_lon  \
# Date_Hour
# 2010-01-01 09:00:00  (29.731311, -95.36411439999999)
# 2010-01-01 12:00:00  (29.728306, -95.36597750000001)
# 2010-01-01 12:00:00        (29.7294834, -95.3507063)
# 2010-01-01 12:00:00  (29.728306, -95.36597750000001)
# 2010-01-01 12:00:00        (29.7294834, -95.3507063)
#
#                                                  full_address
# Date_Hour
# 2010-01-01 09:00:00     3450 Nagle St, Houston, TX 77004, USA
# 2010-01-01 12:00:00  2650 Truxillo St, Houston, TX 77004, USA
# 2010-01-01 12:00:00   3450 Rosalie St, Houston, TX 77004, USA
# 2010-01-01 12:00:00  2650 Truxillo St, Houston, TX 77004, USA
# 2010-01-01 12:00:00   3450 Rosalie St, Houston, TX 77004, USA

# %%
df.to_csv('crime_data_clean/crime_10H50_10_17FINAL.csv')
