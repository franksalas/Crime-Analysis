# %%
import pandas as pd
import numpy as np

# %%
data =  'crime_data_clean/crime_final_clean10_17.csv'

# %%
df = pd.read_csv(data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1003727 entries, 0 to 1003726
# Data columns (total 12 columns):
# Date_Hour      1003727 non-null object
# Beat           1003727 non-null object
# BlockRange     1003571 non-null object
# StreetName     1003725 non-null object
# OffenseType    1003727 non-null object
# Premise        1003727 non-null object
# NumOffenses    1003727 non-null int64
# Hour           1003727 non-null int64
# day            1003727 non-null int64
# weekday        1003727 non-null object
# month          1003727 non-null object
# year           1003727 non-null int64
# dtypes: int64(4), object(8)
# memory usage: 91.9+ MB

# %%
# date
df.Date_Hour = pd.to_datetime(df.Date_Hour)
df = df.set_index('Date_Hour').sort_index(ascending=True)

# %%
df.head()
# Out:
#              Beat   BlockRange    StreetName         OffenseType  \
# Date_Hour
# 2010-01-01  10H10      500-599      EASTWOOD            Burglary
# 2010-01-01   4F20    4800-4899    LAURELDALE  Aggravated Assault
# 2010-01-01   1A10      300-399      HAMILTON          Auto Theft
# 2010-01-01  24C40  24000-24099  LAKE HOUSTON          Auto Theft
# 2010-01-01  24C10  21700-21799     LAKEPOINT               Theft
#
#                                   Premise  NumOffenses  Hour  day weekday  \
# Date_Hour
# 2010-01-01  misc. business (non-specific)            1     0    1  Friday
# 2010-01-01                residence/house            1     0    1  Friday
# 2010-01-01     bar/night club parking lot            1     0    1  Friday
# 2010-01-01           road/street/sidewalk            1     0    1  Friday
# 2010-01-01                residence/house            1     0    1  Friday
#
#            month  year
# Date_Hour
# 2010-01-01   Jan  2010
# 2010-01-01   Jan  2010
# ...

# %% [markdown]
# ## Select Beats
# - create list with select police beats where selected stadiums are located
# - filter dataframe with those beats

# %%
selected_beats = ['1A10','10H30','10H50','10H80','15E40' ]

# %%
sel_df = df[df['Beat'].isin(selected_beats)]

# %%
sel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 51606 entries, 2010-01-01 00:00:00 to 2017-12-31 22:00:00
# Data columns (total 11 columns):
# Beat           51606 non-null object
# BlockRange     51484 non-null object
# StreetName     51606 non-null object
# OffenseType    51606 non-null object
# Premise        51606 non-null object
# NumOffenses    51606 non-null int64
# Hour           51606 non-null int64
# day            51606 non-null int64
# weekday        51606 non-null object
# month          51606 non-null object
# year           51606 non-null int64
# dtypes: int64(4), object(7)
# memory usage: 4.7+ MB

# %% [markdown]
# ## Inspect BlockRange

# %%
len(sel_df[sel_df.BlockRange.isnull()])
# Out:
# 122

# %%
sel_df[sel_df.BlockRange.isnull()].head()
# Out:
#                      Beat BlockRange             StreetName OffenseType  \
# Date_Hour
# 2013-06-11 11:00:00  1A10        NaN                  HAYES       Theft
# 2013-06-29 15:00:00  1A10        NaN                   RUSK       Theft
# 2013-11-23 08:00:00  1A10        NaN           METROPOLITAN       Theft
# 2014-01-01 13:00:00  1A10        NaN             TIDWELL RD       Theft
# 2014-04-21 14:00:00  1A10        NaN  HUNTINGTON VENTURE DR       Theft
#
#                       Premise  NumOffenses  Hour  day    weekday month  year
# Date_Hour
# 2013-06-11 11:00:00  no label            1    11   11    Tuesday   Jun  2013
# 2013-06-29 15:00:00  no label            1    15   29   Saturday   Jun  2013
# 2013-11-23 08:00:00  no label            1     8   23   Saturday   Nov  2013
# 2014-01-01 13:00:00  no label            1    13    1  Wednesday   Jan  2014
# 2014-04-21 14:00:00  no label            1    14   21     Monday   Apr  2014

# %%
sel_df.Beat.value_counts(dropna=False)
# Out:
# 15E40    16386
# 1A10     15325
# 10H50     8017
# 10H80     7480
# 10H30     4398
# Name: Beat, dtype: int64

# %%
sel_df = sel_df.dropna(subset=['BlockRange'])

# %%
len(sel_df[sel_df.BlockRange.isnull()])
# Out:
# 0

# %%
sel_df.Beat.value_counts(dropna=False)
# Out:
# 15E40    16386
# 1A10     15204
# 10H50     8017
# 10H80     7479
# 10H30     4398
# Name: Beat, dtype: int64

# %% [markdown]
# ----

# %% [markdown]
# # Save Final Clean Data

# %%
sel_df.to_csv('crime_data_clean/beats_filter_10_17.csv')

# %%
sel_df.Beat.unique()
# Out:
# array(['1A10', '10H30', '10H50', '15E40', '10H80'], dtype=object)

# %%
crime_10H50_10_17 = sel_df[sel_df.Beat =='10H50']
crime_1A10_10_17 = sel_df[sel_df.Beat =='1A10']
crime_10H80_10_17 = sel_df[sel_df.Beat =='10H80']
crime_15E40_10_17 = sel_df[sel_df.Beat =='15E40']
crime_10H30_10_17 = sel_df[sel_df.Beat =='10H30']

# %% [markdown]
# # save beat data

# %%
crime_10H50_10_17.to_csv('crime_data_clean/crime_10H50_10_17.csv')
crime_1A10_10_17.to_csv('crime_data_clean/crime_1A10_10_17.csv')
crime_10H80_10_17.to_csv('crime_data_clean/crime_10H80_10_17.csv')
crime_15E40_10_17.to_csv('crime_data_clean/crime_15E40_10_17.csv')
crime_10H30_10_17.to_csv('crime_data_clean/crime_10H30_10_17.csv')

# %%
ls crime_data_clean/
# Out:
# beats_filter_10_17.csv*  crime_final_clean10_17.csv*
# crime_10H30_10_17.csv*   new/
# crime_10H50_10_17.csv*   stadium_beats_geocode.csv*
# crime_10H80_10_17.csv*   stadiums_final.csv*
# crime_15E40_10_17.csv*   years/
# crime_1A10_10_17.csv*

# %%
crime_10H80_10_17
# Out:
#                       Beat BlockRange        StreetName OffenseType  \
# Date_Hour
# 2010-01-03 16:00:00  10H80  2400-2499             SOUTH       Theft
# 2010-01-03 17:00:00  10H80  5100-5199       MORNINGSIDE    Burglary
# 2010-01-03 22:00:00  10H80  1800-1899           MILFORD       Theft
# 2010-01-03 22:00:00  10H80  1900-1999            VASSAR       Theft
# 2010-01-04 17:00:00  10H80  2400-2499        UNIVERSITY       Theft
# 2010-01-04 18:00:00  10H80  2300-2399        WORDSWORTH       Theft
# 2010-01-05 13:00:00  10H80    800-899          ROSEDALE       Theft
# 2010-01-05 15:00:00  10H80  2500-2599         ROBINHOOD       Theft
# 2010-01-05 20:00:00  10H80  2300-2399             SWIFT    Burglary
# 2010-01-06 00:00:00  10H80  2300-2399          SHERIDAN       Theft
# 2010-01-06 10:00:00  10H80  2500-2599             TIMES       Theft
# 2010-01-06 22:00:00  10H80  6900-6999              MAIN     Robbery
# 2010-01-07 12:00:00  10H80  2500-2599        UNIVERSITY       Theft
# ...
