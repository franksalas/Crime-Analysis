# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path =  'data/ready/bas.csv'

# %%
bas = pd.read_csv(path, index_col='days',parse_dates=True)

# %%
bas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2923 entries, 2010-01-01 to 2017-12-31
# Data columns (total 4 columns):
# crime    2923 non-null int64
# game     2923 non-null int64
# beat     2923 non-null object
# sport    2923 non-null object
# dtypes: int64(2), object(2)
# memory usage: 114.2+ KB

# %%
bas[bas.game== 1]
# Out:
#             crime  game  beat sport
# days
# 2010-04-05     12     1  1A10   bas
# 2010-04-06      7     1  1A10   bas
# 2010-04-07      6     1  1A10   bas
# 2010-04-09      9     1  1A10   bas
# 2010-04-10      9     1  1A10   bas
# 2010-04-11      6     1  1A10   bas
# 2010-04-20      2     1  1A10   bas
# 2010-04-21      1     1  1A10   bas
# 2010-04-22      7     1  1A10   bas
# 2010-04-23      8     1  1A10   bas
# 2010-04-24      5     1  1A10   bas
# 2010-04-25      6     1  1A10   bas
# 2010-04-27      8     1  1A10   bas
# 2010-04-28      2     1  1A10   bas
# 2010-04-29      9     1  1A10   bas
# 2010-05-03      8     1  1A10   bas
# 2010-05-04      8     1  1A10   bas
# 2010-05-05      2     1  1A10   bas
# 2010-05-06      1     1  1A10   bas
# 2010-05-07     12     1  1A10   bas
# 2010-05-08      7     1  1A10   bas
# 2010-05-09      5     1  1A10   bas
# 2010-05-19      8     1  1A10   bas
# 2010-05-20      9     1  1A10   bas
# 2010-05-21      8     1  1A10   bas
# ...

# %%
bas = bas.add_prefix('baseball_')
bas.head()
# Out:
#             baseball_crime  baseball_game baseball_beat baseball_sport
# days
# 2010-01-01              11              0          1A10            bas
# 2010-01-02              11              0          1A10            bas
# 2010-01-03               8              0          1A10            bas
# 2010-01-04               6              0          1A10            bas
# 2010-01-05               5              0          1A10            bas

# %%
bas = bas.drop(['baseball_beat', 'baseball_sport'], axis=1)

# %%
bas.head()
# Out:
#             baseball_crime  baseball_game
# days
# 2010-01-01              11              0
# 2010-01-02              11              0
# 2010-01-03               8              0
# 2010-01-04               6              0
# 2010-01-05               5              0

# %% [markdown]
# ## SOC

# %%
path =  'data/ready/soc.csv'

# %%
soc = pd.read_csv(path, index_col='days',parse_dates=True)

# %%
soc.head()
# Out:
#             crime  game   beat sport
# days
# 2010-01-01      3     0  10H30   soc
# 2010-01-02      1     0  10H30   soc
# 2010-01-03      2     0  10H30   soc
# 2010-01-04      1     0  10H30   soc
# 2010-01-05      2     0  10H30   soc

# %%
soc = soc.add_prefix('soccer_')
soc.head()
# Out:
#             soccer_crime  soccer_game soccer_beat soccer_sport
# days
# 2010-01-01             3            0       10H30          soc
# 2010-01-02             1            0       10H30          soc
# 2010-01-03             2            0       10H30          soc
# 2010-01-04             1            0       10H30          soc
# 2010-01-05             2            0       10H30          soc

# %%
soc = soc.drop(['soccer_beat', 'soccer_sport'], axis=1)

# %%
soc.head()
# Out:
#             soccer_crime  soccer_game
# days
# 2010-01-01             3            0
# 2010-01-02             1            0
# 2010-01-03             2            0
# 2010-01-04             1            0
# 2010-01-05             2            0

# %% [markdown]
# # bkb

# %%
path =  'data/ready/bkb.csv'
bkb = pd.read_csv(path, index_col='days',parse_dates=True)

# %%
bkb.head()
# Out:
#             crime  game  beat sport
# days
# 2010-01-01     11     0  1A10   bkb
# 2010-01-02     11     0  1A10   bkb
# 2010-01-03      8     0  1A10   bkb
# 2010-01-04      6     0  1A10   bkb
# 2010-01-05      5     0  1A10   bkb

# %%
bkb = bkb.add_prefix('basketball_')
bkb.head()
# Out:
#             basketball_crime  basketball_game basketball_beat basketball_sport
# days
# 2010-01-01                11                0            1A10              bkb
# 2010-01-02                11                0            1A10              bkb
# 2010-01-03                 8                0            1A10              bkb
# 2010-01-04                 6                0            1A10              bkb
# 2010-01-05                 5                0            1A10              bkb

# %%
bkb = bkb.drop(['basketball_beat', 'basketball_sport'], axis=1)

# %%
bkb.head()
# Out:
#             basketball_crime  basketball_game
# days
# 2010-01-01                11                0
# 2010-01-02                11                0
# 2010-01-03                 8                0
# 2010-01-04                 6                0
# 2010-01-05                 5                0

# %% [markdown]
# ## FB

# %%
path =  'data/ready/fb.csv'
fb= pd.read_csv(path, index_col='days',parse_dates=True)

# %%
fb.head()
# Out:
#             crime  game          beat sport
# days
# 2010-01-01      2     0  1.500000e+41    fb
# 2010-01-02      2     0  1.500000e+41    fb
# 2010-01-03      5     1  1.500000e+41    fb
# 2010-01-04      2     0  1.500000e+41    fb
# 2010-01-05      4     0  1.500000e+41    fb

# %%
fb = fb.add_prefix('football_')
fb.head()
# Out:
#             football_crime  football_game  football_beat football_sport
# days
# 2010-01-01               2              0   1.500000e+41             fb
# 2010-01-02               2              0   1.500000e+41             fb
# 2010-01-03               5              1   1.500000e+41             fb
# 2010-01-04               2              0   1.500000e+41             fb
# 2010-01-05               4              0   1.500000e+41             fb

# %%
fb = fb.drop(['football_beat','football_sport'], axis=1)

# %%
fb.head()
# Out:
#             football_crime  football_game
# days
# 2010-01-01               2              0
# 2010-01-02               2              0
# 2010-01-03               5              1
# 2010-01-04               2              0
# 2010-01-05               4              0

# %% [markdown]
# ## CFB

# %%
path =  'data/ready/cfbUH.csv'
cfbUH= pd.read_csv(path, index_col='days',parse_dates=True)

# %%
cfbUH.head()
# Out:
#             crime  game   beat sport
# days
# 2010-01-01      5     0  10H50   cfb
# 2010-01-02      0     0  10H50   cfb
# 2010-01-03      1     0  10H50   cfb
# 2010-01-04      6     0  10H50   cfb
# 2010-01-05      1     0  10H50   cfb

# %%
cfbUH = cfbUH.add_prefix('CFBUH_')
cfbUH.head()
# Out:
#             CFBUH_crime  CFBUH_game CFBUH_beat CFBUH_sport
# days
# 2010-01-01            5           0      10H50         cfb
# 2010-01-02            0           0      10H50         cfb
# 2010-01-03            1           0      10H50         cfb
# 2010-01-04            6           0      10H50         cfb
# 2010-01-05            1           0      10H50         cfb

# %%
cfbUH = cfbUH.drop(['CFBUH_beat','CFBUH_sport'], axis=1)

# %%
cfbUH.head()
# Out:
#             CFBUH_crime  CFBUH_game
# days
# 2010-01-01            5           0
# 2010-01-02            0           0
# 2010-01-03            1           0
# 2010-01-04            6           0
# 2010-01-05            1           0

# %%
path =  'data/ready/cfbRU.csv'
cfbRU= pd.read_csv(path, index_col='days',parse_dates=True)

# %%
cfbRU.head()
# Out:
#             crime  game   beat sport
# days
# 2010-01-01      0     0  10H80   cfb
# 2010-01-02      0     0  10H80   cfb
# 2010-01-03      4     0  10H80   cfb
# 2010-01-04      2     0  10H80   cfb
# 2010-01-05      3     0  10H80   cfb

# %%
cfbRU = cfbRU.add_prefix('CFBRU_')
cfbRU.head()
# Out:
#             CFBRU_crime  CFBRU_game CFBRU_beat CFBRU_sport
# days
# 2010-01-01            0           0      10H80         cfb
# 2010-01-02            0           0      10H80         cfb
# 2010-01-03            4           0      10H80         cfb
# 2010-01-04            2           0      10H80         cfb
# 2010-01-05            3           0      10H80         cfb

# %%
cfbRU = cfbRU.drop(['CFBRU_beat','CFBRU_sport'], axis=1)

# %%
cfbRU.head()
# Out:
#             CFBRU_crime  CFBRU_game
# days
# 2010-01-01            0           0
# 2010-01-02            0           0
# 2010-01-03            4           0
# 2010-01-04            2           0
# 2010-01-05            3           0

# %%
top = bkb.join([bas,soc,fb,cfbUH,cfbRU])
top.head()
# Out:
#             basketball_crime  basketball_game  baseball_crime  baseball_game  \
# days
# 2010-01-01                11                0              11              0
# 2010-01-02                11                0              11              0
# 2010-01-03                 8                0               8              0
# 2010-01-04                 6                0               6              0
# 2010-01-05                 5                0               5              0
#
#             soccer_crime  soccer_game  football_crime  football_game  \
# days
# 2010-01-01             3            0               2              0
# 2010-01-02             1            0               2              0
# 2010-01-03             2            0               5              1
# 2010-01-04             1            0               2              0
# 2010-01-05             2            0               4              0
#
#             CFBUH_crime  CFBUH_game  CFBRU_crime  CFBRU_game
# days
# ...

# %%
 ax = sns.heatmap(top)

# %%
top.head()

# %%
top.basketball_crime.plot()
top.soccer_crime.plot()
#top.baseball_crime.plot()

# %%
top.corr()
# Out:
#                   basketball_crime  basketball_game  baseball_crime  \
# basketball_crime          1.000000         0.044915        1.000000
# basketball_game           0.044915         1.000000        0.044915
# baseball_crime            1.000000         0.044915        1.000000
# baseball_game             0.103924        -0.137524        0.103924
# soccer_crime              0.096175        -0.016313        0.096175
# soccer_game               0.022985        -0.058488        0.022985
# football_crime            0.006437         0.029507        0.006437
# football_game             0.003751        -0.019724        0.003751
# CFBUH_crime               0.007559        -0.007019        0.007559
# CFBUH_game                0.026994         0.020950        0.026994
# CFBRU_crime              -0.024057        -0.041642       -0.024057
# CFBRU_game                0.025162        -0.000572        0.025162
#
#                   baseball_game  soccer_crime  soccer_game  football_crime  \
# ...

# %%
sns.distplot(top)
# Out:
# /home/frank/miniconda3/envs/springboard/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6448: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-079fe6b389a4> in <module>()
# ----> 1 sns.distplot(top)
#
# ~/miniconda3/envs/springboard/lib/python3.6/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     216         hist_color = hist_kws.pop("color", color)
#     217         ax.hist(a, bins, orientation=orientation,
# --> 218                 color=hist_color, **hist_kws)
#     219         if hist_color != color:
#     220             hist_kws["color"] = hist_color
#
# ...
