# %%
import numpy as np
import pandas as pd
from functools import reduce
import seaborn as sns
from pandas.tseries.holiday import USFederalHolidayCalendar as calendar
from datetime import datetime
import matplotlib.pyplot as plt
# special matplotlib argument for improved plots
from matplotlib import rcParams
sns.set_style("whitegrid")
#sns.set_context("poster") # ugly
sns.set_context("talk")  # better
plt.style.use('ggplot')

# %%
ls data/ready/
# Out:
# Astros_clean.csv*        DUMMY_Rockets_final.csv*  NBA.csv*
# bas.csv*                 DUMMY_Texans_final.csv*   NFL.csv*
# bkb.csv*                 DUMMY_UH_final.csv*       Rice_clean.csv*
# cfbRU.csv*               dynamo_clean.csv*         Rockets_clean.csv*
# cfbUH.csv*               fb.csv*                   soc.csv*
# DUMMY_Astros_final.csv*  FINAL_DATA.csv*           Texans_clean.csv*
# DUMMY_Dynamo_final.csv*  MLB.csv*                  UHCFB.csv*
# DUMMY_Rice_final.csv*    MLS.csv*                  UH_clean.csv*

# %%
cfbuh = 'UHCFB'
cfbru = 'cfbRU'
bkb = 'NBA'
bsb = 'MLB'
fb = 'NFL'
soc = 'MLS'

# %%
path = 'data/ready/{}.csv'.format(soc)
df_mls = pd.read_csv(path)
df_mls = df_mls.drop(['10H30_beat'],axis=1)
df_mls.head()
# Out:
#          days  10H30_crime 10H30_sports 10H30_game
# 0  2010-01-01            3          MLS   None_MLS
# 1  2010-01-02            1          MLS   None_MLS
# 2  2010-01-03            2          MLS   None_MLS
# 3  2010-01-04            1          MLS   None_MLS
# 4  2010-01-05            2          MLS   None_MLS

# %%
path = 'data/ready/{}.csv'.format(bkb)
df_nba = pd.read_csv(path)
df_nba = df_nba.drop(['1A10_beat'],axis=1)

df_nba.head()
# Out:
#          days  1A10_crime 1A10_sports 1A10_game
# 0  2010-01-01          11         NBA  None_NBA
# 1  2010-01-02          11         NBA  None_NBA
# 2  2010-01-03           8         NBA  None_NBA
# 3  2010-01-04           6         NBA  None_NBA
# 4  2010-01-05           5         NBA  None_NBA

# %%
path = 'data/ready/{}.csv'.format(bsb)
df_mlb = pd.read_csv(path)
df_mlb = df_mlb.drop(['1A10_beat'],axis=1)

df_mlb.head()
# Out:
#          days  1A10_crime 1A10_sports 1A10_game
# 0  2010-01-01          11         MLB  None_MLB
# 1  2010-01-02          11         MLB  None_MLB
# 2  2010-01-03           8         MLB  None_MLB
# 3  2010-01-04           6         MLB  None_MLB
# 4  2010-01-05           5         MLB  None_MLB

# %%
path = 'data/ready/{}.csv'.format(fb)
df_nfl = pd.read_csv(path)
df_nfl = df_nfl.drop(['15E40_beat'],axis=1)

df_nfl.head()
# Out:
#          days  15E40_crime 15E40_sports 15E40_game
# 0  2010-01-01            2          NFL   None_NFL
# 1  2010-01-02            2          NFL   None_NFL
# 2  2010-01-03            5          NFL    Won_NFL
# 3  2010-01-04            2          NFL   None_NFL
# 4  2010-01-05            4          NFL   None_NFL

# %%
path = 'data/ready/{}.csv'.format(cfbuh)
df_uh = pd.read_csv(path)
df_uh = df_uh.drop(['10H50_beat'],axis=1)

df_uh.head()
# Out:
#          days  10H50_crime 10H50_sports 10H50_game
# 0  2010-01-01            5          CFB   None_CFB
# 1  2010-01-02            0          CFB   None_CFB
# 2  2010-01-03            1          CFB   None_CFB
# 3  2010-01-04            6          CFB   None_CFB
# 4  2010-01-05            1          CFB   None_CFB

# %%
path = 'data/ready/{}.csv'.format(cfbru)
df_ru = pd.read_csv(path)
df_ru = df_ru.drop(['10H80_beat'],axis=1)

df_ru.head()
# Out:
#          days  10H80_crime 10H80_sports 10H80_game
# 0  2010-01-01            0          CFB   None_CFB
# 1  2010-01-02            0          CFB   None_CFB
# 2  2010-01-03            4          CFB   None_CFB
# 3  2010-01-04            2          CFB   None_CFB
# 4  2010-01-05            3          CFB   None_CFB

# %%
dfs = [df_ru,df_uh,df_mlb,df_mls,df_nba,df_nfl]

# %%
df_final = reduce(lambda left,right: pd.merge(left,right,on='days'), dfs)

# %%
df_final.head()
# Out:
#          days  10H80_crime 10H80_sports 10H80_game  10H50_crime 10H50_sports  \
# 0  2010-01-01            0          CFB   None_CFB            5          CFB
# 1  2010-01-02            0          CFB   None_CFB            0          CFB
# 2  2010-01-03            4          CFB   None_CFB            1          CFB
# 3  2010-01-04            2          CFB   None_CFB            6          CFB
# 4  2010-01-05            3          CFB   None_CFB            1          CFB
#
#   10H50_game  1A10_crime_x 1A10_sports_x 1A10_game_x  10H30_crime  \
# 0   None_CFB            11           MLB    None_MLB            3
# 1   None_CFB            11           MLB    None_MLB            1
# 2   None_CFB             8           MLB    None_MLB            2
# 3   None_CFB             6           MLB    None_MLB            1
# 4   None_CFB             5           MLB    None_MLB            2
#
#   10H30_sports 10H30_game  1A10_crime_y 1A10_sports_y 1A10_game_y  \
# 0          MLS   None_MLS            11           NBA    None_NBA
# 1          MLS   None_MLS            11           NBA    None_NBA
# 2          MLS   None_MLS             8           NBA    None_NBA
# 3          MLS   None_MLS             6           NBA    None_NBA
# 4          MLS   None_MLS             5           NBA    None_NBA
#
#    15E40_crime 15E40_sports 15E40_game
# 0            2          NFL   None_NFL
# 1            2          NFL   None_NFL
# 2            5          NFL    Won_NFL
# 3            2          NFL   None_NFL
# 4            4          NFL   None_NFL

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2923 entries, 0 to 2922
# Data columns (total 19 columns):
# days             2923 non-null object
# 10H80_crime      2923 non-null int64
# 10H80_sports     2923 non-null object
# 10H80_game       2923 non-null object
# 10H50_crime      2923 non-null int64
# 10H50_sports     2923 non-null object
# 10H50_game       2923 non-null object
# 1A10_crime_x     2923 non-null int64
# 1A10_sports_x    2923 non-null object
# 1A10_game_x      2923 non-null object
# 10H30_crime      2923 non-null int64
# 10H30_sports     2923 non-null object
# 10H30_game       2923 non-null object
# 1A10_crime_y     2923 non-null int64
# 1A10_sports_y    2923 non-null object
# 1A10_game_y      2923 non-null object
# 15E40_crime      2923 non-null int64
# 15E40_sports     2923 non-null object
# 15E40_game       2923 non-null object
# dtypes: int64(6), object(13)
# memory usage: 456.7+ KB

# %% [markdown]
# ## Any nulls?

# %%
df_final[df_final.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [days, 10H80_crime, 10H80_sports, 10H80_game, 10H50_crime, 10H50_sports, 10H50_game, 1A10_crime_x, 1A10_sports_x, 1A10_game_x, 10H30_crime, 10H30_sports, 10H30_game, 1A10_crime_y, 1A10_sports_y, 1A10_game_y, 15E40_crime, 15E40_sports, 15E40_game]
# Index: []

# %% [markdown]
# ## Remove duplicate col
# - `1A10_crime_x`,`1A10_crime_y`  are the same,
# - drop one and rename

# %%
df_final.drop(['1A10_crime_x'], axis=1,inplace=True)
df_final = df_final.rename(columns = {'1A10_crime_y':'1A10_crime'})

# %%
df_final.head()
# Out:
#          days  10H80_crime 10H80_sports 10H80_game  10H50_crime 10H50_sports  \
# 0  2010-01-01            0          CFB   None_CFB            5          CFB
# 1  2010-01-02            0          CFB   None_CFB            0          CFB
# 2  2010-01-03            4          CFB   None_CFB            1          CFB
# 3  2010-01-04            2          CFB   None_CFB            6          CFB
# 4  2010-01-05            3          CFB   None_CFB            1          CFB
#
#   10H50_game 1A10_sports_x 1A10_game_x  10H30_crime 10H30_sports 10H30_game  \
# 0   None_CFB           MLB    None_MLB            3          MLS   None_MLS
# 1   None_CFB           MLB    None_MLB            1          MLS   None_MLS
# 2   None_CFB           MLB    None_MLB            2          MLS   None_MLS
# 3   None_CFB           MLB    None_MLB            1          MLS   None_MLS
# 4   None_CFB           MLB    None_MLB            2          MLS   None_MLS
#
#    1A10_crime 1A10_sports_y 1A10_game_y  15E40_crime 15E40_sports 15E40_game
# 0          11           NBA    None_NBA            2          NFL   None_NFL
# 1          11           NBA    None_NBA            2          NFL   None_NFL
# 2           8           NBA    None_NBA            5          NFL    Won_NFL
# 3           6           NBA    None_NBA            2          NFL   None_NFL
# 4           5           NBA    None_NBA            4          NFL   None_NFL

# %% [markdown]
# ## datetime days

# %%
#df_dm = pd.get_dummies(df_final)

df_final['days'] = pd.to_datetime(df_final['days'])
#df_final = df_final.set_index('days')
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2923 entries, 0 to 2922
# Data columns (total 18 columns):
# days             2923 non-null datetime64[ns]
# 10H80_crime      2923 non-null int64
# 10H80_sports     2923 non-null object
# 10H80_game       2923 non-null object
# 10H50_crime      2923 non-null int64
# 10H50_sports     2923 non-null object
# 10H50_game       2923 non-null object
# 1A10_sports_x    2923 non-null object
# 1A10_game_x      2923 non-null object
# 10H30_crime      2923 non-null int64
# 10H30_sports     2923 non-null object
# 10H30_game       2923 non-null object
# 1A10_crime       2923 non-null int64
# 1A10_sports_y    2923 non-null object
# 1A10_game_y      2923 non-null object
# 15E40_crime      2923 non-null int64
# 15E40_sports     2923 non-null object
# 15E40_game       2923 non-null object
# dtypes: datetime64[ns](1), int64(5), object(12)
# memory usage: 513.9+ KB

# %%
df_final.head()
# Out:
#         days  10H80_crime 10H80_sports 10H80_game  10H50_crime 10H50_sports  \
# 0 2010-01-01            0          CFB   None_CFB            5          CFB
# 1 2010-01-02            0          CFB   None_CFB            0          CFB
# 2 2010-01-03            4          CFB   None_CFB            1          CFB
# 3 2010-01-04            2          CFB   None_CFB            6          CFB
# 4 2010-01-05            3          CFB   None_CFB            1          CFB
#
#   10H50_game 1A10_sports_x 1A10_game_x  10H30_crime 10H30_sports 10H30_game  \
# 0   None_CFB           MLB    None_MLB            3          MLS   None_MLS
# 1   None_CFB           MLB    None_MLB            1          MLS   None_MLS
# 2   None_CFB           MLB    None_MLB            2          MLS   None_MLS
# 3   None_CFB           MLB    None_MLB            1          MLS   None_MLS
# 4   None_CFB           MLB    None_MLB            2          MLS   None_MLS
#
#    1A10_crime 1A10_sports_y 1A10_game_y  15E40_crime 15E40_sports 15E40_game
# 0          11           NBA    None_NBA            2          NFL   None_NFL
# 1          11           NBA    None_NBA            2          NFL   None_NFL
# 2           8           NBA    None_NBA            5          NFL    Won_NFL
# 3           6           NBA    None_NBA            2          NFL   None_NFL
# 4           5           NBA    None_NBA            4          NFL   None_NFL

# %% [markdown]
# ## Add Holiday column

# %%
# seasons = [0,0,1,1,1,2,2,2,3,3,3,0] #dec - feb is winter, then spring, summer, fall etc
# season = lambda x: seasons[(datetime.strptime(x, "%Y-%m-%d" ).month-1)]
wknd = [5,6]
wkday = [0,1,2,3,4]

# %%
df_final['wkend'] = df_final['days'].dt.weekday.isin(wknd).astype('int')

# %%
df_final['wkday']= df_final['days'].dt.weekday.isin(wkday).astype('int')

# %%
cal = calendar()
holidays = cal.holidays(start=df_final.days.min(), end=df_final.days.max())
df_final['hol'] = df_final['days'].isin(holidays).astype('int')

# %%
df

# %%
df_final.head()
# Out:
#         days  10H80_crime 10H80_sports 10H80_game  10H50_crime 10H50_sports  \
# 0 2010-01-01            0          CFB   None_CFB            5          CFB
# 1 2010-01-02            0          CFB   None_CFB            0          CFB
# 2 2010-01-03            4          CFB   None_CFB            1          CFB
# 3 2010-01-04            2          CFB   None_CFB            6          CFB
# 4 2010-01-05            3          CFB   None_CFB            1          CFB
#
#   10H50_game 1A10_sports_x 1A10_game_x  10H30_crime ...  10H30_game  \
# 0   None_CFB           MLB    None_MLB            3 ...    None_MLS
# 1   None_CFB           MLB    None_MLB            1 ...    None_MLS
# 2   None_CFB           MLB    None_MLB            2 ...    None_MLS
# 3   None_CFB           MLB    None_MLB            1 ...    None_MLS
# 4   None_CFB           MLB    None_MLB            2 ...    None_MLS
#
#   1A10_crime  1A10_sports_y 1A10_game_y 15E40_crime  15E40_sports 15E40_game  \
# 0         11            NBA    None_NBA           2           NFL   None_NFL
# 1         11            NBA    None_NBA           2           NFL   None_NFL
# 2          8            NBA    None_NBA           5           NFL    Won_NFL
# 3          6            NBA    None_NBA           2           NFL   None_NFL
# 4          5            NBA    None_NBA           4           NFL   None_NFL
#
#   wkend  wkday  hol
# 0     0      1    1
# 1     1      0    0
# 2     1      0    0
# 3     0      1    0
# 4     0      1    0
#
# [5 rows x 21 columns]

# %%
df_dum = pd.get_dummies(df_final)

# %%
df_dum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2923 entries, 0 to 2922
# Data columns (total 33 columns):
# days                    2923 non-null datetime64[ns]
# 10H80_crime             2923 non-null int64
# 10H50_crime             2923 non-null int64
# 10H30_crime             2923 non-null int64
# 1A10_crime              2923 non-null int64
# 15E40_crime             2923 non-null int64
# wkend                   2923 non-null int64
# wkday                   2923 non-null int64
# hol                     2923 non-null int64
# 10H80_sports_CFB        2923 non-null uint8
# 10H80_game_Lost_CFB     2923 non-null uint8
# 10H80_game_None_CFB     2923 non-null uint8
# 10H80_game_Won_CFB      2923 non-null uint8
# 10H50_sports_CFB        2923 non-null uint8
# 10H50_game_Lost_CFB     2923 non-null uint8
# 10H50_game_None_CFB     2923 non-null uint8
# 10H50_game_Won_CFB      2923 non-null uint8
# 1A10_sports_x_MLB       2923 non-null uint8
# 1A10_game_x_Lost_MLB    2923 non-null uint8
# 1A10_game_x_None_MLB    2923 non-null uint8
# 1A10_game_x_Won_MLB     2923 non-null uint8
# 10H30_sports_MLS        2923 non-null uint8
# 10H30_game_Lost_MLS     2923 non-null uint8
# 10H30_game_None_MLS     2923 non-null uint8
# 10H30_game_Won_MLS      2923 non-null uint8
# 1A10_sports_y_NBA       2923 non-null uint8
# 1A10_game_y_Lost_NBA    2923 non-null uint8
# 1A10_game_y_None_NBA    2923 non-null uint8
# 1A10_game_y_Won_NBA     2923 non-null uint8
# 15E40_sports_NFL        2923 non-null uint8
# 15E40_game_Lost_NFL     2923 non-null uint8
# 15E40_game_None_NFL     2923 non-null uint8
# 15E40_game_Won_NFL      2923 non-null uint8
# dtypes: datetime64[ns](1), int64(8), uint8(24)
# memory usage: 376.9 KB

# %%
df_dum.head()
# Out:
#         days  10H80_crime  10H50_crime  10H30_crime  1A10_crime  15E40_crime  \
# 0 2010-01-01            0            5            3          11            2
# 1 2010-01-02            0            0            1          11            2
# 2 2010-01-03            4            1            2           8            5
# 3 2010-01-04            2            6            1           6            2
# 4 2010-01-05            3            1            2           5            4
#
#    wkend  wkday  hol  10H80_sports_CFB         ...          \
# 0      0      1    1                 1         ...
# 1      1      0    0                 1         ...
# 2      1      0    0                 1         ...
# 3      0      1    0                 1         ...
# 4      0      1    0                 1         ...
#
#    10H30_game_None_MLS  10H30_game_Won_MLS  1A10_sports_y_NBA  \
# 0                    1                   0                  1
# 1                    1                   0                  1
# 2                    1                   0                  1
# 3                    1                   0                  1
# 4                    1                   0                  1
#
#    1A10_game_y_Lost_NBA  1A10_game_y_None_NBA  1A10_game_y_Won_NBA  \
# 0                     0                     1                    0
# 1                     0                     1                    0
# 2                     0                     1                    0
# 3                     0                     1                    0
# 4                     0                     1                    0
#
#    15E40_sports_NFL  15E40_game_Lost_NFL  15E40_game_None_NFL  \
# 0                 1                    0                    1
# 1                 1                    0                    1
# 2                 1                    0                    0
# 3                 1                    0                    1
# 4                 1                    0                    1
#
#    15E40_game_Won_NFL
# 0                   0
# 1                   0
# 2                   1
# 3                   0
# 4                   0
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Rename columns with same beat

# %%
df_dum = df_dum.rename(columns = {'1A10_sports_x_MLB':'1A10_sports_MLB',
                                      '1A10_game_x_Lost_MLB':'1A10_game_Lost_MLB',
                                      '1A10_game_x_Won_MLB': '1A10_game_Won_MLB',
                                      '1A10_game_x_None_MLB':'1A10_game_None_MLB',
                                      '1A10_sports_y_NBA':'1A10_sports_NBA',
                                      '1A10_game_y_Lost_NBA':'1A10_game_Lost_NBA',
                                      '1A10_game_y_Won_NBA': '1A10_game_Won_NBA',
                                      '1A10_game_y_None_NBA':'1A10_game_None_NBA',
                                     })

# %%
df_dum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2923 entries, 0 to 2922
# Data columns (total 33 columns):
# days                   2923 non-null datetime64[ns]
# 10H80_crime            2923 non-null int64
# 10H50_crime            2923 non-null int64
# 10H30_crime            2923 non-null int64
# 1A10_crime             2923 non-null int64
# 15E40_crime            2923 non-null int64
# wkend                  2923 non-null int64
# wkday                  2923 non-null int64
# hol                    2923 non-null int64
# 10H80_sports_CFB       2923 non-null uint8
# 10H80_game_Lost_CFB    2923 non-null uint8
# 10H80_game_None_CFB    2923 non-null uint8
# 10H80_game_Won_CFB     2923 non-null uint8
# 10H50_sports_CFB       2923 non-null uint8
# 10H50_game_Lost_CFB    2923 non-null uint8
# 10H50_game_None_CFB    2923 non-null uint8
# 10H50_game_Won_CFB     2923 non-null uint8
# 1A10_sports_MLB        2923 non-null uint8
# 1A10_game_Lost_MLB     2923 non-null uint8
# 1A10_game_None_MLB     2923 non-null uint8
# 1A10_game_Won_MLB      2923 non-null uint8
# 10H30_sports_MLS       2923 non-null uint8
# 10H30_game_Lost_MLS    2923 non-null uint8
# 10H30_game_None_MLS    2923 non-null uint8
# 10H30_game_Won_MLS     2923 non-null uint8
# 1A10_sports_NBA        2923 non-null uint8
# 1A10_game_Lost_NBA     2923 non-null uint8
# 1A10_game_None_NBA     2923 non-null uint8
# 1A10_game_Won_NBA      2923 non-null uint8
# 15E40_sports_NFL       2923 non-null uint8
# 15E40_game_Lost_NFL    2923 non-null uint8
# 15E40_game_None_NFL    2923 non-null uint8
# 15E40_game_Won_NFL     2923 non-null uint8
# dtypes: datetime64[ns](1), int64(8), uint8(24)
# memory usage: 296.9 KB

# %%
path = 'data/ready/{}.csv'.format('DATA_FINAL')

df_dum.to_csv(path)

# %%
df_dum.describe()
# Out:
#        10H80_crime  10H50_crime  10H30_crime   1A10_crime  15E40_crime  \
# count  2923.000000  2923.000000  2923.000000  2923.000000  2923.000000
# mean      2.559015     2.743414     1.504961     5.203900     5.607595
# std       1.791738     1.786668     1.468897     2.962836     3.012461
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     1.000000     0.000000     3.000000     3.000000
# 50%       2.000000     2.000000     1.000000     5.000000     5.000000
# 75%       4.000000     4.000000     2.000000     7.000000     7.000000
# max      12.000000    14.000000    11.000000    36.000000    32.000000
#
#              wkend        wkday          hol  10H80_sports_CFB  \
# count  2923.000000  2923.000000  2923.000000            2923.0
# mean      0.286350     0.713650     0.027369               1.0
# std       0.452132     0.452132     0.163185               0.0
# min       0.000000     0.000000     0.000000               1.0
# 25%       0.000000     0.000000     0.000000               1.0
# 50%       0.000000     1.000000     0.000000               1.0
# 75%       1.000000     1.000000     0.000000               1.0
# max       1.000000     1.000000     1.000000               1.0
#
#        10H80_game_Lost_CFB         ...          10H30_game_None_MLS  \
# count          2923.000000         ...                  2923.000000
# mean              0.006842         ...                     0.953130
# std               0.082449         ...                     0.211396
# min               0.000000         ...                     0.000000
# 25%               0.000000         ...                     1.000000
# 50%               0.000000         ...                     1.000000
# 75%               0.000000         ...                     1.000000
# max               1.000000         ...                     1.000000
#
#        10H30_game_Won_MLS  1A10_sports_NBA  1A10_game_Lost_NBA  \
# count         2923.000000           2923.0         2923.000000
# mean             0.024632              1.0            0.037633
# std              0.155028              0.0            0.190339
# min              0.000000              1.0            0.000000
# 25%              0.000000              1.0            0.000000
# 50%              0.000000              1.0            0.000000
# 75%              0.000000              1.0            0.000000
# max              1.000000              1.0            1.000000
#
#        1A10_game_None_NBA  1A10_game_Won_NBA  15E40_sports_NFL  \
# count         2923.000000        2923.000000            2923.0
# mean             0.887444           0.074923               1.0
# std              0.316103           0.263312               0.0
# min              0.000000           0.000000               1.0
# 25%              1.000000           0.000000               1.0
# 50%              1.000000           0.000000               1.0
# 75%              1.000000           0.000000               1.0
# max              1.000000           1.000000               1.0
#
#        15E40_game_Lost_NFL  15E40_game_None_NFL  15E40_game_Won_NFL
# count          2923.000000          2923.000000         2923.000000
# mean              0.009921             0.976394            0.013685
# std               0.099127             0.151844            0.116198
# min               0.000000             0.000000            0.000000
# 25%               0.000000             1.000000            0.000000
# 50%               0.000000             1.000000            0.000000
# 75%               0.000000             1.000000            0.000000
# max               1.000000             1.000000            1.000000
#
# [8 rows x 32 columns]

# %%
df_dum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2923 entries, 0 to 2922
# Data columns (total 33 columns):
# days                   2923 non-null datetime64[ns]
# 10H80_crime            2923 non-null int64
# 10H50_crime            2923 non-null int64
# 10H30_crime            2923 non-null int64
# 1A10_crime             2923 non-null int64
# 15E40_crime            2923 non-null int64
# wkend                  2923 non-null int64
# wkday                  2923 non-null int64
# hol                    2923 non-null int64
# 10H80_sports_CFB       2923 non-null uint8
# 10H80_game_Lost_CFB    2923 non-null uint8
# 10H80_game_None_CFB    2923 non-null uint8
# 10H80_game_Won_CFB     2923 non-null uint8
# 10H50_sports_CFB       2923 non-null uint8
# 10H50_game_Lost_CFB    2923 non-null uint8
# 10H50_game_None_CFB    2923 non-null uint8
# 10H50_game_Won_CFB     2923 non-null uint8
# 1A10_sports_MLB        2923 non-null uint8
# 1A10_game_Lost_MLB     2923 non-null uint8
# 1A10_game_None_MLB     2923 non-null uint8
# 1A10_game_Won_MLB      2923 non-null uint8
# 10H30_sports_MLS       2923 non-null uint8
# 10H30_game_Lost_MLS    2923 non-null uint8
# 10H30_game_None_MLS    2923 non-null uint8
# 10H30_game_Won_MLS     2923 non-null uint8
# 1A10_sports_NBA        2923 non-null uint8
# 1A10_game_Lost_NBA     2923 non-null uint8
# 1A10_game_None_NBA     2923 non-null uint8
# 1A10_game_Won_NBA      2923 non-null uint8
# 15E40_sports_NFL       2923 non-null uint8
# 15E40_game_Lost_NFL    2923 non-null uint8
# 15E40_game_None_NFL    2923 non-null uint8
# 15E40_game_Won_NFL     2923 non-null uint8
# dtypes: datetime64[ns](1), int64(8), uint8(24)
# memory usage: 376.9 KB

# %%
## drop_date

# %%
dd = df_dum.drop(['days'],axis=1)

# %%
dd.describe()
# Out:
#        10H80_crime  10H50_crime  10H30_crime   1A10_crime  15E40_crime  \
# count  2923.000000  2923.000000  2923.000000  2923.000000  2923.000000
# mean      2.559015     2.743414     1.504961     5.203900     5.607595
# std       1.791738     1.786668     1.468897     2.962836     3.012461
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     1.000000     0.000000     3.000000     3.000000
# 50%       2.000000     2.000000     1.000000     5.000000     5.000000
# 75%       4.000000     4.000000     2.000000     7.000000     7.000000
# max      12.000000    14.000000    11.000000    36.000000    32.000000
#
#              wkend        wkday          hol  10H80_sports_CFB  \
# count  2923.000000  2923.000000  2923.000000            2923.0
# mean      0.286350     0.713650     0.027369               1.0
# std       0.452132     0.452132     0.163185               0.0
# min       0.000000     0.000000     0.000000               1.0
# 25%       0.000000     0.000000     0.000000               1.0
# 50%       0.000000     1.000000     0.000000               1.0
# 75%       1.000000     1.000000     0.000000               1.0
# max       1.000000     1.000000     1.000000               1.0
#
#        10H80_game_Lost_CFB         ...          10H30_game_None_MLS  \
# count          2923.000000         ...                  2923.000000
# mean              0.006842         ...                     0.953130
# std               0.082449         ...                     0.211396
# min               0.000000         ...                     0.000000
# 25%               0.000000         ...                     1.000000
# 50%               0.000000         ...                     1.000000
# 75%               0.000000         ...                     1.000000
# max               1.000000         ...                     1.000000
#
#        10H30_game_Won_MLS  1A10_sports_NBA  1A10_game_Lost_NBA  \
# count         2923.000000           2923.0         2923.000000
# mean             0.024632              1.0            0.037633
# std              0.155028              0.0            0.190339
# min              0.000000              1.0            0.000000
# 25%              0.000000              1.0            0.000000
# 50%              0.000000              1.0            0.000000
# 75%              0.000000              1.0            0.000000
# max              1.000000              1.0            1.000000
#
#        1A10_game_None_NBA  1A10_game_Won_NBA  15E40_sports_NFL  \
# count         2923.000000        2923.000000            2923.0
# mean             0.887444           0.074923               1.0
# std              0.316103           0.263312               0.0
# min              0.000000           0.000000               1.0
# 25%              1.000000           0.000000               1.0
# 50%              1.000000           0.000000               1.0
# 75%              1.000000           0.000000               1.0
# max              1.000000           1.000000               1.0
#
#        15E40_game_Lost_NFL  15E40_game_None_NFL  15E40_game_Won_NFL
# count          2923.000000          2923.000000         2923.000000
# mean              0.009921             0.976394            0.013685
# std               0.099127             0.151844            0.116198
# min               0.000000             0.000000            0.000000
# 25%               0.000000             1.000000            0.000000
# 50%               0.000000             1.000000            0.000000
# 75%               0.000000             1.000000            0.000000
# max               1.000000             1.000000            1.000000
#
# [8 rows x 32 columns]

# %%
dd.head()
# Out:
#    10H80_crime  10H50_crime  10H30_crime  1A10_crime  15E40_crime  wkend  \
# 0            0            5            3          11            2      0
# 1            0            0            1          11            2      1
# 2            4            1            2           8            5      1
# 3            2            6            1           6            2      0
# 4            3            1            2           5            4      0
#
#    wkday  hol  10H80_sports_CFB  10H80_game_Lost_CFB         ...          \
# 0      1    1                 1                    0         ...
# 1      0    0                 1                    0         ...
# 2      0    0                 1                    0         ...
# 3      1    0                 1                    0         ...
# 4      1    0                 1                    0         ...
#
#    10H30_game_None_MLS  10H30_game_Won_MLS  1A10_sports_NBA  \
# 0                    1                   0                1
# 1                    1                   0                1
# 2                    1                   0                1
# 3                    1                   0                1
# 4                    1                   0                1
#
#    1A10_game_Lost_NBA  1A10_game_None_NBA  1A10_game_Won_NBA  \
# 0                   0                   1                  0
# 1                   0                   1                  0
# 2                   0                   1                  0
# 3                   0                   1                  0
# 4                   0                   1                  0
#
#    15E40_sports_NFL  15E40_game_Lost_NFL  15E40_game_None_NFL  \
# 0                 1                    0                    1
# 1                 1                    0                    1
# 2                 1                    0                    0
# 3                 1                    0                    1
# 4                 1                    0                    1
#
#    15E40_game_Won_NFL
# 0                   0
# 1                   0
# 2                   1
# 3                   0
# 4                   0
#
# [5 rows x 32 columns]

# %%
sns.heatmap(dd)

# %%
dd[['10H80_crime','10H50_crime']].plot.area()

# %%
dd['10H80_crime'].value_counts().sort_index().plot.line()

# %%
df_dum.head()
# Out:
#         days  10H80_crime  10H50_crime  10H30_crime  1A10_crime  15E40_crime  \
# 0 2010-01-01            0            5            3          11            2
# 1 2010-01-02            0            0            1          11            2
# 2 2010-01-03            4            1            2           8            5
# 3 2010-01-04            2            6            1           6            2
# 4 2010-01-05            3            1            2           5            4
#
#    wkend  wkday  hol  10H80_sports_CFB         ...          \
# 0      0      1    1                 1         ...
# 1      1      0    0                 1         ...
# 2      1      0    0                 1         ...
# 3      0      1    0                 1         ...
# 4      0      1    0                 1         ...
#
#    10H30_game_None_MLS  10H30_game_Won_MLS  1A10_sports_NBA  \
# 0                    1                   0                1
# 1                    1                   0                1
# 2                    1                   0                1
# 3                    1                   0                1
# 4                    1                   0                1
#
#    1A10_game_Lost_NBA  1A10_game_None_NBA  1A10_game_Won_NBA  \
# 0                   0                   1                  0
# 1                   0                   1                  0
# 2                   0                   1                  0
# 3                   0                   1                  0
# 4                   0                   1                  0
#
#    15E40_sports_NFL  15E40_game_Lost_NFL  15E40_game_None_NFL  \
# 0                 1                    0                    1
# 1                 1                    0                    1
# 2                 1                    0                    0
# 3                 1                    0                    1
# 4                 1                    0                    1
#
#    15E40_game_Won_NFL
# 0                   0
# 1                   0
# 2                   1
# 3                   0
# 4                   0
#
# [5 rows x 33 columns]

# %%
sns.distplot(dd[['10H80_crime']])
# Out:
# /home/frank/miniconda3/envs/springboard/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6448: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.regplot(data=df_dum,x='10H80_crime',y='10H50_crime')

# %%
#sns.pairplot(df_dum)

# %%
crd = dd.iloc[:,0:6]

# %%
sns.pairplot(crd)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2923 entries, 0 to 2922
# Data columns (total 21 columns):
# days             2923 non-null datetime64[ns]
# 10H80_crime      2923 non-null int64
# 10H80_sports     2923 non-null object
# 10H80_game       2923 non-null object
# 10H50_crime      2923 non-null int64
# 10H50_sports     2923 non-null object
# 10H50_game       2923 non-null object
# 1A10_sports_x    2923 non-null object
# 1A10_game_x      2923 non-null object
# 10H30_crime      2923 non-null int64
# 10H30_sports     2923 non-null object
# 10H30_game       2923 non-null object
# 1A10_crime       2923 non-null int64
# 1A10_sports_y    2923 non-null object
# 1A10_game_y      2923 non-null object
# 15E40_crime      2923 non-null int64
# 15E40_sports     2923 non-null object
# 15E40_game       2923 non-null object
# wkend            2923 non-null int64
# wkday            2923 non-null int64
# hol              2923 non-null int64
# dtypes: datetime64[ns](1), int64(8), object(12)
# memory usage: 582.4+ KB

# %%
plt.scatter(df_final['10H80_crime'], df_final['wkday'])
plt.show()

# %%
plt.scatter(df_final['10H80_crime'], df_final['10H30_crime'])
plt.show()

# %%
plt.hist(np.log(df_final['10H80_crime']))
plt.title("CRIM")
plt.xlabel("Crime rate per capita")
plt.ylabel("Frequencey")
plt.show()
# Out:
# /home/frank/miniconda3/envs/springboard/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-121-b01b209a3572> in <module>()
# ----> 1 plt.hist(np.log(df_final['10H80_crime']))
#       2 plt.title("CRIM")
#       3 plt.xlabel("Crime rate per capita")
#       4 plt.ylabel("Frequencey")
#       5 plt.show()
#
# ~/miniconda3/envs/springboard/lib/python3.6/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, hold, data, **kwargs)
#    3027                       histtype=histtype, align=align, orientation=orientation,
#    3028                       rwidth=rwidth, log=log, color=color, label=label,
# -> 3029                       stacked=stacked, normed=normed, data=data, **kwargs)
#    3030     finally:
#    3031         ax._hold = washold
#
# ~/miniconda3/envs/springboard/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1843                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1844                         RuntimeWarning, stacklevel=2)
# -> 1845             return func(ax, *args, **kwargs)
#    1846
#    1847         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/miniconda3/envs/springboard/lib/python3.6/site-packages/matplotlib/axes/_axes.py in hist(***failed resolving arguments***)
#    6514             # this will automatically overwrite bins,
#    6515             # so that each histogram uses the same bins
# -> 6516             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6517             m = m.astype(float)  # causes problems later if it's an int
#    6518             if mlast is None:
#
# ~/miniconda3/envs/springboard/lib/python3.6/site-packages/numpy/lib/function_base.py in histogram(a, bins, range, normed, weights, density)
#     668     if not np.all(np.isfinite([first_edge, last_edge])):
#     669         raise ValueError(
# --> 670             'range parameter must be finite.')
#     671     if first_edge == last_edge:
#     672         first_edge -= 0.5
#
# ValueError: range parameter must be finite.

# %%
# Import regression modules
import statsmodels.api as sm
from statsmodels.formula.api import ols
# Out:
# /home/frank/miniconda3/envs/springboard/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
dd.head()
# Out:
#    10H80_crime  10H50_crime  10H30_crime  1A10_crime  15E40_crime  wkend  \
# 0            0            5            3          11            2      0
# 1            0            0            1          11            2      1
# 2            4            1            2           8            5      1
# 3            2            6            1           6            2      0
# 4            3            1            2           5            4      0
#
#    wkday  hol  10H80_sports_CFB  10H80_game_Lost_CFB         ...          \
# 0      1    1                 1                    0         ...
# 1      0    0                 1                    0         ...
# 2      0    0                 1                    0         ...
# 3      1    0                 1                    0         ...
# 4      1    0                 1                    0         ...
#
#    10H30_game_None_MLS  10H30_game_Won_MLS  1A10_sports_NBA  \
# 0                    1                   0                1
# 1                    1                   0                1
# 2                    1                   0                1
# 3                    1                   0                1
# 4                    1                   0                1
#
#    1A10_game_Lost_NBA  1A10_game_None_NBA  1A10_game_Won_NBA  \
# 0                   0                   1                  0
# 1                   0                   1                  0
# 2                   0                   1                  0
# 3                   0                   1                  0
# 4                   0                   1                  0
#
#    15E40_sports_NFL  15E40_game_Lost_NFL  15E40_game_None_NFL  \
# 0                 1                    0                    1
# 1                 1                    0                    1
# 2                 1                    0                    0
# 3                 1                    0                    1
# 4                 1                    0                    1
#
#    15E40_game_Won_NFL
# 0                   0
# 1                   0
# 2                   1
# 3                   0
# 4                   0
#
# [5 rows x 32 columns]

# %%
from sklearn.linear_model import LinearRegression
X = dd.drop('10H80_crime', axis = 1)

# This creates a LinearRegression object
lm = LinearRegression()
lm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Use all 13 predictors to fit linear regression model
lm.fit(X, dd['10H80_crime'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print('Estimated intercept coefficient: {}'.format(lm.intercept_))
# Out:
# Estimated intercept coefficient: 2.115600998713444

# %%
print('Number of coefficients: {}'.format(len(lm.coef_)))
# Out:
# Number of coefficients: 31

# %%
# The coefficients
pd.DataFrame({'features': X.columns, 'estimatedCoefficients': lm.coef_})[['features', 'estimatedCoefficients']]
# Out:
#                features  estimatedCoefficients
# 0           10H50_crime           5.929273e-03
# 1           10H30_crime           1.892650e-02
# 2            1A10_crime          -6.300503e-03
# 3           15E40_crime           1.079870e-02
# 4                 wkend          -4.098137e-01
# 5                 wkday           4.098137e-01
# 6                   hol          -1.023533e+00
# 7      10H80_sports_CFB          -3.053113e-16
# 8   10H80_game_Lost_CFB          -5.406823e-01
# 9   10H80_game_None_CFB           2.481352e-01
# 10   10H80_game_Won_CFB           2.925470e-01
# 11     10H50_sports_CFB           5.551115e-17
# 12  10H50_game_Lost_CFB           1.823056e-01
# 13  10H50_game_None_CFB          -4.131074e-02
# 14   10H50_game_Won_CFB          -1.409949e-01
# 15      1A10_sports_MLB           0.000000e+00
# 16   1A10_game_Lost_MLB           1.084316e-02
# 17   1A10_game_None_MLB          -4.130367e-03
# 18    1A10_game_Won_MLB          -6.712797e-03
# 19     10H30_sports_MLS           0.000000e+00
# 20  10H30_game_Lost_MLS          -7.343206e-04
# 21  10H30_game_None_MLS          -1.742083e-01
# 22   10H30_game_Won_MLS           1.749426e-01
# 23      1A10_sports_NBA           0.000000e+00
# 24   1A10_game_Lost_NBA          -9.147447e-02
# 25   1A10_game_None_NBA           1.355398e-01
# 26    1A10_game_Won_NBA          -4.406537e-02
# 27     15E40_sports_NFL           0.000000e+00
# 28  15E40_game_Lost_NFL           4.248587e-02
# 29  15E40_game_None_NFL           7.623905e-02
# 30   15E40_game_Won_NFL          -1.187249e-01

# %%
# first five predicted prices
lm.predict(X)[0:5]
# Out:
# array([1.78086412, 1.91727037, 1.79845977, 2.80397599, 2.82115402])

# %%
sns.distplot(lm.predict(X))
# Out:
# /home/frank/miniconda3/envs/springboard/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6448: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
# your turn# your t 
plt.hist(lm.predict(X), bins='auto')
plt.title("Predicted Prices")
plt.xlabel("Predicted Prices")
plt.ylabel("Frequency")
plt.show()

# %%
coll = dd['10H80_crime']
print(np.sum((coll - lm.predict(X)) ** 2))
# Out:
# 8895.264285357587

# %%
print(np.sum(lm.predict(X) - np.mean(coll)) ** 2)
# Out:
# 3.3476101373958857e-26

# %%
dd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2923 entries, 0 to 2922
# Data columns (total 32 columns):
# 10H80_crime            2923 non-null int64
# 10H50_crime            2923 non-null int64
# 10H30_crime            2923 non-null int64
# 1A10_crime             2923 non-null int64
# 15E40_crime            2923 non-null int64
# wkend                  2923 non-null int64
# wkday                  2923 non-null int64
# hol                    2923 non-null int64
# 10H80_sports_CFB       2923 non-null uint8
# 10H80_game_Lost_CFB    2923 non-null uint8
# 10H80_game_None_CFB    2923 non-null uint8
# 10H80_game_Won_CFB     2923 non-null uint8
# 10H50_sports_CFB       2923 non-null uint8
# 10H50_game_Lost_CFB    2923 non-null uint8
# 10H50_game_None_CFB    2923 non-null uint8
# 10H50_game_Won_CFB     2923 non-null uint8
# 1A10_sports_MLB        2923 non-null uint8
# 1A10_game_Lost_MLB     2923 non-null uint8
# 1A10_game_None_MLB     2923 non-null uint8
# 1A10_game_Won_MLB      2923 non-null uint8
# 10H30_sports_MLS       2923 non-null uint8
# 10H30_game_Lost_MLS    2923 non-null uint8
# 10H30_game_None_MLS    2923 non-null uint8
# 10H30_game_Won_MLS     2923 non-null uint8
# 1A10_sports_NBA        2923 non-null uint8
# 1A10_game_Lost_NBA     2923 non-null uint8
# 1A10_game_None_NBA     2923 non-null uint8
# 1A10_game_Won_NBA      2923 non-null uint8
# 15E40_sports_NFL       2923 non-null uint8
# 15E40_game_Lost_NFL    2923 non-null uint8
# 15E40_game_None_NFL    2923 non-null uint8
# 15E40_game_Won_NFL     2923 non-null uint8
# dtypes: int64(8), uint8(24)
# memory usage: 354.0 KB

# %%
crm10 = dd['10H80_crime']
cc = dd['10H80_game_Won_CFB']

# your turn# your t 
lm = LinearRegression()

X = crm10
X = X.values.reshape((-1,1))
lm.fit(X, cc)

prediction = lm.predict(X)
print('lm.coef_ : {}'.format(lm.coef_))
print('lm.intersept_ : {}'.format(lm.intercept_))
# Out:
# lm.coef_ : [-0.00127661]
# lm.intersept_ : 0.011819730886949298

# %%
# ESS/TSS/R_sq# ESS/TS 
RSS = np.sum((cc - prediction) ** 2)
ESS = np.sum(prediction - np.mean(cc)) ** 2
R_sq = lm.score(X, cc)

print('Residual Sum-of-Squares RSS       : {}'.format(RSS))
print('Explained Sum-of-Squares ESS      : {}'.format(ESS))
print('Coefficient of Determination R-sq : {}'.format(R_sq))
# Out:
# Residual Sum-of-Squares RSS       : 24.77089066043225
# Explained Sum-of-Squares ESS      : 5.307092554753467e-30
# Coefficient of Determination R-sq : 0.0006167922644101376

# %%
from sklearn.feature_selection import f_regression
F,p_val = f_regression(X, cc)
print('F-statistic: {}'.format(F[0]))
# Out:
# F-statistic: 1.8027621340816429

# %%
dd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2923 entries, 0 to 2922
# Data columns (total 32 columns):
# 10H80_crime            2923 non-null int64
# 10H50_crime            2923 non-null int64
# 10H30_crime            2923 non-null int64
# 1A10_crime             2923 non-null int64
# 15E40_crime            2923 non-null int64
# wkend                  2923 non-null int64
# wkday                  2923 non-null int64
# hol                    2923 non-null int64
# 10H80_sports_CFB       2923 non-null uint8
# 10H80_game_Lost_CFB    2923 non-null uint8
# 10H80_game_None_CFB    2923 non-null uint8
# 10H80_game_Won_CFB     2923 non-null uint8
# 10H50_sports_CFB       2923 non-null uint8
# 10H50_game_Lost_CFB    2923 non-null uint8
# 10H50_game_None_CFB    2923 non-null uint8
# 10H50_game_Won_CFB     2923 non-null uint8
# 1A10_sports_MLB        2923 non-null uint8
# 1A10_game_Lost_MLB     2923 non-null uint8
# 1A10_game_None_MLB     2923 non-null uint8
# 1A10_game_Won_MLB      2923 non-null uint8
# 10H30_sports_MLS       2923 non-null uint8
# 10H30_game_Lost_MLS    2923 non-null uint8
# 10H30_game_None_MLS    2923 non-null uint8
# 10H30_game_Won_MLS     2923 non-null uint8
# 1A10_sports_NBA        2923 non-null uint8
# 1A10_game_Lost_NBA     2923 non-null uint8
# 1A10_game_None_NBA     2923 non-null uint8
# 1A10_game_Won_NBA      2923 non-null uint8
# 15E40_sports_NFL       2923 non-null uint8
# 15E40_game_Lost_NFL    2923 non-null uint8
# 15E40_game_None_NFL    2923 non-null uint8
# 15E40_game_Won_NFL     2923 non-null uint8
# dtypes: int64(8), uint8(24)
# memory usage: 354.0 KB

# %%
# your turn
crm10 = dd['10H80_crime']

X = dd[['15E40_crime','10H50_crime','1A10_crime']]
X = X.values.reshape((-1,3))
lm = LinearRegression()
lm.fit(X, crm10)
prediction = lm.predict(X)

print('lm.coef_ : {}'.format(lm.coef_))
print('lm.intersept_: {}'.format(lm.intercept_))
# Out:
# lm.coef_ : [ 0.0130788   0.01703364 -0.01471162]
# lm.intersept_: 2.515501569058179

# %%
# ESS/TSS/R_sq
RSS = np.sum((crm10 - prediction )** 2)
ESS = np.sum(prediction - np.mean(crm10)) ** 2
R_sq = lm.score(X, crm10)

print('Residual Sum-of-Squares RSS       : {}'.format(RSS))
print('Explained Sum-of-Squares ESS      : {}'.format(ESS))
print('Coefficient of Determination R-sq : {}'.format(R_sq))
# Out:
# Residual Sum-of-Squares RSS       : 9367.589420887245
# Explained Sum-of-Squares ESS      : 8.905924075583135e-26
# Coefficient of Determination R-sq : 0.0013837689535134423

# %%
N = len(X)
K = 3
F = (R_sq/(1-R_sq))*(N-K-1)/K
print('F-statistic: ', F)
# Out:
# F-statistic:  1.3482728899345346

# %%
F,p_val = f_regression(X, crm10)
print('F-statistic: {}'.format(F))
# Out:
# F-statistic: [1.49061023 0.9231078  1.69152422]
