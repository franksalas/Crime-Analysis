# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
path =  'data/ready/DUMMY_Astros_final.csv'

# %%
df = pd.read_csv(path,index_col='Unnamed: 0', parse_dates=True)

# %%
df.head()
# Out:
#             Hour  OffenseType_Aggravated Assault  OffenseType_Auto Theft  \
# 2010-01-01     0                               0                       1
# 2010-01-01     0                               0                       0
# 2010-01-01     0                               0                       0
# 2010-01-01     0                               0                       0
# 2010-01-01     0                               0                       0
#
#             OffenseType_Burglary  OffenseType_Murder  OffenseType_Rape  \
# 2010-01-01                     0                   0                 0
# 2010-01-01                     0                   0                 0
# 2010-01-01                     1                   0                 0
# 2010-01-01                     0                   0                 0
# 2010-01-01                     0                   0                 0
#
#             OffenseType_Robbery  OffenseType_Theft     game
# ...

# %%
sns.distplot(df.Hour)
# Out:
# /home/frank/miniconda3/envs/springboard/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6448: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
_ = pd.scatter_matrix(df,
                      figsize=[8,8],
                      
                      s=150,
                      marker = 'D')
# Out:
# /home/frank/miniconda3/envs/springboard/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.scatter_matrix is deprecated. Use pandas.plotting.scatter_matrix instead
#   """

# %%
df.head()
# Out:
#             Hour  OffenseType_Aggravated Assault  OffenseType_Auto Theft  \
# 2010-01-01     0                               0                       1
# 2010-01-01     0                               0                       0
# 2010-01-01     0                               0                       0
# 2010-01-01     0                               0                       0
# 2010-01-01     0                               0                       0
#
#             OffenseType_Burglary  OffenseType_Murder  OffenseType_Rape  \
# 2010-01-01                     0                   0                 0
# 2010-01-01                     0                   0                 0
# 2010-01-01                     1                   0                 0
# 2010-01-01                     0                   0                 0
# 2010-01-01                     0                   0                 0
#
#             OffenseType_Robbery  OffenseType_Theft     game
# ...

# %%
sns.lmplot( x='OffenseType_Burglary', y="OffenseType_Robbery", data=df, fit_reg=False, hue='game', legend=True)
