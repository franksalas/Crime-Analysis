# %%
import pandas as pd
import glob, os
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Source
# - [Houston Police Department Crime Statistics](http://www.houstontx.gov/police/cs/crime-stats-archives.htm)
# 	- years: 2008 - 2017
# 	- format: Access or Excel

# %%
ls crime_data/2014
# Out:
# apr14.xls*  dec14.xls*  jan14.xls*  jun14.xls*  may14.xls*  oct14.xls*
# aug14.xls*  feb14.xls*  jul14.xls*  mar14.xls*  nov14.xls*  sep14.xls*

# %% [markdown]
# ## combine all files into one dataframe

# %%
path = 'crime_data/2014'
all_files = glob.glob(os.path.join(path, "*.xls")) 

df_from_each_file = (pd.read_excel(f) for f in all_files)
df   = pd.concat(df_from_each_file, ignore_index=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121750 entries, 0 to 121749
# Data columns (total 15 columns):
# # Of             7613 non-null float64
# # Of Offenses    52214 non-null float64
# # Offenses       10319 non-null float64
# # offenses       51604 non-null float64
# Beat             121734 non-null object
# Block Range      69989 non-null object
# BlockRange       51604 non-null object
# Date             121746 non-null datetime64[ns]
# Hour             121750 non-null object
# Offense Type     121750 non-null object
# Premise          92169 non-null object
# Street Name      70146 non-null object
# StreetName       51604 non-null object
# Suffix           121750 non-null object
# Type             121750 non-null object
# dtypes: datetime64[ns](1), float64(4), object(10)
# memory usage: 13.9+ MB

# %%
df.head(5)
# Out:
#    # Of  # Of Offenses  # Offenses  # offenses   Beat Block Range BlockRange  \
# 0   NaN            1.0         NaN         NaN  14D30   8500-8599        NaN
# 1   NaN            1.0         NaN         NaN  10H20   3600-3699        NaN
# 2   NaN            3.0         NaN         NaN   5F30   7400-7499        NaN
# 3   NaN            2.0         NaN         NaN  17E10   5400-5499        NaN
# 4   NaN            1.0         NaN         NaN  18F50   9300-9399        NaN
#
#         Date Hour Offense Type Premise         Street Name StreetName Suffix  \
# 0 2014-04-19   17       Murder     18D  MARTIN LUTHER KING        NaN      -
# 1 2014-04-28    5       Murder     13R            MCKINNEY        NaN      -
# 2 2014-04-27   18       Murder     20A            HILLMONT        NaN      -
# 3 2014-04-09   18       Murder     20A             RENWICK        NaN      -
# 4 2014-04-24    3       Murder     03B            RICHMOND        NaN      -
#
#    Type
# 0  BLVD
# 1    ST
# 2     -
# 3     -
# 4   AVE

# %% [markdown]
# ## Lets create a copy

# %%
df1 = df.copy()

# %%
df1.columns
# Out:
# Index(['# Of', '# Of Offenses', '# Offenses', '# offenses', 'Beat',
#        'Block Range', 'BlockRange', 'Date', 'Hour', 'Offense Type', 'Premise',
#        'Street Name', 'StreetName', 'Suffix', 'Type'],
#       dtype='object')

# %% [markdown]
# ## Duplicate columns
# We have duplicate columns with diffrent names
# - '# Of','# Of Offenses', '# Offenses', '# offenses'
# - 'Block Range', 'BlockRange'
# - 'Street Name', 'StreetName'
#
#
# lets concat the columns remove nan values and reindex

# %%
df1['BlockRange'] = pd.concat([df1['Block Range'].dropna(), df1['BlockRange'].dropna()]).reindex_like(df1)
df1['StreetName'] = pd.concat([df1['Street Name'].dropna(), df1['StreetName'].dropna()]).reindex_like(df1)
df1['# offenses'] = pd.concat([df1['# Of'].dropna(),df1['# Of Offenses'].dropna(),df1['# offenses'].dropna(), df1['# Offenses'].dropna()]).reindex_like(df1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121750 entries, 0 to 121749
# Data columns (total 15 columns):
# # Of             7613 non-null float64
# # Of Offenses    52214 non-null float64
# # Offenses       10319 non-null float64
# # offenses       121750 non-null float64
# Beat             121734 non-null object
# Block Range      69989 non-null object
# BlockRange       121593 non-null object
# Date             121746 non-null datetime64[ns]
# Hour             121750 non-null object
# Offense Type     121750 non-null object
# Premise          92169 non-null object
# Street Name      70146 non-null object
# StreetName       121750 non-null object
# Suffix           121750 non-null object
# Type             121750 non-null object
# dtypes: datetime64[ns](1), float64(4), object(10)
# memory usage: 13.9+ MB

# %%
df1.head(5)
# Out:
#    # Of  # Of Offenses  # Offenses  # offenses   Beat Block Range BlockRange  \
# 0   NaN            1.0         NaN         1.0  14D30   8500-8599  8500-8599
# 1   NaN            1.0         NaN         1.0  10H20   3600-3699  3600-3699
# 2   NaN            3.0         NaN         3.0   5F30   7400-7499  7400-7499
# 3   NaN            2.0         NaN         2.0  17E10   5400-5499  5400-5499
# 4   NaN            1.0         NaN         1.0  18F50   9300-9399  9300-9399
#
#         Date Hour Offense Type Premise         Street Name  \
# 0 2014-04-19   17       Murder     18D  MARTIN LUTHER KING
# 1 2014-04-28    5       Murder     13R            MCKINNEY
# 2 2014-04-27   18       Murder     20A            HILLMONT
# 3 2014-04-09   18       Murder     20A             RENWICK
# 4 2014-04-24    3       Murder     03B            RICHMOND
#
#            StreetName Suffix  Type
# 0  MARTIN LUTHER KING      -  BLVD
# 1            MCKINNEY      -    ST
# 2            HILLMONT      -     -
# 3             RENWICK      -     -
# 4            RICHMOND      -   AVE

# %% [markdown]
# ## create a subdataframe with the columns that we want

# %%
df14 = df1[['Date','Beat','BlockRange','StreetName','Offense Type','Premise','# offenses','Hour']]

# %%
df14.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121750 entries, 0 to 121749
# Data columns (total 8 columns):
# Date            121746 non-null datetime64[ns]
# Beat            121734 non-null object
# BlockRange      121593 non-null object
# StreetName      121750 non-null object
# Offense Type    121750 non-null object
# Premise         92169 non-null object
# # offenses      121750 non-null float64
# Hour            121750 non-null object
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 7.4+ MB

# %%
df14.tail()
# Out:
#              Date Beat BlockRange   StreetName Offense Type  \
# 121745 2014-09-15  UNK  2400-2499          LEE     Burglary
# 121746 2014-09-18  UNK  7900-7999  SAM HOUSTON        Theft
# 121747 2014-09-19  UNK  2700-2799         YALE     Burglary
# 121748 2014-09-18  UNK  9300-9399      GESSNER     Burglary
# 121749 2014-09-28  UNK  7900-7999      GESSNER        Theft
#
#                                     Premise  # offenses Hour
# 121745                   Residence or House         1.0   21
# 121746                Apartment Parking Lot         1.0   18
# 121747  Restaurant or Cafeteria Parking Lot         1.0    3
# 121748              Barber And Beauty Shops         1.0    7
# 121749                                  NaN         1.0    2

# %% [markdown]
# ## Now we can inspect df

# %%
df14.Date.unique() ##  timestamp
# Out:
# array(['2014-04-19T00:00:00.000000000', '2014-04-28T00:00:00.000000000',
#        '1914-11-02T00:00:00.000000000', '2014-09-05T00:00:00.000000000',
#        '2013-08-30T00:00:00.000000000', '2010-10-30T00:00:00.000000000',
#        '2005-10-27T00:00:00.000000000', '2006-08-21T00:00:00.000000000',
#        '2004-08-07T00:00:00.000000000', '2007-01-01T00:00:00.000000000',
#        '2013-05-06T00:00:00.000000000', '2003-01-24T00:00:00.000000000',
#        '2014-09-12T00:00:00.000000000', '2003-05-28T00:00:00.000000000',
#        '2013-11-25T00:00:00.000000000', '2009-09-16T00:00:00.000000000',
#        '2003-07-02T00:00:00.000000000', '2008-06-13T00:00:00.000000000',
#        '1971-02-03T00:00:00.000000000', '2011-08-01T00:00:00.000000000',
#        '2013-08-07T00:00:00.000000000', '2013-06-04T00:00:00.000000000',
#        '1914-09-08T00:00:00.000000000', '2013-06-25T00:00:00.000000000',
#        '2010-09-15T00:00:00.000000000', '2004-11-01T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %%
df14.Beat.unique()  ##
# Out:
# array(['14D30', '10H20', '5F30', '17E10', '18F50', '10H70', '19G20',
#        '2A10', '17E30', '2A60', '5F10', '16E20', '17E20', '19G40',
#        '19G10', '3B40', '10H50', '10H40', '16E30', '15E40', '6B50',
#        '6B40', '18F30', '2A40', '10H10', '3B30', '11H20', '12D70', '8C10',
#        '3B10', '14D40', '14D20', '1A50', '11H10', '9C40', '3B50', '2A20',
#        '7C30', '20G40', '1A30', '2A30', '6B60', '18F60', '1A20', '4F10',
#        '15E30', '12D30', '4F20', '19G50', '8C60', '15E20', '17E40',
#        '9C20', '14D10', '2A50', '1A10', '6B30', '7C40', '19G30', '11H30',
#        '9C30', '7C50', '20G10', '13D20', '13D10', '18F40', '20G30',
#        '6B10', '7C20', '12D40', '20G20', '16E40', '20G50', '12D20',
#        '5F40', '14D50', '13D30', '18F20', '12D10', '20G60', '15E10',
#        '5F20', '20G80', '7C10', '4F30', '6B20', '10H60', '8C20', '8C40',
#        '13D40', '16E10', '8C50', '8C30', '24C20', '24C50', '9C10',
#        '20G70', '24C10', '12D60', 'UNK', '10H30', '11H50', '24C30',
#        '12D50', '11H40', '10H80', '18F10', '24C60', '1A40', '24C40',
#        '21I50', '21I10', '23J50', '21I30', '21I20', '21I60', '21I70',
#        '23J40', 'UH-3P', '21I40', '23J30', nan, 'HCSO', 'OOJ', "'18F20",
#        "'1A30", "'14D10", "'6B20", "'3B40", "'2A50", "'2A30", "'18F30",
#        "'13D10", "'8C30", "'24C10", "'20G10", "'19G30", "'18F40",
#        "'11H30", "'12D10", "'10H10", "'5F40", "'7C50", "'21I50", "'8C20",
#        "'8C60", "'1A50", "'20G20", "'17E30", "'16E20", "'20G70", "'24C40",
#        "'15E40", "'20G30", "'1A40", "'19G10", "'19G50", "'4F10", "'4F20",
#        "'15E30", "'1A20", "'8C10", "'11H10", "'9C20", "'6B60", "'3B10",
#        "'20G40", "'2A20", "'10H20", "'12D60", "'9C40", "'UNK", "'8C40",
#        "'2A40", "'19G20", "'6B10", "'10H50", "'18F60", "'16E40", "'10H40",
#        "'6B40", "'7C30", "'6B30", "'5F30", "'8C50", "'1A10", "'10H30",
#        "'21I10", "'13D40", "'19G40", "'2A60", "'5F20", "'17E20", "'17E10",
#        "'10H60", "'24C30", "'11H50", "'7C40", "'14D20", "'12D50",
#        "'12D20", "'3B50", "'18F50", "'13D20", "'7C20", "'7C10", "'24C50",
#        "'15E10", "'15E20", "'9C10", "'12D30", "'10H70", "'3B30", "'16E10",
#        "'17E40", "'6B50", "'9C30", "'10H80", "'20G50", "'18F10", "'14D40",
#        "'11H20", "'14D30", "'16E30", "'2A10", "'20G60", "'5F10", "'20G80",
#        "'12D40", "'12D70", "'11H40", "'24C20", "'14D50", "'4F30",
#        "'23J50"], dtype=object)

# %%
df14.Beat.value_counts(dropna=False)  # needs cleanup
# Out:
# 19G10     2653
# 1A20      2570
# 6B60      2520
# 13D20     2447
# 1A10      2443
# 12D10     2370
# 17E10     2267
# 3B10      2047
# 18F30     2038
# 17E40     2030
# 18F20     2018
# 6B10      1991
# 14D20     1976
# 5F30      1911
# 2A50      1902
# 18F40     1834
# 20G30     1827
# 1A30      1777
# 18F50     1765
# 7C20      1760
# 5F40      1759
# 15E40     1741
# 20G50     1716
# 3B50      1712
# 11H10     1690
# 1A50      1684
# 9C40      1605
# 6B30      1546
# 17E30     1536
# 14D10     1477
#           ...
# '16E10       4
# '9C10        3
# 21I40        3
# '2A40        3
# '11H50       3
# 'UNK         3
# '4F10        3
# '16E40       3
# '24C10       3
# '3B30        3
# '5F10        3
# '10H20       3
# 23J40        3
# '24C30       2
# '21I50       2
# '12D40       2
# '14D50       2
# '21I10       2
# 23J30        2
# '11H20       2
# UH-3P        2
# '24C50       1
# '8C40        1
# '8C50        1
# '24C40       1
# '24C20       1
# '16E30       1
# '1A40        1
# '11H40       1
# '23J50       1
# Name: Beat, Length: 235, dtype: int64

# %%
df14.BlockRange.unique()  # UNK val
# Out:
# array(['8500-8599', '3600-3699', '7400-7499', '5400-5499', '9300-9399',
#        '2100-2199', '11100-11199', '10100-10199', '9000-9099',
#        '1700-1799', '1800-1899', '13100-13199', '7100-7199', '9700-9799',
#        '8800-8899', '500-599', '8700-8799', '2800-2899', '4500-4599',
#        '14700-14799', '2600-2699', '7200-7299', '100-199', '1300-1399',
#        '6500-6599', '6400-6499', '1400-1499', '3000-3099', '400-499',
#        '7300-7399', '4000-4099', '15200-15299', '4400-4499', '4200-4299',
#        '12800-12899', '3800-3899', '11700-11799', '2900-2999',
#        '6700-6799', '4800-4899', '5900-5999', '1200-1299', '4700-4799',
#        '11500-11599', '7500-7599', '1000-1099', '2400-2499', '6200-6299',
#        '2700-2799', '1900-1999', '1100-1199', '13700-13799', '9400-9499',
#        '9800-9899', '700-799', '9600-9699', '800-899', '5600-5699',
#        '6600-6699', '12600-12699', '11400-11499', '8600-8699',
#        '9900-9999', '7900-7999', '3200-3299', '12300-12399', '6000-6099',
#        '6300-6399', '17100-17199', '6100-6199', '300-399', '9500-9599',
#        '5700-5799', '2200-2299', '13000-13099', '8400-8499',
# 9500-9599        1262
# 7500-7599        1231
# 2700-2799        1211
# 5000-5099        1195
# 500-599          1184
# 1500-1599        1176
# 600-699          1168
# 1300-1399        1165
# 2500-2599        1139
# 6100-6199        1137
# 3800-3899        1118
# 5800-5899        1115
# 1100-1199        1113
# 1400-1499        1110
# 6400-6499        1109
# 2100-2199        1107
# 6000-6099        1099
# 5100-5199        1089
#                  ...
# 29800-29899         3
# 19300-19399         3
# 19800-19899         3
# 24900-24999         2
# 21500-21599         2
# 20000-20099         2
# 21400-21499         2
# 22000-22099         2
# 20500-20599         2
# 25800-25899         2
# 19900-19999         2
# 23100-23199         2
# 25500-25599         1
# 100000-100099       1
# 22800-22899         1
# 20400-20499         1
# 21900-21999         1
# 20700-20799         1
# 20100-20199         1
# 19700-19799         1
# 111100-111199       1
# 28200-28299         1
# 27700-27799         1
# 24300-24399         1
# 20300-20399         1
# 83000-83099         1
# 25000-25099         1
# 23800-23899         1
# 24700-24799         1
# 27300-27399         1
# Name: BlockRange, Length: 251, dtype: int64

# %%
df14.StreetName.unique()  #
# Out:
# array(['MARTIN LUTHER KING', 'MCKINNEY', 'HILLMONT', ..., 'ELANA',
#        'JOHNSTON', 'TIMOTHY'], dtype=object)

# %%
df14.StreetName.value_counts(dropna=False)  #
# Out:
# WESTHEIMER                  3458
# NORTH                       1790
# GULF                        1756
# GESSNER                     1680
# RICHMOND                    1628
# KATY                        1265
# BELLAIRE                    1225
# SOUTHWEST                   1207
# MAIN                        1203
# BISSONNET                   1194
# NORTHWEST                   1032
# FM 1960                      998
# BEECHNUT                     958
# GREENS                       951
# FONDREN                      933
# BELLFORT                     923
# BROADWAY                     921
# SAM HOUSTON                  888
# TIDWELL                      858
# POST OAK                     842
# LITTLE YORK                  835
# EAST                         809
# WAYSIDE                      801
# LOOP                         798
# SHEPHERD                     768
# AIRLINE                      687
# HILLCROFT                    684
# FANNIN                       611
# KIRBY                        602
# CULLEN                       539
#                             ...
# RAM                            1
# PHILMONT                       1
# CALHOUN RD                     1
# W.LAKE HOUSTON PWY             1
# HILLVALE                       1
# 6TH 1/2                        1
# RICHMOND HILL                  1
# FAWNGROVE                      1
# FULLERTON                      1
# TRANQUIL OAKS                  1
# 212.5 LENOX                    1
# WHEATON                        1
# ARP                            1
# HOLTCAMP                       1
# SOUTINE                        1
# KEW GARDEN                     1
# REDWOOD BOUGH                  1
# OAKSHIRE                       1
# ROYAL CRESCENT                 1
# SCAUP                          1
# ALIEF VILLAGE                  1
# STAGDON DR / OLD OAK  LN       1
# HYACINTH                       1
# BRIARTURN                      1
# RUSTIC CREEK                   1
# MASON ST.                      1
# FUQUA PR                       1
# MCKEAN                         1
# FANNIN EXIT                    1
# CANE VALLEY                    1
# Name: StreetName, Length: 7970, dtype: int64

# %%
df14['Offense Type'].unique()  # clean
# Out:
# array(['Murder', 'Rape', 'Robbery', 'Aggravated Assault', 'Burglary',
#        'Auto Theft', 'Theft'], dtype=object)

# %%
df14['Offense Type'].value_counts(dropna=False) # preatty clean
# Out:
# Theft                 66675
# Burglary              21145
# Auto Theft            13454
# Robbery                9998
# Aggravated Assault     9460
# Rape                    788
# Murder                  230
# Name: Offense Type, dtype: int64

# %%
df14.Premise.unique()  #lots of num& letter, & nan values
# Out:
# array(['18D', '13R', '20A', '03B', '250', '20D', '20N', '18A', '20R',
#        '20C', '150', '18N', '18P', '140', '18G', '22H', '18B', '18O',
#        '070', '18T', '210', '13S', '13B', '18M', '190', '11R', '05L',
#        '18U', '18C', '080', '24E', '24C', '23S', '100', '18R', '05O',
#        '03S', '120', '05Z', '18H', '05N', '01B', '05F', '20M', '05D',
#        '240', '18S', '24A', '13H', '11P', '20P', '13A', '20L', '18W',
#        '05C', '05M', '170', '05B', '09P', '---', '20G', '09D', '040',
#        '05E', '05Q', '24P', '24G', '05W', '20V', '05U', '05V', '060',
#        '22M', '24F', '05Y', '05R', '25V', '11G', '05X', '05G', '11L',
#        '22E', '11F', '04V', '09H', '24S', '02B', '22C', '22P', '01A',
#        '22U', '01K', '02S', '11S', '01P', '05S', '05H', '05T', '06',
#        '22D', '24B', '05A', '24J', '24M', '24T', '02C', '24V', '23C', 'N',
#        '09R', '05P', '01T', '13T', '18L', 'Residence or House',
#        'Driveway', 'Apartment Parking Lot', nan,
#        'Bar or Night Club Parking Lot', 'Convenience Store',
#        'Vacant Storage Fac (Barn,Garage,Warehouse)',
#        'Department or Discount Store', 'Warehouse',
#        'Strip Business Center Parking Lot',
#        'Factory, Manufacturing, or Industrial', 'Other Parking Lot',
#        'Apartment', 'Vehicle/Auto Sales/Lease/Auto Parts Store',
#        'Road, Street, or Sidewalk', 'Vacant Building (Commercial)',
#        'Condominium', 'Miscellaneous Business (Non-Specific)',
#        'Convenience Store Parking Lot',
#        'Commercial Parking Lot or Garage', 'Garage or Carport',
#        'Multi-Plex Home (Duplex,Triplex Etc.)',
#        'Laundry or Dry Cleaners Parking Lot',
#        "Physician, Doctor, Dentist's Office", 'Commercial Building',
#        'Service or Gas Station',
#        'Vacant Single Occ Resd(House,Townhs,Dplex)',
#        'Grocery Store or Supermarket', 'Auto Repair', 'Bar or Night Club',
#        'Restaurant or Cafeteria', 'Restaurant or Cafeteria Parking Lot',
#        'Bus Stop', 'Bus Station',
#        'Church, Synagogue, or Temple Parking Lot',
#        'Drug Store or Medical Supply', 'Office Building',
#        'Grocery Store or Supermarket Parking Lot',
#        'Hotel, Motel, Inn, Etc.', 'Alley', 'Mall Common Area',
#        'Church, Synagogue, or Temple', 'Construction Site',
#        'Vacant Other Out Build/Monument/UnderConst',
#        'Vacant Grocery Store or Supermarket', 'Elementary School',
#        'Liquor Store', 'Laundry, Dry Cleaners, Washaterias',
#        'Vacant Other Residential (Apartment,Dorms)',
#        'Parks and Recreation, Zoo, Swimming Pool', 'Hospital',
#        'Specialty Store (Non-Specific)', 'Government or Public Building',
#        'Amusement Park, Bowling Alley, Skate Rink',
#        'Hospital Parking Lot', 'Daycare, Child Care, or Kindergarten',
#        'University or College',
#        'Toys, Arts Craft,Musical, Bike,Pet Stores',
#        'Hotel or Motel Parking Lot', 'Mall Parking Lot', 'Body Shop',
#        'Gym, Recreat, Club House, Indoor Pool, Spa',
#        'Pawn, Resale Shop, or Flea Market',
#        'Savings and Loan Institutions', 'Other, Unknown, or Not Listed',
#        'Barber And Beauty Shops', 'Car Wash',
#        'Field, Woods, Forest, Park', 'Check Cashing Places',
#        'Pool Hall or Game Room', 'Adult Book Store or Newsstand',
#        'Furniture, Appliances, Radios, TV Store',
#        'Rental Storage Facility',
#        'Theatres, Dinner Theaters, Auditoriums', 'Park and Ride Terminal',
#        'Mobile Home', 'Bank', 'Private School', 'Clothing Store',
#        'Electronics Store, Electrical Supplies', 'Video Rental & Sales',
#        'Jewelry Stores', 'Sexually Oriented Business Parking Lot',
#        'Apartment Laundry', 'Rehabilitation Center', 'Police Station',
#        'Light Rail (Metro Rail) Vehicle', 'Nursing Home',
#        'Light Rail Platform', 'Book, Record, Stationary, Office Supplies',
#        'Stadium, Sports Arena, Race Track', 'Sexually Oriented Club',
#        'Bank or Savings Institution Parking Lot',
#        'Convention Center or Exhibit Halls', 'Libraries, Museums',
#        'Railroad Track or Right Of Way', 'Apartment Rental Office',
#        'Airport Terminal', 'Liquor Store Parking Lot', 'Middle School',
#        'Commercial Or Training School', 'Tollway', 'High Rise',
#        'Freeway Service Road', 'Highway or Freeway',
#        'Vacant School or College/University',
#        'Maintenance or Building Services',
#        'Utility Company, Electric, Gas, Water',
#        'Vacant Government or Public Building',
#        'Lake, Pond, Waterway, Bayou, River',
#        'Marine Vehicle Sales, Boats, Sailboats', 'High School',
#        'Jail or Prison', 'Vacant Restaurant', 'Fire Station',
#        'Sporting Goods or Gun Shops', 'Credit Union',
#        'Garden Supply, Nursery, or Florist',
#        'Social Services or Public Charities', 'Vacant Hotel, Motel, Etc.',
#        '160', '21V', '11C', '20H', '25R', '11V', '19V', '12V', '22V',
#        '14V', '20W', '01R', 'Train (Not Metro) Terminal',
#        'Contra-Flow, Managed, or HOV Lanes',
#        'Vacant Church, Synagogue, or Temple',
#        'Vacant Industrial or Manufacturing Blding', 'Vacant Bank'],
#       dtype=object)

# %%
df14.Premise.value_counts(dropna=False)  # LOTS NAN values!!!
# Out:
# NaN                                          29581
# 20R                                           6410
# Residence or House                            6384
# 20A                                           6094
# 18A                                           6072
# Apartment                                     4786
# Apartment Parking Lot                         4517
# 13R                                           3836
# Road, Street, or Sidewalk                     3465
# 20D                                           3222
# 18O                                           2999
# 18R                                           1757
# 080                                           1702
# Driveway                                      1665
# 120                                           1411
# Restaurant or Cafeteria Parking Lot           1411
# Department or Discount Store                  1277
# 18P                                           1181
# 23S                                           1104
# Other Parking Lot                             1071
# Miscellaneous Business (Non-Specific)         1017
# 18T                                            990
# 210                                            974
# Grocery Store or Supermarket                   927
# 250                                            906
# Commercial Parking Lot or Garage               899
# 240                                            887
# Service or Gas Station                         737
# 18M                                            662
# Strip Business Center Parking Lot              649
#                                              ...
# 22C                                              5
# Credit Union                                     5
# Vacant Hotel, Motel, Etc.                        5
# Vacant Church, Synagogue, or Temple              5
# Jail or Prison                                   5
# 01K                                              5
# 13T                                              4
# Vacant Restaurant                                4
# 12V                                              4
# 160                                              3
# 14V                                              3
# 25V                                              3
# 24V                                              3
# Fire Station                                     3
# Vacant Industrial or Manufacturing Blding        2
# Vacant Government or Public Building             2
# Train (Not Metro) Terminal                       2
# 25R                                              2
# 20W                                              2
# 11V                                              2
# 02C                                              1
# Marine Vehicle Sales, Boats, Sailboats           1
# 22V                                              1
# 01R                                              1
# 24M                                              1
# Vacant Bank                                      1
# 23C                                              1
# Tollway                                          1
# 19V                                              1
# Contra-Flow, Managed, or HOV Lanes               1
# Name: Premise, Length: 251, dtype: int64

# %%
df14['# offenses'].unique()
# Out:
# array([ 1.,  3.,  2.,  4.,  6.,  5., 12., 29.,  7.])

# %%
df14['# offenses'].value_counts(dropna=False)  # 2 locations with 10 offenses?
# Out:
# 1.0     119966
# 2.0       1560
# 3.0        176
# 4.0         27
# 5.0         11
# 6.0          7
# 7.0          1
# 12.0         1
# 29.0         1
# Name: # offenses, dtype: int64

# %%
df14.Hour.unique()  ## this needs cleanup!!!
# Out:
# array([17, 5, 18, 3, 6, 21, 13, 14, 2, 23, 12, 0, 8, 19, 20, 1, 9, 16, 15,
#        10, 22, 7, 11, 4, 24, '07', '05', '22', '15', '10', '19', '09',
#        '08', '14', "'15", '02', '12', "'07", '16', "'19", "'18", '21',
#        '17', '11', '13', '18', '06', "'00", "'05", "'13", "'14", "'22",
#        "'23", '04', '03', '23', '20', '00', "'20", "'16", '01', "'17",
#        "'06", "'03", "'01", "'09", "'02", "'10", "'11", "'12", "'21",
#        "'08", "'04"], dtype=object)

# %%
df14.Hour.value_counts(dropna=False)  #strip the string chars and keep only nums
# Out:
# 18     6665
# 15     6615
# 16     6553
# 17     6430
# 12     6415
# 19     6192
# 14     6181
# 20     5899
# 13     5889
# 10     5732
# 11     5686
# 9      5313
# 21     5291
# 22     5003
# 8      4927
# 0      4446
# 23     4071
# 7      4001
# 6      2643
# 1      2420
# 2      2414
# 3      1910
# 5      1825
# 4      1615
# 14      412
# 15      410
# 09      405
# 16      400
# 11      383
# 12      377
#        ...
# 02      144
# 05      129
# 03      117
# 01      115
# 04       94
# '00      91
# '12      73
# '18      69
# '22      64
# '17      56
# '16      53
# '20      51
# '23      48
# '19      48
# '21      48
# '14      44
# '08      43
# '15      43
# '10      40
# '13      38
# '11      33
# '07      29
# '09      25
# '02      25
# '01      24
# '06      17
# '05      16
# '03      12
# '04      10
# 24        1
# Name: Hour, Length: 73, dtype: int64

# %% [markdown]
# # Cleanup
# ## Premise Column
#
# - strip empty spaces : NOT NEEDED

# %%
len(df14.Premise.unique())
# Out:
# 251

# %%
df14['Premise'] = df14['Premise'].str.strip()
# Out:
# /home/salas/miniconda3/envs/springboard/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
len(df14.Premise.unique())
# Out:
# 251

# %%
df14[df14.Premise.isnull()].head()  # 29581
# Out:
#             Date   Beat BlockRange  StreetName        Offense Type Premise  \
# 10412 2014-08-08  10H10  5300-5399  HARRISBURG  Aggravated Assault     NaN
# 10419 2014-08-23  10H10        UNK       ENNIS               Theft     NaN
# 10420 2014-08-25  10H10    100-199    LOCKWOOD               Theft     NaN
# 10423 2014-08-02  10H10    200-299     ROBERTS               Theft     NaN
# 10448 2014-07-27  10H10  3900-3999      BERING  Aggravated Assault     NaN
#
#        # offenses Hour
# 10412         1.0   18
# 10419         1.0    0
# 10420         1.0   12
# 10423         1.0   18
# 10448         1.0   15

# %%
df14.Premise.value_counts(dropna=False).head()  # LOTS NANS
# Out:
# NaN                   29581
# 20R                    6410
# Residence or House     6384
# 20A                    6094
# 18A                    6072
# Name: Premise, dtype: int64

# %% [markdown]
# # Cleanup
# ## Offense Type Column
# superclean: no need to touch

# %%
df14['Offense Type'].value_counts(dropna=False)
# Out:
# Theft                 66675
# Burglary              21145
# Auto Theft            13454
# Robbery                9998
# Aggravated Assault     9460
# Rape                    788
# Murder                  230
# Name: Offense Type, dtype: int64

# %%
df14['Offense Type'].unique()
# Out:
# array(['Murder', 'Rape', 'Robbery', 'Aggravated Assault', 'Burglary',
#        'Auto Theft', 'Theft'], dtype=object)

# %%
len(df14['Offense Type'].unique())
# Out:
# 7

# %%
df14['Offense Type'] = df14['Offense Type'].str.strip()
# Out:
# /home/salas/miniconda3/envs/springboard/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df14['Offense Type'].value_counts(dropna=False)
# Out:
# Theft                 66675
# Burglary              21145
# Auto Theft            13454
# Robbery                9998
# Aggravated Assault     9460
# Rape                    788
# Murder                  230
# Name: Offense Type, dtype: int64

# %%
len(df14['Offense Type'].unique())
# Out:
# 7

# %% [markdown]
# # Cleanup
# ## StreetName Column
#
# - strip empty spaces
# - find similar values and combine ( needs done)

# %%
df14.StreetName.value_counts(dropna=False).head()
# Out:
# WESTHEIMER    3458
# NORTH         1790
# GULF          1756
# GESSNER       1680
# RICHMOND      1628
# Name: StreetName, dtype: int64

# %%
len(df14.StreetName.unique())
# Out:
# 7970

# %%
df14['StreetName'] = df14['StreetName'].str.strip()
# Out:
# /home/salas/miniconda3/envs/springboard/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
len(df14.StreetName.unique())
# Out:
# 7966

# %%
df14[df14.StreetName.isnull()].head()  # 24 nan values
# Out:
#             Date  Beat BlockRange StreetName Offense Type  \
# 15965 2014-08-06  1A20        UNK        NaN        Theft
# 17617 2014-07-21  2A30        UNK        NaN        Theft
# 17631 2014-08-15  2A30        UNK        NaN     Burglary
# 17689 2014-08-15  2A30        UNK        NaN   Auto Theft
# 17712 2014-08-21  2A30        UNK        NaN        Theft
#
#                      Premise  # offenses Hour
# 15965                    NaN         1.0   17
# 17617               Driveway         1.0   10
# 17631      Garage or Carport         1.0    6
# 17689  Apartment Parking Lot         1.0   15
# 17712     Residence or House         1.0   12

# %%
df14.StreetName.value_counts(dropna=False).head()
# Out:
# WESTHEIMER    3458
# NORTH         1790
# GULF          1756
# GESSNER       1680
# RICHMOND      1628
# Name: StreetName, dtype: int64

# %% [markdown]
# # Cleanup
# ## BlockRange Column
#
# - create mask to find 'UNK' values
# - match with similar beat value (Needs to be done)

# %%
df14.BlockRange.value_counts(dropna=False).head()  # find UNK
# Out:
# 100-199      1880
# 2300-2399    1671
# 900-999      1636
# 1000-1099    1415
# 4400-4499    1412
# Name: BlockRange, dtype: int64

# %%
unk = df14.BlockRange == 'UNK'  # boolean mask

# %%
df14[unk].head()  # 805 rows
# Out:
#             Date   Beat BlockRange    StreetName Offense Type  \
# 10419 2014-08-23  10H10        UNK         ENNIS        Theft
# 10426 2014-08-23  10H10        UNK         ENNIS        Theft
# 10666 2014-08-25  10H40        UNK        FANNIN        Theft
# 10674 2014-06-28  10H40        UNK       MCGOWEN        Theft
# 10833 2014-08-25  10H60        UNK  2 CHARLESTON        Theft
#
#                          Premise  # offenses Hour
# 10419                        NaN         1.0    0
# 10426          Other Parking Lot         1.0    0
# 10666  Road, Street, or Sidewalk         1.0   20
# 10674          Bar or Night Club         1.0   20
# 10833         Residence or House         1.0   23

# %% [markdown]
# # Cleanup
# ## Beat Column
#
# - strip empty spaces

# %%
df14.Beat.unique()
# Out:
# array(['14D30', '10H20', '5F30', '17E10', '18F50', '10H70', '19G20',
#        '2A10', '17E30', '2A60', '5F10', '16E20', '17E20', '19G40',
#        '19G10', '3B40', '10H50', '10H40', '16E30', '15E40', '6B50',
#        '6B40', '18F30', '2A40', '10H10', '3B30', '11H20', '12D70', '8C10',
#        '3B10', '14D40', '14D20', '1A50', '11H10', '9C40', '3B50', '2A20',
#        '7C30', '20G40', '1A30', '2A30', '6B60', '18F60', '1A20', '4F10',
#        '15E30', '12D30', '4F20', '19G50', '8C60', '15E20', '17E40',
#        '9C20', '14D10', '2A50', '1A10', '6B30', '7C40', '19G30', '11H30',
#        '9C30', '7C50', '20G10', '13D20', '13D10', '18F40', '20G30',
#        '6B10', '7C20', '12D40', '20G20', '16E40', '20G50', '12D20',
#        '5F40', '14D50', '13D30', '18F20', '12D10', '20G60', '15E10',
#        '5F20', '20G80', '7C10', '4F30', '6B20', '10H60', '8C20', '8C40',
#        '13D40', '16E10', '8C50', '8C30', '24C20', '24C50', '9C10',
#        '20G70', '24C10', '12D60', 'UNK', '10H30', '11H50', '24C30',
#        '12D50', '11H40', '10H80', '18F10', '24C60', '1A40', '24C40',
#        '21I50', '21I10', '23J50', '21I30', '21I20', '21I60', '21I70',
#        '23J40', 'UH-3P', '21I40', '23J30', nan, 'HCSO', 'OOJ', "'18F20",
#        "'1A30", "'14D10", "'6B20", "'3B40", "'2A50", "'2A30", "'18F30",
#        "'13D10", "'8C30", "'24C10", "'20G10", "'19G30", "'18F40",
#        "'11H30", "'12D10", "'10H10", "'5F40", "'7C50", "'21I50", "'8C20",
#        "'8C60", "'1A50", "'20G20", "'17E30", "'16E20", "'20G70", "'24C40",
#        "'15E40", "'20G30", "'1A40", "'19G10", "'19G50", "'4F10", "'4F20",
#        "'15E30", "'1A20", "'8C10", "'11H10", "'9C20", "'6B60", "'3B10",
#        "'20G40", "'2A20", "'10H20", "'12D60", "'9C40", "'UNK", "'8C40",
#        "'2A40", "'19G20", "'6B10", "'10H50", "'18F60", "'16E40", "'10H40",
#        "'6B40", "'7C30", "'6B30", "'5F30", "'8C50", "'1A10", "'10H30",
#        "'21I10", "'13D40", "'19G40", "'2A60", "'5F20", "'17E20", "'17E10",
#        "'10H60", "'24C30", "'11H50", "'7C40", "'14D20", "'12D50",
#        "'12D20", "'3B50", "'18F50", "'13D20", "'7C20", "'7C10", "'24C50",
#        "'15E10", "'15E20", "'9C10", "'12D30", "'10H70", "'3B30", "'16E10",
#        "'17E40", "'6B50", "'9C30", "'10H80", "'20G50", "'18F10", "'14D40",
#        "'11H20", "'14D30", "'16E30", "'2A10", "'20G60", "'5F10", "'20G80",
#        "'12D40", "'12D70", "'11H40", "'24C20", "'14D50", "'4F30",
#        "'23J50"], dtype=object)

# %%
len(df14.Beat.unique())
# Out:
# 235

# %%
df14['Beat'] = df14['Beat'].str.strip()
# Out:
# /home/salas/miniconda3/envs/springboard/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
len(df14.Beat.unique())
# Out:
# 235

# %%
df14.Beat.value_counts(dropna=False)
# Out:
# 19G10     2653
# 1A20      2570
# 6B60      2520
# 13D20     2447
# 1A10      2443
# 12D10     2370
# 17E10     2267
# 3B10      2047
# 18F30     2038
# 17E40     2030
# 18F20     2018
# 6B10      1991
# 14D20     1976
# 5F30      1911
# 2A50      1902
# 18F40     1834
# 20G30     1827
# 1A30      1777
# 18F50     1765
# 7C20      1760
# 5F40      1759
# 15E40     1741
# 20G50     1716
# 3B50      1712
# 11H10     1690
# 1A50      1684
# 9C40      1605
# 6B30      1546
# 17E30     1536
# 14D10     1477
#           ...
# '16E10       4
# '9C10        3
# 21I40        3
# '2A40        3
# '11H50       3
# 'UNK         3
# '4F10        3
# '16E40       3
# '24C10       3
# '3B30        3
# '5F10        3
# '10H20       3
# 23J40        3
# '24C30       2
# '21I50       2
# '12D40       2
# '14D50       2
# '21I10       2
# 23J30        2
# '11H20       2
# UH-3P        2
# '24C50       1
# '8C40        1
# '8C50        1
# '24C40       1
# '24C20       1
# '16E30       1
# '1A40        1
# '11H40       1
# '23J50       1
# Name: Beat, Length: 235, dtype: int64

# %%
df14[df14['Beat'].isnull()].head() # 16 nan values
# Out:
#             Date Beat BlockRange StreetName Offense Type Premise  # offenses  \
# 52628 2014-07-19  NaN  2100-2199    VINTAGE        Theft     NaN         1.0
# 52629 2014-07-13  NaN    500-599     W.38TH        Theft     NaN         1.0
# 52630 2014-07-26  NaN  6100-6199   ATTWATER         Rape     NaN         1.0
# 52631 2014-07-13  NaN  7800-7899    FM 1960        Theft     NaN         1.0
# 52632 2014-07-14  NaN  6600-6699      MERRY        Theft     NaN         1.0
#
#       Hour
# 52628   11
# 52629    8
# 52630   15
# 52631   15
# 52632    9

# %% [markdown]
# ## Cleanup
#
# ### time column

# %%
df14.Hour.unique()
# Out:
# array([17, 5, 18, 3, 6, 21, 13, 14, 2, 23, 12, 0, 8, 19, 20, 1, 9, 16, 15,
#        10, 22, 7, 11, 4, 24, '07', '05', '22', '15', '10', '19', '09',
#        '08', '14', "'15", '02', '12', "'07", '16', "'19", "'18", '21',
#        '17', '11', '13', '18', '06', "'00", "'05", "'13", "'14", "'22",
#        "'23", '04', '03', '23', '20', '00', "'20", "'16", '01', "'17",
#        "'06", "'03", "'01", "'09", "'02", "'10", "'11", "'12", "'21",
#        "'08", "'04"], dtype=object)

# %%
df14.Hour.value_counts(dropna=False)  # too much trouble to clean?
# Out:
# 18     6665
# 15     6615
# 16     6553
# 17     6430
# 12     6415
# 19     6192
# 14     6181
# 20     5899
# 13     5889
# 10     5732
# 11     5686
# 9      5313
# 21     5291
# 22     5003
# 8      4927
# 0      4446
# 23     4071
# 7      4001
# 6      2643
# 1      2420
# 2      2414
# 3      1910
# 5      1825
# 4      1615
# 14      412
# 15      410
# 09      405
# 16      400
# 11      383
# 12      377
#        ...
# 02      144
# 05      129
# 03      117
# 01      115
# 04       94
# '00      91
# '12      73
# '18      69
# '22      64
# '17      56
# '16      53
# '20      51
# '23      48
# '19      48
# '21      48
# '14      44
# '08      43
# '15      43
# '10      40
# '13      38
# '11      33
# '07      29
# '09      25
# '02      25
# '01      24
# '06      17
# '05      16
# '03      12
# '04      10
# 24        1
# Name: Hour, Length: 73, dtype: int64

# %% [markdown]
# ## Cleanup
#
# ### Date column
# - convert to datetime
# - index date colimn
# - sort index

# %%
df14.head(5)
# Out:
#         Date   Beat BlockRange          StreetName Offense Type Premise  \
# 0 2014-04-19  14D30  8500-8599  MARTIN LUTHER KING       Murder     18D
# 1 2014-04-28  10H20  3600-3699            MCKINNEY       Murder     13R
# 2 2014-04-27   5F30  7400-7499            HILLMONT       Murder     20A
# 3 2014-04-09  17E10  5400-5499             RENWICK       Murder     20A
# 4 2014-04-24  18F50  9300-9399            RICHMOND       Murder     03B
#
#    # offenses Hour
# 0         1.0   17
# 1         1.0    5
# 2         3.0   18
# 3         2.0   18
# 4         1.0    3

# %%
df14['Date'] = pd.to_datetime(df14['Date'])

df14 = df14.set_index('Date').sort_index(ascending=True)
# Out:
# /home/salas/miniconda3/envs/springboard/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df14.head(5)
# Out:
#              Beat   BlockRange    StreetName Offense Type  \
# Date
# 1914-09-08  24C60  12700-12799  LAKE HOUSTON     Burglary
# 1914-11-02  18F60    8800-8899      BELLAIRE     Burglary
# 1914-12-03  12D20  12800-12899          GULF   Auto Theft
# 1920-06-28  17E40  12100-12199    FAIRMEADOW        Theft
# 1924-12-09    UNK  11000-11099        EASTEX        Theft
#
#                                           Premise  # offenses Hour
# Date
# 1914-09-08                Restaurant or Cafeteria         1.0    7
# 1914-11-02  Miscellaneous Business (Non-Specific)         1.0    3
# 1914-12-03                                    NaN         1.0   19
# 1920-06-28                                    NaN         1.0   16
# 1924-12-09      Strip Business Center Parking Lot         1.0   11

# %%
df14.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 121750 entries, 1914-09-08 to NaT
# Data columns (total 7 columns):
# Beat            121734 non-null object
# BlockRange      121593 non-null object
# StreetName      121726 non-null object
# Offense Type    121750 non-null object
# Premise         92169 non-null object
# # offenses      121750 non-null float64
# Hour            121750 non-null object
# dtypes: float64(1), object(6)
# memory usage: 7.4+ MB

# %% [markdown]
# ## Odd dates
# `DatetimeIndex: 121750 entries, 1914-09-08 to NaT`
#
# - some values are not from this year, lets look

# %%
df2014 = df14.loc['2014-01-01':'2014-12-31']  # rows with date from 01,01,14 - 12,31,14

# %%
df2014_wrong_date = df14[:"2013"]  # rows with year 0  upto 2014

# %%
df2014.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 120520 entries, 2014-01-01 to 2014-12-31
# Data columns (total 7 columns):
# Beat            120506 non-null object
# BlockRange      120367 non-null object
# StreetName      120496 non-null object
# Offense Type    120520 non-null object
# Premise         91064 non-null object
# # offenses      120520 non-null float64
# Hour            120520 non-null object
# dtypes: float64(1), object(6)
# memory usage: 7.4+ MB

# %% [markdown]
# # NAN values
#
# - Beat: 14
# - BlockRange: 153
# - StreetName: 24
# - Offense Type: 0
# - Premise: 29456
# - Hour: 0

# %%
beat_nan = df2014.Beat.isnull()
block_nan = df2014.BlockRange.isnull()
str_nan = df2014.StreetName.isnull()
off_nan = df2014['Offense Type'].isnull()
premise_nan = df2014.Premise.isnull()  #
hour_nan = df2014.Hour.isnull()  #

# %%
len(df2014[hour_nan])
# Out:
# 0

# %% [markdown]
# ## DROP nan
# drop nan values of StreetName

# %%
df2014.head()
# Out:
#              Beat BlockRange        StreetName        Offense Type Premise  \
# Date
# 2014-01-01  19G10  7400-7499  WEST SAM HOUSTON               Theft     18O
# 2014-01-01  19G10  7400-7499  WEST SAM HOUSTON               Theft     11R
# 2014-01-01   1A10  1500-1599            PIERCE             Robbery     13R
# 2014-01-01  19G10  7400-7499  WEST SAM HOUSTON               Theft     18O
# 2014-01-01   4F10  9500-9599        LONG POINT  Aggravated Assault     20A
#
#             # offenses Hour
# Date
# 2014-01-01         1.0   12
# 2014-01-01         1.0   11
# 2014-01-01         1.0    6
# 2014-01-01         1.0   11
# 2014-01-01         1.0   10

# %%
df2014 = df2014.dropna(subset=['StreetName'])  # drop nan values from StreetName,

# %%
df2014.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 120496 entries, 2014-01-01 to 2014-12-31
# Data columns (total 7 columns):
# Beat            120482 non-null object
# BlockRange      120346 non-null object
# StreetName      120496 non-null object
# Offense Type    120496 non-null object
# Premise         91047 non-null object
# # offenses      120496 non-null float64
# Hour            120496 non-null object
# dtypes: float64(1), object(6)
# memory usage: 7.4+ MB

# %%
df2014['Premise'] = df2014['Premise'].fillna('unk')

# %%
df2014.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 120496 entries, 2014-01-01 to 2014-12-31
# Data columns (total 7 columns):
# Beat            120482 non-null object
# BlockRange      120346 non-null object
# StreetName      120496 non-null object
# Offense Type    120496 non-null object
# Premise         120496 non-null object
# # offenses      120496 non-null float64
# Hour            120496 non-null object
# dtypes: float64(1), object(6)
# memory usage: 7.4+ MB

# %% [markdown]
# ## Final result
#
# - Beat            120482 non-null object
# - BlockRange      120346 non-null object
#
# - Hour column still has extra quotes that needs to be removed
#
#
#
# will leave as is , can be fill with similar data from other years

# %% [markdown]
# ## Save clean data to  to csv

# %%
df2014.to_csv('clean_data/crime_data/crime14_clean.csv')

# %%
ls clean_data/crime_data/
# Out:
# crime14_clean.csv*  crime15_clean.csv*  crime16_clean.csv*  crime17_clean.csv*
