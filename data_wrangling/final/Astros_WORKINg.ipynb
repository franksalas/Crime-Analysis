# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd
import seaborn as sns

# %%
path ='data/crime_astros_final.csv'
games = 'sports_scores/astros_1A10.csv'

# %%
df = pd.read_csv(path)
df=df.rename(columns = {'Unnamed: 0':'date',
                       'Hour':'hour'})
df.hour = df.hour.astype(int)
df.day = df.day.astype(int)
df.year = df.year.astype(int)
df.date = pd.to_datetime(df.date)  # datetime index
df = df.set_index('date').sort_index(ascending=True)
df['game_on'] = np.where(df.game =='No Game',0,1)
df.drop(['game'],axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 23947 entries, 2010-01-01 to 2017-12-31
# Data columns (total 14 columns):
# Beat            23947 non-null object
# OffenseType     23947 non-null object
# Premise         23947 non-null object
# NumOffenses     23947 non-null float64
# hour            23947 non-null int64
# day             23947 non-null int64
# weekday         23947 non-null object
# month           23947 non-null object
# year            23947 non-null int64
# lat             23947 non-null float64
# lon             23947 non-null float64
# add             23947 non-null object
# dist_stadium    23947 non-null float64
# game_on         23947 non-null int64
# dtypes: float64(4), int64(4), object(6)
# memory usage: 3.4+ MB

# %%
df.head()
# Out:
#             Beat OffenseType                          Premise  NumOffenses  \
# date
# 2010-01-01  1A10  Auto Theft       bar/night club parking lot          1.0
# 2010-01-01  1A10       Theft                   bar/night club          1.0
# 2010-01-01  1A10    Burglary                  office building          1.0
# 2010-01-01  1A10       Theft                    other/unknown          1.0
# 2010-01-01  1A10       Theft  convention center/exhibit halls          1.0
#
#             hour  day weekday month  year        lat        lon  \
# date
# 2010-01-01     0    1  Friday   Jan  2010  29.757212 -95.353294
# 2010-01-01     0    1  Friday   Jan  2010  29.753512 -95.363811
# 2010-01-01     0    1  Friday   Jan  2010  29.760954 -95.362089
# 2010-01-01     0    1  Friday   Jan  2010  29.755595 -95.367677
# 2010-01-01     0    1  Friday   Jan  2010  29.752015 -95.359181
#
#                                                           add  dist_stadium  \
# date
# 2010-01-01            350 Hamilton St, Houston, TX 77002, USA      0.137184
# 2010-01-01           1250 Caroline St, Houston, TX 77002, USA      0.549562
# 2010-01-01              450 S Main St, Houston, TX 77002, USA      0.480008
# 2010-01-01             1250 Travis St, Houston, TX 77002, USA      0.734357
# 2010-01-01  1050 Avenida De Las Americas, Houston, TX 7701...      0.403381
#
#             game_on
# date
# 2010-01-01        0
# 2010-01-01        0
# 2010-01-01        0
# 2010-01-01        0
# 2010-01-01        0

# %%
# games = df[['game_on']]
# games.head()

# %%
games = 'sports_scores/astros_1A10.csv'

# %%
game_df = pd.read_csv(games,index_col='date').sort_index(ascending=True)

## win column
game_df['win'] =  np.where(game_df['team_score'] > game_df['opp_score'],1,0)

# only oposing name and win boolean
#df = df[['opposing','win']]
game_df = game_df[['win']]


# show

game_df.head()
# Out:
#             win
# date
# 2010-04-05    0
# 2010-04-06    0
# 2010-04-07    0
# 2010-04-09    0
# 2010-04-10    0

# %% [markdown]
# ## merge

# %%
crime_game = pd.merge(df,game_df,  left_index=True, right_index=True, how='left')
crime_game
# Out:
# 2017-12-31 -95.354628              750 Walnut St, Houston, TX 77002, USA
# 2017-12-31 -95.341881          450 N Live Oak St, Houston, TX 77003, USA
# 2017-12-31 -95.347639           2350 Commerce St, Houston, TX 77003, USA
# 2017-12-31 -95.284769         6950 Oak Village Dr, Humble, TX 77396, USA
# 2017-12-31 -95.346909             3650 Dennis St, Houston, TX 77004, USA
#
#             dist_stadium  game_on  win
# date
# 2010-01-01      0.137184        0  NaN
# 2010-01-01      0.549562        0  NaN
# 2010-01-01      0.480008        0  NaN
# 2010-01-01      0.734357        0  NaN
# 2010-01-01      0.403381        0  NaN
# 2010-01-01      0.617517        0  NaN
# 2010-01-01      0.513569        0  NaN
# 2010-01-01      0.286270        0  NaN
# 2010-01-01      0.734357        0  NaN
# 2010-01-01      0.513569        0  NaN
# 2010-01-01      0.688051        0  NaN
# 2010-01-01      1.646844        0  NaN
# 2010-01-01      0.464100        0  NaN
# 2010-01-01      0.484864        0  NaN
# 2010-01-01      0.484864        0  NaN
# 2010-01-01      1.293373        0  NaN
# 2010-01-01      0.352089        0  NaN
# 2010-01-01      0.833475        0  NaN
# 2010-01-02      0.770779        0  NaN
# 2010-01-02      0.589988        0  NaN
# 2010-01-02      0.734357        0  NaN
# 2010-01-02      0.484539        0  NaN
# 2010-01-02      0.734357        0  NaN
# 2010-01-02      0.403381        0  NaN
# 2010-01-02      0.479434        0  NaN
# 2010-01-02      0.856047        0  NaN
# 2010-01-02      0.301551        0  NaN
# 2010-01-02      0.399452        0  NaN
# 2010-01-02      0.560088        0  NaN
# 2010-01-02      1.150279        0  NaN
# ...                  ...      ...  ...
# 2017-12-27     18.910601        0  NaN
# 2017-12-27      2.628923        0  NaN
# 2017-12-27      0.902945        0  NaN
# 2017-12-27      0.315227        0  NaN
# 2017-12-28      0.209963        0  NaN
# 2017-12-28      0.537568        0  NaN
# 2017-12-28      1.079949        0  NaN
# 2017-12-28      1.463465        0  NaN
# 2017-12-28      0.852013        0  NaN
# 2017-12-28      7.236403        0  NaN
# 2017-12-28      0.833475        0  NaN
# 2017-12-29      0.856047        0  NaN
# 2017-12-29      0.592771        0  NaN
# 2017-12-29      7.348322        0  NaN
# 2017-12-29      5.751672        0  NaN
# 2017-12-29      0.547409        0  NaN
# 2017-12-29      1.044944        0  NaN
# 2017-12-29      0.735014        0  NaN
# 2017-12-30     22.639994        0  NaN
# 2017-12-30      0.896988        0  NaN
# 2017-12-30      0.852013        0  NaN
# 2017-12-30     12.171158        0  NaN
# 2017-12-31      0.470373        0  NaN
# 2017-12-31      1.049378        0  NaN
# 2017-12-31     11.425112        0  NaN
# 2017-12-31      0.704084        0  NaN
# 2017-12-31      0.839089        0  NaN
# 2017-12-31      0.477558        0  NaN
# 2017-12-31     13.060760        0  NaN
# 2017-12-31      1.853094        0  NaN
#
# [23963 rows x 15 columns]

# %%
ww.win.unique()

# %%
crime_sum_days = df.groupby(df.index)['OffenseType',].count()
crime_sum_days.head()
# Out:
#             OffenseType
# date
# 2010-01-01           18
# 2010-01-02           13
# 2010-01-03           12
# 2010-01-04            9
# 2010-01-05            8

# %% [markdown]
# ## Trim df

# %%
print(list(df.columns))

# %%
#df= df[[ 'OffenseType', 'hour', 'weekday', 'dist_stadium', 'game_on']]
df = df[[ 'OffenseType', 'hour', 'dist_stadium', 'game_on']]

# %%
df.head()

# %%
df.describe()

# %% [markdown]
# ## TEST1

# %%
one_mile =  df.dist_stadium <= 3.0
df = df[one_mile]

# %%
# find distribution of target column / trying to predict
sns.distplot(df['dist_stadium'])

# %%
df.corr()

# %%
sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# ## Get dummies

# %%
pd.get_dummies?

# %%
dfdm = pd.get_dummies(df, drop_first=True)

# %%
sns.heatmap(dfdm.corr(),annot=False)

# %%
dfdm.head()

# %%
df.head()

# %% [markdown]
# ## Pairplot

# %%
#sns.pairplot(dfdm)

# %%
#dfdm.drop(['dist_stadium'],axis=1)
#dfdm['game_on']

# %%
sns.lmplot(x='game_on',y='dist_stadium', data=dfdm)

# %%
from sklearn.cross_validation import train_test_split

X = dfdm.drop(['dist_stadium'],axis=1)

y = dfdm['dist_stadium']

X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                test_size=0.3,
                                random_state=42)

# %% [markdown]
# # train model

# %%
from sklearn.linear_model import LinearRegression

# create a linear regression object
model =  LinearRegression()


# train fit model
model.fit(X_train,y_train)

# %% [markdown]
# # Evalueate model

# %%
print(model.intercept_)
print(model.coef_)

# %% [markdown]
# ## Create a dataframe from coeff

# %%
coeff_df = pd.DataFrame(model.coef_,X.columns,columns=['Coefficient'])
coeff_df

# %% [markdown]
# ## Predictions from our test

# %%
predictions = model.predict(X_test)

# %% [markdown]
# ## Pefrorm scatteplot

# %%
plt.scatter(y_test,predictions)
plt.xlabel('Y Test (True Values)')
plt.ylabel('Predicted Y')
plt.show()

# %%
# histogram of the residuals
sns.distplot((y_test - predictions),bins='auto')

# %% [markdown]
# ## Calculate metrics

# %%
from sklearn import metrics

# %% [markdown]
# ## MAE
# **Mean Absolute Error** (MAE) is the mean of the absolute value of the errors:
# - mean of the absolute error
# - take your error and take the absolute value of it and average it out.
#
# $$\frac 1n\sum_{i=1}^n|y_i-\hat{y}_i|$$

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))

# %%
def L1(yHat, y):
    return np.sum(np.absolute(yHat - y))

L1(y_test,predictions)

# %% [markdown]
# # MSE
#
# **Mean Squared Error** (MSE) is the mean of the squared errors:
#
# - mean of the squared errors
# - popular b/c it punish larger errors
# - more usefull in the real world  because it takes into account larger b/c its square them.
#
#
# $$\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2$$

# %%
print('MSE:', metrics.mean_squared_error(y_test, predictions))

# %%
def MSE(yHat, y):
    return np.sum((yHat - y)**2) / y.size

MSE(y_test,predictions)

# %% [markdown]
# # RMSE
# **Root Mean Squared Error** (RMSE) is the square root of the mean of the squared errors:
#
# $$\sqrt{\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2}$$

# %%
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))

# %% [markdown]
# ## RSQ

# %%
print('RSQ:', metrics.explained_variance_score(y_test, predictions))

# %%
params = pd.Series(model.coef_, index=X.columns)
params

# %%
from sklearn.utils import resample
np.random.seed(1)
err = np.std([model.fit(*resample(X, y)).coef_
              for i in range(1000)], 0)

# %%
print(pd.DataFrame({'effect': params.round(0),
                    'error': err.round(0)}))
