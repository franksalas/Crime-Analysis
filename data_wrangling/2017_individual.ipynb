# %%
import pandas as pd
import glob, os


import numpy as np
import matplotlib.pyplot as plt
import googlemaps
import gmaps
API_KEY = 'AIzaSyC-mLUTfYy6RwWdhnXQ5y4bYnPJLl_NRE0' 
gmaps_dev = googlemaps.Client(key=API_KEY) ## 
gmaps.configure(api_key=API_KEY) #

# %%
ls crime_data/2017
# Out:
# apr17.xls*  dec17.xls*  jan17.xls*  jun17.xls*  may17.xls*  oct17.xls*
# aug17.xls*  feb17.xls*  jul17.xls*  mar17.xls*  nov17.xls*  sep17.xls*

# %%
dfjan = pd.read_excel('crime_data/2017/jan17.xls', index_col='Date')
dffeb = pd.read_excel('crime_data/2017/feb17.xls', index_col='Date')
dfmar = pd.read_excel('crime_data/2017/mar17.xls', index_col='Date')
dfapr = pd.read_excel('crime_data/2017/apr17.xls', index_col='Date')
dfmay = pd.read_excel('crime_data/2017/may17.xls', index_col='Date')
dfjun = pd.read_excel('crime_data/2017/jun17.xls', index_col='Date')
dfjul = pd.read_excel('crime_data/2017/jul17.xls', index_col='Date')
dfaug = pd.read_excel('crime_data/2017/aug17.xls', index_col='Date')
dfsep = pd.read_excel('crime_data/2017/sep17.xls', index_col='Date')
dfoct = pd.read_excel('crime_data/2017/oct17.xls', index_col='Date')
dfnov = pd.read_excel('crime_data/2017/nov17.xls', index_col='Date')
dfdec = pd.read_excel('crime_data/2017/dec17.xls', index_col='Date')
# Out:
# WARNING *** file size (3078551) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
10718+9766+9932 +9962 +10492+10326 +10453 +10091 +8677 +9759 +9642 +9909
# Out:
# 119727

# %%
dfdec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9909 entries, 12/01/2017 to 12/31/2017
# Data columns (total 9 columns):
# Hour            9909 non-null int64
# Offense Type    9909 non-null object
# Beat            9909 non-null object
# Premise         9909 non-null object
# Block Range     9909 non-null object
# Street Name     9909 non-null object
# Type            9909 non-null object
# Suffix          9909 non-null object
# Offenses        9909 non-null int64
# dtypes: int64(2), object(7)
# memory usage: 774.1+ KB

# %%
dffeb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9766 entries, 2017-02-09 to 2017-02-21
# Data columns (total 9 columns):
# Hour            9766 non-null int64
# Offense Type    9766 non-null object
# Beat            9766 non-null object
# Premise         9646 non-null object
# BlockRange      9766 non-null object
# StreetName      9766 non-null object
# Type            9766 non-null object
# Suffix          9766 non-null object
# # offenses      9766 non-null int64
# dtypes: int64(2), object(7)
# memory usage: 763.0+ KB

# %%
dffeb.loc['2017']
# Out:
#             Hour        Offense Type   Beat  \
# Date
# 2017-02-09    17             Robbery  10H10
# 2017-02-09    17            Burglary  10H10
# 2017-02-11     9               Theft  10H10
# 2017-02-11    11            Burglary  10H10
# 2017-02-11    17               Theft  10H10
# 2017-02-12    16               Theft  10H10
# 2017-02-13    13               Theft  10H10
# 2017-02-14     7               Theft  10H10
# 2017-02-14    20            Burglary  10H10
# 2017-02-17    10          Auto Theft  10H10
# 2017-02-18     2          Auto Theft  10H10
# 2017-02-18    10               Theft  10H10
# 2017-02-18    22               Theft  10H10
# 2017-02-19     7            Burglary  10H10
# 2017-02-19     7               Theft  10H10
# 2017-01-02    15               Theft  10H10
# 2017-02-01     3            Burglary  10H10
# 2017-02-01    12               Theft  10H10
# 2017-02-01    21               Theft  10H10
# 2017-02-02     7          Auto Theft  10H10
# ...
