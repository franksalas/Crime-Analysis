# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import googlemaps
import gmaps
API_KEY = 'AIzaSyC-mLUTfYy6RwWdhnXQ5y4bYnPJLl_NRE0' 
gmaps_dev = googlemaps.Client(key=API_KEY) ## 
gmaps.configure(api_key=API_KEY) #

# %%
ls crime_data/2016
# Out:
# apr16.xls*  dec16.xls*  jan16.xls*  jun16.xls*  may16.xls*  oct16.xls*
# aug16.xls*  feb16.xls*  jul16.xls*  mar16.xls*  nov16.xls*  sep16.xls*

# %%
# ImportError: Install xlrd >= 0.9.0 for Excel support

df = pd.read_excel('crime_data/2016/jan16.xls', index_col='Date')
df.head()
# Out:
#             Hour        Offense Type   Beat                           Premise  \
# Date
# 2016-01-22    11             Robbery  10H10                 Convenience Store
# 2016-01-22    16               Theft  10H10                Residence or House
# 2016-01-23    20  Aggravated Assault  10H10         Road, Street, or Sidewalk
# 2016-01-24    22                Rape  10H10             Apartment Parking Lot
# 2016-01-26    22               Theft  10H10  Commercial Parking Lot or Garage
#
#            BlockRange StreetName Type Suffix  # offenses
# Date
# 2016-01-22  5200-5299      CANAL   ST      -           1
# 2016-01-22    200-299     STILES   ST      N           1
# 2016-01-23    100-199       YORK    -      N           1
# 2016-01-24  1900-1999    RUNNELS    -      -           1
# 2016-01-26  2000-2099    W. GRAY    -      -           1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10469 entries, 2016-01-22 to 2015-12-31
# Data columns (total 9 columns):
# Hour            10469 non-null int64
# Offense Type    10469 non-null object
# Beat            10469 non-null object
# Premise         10351 non-null object
# BlockRange      10469 non-null object
# StreetName      10469 non-null object
# Type            10469 non-null object
# Suffix          10469 non-null object
# # offenses      10469 non-null int64
# dtypes: int64(2), object(7)
# memory usage: 817.9+ KB

# %% [markdown]
# ## Find all the beats around houston

# %%
df['Beat'].unique()
# Out:
# array(['10H10', '10H20', '10H30', '10H40', '10H50', '10H60', '10H70',
#        '10H80', '11H10', '11H20', '11H30', '11H40', '11H50', '12D10',
#        '12D20', '12D30', '12D40', '12D50', '12D60', '12D70', '13D10',
#        '13D20', '13D30', '13D40', '14D10', '14D20', '14D30', '14D40',
#        '14D50', '15E10', '15E20', '15E30', '15E40', '16E10', '16E20',
#        '16E30', '16E40', '17E10', '17E20', '17E30', '17E40', '18F10',
#        '18F20', '18F30', '18F40', '18F50', '18F60', '19G10', '19G20',
#        '19G30', '19G40', '19G50', '1A10', '1A20', '1A30', '1A40', '1A50',
#        '20G10', '20G20', '20G30', '20G40', '20G50', '20G60', '20G70',
#        '20G80', '21I10', '21I30', '21I40', '21I50', '21I60', '23J50',
#        '24C10', '24C20', '24C30', '24C40', '24C50', '24C60', '2A10',
#        '2A20', '2A30', '2A40', '2A50', '2A60', '3B10', '3B30', '3B40',
#        '3B50', '4F10', '4F20', '4F30', '5F10', '5F20', '5F30', '5F40',
# ...

# %%
beat_plot = df.groupby(['Beat'])['Beat'].count().sort_values( ascending=False)
beat_plot = beat_plot.head(10)
beat_plot.plot(kind='barh')

# %% [markdown]
# ## beat 15E40
# reliant stadium

# %%
reliant = df[df['Beat'] =='15E40']

reliant.head()
# Out:
#             Hour Offense Type   Beat                                Premise  \
# Date
# 2016-01-24     7        Theft  15E40      Stadium, Sports Arena, Race Track
# 2016-01-23    22         Rape  15E40                              Apartment
# 2016-01-24    12      Robbery  15E40  Miscellaneous Business (Non-Specific)
# 2016-01-24    16        Theft  15E40                              Apartment
# 2016-01-24    20        Theft  15E40      Stadium, Sports Arena, Race Track
#
#            BlockRange  StreetName Type Suffix  # offenses
# Date
# 2016-01-24  8400-8499       KIRBY   DR      -           1
# 2016-01-23  8200-8299   CAMBRIDGE   ST      -           1
# 2016-01-24  9400-9499        MAIN   ST      -           1
# 2016-01-24  2100-2199  HOLLY HALL    -      -           1
# 2016-01-24  8400-8499       KIRBY   DR      -           1

# %%
reliant.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 166 entries, 2016-01-24 to 2015-12-31
# Data columns (total 9 columns):
# Hour            166 non-null int64
# Offense Type    166 non-null object
# Beat            166 non-null object
# Premise         162 non-null object
# BlockRange      166 non-null object
# StreetName      166 non-null object
# Type            166 non-null object
# Suffix          166 non-null object
# # offenses      166 non-null int64
# dtypes: int64(2), object(7)
# memory usage: 13.0+ KB

# %% [markdown]
# ## create new df with specific data

# %%
rel = reliant[['Hour','Offense Type','Premise','BlockRange','StreetName','# offenses']]

rel.head()
# Out:
#             Hour Offense Type                                Premise  \
# Date
# 2016-01-24     7        Theft      Stadium, Sports Arena, Race Track
# 2016-01-23    22         Rape                              Apartment
# 2016-01-24    12      Robbery  Miscellaneous Business (Non-Specific)
# 2016-01-24    16        Theft                              Apartment
# 2016-01-24    20        Theft      Stadium, Sports Arena, Race Track
#
#            BlockRange  StreetName  # offenses
# Date
# 2016-01-24  8400-8499       KIRBY           1
# 2016-01-23  8200-8299   CAMBRIDGE           1
# 2016-01-24  9400-9499        MAIN           1
# 2016-01-24  2100-2199  HOLLY HALL           1
# 2016-01-24  8400-8499       KIRBY           1

# %%
rel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 166 entries, 2016-01-24 to 2015-12-31
# Data columns (total 6 columns):
# Hour            166 non-null int64
# Offense Type    166 non-null object
# Premise         162 non-null object
# BlockRange      166 non-null object
# StreetName      166 non-null object
# # offenses      166 non-null int64
# dtypes: int64(2), object(4)
# memory usage: 9.1+ KB

# %%
rel['Offense Type'].unique()

# %%
rel_plot = rel.groupby(['Offense Type'])['Offense Type'].count().sort_values( ascending=False)
#rel_plot = rel_plot.head(10)
rel_plot.plot(kind='barh')

# %%
rel['Premise'].unique()

# %%
rel.info()

# %% [markdown]
# ## Find nan values

# %%
rel[rel['Premise'].isnull()]
# Out:
#             Hour Offense Type Premise BlockRange StreetName  # offenses
# Date
# 2016-01-10     0     Burglary     NaN  7600-7699     FANNIN           1
# 2016-01-02    20   Auto Theft     NaN  2600-2699       LOOP           1
# 2016-01-18     3        Theft     NaN  1800-1899   EL PASEO           1
# 2016-01-13    23        Theft     NaN  9200-9299       MAIN           1

# %% [markdown]
# ## working with specific dates

# %%
rel.loc['2016-01-01']

# %%
rel['Offense Type'].unique()

# %% [markdown]
# # only show sundays!

# %%
rel_sunday = rel[rel.index.dayofweek == 6]

rel_sunday
# Out:
#             Hour Offense Type                                   Premise  \
# Date
# 2016-01-24     7        Theft         Stadium, Sports Arena, Race Track
# 2016-01-24    12      Robbery     Miscellaneous Business (Non-Specific)
# 2016-01-24    16        Theft                                 Apartment
# 2016-01-24    20        Theft         Stadium, Sports Arena, Race Track
# 2016-01-31    21        Theft  Grocery Store or Supermarket Parking Lot
# 2016-01-31     9        Theft              Drug Store or Medical Supply
# 2016-01-31    19        Theft                                 Apartment
# 2016-01-31    17        Theft              Department or Discount Store
# 2016-01-31    16     Burglary                                 Apartment
# 2016-01-10    16        Theft              Department or Discount Store
# 2016-01-10    17        Theft                 Road, Street, or Sidewalk
# 2016-01-10    17        Theft              Grocery Store or Supermarket
# ...

# %% [markdown]
# ## cleanup the address

# %%
rel_sunday.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 24 entries, 2016-01-24 to 2016-01-17
# Data columns (total 8 columns):
# Hour            24 non-null int64
# Offense Type    24 non-null object
# Premise         23 non-null object
# BlockRange      24 non-null object
# StreetName      24 non-null object
# # offenses      24 non-null int64
# add             24 non-null object
# gps             24 non-null object
# dtypes: int64(2), object(6)
# memory usage: 2.3+ KB

# %%
rel_sunday[['BlockRange', 'StreetName']].apply(lambda x: ' '.join(x), axis=1)
# Out:
# Date
# 2016-01-24               8400-8499 KIRBY
# 2016-01-24                9400-9499 MAIN
# 2016-01-24          2100-2199 HOLLY HALL
# 2016-01-24               8400-8499 KIRBY
# 2016-01-31               7700-7799 KIRBY
# 2016-01-31                7900-7999 MAIN
# 2016-01-31             7600-7699 PHOENIX
# 2016-01-31    9700-9799 BUFFALO SPEEDWAY
# 2016-01-31          2200-2299 HOLLY HALL
# 2016-01-10                9400-9499 MAIN
# 2016-01-10                2400-2499 LOOP
# 2016-01-10               7700-7799 KIRBY
# 2016-01-10             2800-2899 BARTELL
# 2016-01-10              7600-7699 FANNIN
# 2016-01-10                9800-9899 MAIN
# 2016-01-03              8500-8599 KNIGHT
# 2016-01-03                   UNK RELIANT
# 2016-01-03            1600-1699 BELLFORT
# 2016-01-03               8900-8999 KIRBY
# 2016-01-03           1300-1399 LA CONCHA
# 2016-01-17                8500-8599 MAIN
# 2016-01-17                8500-8599 MAIN
# 2016-01-17                9200-9299 MAIN
# ...

# %%
geocode_result = gmaps_dev.geocode('8900-8999 KIRBY, Houston, TX')

# %%
import pprint  # "pretty-print" arbitrary Python data structures
pprint.pprint(geocode_result)
# Out:
# [{'address_components': [{'long_name': '8900',
#                           'short_name': '8900',
#                           'types': ['street_number']},
#                          {'long_name': 'Kirby Drive',
#                           'short_name': 'Kirby Dr',
#                           'types': ['route']},
#                          {'long_name': 'Southwest Houston',
#                           'short_name': 'Southwest Houston',
#                           'types': ['neighborhood', 'political']},
#                          {'long_name': 'Houston',
#                           'short_name': 'Houston',
#                           'types': ['locality', 'political']},
#                          {'long_name': 'Harris County',
#                           'short_name': 'Harris County',
#                           'types': ['administrative_area_level_2',
#                                     'political']},
#                          {'long_name': 'Texas',
# ...

# %%
type(geocode_result)
# Out:
# list

# %%
geocode_result[0]['geometry']['location']
# Out:
# {'lat': 29.6743803, 'lng': -95.4127372}

# %%
add = tuple(geocode_result[0]['geometry']['location'].values())

# %%
type(add)
# Out:
# tuple

# %%
add = [add]

# %%
add
# Out:
# [(29.6743803, -95.4127372)]

# %%
# !jupyter nbextension enable --py --sys-prefix gmaps
# Out:
# Enabling notebook extension jupyter-gmaps/extension...
#       - Validating: OK

# %%
# !jupyter nbextension enable --py --sys-prefix widgetsnbextension
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK

# %%
fig =gmaps.figure()
marker = gmaps.marker_layer(add)
fig.add_layer(marker)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
rel_sunday[]

# %% [markdown]
# ```python
# import gmaps.datasets
#
# gmaps.datasets.load_dataset("taxi_rides")
#
# '''
# [(37.782551, -122.445368),
#  (37.782745, -122.444586),
#  (37.782842, -122.443688),
#  (37.782919, -122.442815),
#  (37.782992, -122.442112),
#  (37.7831, -122.441461),
#  (37.783206, -122.440829),
#  (37.783273, -122.440324),
#  (37.783316, -122.440023),
# ...
#
# '''
#
# ```

# %%
new_add = rel_sunday[['BlockRange', 'StreetName']].apply(lambda x: ' '.join(x), axis=1)
new_add
# Out:
# Date
# 2016-01-24               8400-8499 KIRBY
# 2016-01-24                9400-9499 MAIN
# 2016-01-24          2100-2199 HOLLY HALL
# 2016-01-24               8400-8499 KIRBY
# 2016-01-31               7700-7799 KIRBY
# 2016-01-31                7900-7999 MAIN
# 2016-01-31             7600-7699 PHOENIX
# 2016-01-31    9700-9799 BUFFALO SPEEDWAY
# 2016-01-31          2200-2299 HOLLY HALL
# 2016-01-10                9400-9499 MAIN
# 2016-01-10                2400-2499 LOOP
# 2016-01-10               7700-7799 KIRBY
# 2016-01-10             2800-2899 BARTELL
# 2016-01-10              7600-7699 FANNIN
# 2016-01-10                9800-9899 MAIN
# 2016-01-03              8500-8599 KNIGHT
# 2016-01-03                   UNK RELIANT
# 2016-01-03            1600-1699 BELLFORT
# 2016-01-03               8900-8999 KIRBY
# 2016-01-03           1300-1399 LA CONCHA
# 2016-01-17                8500-8599 MAIN
# 2016-01-17                8500-8599 MAIN
# 2016-01-17                9200-9299 MAIN
# ...

# %%
def get_loc(add):
    cor = []
    for i in add:
        gps = gmaps_dev.geocode('{}, Houston, TX'.format(i))
        #print(tuple(gps[0]['geometry']['location'].values()))
        result = tuple(gps[0]['geometry']['location'].values())
        #cor.append(tuple(gps[int(i)]['geometry']['location'].values())
        cor.append(result)
    return cor

# %%
gps_loco = get_loc(new_add.values)

# %%
gps_loco
# Out:
# [(29.6847027, -95.4109208),
#  (29.6812612, -95.42302099999999),
#  (29.685262, -95.4000069),
#  (29.6847027, -95.4109208),
#  (29.697703, -95.4182209),
#  (29.6947179, -95.4153736),
#  (29.6995311, -95.4036141),
#  (29.681094, -95.4271278),
#  (29.68423499999999, -95.39888300000001),
#  (29.6812612, -95.42302099999999),
#  (29.679237, -95.415899),
#  (29.697703, -95.4182209),
#  (29.680411, -95.419178),
#  (29.6929462, -95.401127),
#  (29.679201, -95.4277652),
#  (29.6822688, -95.3999578),
#  (29.7474286, -95.47368519999999),
#  (29.667682, -95.392416),
#  (29.6743803, -95.4127372),
#  (29.6907704, -95.4125396),
#  (29.6916999, -95.4172361),
#  (29.6916999, -95.4172361),
#  (29.684986, -95.422257),
#  (29.7149951, -95.39743299999999)]

# %%
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(gps_loco))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
fig = gmaps.figure()
layer = gmaps.symbol_layer(gps_loco, fill_color="green", stroke_color="Red", scale=5)
#markers = gmaps.marker_layer(layer)
#print(layer)
fig.add_layer(layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
df['Offense Type'].value_counts(dropna=False)
# Out:
# Theft                 6087
# Burglary              1501
# Auto Theft            1057
# Robbery                891
# Aggravated Assault     794
# Rape                   120
# Murder                  19
# Name: Offense Type, dtype: int64

# %%
rel_sunday
# Out:
#             Hour Offense Type                                   Premise  \
# Date
# 2016-01-24     7        Theft         Stadium, Sports Arena, Race Track
# 2016-01-24    12      Robbery     Miscellaneous Business (Non-Specific)
# 2016-01-24    16        Theft                                 Apartment
# 2016-01-24    20        Theft         Stadium, Sports Arena, Race Track
# 2016-01-31    21        Theft  Grocery Store or Supermarket Parking Lot
# 2016-01-31     9        Theft              Drug Store or Medical Supply
# 2016-01-31    19        Theft                                 Apartment
# 2016-01-31    17        Theft              Department or Discount Store
# 2016-01-31    16     Burglary                                 Apartment
# 2016-01-10    16        Theft              Department or Discount Store
# 2016-01-10    17        Theft                 Road, Street, or Sidewalk
# 2016-01-10    17        Theft              Grocery Store or Supermarket
# ...

# %%
rel_sunday['add'] = rel_sunday[['BlockRange', 'StreetName']].apply(lambda x: ' '.join(x), axis=1)

rel_sunday.head()
# Out:
# /home/salas/miniconda3/envs/sbc/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#             Hour Offense Type                                   Premise  \
# Date
# 2016-01-24     7        Theft         Stadium, Sports Arena, Race Track
# 2016-01-24    12      Robbery     Miscellaneous Business (Non-Specific)
# 2016-01-24    16        Theft                                 Apartment
# 2016-01-24    20        Theft         Stadium, Sports Arena, Race Track
# 2016-01-31    21        Theft  Grocery Store or Supermarket Parking Lot
#
#            BlockRange  StreetName  # offenses                   add
# Date
# ...

# %%
def get_loc(row):
    gps = gmaps_dev.geocode('{}, Houston, TX'.format(row))
    result = tuple(gps[0]['geometry']['location'].values())
    return result

# %%
def get_loc(row):
    gps = gmaps_dev.geocode('{}, Houston, TX'.format(row))
    result = tuple(gps[0]['geometry']['location'].values())
    return result

# %%
rel_sunday['gps'] = rel_sunday['add'].apply(get_loc)
# Out:
# /home/salas/miniconda3/envs/sbc/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
rel_sunday
# Out:
#             Hour Offense Type                                   Premise  \
# Date
# 2016-01-24     7        Theft         Stadium, Sports Arena, Race Track
# 2016-01-24    12      Robbery     Miscellaneous Business (Non-Specific)
# 2016-01-24    16        Theft                                 Apartment
# 2016-01-24    20        Theft         Stadium, Sports Arena, Race Track
# 2016-01-31    21        Theft  Grocery Store or Supermarket Parking Lot
# 2016-01-31     9        Theft              Drug Store or Medical Supply
# 2016-01-31    19        Theft                                 Apartment
# 2016-01-31    17        Theft              Department or Discount Store
# 2016-01-31    16     Burglary                                 Apartment
# 2016-01-10    16        Theft              Department or Discount Store
# 2016-01-10    17        Theft                 Road, Street, or Sidewalk
# 2016-01-10    17        Theft              Grocery Store or Supermarket
# ...

# %%
rel_sunday['gps']
# Out:
# Date
# 2016-01-24                  (29.6847027, -95.4109208)
# 2016-01-24           (29.6812612, -95.42302099999999)
# 2016-01-24                   (29.685262, -95.4000069)
# 2016-01-24                  (29.6847027, -95.4109208)
# 2016-01-31                   (29.697703, -95.4182209)
# 2016-01-31                  (29.6947179, -95.4153736)
# 2016-01-31                  (29.6995311, -95.4036141)
# 2016-01-31                   (29.681094, -95.4271278)
# 2016-01-31    (29.68423499999999, -95.39888300000001)
# 2016-01-10           (29.6812612, -95.42302099999999)
# 2016-01-10                    (29.679237, -95.415899)
# 2016-01-10                   (29.697703, -95.4182209)
# 2016-01-10                    (29.680411, -95.419178)
# 2016-01-10                   (29.6929462, -95.401127)
# 2016-01-10                  (29.6788827, -95.4267682)
# 2016-01-03                  (29.6822688, -95.3999578)
# 2016-01-03           (29.7474286, -95.47368519999999)
# ...

# %%
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(rel_sunday['gps'].values))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
